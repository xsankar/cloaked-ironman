# %%
from pyspark.context import SparkContext
print "Running Spark Version %s" % (sc.version)
# Out:
# Running Spark Version 1.1.0

# %%
from pyspark.conf import SparkConf
conf = SparkConf()
print conf.toDebugString()
# Out:
# spark.app.name=pyspark-shell
# spark.io.compression.codec=org.apache.spark.io.LZFCompressionCodec
# spark.master=local[*]
# spark.submit.pyFiles=

# %%
# imports
from operator import add

# %%
lines = sc.textFile("sotu/2009-2014-BO.txt")
word_count_bo = lines.flatMap(lambda x: x.split(' ')).\
    map(lambda x: (x.lower().rstrip().lstrip().rstrip(',').rstrip('.'), 1)).\
    reduceByKey(add)
word_count_bo.count()
#6658 without lower, 6299 with lower, rstrip,lstrip 4835
# Out:
# 4835

# %%
#output = word_count_bo.collect()
#for (word, count) in output:
#    print "%s: %i" % (word, count)

# %%
lines = sc.textFile("sotu/2001-2008-GWB.txt")
word_count_gwb = lines.flatMap(lambda x: x.split(' ')).map(lambda x: (x.lower().rstrip().lstrip().rstrip(',').rstrip('.'), 1)).reduceByKey(add)
word_count_gwb.count()
# Out:
# 4957

# %%
lines = sc.textFile("sotu/1994-2000-WJC.txt")
word_count_wjc = lines.flatMap(lambda x: x.split(' ')).map(lambda x: (x.lower().rstrip().lstrip().rstrip(',').rstrip('.'), 1)).reduceByKey(add)
word_count_wjc.count()
# Out:
# 5476

# %%
lines = sc.textFile("sotu/1961-1963-JFK.txt")
word_count_jfk = lines.flatMap(lambda x: x.split(' ')).map(lambda x: (x.lower().rstrip().lstrip().rstrip(',').rstrip('.'), 1)).reduceByKey(add)
word_count_jfk.count()
# Out:
# 3656

# %%
lines = sc.textFile("sotu/1934-1945-FDR.txt")
word_count_fdr = lines.flatMap(lambda x: x.split(' ')).map(lambda x: (x.lower().rstrip().lstrip().rstrip(',').rstrip('.'), 1)).reduceByKey(add)
word_count_fdr.count()
# Out:
# 5933

# %%
lines = sc.textFile("sotu/1861-1864-AL.txt")
word_count_al = lines.flatMap(lambda x: x.split(' ')).map(lambda x: (x.lower().rstrip().lstrip().rstrip(',').rstrip('.'), 1)).reduceByKey(add)
word_count_al.count()
# Out:
# 4156

# %%
lines = sc.textFile("sotu/1790-1796-GW.txt")
word_count_gw = lines.flatMap(lambda x: x.split(' ')).map(lambda x: (x.lower().rstrip().lstrip().rstrip(',').rstrip('.'), 1)).reduceByKey(add)
word_count_gw.count()
# Out:
# 2951

# %%
common_words = ["us","has","all", "they", "from", "who","what","on","by","more","as","not","their","can",
                             "new","it","but","be","are","--","i","have","this","will","for","with","is","that","in",
                             "our","we","a","of","to","and","the","that's","or","make","do","you","at","it\'s","than",
                             "if","know","last","about","no","just","now","an","because","<p>we","why","we\'ll","how",
                             "two","also","every","come","we've","year","over","get","take","one","them","we\'re","need",
                             "want","when","like","most","-","been","first","where","so","these","they\'re","good","would",
                             "there","should","-->","<!--","up","i\'m","his","their","which","may","were","such","some",
                             "those","was","here","she","he","its","her","his","don\'t","i\'ve","what\'s","didn\'t",
                             "shouldn\'t","(applause.)","let\'s","doesn\'t"]

# %%
word_count_bo_1 = word_count_bo.sortBy(lambda x: x[1],ascending=False)

# %%
for x in word_count_bo_1.take(10):
    print x
# Out:
# (u'the', 1812)
# (u'and', 1375)
# (u'to', 1351)
# (u'of', 1013)
# (u'a', 802)
# (u'that', 778)
# (u'we', 719)
# (u'our', 698)
# (u'in', 637)
# (u'', 585)

# %%
word_count_bo_clean = word_count_bo_1.filter(lambda x: x[0] not in common_words)

# %%
word_count_bo_clean.count()
# Out:
# 4729

# %%
for x in word_count_bo_clean.collect():
    print x
# Out:
# (u'', 585)
# (u'jobs', 148)
# (u'people', 144)
# (u'american', 133)
# (u'america', 131)
# (u'years', 116)
# (u'work', 108)
# (u'americans', 105)
# (u'time', 89)
# (u'energy', 87)
# (u'tonight', 84)
# (u'congress', 83)
# (u'country', 82)
# (u'help', 81)
# (u'economy', 79)
# (u'tax', 76)
# (u'right', 75)
# (u'businesses', 69)
# (u'my', 65)
# (u'world', 63)
# (u'government', 58)
# (u'education', 58)
# (u'care', 57)
# (u'home', 57)
# (u'families', 56)
# (u'must', 56)
# (u'next', 56)
# (u'health', 55)
# (u'nation', 55)
# (u'business', 54)
# (u'future', 54)
# (u'even', 53)
# (u'back', 53)
# (u'job', 51)
# (u'reform', 51)
# (u'states', 50)
# (u'out', 50)
# (u'deficit', 48)
# (u'down', 47)
# (u'give', 47)
# (u'put', 46)
# (u'me', 44)
# (u'support', 44)
# (u'many', 44)
# (u'security', 43)
# (u'into', 42)
# (u'together', 41)
# (u'your', 41)
# (u'today', 40)
# (u'college', 40)
# (u'after', 40)
# (u'too', 40)
# (u'other', 40)
# (u'way', 39)
# (u'only', 39)
# (u"can't", 39)
# (u'keep', 39)
# (u'own', 39)
# (u'working', 38)
# (u'through', 38)
# (u'plan', 38)
# (u'still', 38)
# (u'day', 38)
# (u'united', 37)
# (u'schools', 36)
# (u'already', 36)
# (u'million', 36)
# (u'made', 36)
# (u'workers', 35)
# (u'change', 35)
# (u'same', 35)
# (u'small', 35)
# (u'clean', 35)
# (u'go', 35)
# (u'create', 34)
# (u'financial', 33)
# (u'again', 33)
# (u'children', 33)
# (u'companies', 32)
# (u'never', 32)
# (u'hard', 32)
# (u'end', 31)
# (u'responsibility', 30)
# (u'budget', 30)
# (u'without', 30)
# (u'power', 29)
# (u'any', 29)
# (u'believe', 29)
# (u'women', 29)
# (u'system', 29)
# (u'best', 28)
# (u'place', 28)
# (u'better', 28)
# (u'while', 28)
# (u'could', 28)
# (u'lead', 28)
# (u'chance', 28)
# (u'law', 28)
# (u'before', 28)
# (u'war', 28)
# (u'cuts', 28)
# (u"america's", 28)
# (u'money', 28)
# (u'pay', 28)
# (u'bill', 28)
# (u'another', 27)
# (u'away', 27)
# (u'had', 27)
# (u'students', 27)
# (u'each', 27)
# (u'nearly', 27)
# (u'across', 27)
# (u'act', 27)
# (u'finally', 26)
# (u'cut', 26)
# (u'millions', 26)
# (u'sure', 26)
# (u'invest', 26)
# (u'oil', 26)
# (u'part', 26)
# (u'afford', 25)
# (u'let', 25)
# (u'ago', 25)
# (u'high', 25)
# (u'kids', 25)
# (u'president', 25)
# (u'said', 25)
# (u'republicans', 25)
# (u'making', 25)
# (u'cannot', 25)
# (u'young', 25)
# (u'both', 25)
# (u'ever', 24)
# (u'values', 24)
# (u'state', 24)
# (u'communities', 24)
# (u'lives', 24)
# (u'spending', 24)
# (u'single', 24)
# (u'administration', 24)
# (u'off', 24)
# (u'leaders', 24)
# (u'credit', 24)
# (u'recovery', 24)
# (u'continue', 24)
# (u'innovation', 24)
# (u'school', 23)
# (u'protect', 23)
# (u'market', 23)
# (u'am', 23)
# (u'ask', 23)
# (u'community', 23)
# (u'gas', 23)
# (u'long', 23)
# (u'men', 23)
# (u'took', 23)
# (u'debt', 23)
# (u'crisis', 23)
# (u'troops', 23)
# (u'citizens', 23)
# (u'meet', 23)
# (u'democrats', 23)
# (u'opportunity', 22)
# (u'federal', 22)
# (u'banks', 22)
# (u'see', 22)
# (u'great', 22)
# (u'well', 22)
# (u'percent', 22)
# (u'save', 22)
# (u'cost', 22)
# (u'stand', 22)
# (u'research', 22)
# (u'insurance', 22)
# (u'built', 22)
# (u'costs', 22)
# (u'bring', 22)
# (u'office', 21)
# (u'against', 21)
# (u'say', 21)
# (u'reduce', 21)
# (u'countries', 21)
# (u'economic', 21)
# (u'higher', 21)
# (u'nuclear', 21)
# (u'union', 20)
# (u'did', 20)
# (u'technology', 20)
# (u'industry', 20)
# (u'company', 20)
# (u'done', 20)
# (u'success', 20)
# (u'recession', 20)
# (u'taxes', 20)
# (u'promise', 20)
# (u'always', 20)
# (u'means', 20)
# (u'progress', 20)
# (u'investments', 20)
# (u'vote', 19)
# (u'different', 19)
# (u'decade', 19)
# (u'washington', 19)
# (u'child', 19)
# (u'three', 19)
# (u'manufacturing', 19)
# (u'chamber', 19)
# (u'pass', 19)
# (u'set', 19)
# (u'few', 19)
# (u'start', 19)
# (u'half', 19)
# (u'move', 19)
# (u'does', 19)
# (u'four', 18)
# (u'life', 18)
# (u'being', 18)
# (u'enough', 18)
# (u'send', 18)
# (u'military', 18)
# (u'possible', 18)
# (u'afghanistan', 18)
# (u'public', 18)
# (u'goal', 18)
# (u'since', 18)
# (u'raise', 18)
# (u'look', 18)
# (u'race', 18)
# (u'serve', 17)
# (u'use', 17)
# (u'decades', 17)
# (u'rules', 17)
# (u'family', 17)
# (u'generation', 17)
# (u'stronger', 17)
# (u'building', 17)
# (u'nations', 17)
# (u'strong', 17)
# (u'programs', 17)
# (u'trillion', 17)
# (u'history', 17)
# (u'century', 17)
# (u'face', 17)
# (u'dollars', 16)
# (u'stop', 16)
# (u'training', 16)
# (u'national', 16)
# (u'behind', 16)
# (u'colleges', 16)
# (u'ahead', 16)
# (u'action', 16)
# (u'passed', 16)
# (u'forward', 16)
# (u'fact', 16)
# (u'housing', 16)
# (u"aren't", 16)
# (u'matter', 16)
# (u'address', 16)
# (u'around', 16)
# (u'iraq', 16)
# (u'created', 16)
# (u'house', 16)
# (u'build', 16)
# (u'big', 16)
# (u'global', 16)
# (u'deserve', 16)
# (u'parties', 16)
# (u'largest', 16)
# (u'commitment', 16)
# (u'skills', 15)
# (u'forces', 15)
# (u'worked', 15)
# (u'live', 15)
# (u'challenges', 15)
# (u'begin', 15)
# (u'helping', 15)
# (u'issue', 15)
# (u'strengthen', 15)
# (u"won't", 15)
# (u'sent', 15)
# (u'five', 15)
# (u'necessary', 15)
# (u'example', 15)
# (u'days', 15)
# (u"there's", 15)
# (u'teachers', 15)
# (u'grow', 15)
# (u'bipartisan', 15)
# (u'leadership', 15)
# (u'al', 15)
# (u'program', 15)
# (u'investment', 15)
# (u'science', 15)
# (u'sense', 15)
# (u'trade', 15)
# (u'idea', 15)
# (u'agree', 15)
# (u'once', 15)
# (u'course', 15)
# (u'afghan', 15)
# (u'growth', 15)
# (u'china', 14)
# (u'free', 14)
# (u'rates', 14)
# (u'bad', 14)
# (u'steps', 14)
# (u'efforts', 14)
# (u'effort', 14)
# (u'thousands', 14)
# (u'dream', 14)
# (u'medicare', 14)
# (u'needs', 14)
# (u'rest', 14)
# (u'parents', 14)
# (u'makes', 14)
# (u'helped', 14)
# (u'student', 14)
# (u'street', 14)
# (u'reforms', 14)
# (u'then', 14)
# (u'months', 14)
# (u'rights', 14)
# (u'prosperity', 14)
# (u'full', 14)
# (u'everyone', 14)
# (u'find', 14)
# (u'defense', 14)
# (u'willing', 14)
# (u'getting', 14)
# (u'savings', 13)
# (u'able', 13)
# (u'growing', 13)
# (u'open', 13)
# (u'middle-class', 13)
# (u'real', 13)
# (u'bless', 13)
# (u'hire', 13)
# (u'veterans', 13)
# (u'week', 13)
# (u'benefits', 13)
# (u'top', 13)
# (u'access', 13)
# (u'products', 13)
# (u'private', 13)
# (u'loans', 13)
# (u'problem', 13)
# (u'homes', 13)
# (u"world's", 13)
# (u'think', 13)
# (u"you're", 13)
# (u'much', 13)
# (u'things', 13)
# (u'left', 13)
# (u'everything', 13)
# (u'hold', 13)
# (u'prevent', 13)
# (u'tomorrow', 13)
# (u'ideas', 13)
# (u'going', 13)
# (u'between', 13)
# (u'common', 13)
# (u'spend', 13)
# (u'abroad', 13)
# (u'win', 13)
# (u'instead', 13)
# (u'middle', 13)
# (u'difficult', 13)
# (u'wage', 12)
# (u'fair', 12)
# (u'dreams', 12)
# (u'easy', 12)
# (u'old', 12)
# (u'solar', 12)
# (u'natural', 12)
# (u'happen', 12)
# (u'require', 12)
# (u'iran', 12)
# (u'share', 12)
# (u'members', 12)
# (u'long-term', 12)
# (u'projects', 12)
# (u'doing', 12)
# (u'allies', 12)
# (u'whether', 12)
# (u'under', 12)
# (u'told', 12)
# (u'secure', 12)
# (u'god', 12)
# (u'seen', 12)
# (u'qaeda', 12)
# (u'earth', 12)
# (u'speak', 12)
# (u'yet', 12)
# (u'longer', 12)
# (u'wait', 12)
# (u'cars', 12)
# (u'fight', 12)
# (u'politics', 12)
# (u'further', 12)
# (u'soon', 12)
# (u'within', 12)
# (u'equal', 12)
# (u'republican', 12)
# (u'party', 12)
# (u'less', 12)
# (u'class', 12)
# (u'little', 11)
# (u'climate', 11)
# (u'folks', 11)
# (u'approach', 11)
# (u'lending', 11)
# (u'ensure', 11)
# (u'incentives', 11)
# (u'affordable', 11)
# (u'comes', 11)
# (u'wall', 11)
# (u'forge', 11)
# (u'markets', 11)
# (u'threat', 11)
# (u'expand', 11)
# (u'reach', 11)
# (u'lower', 11)
# (u'confidence', 11)
# (u'step', 11)
# (u'remains', 11)
# (u'democracy', 11)
# (u'industries', 11)
# (u'tough', 11)
# (u'places', 11)
# (u'lay', 11)
# (u'got', 11)
# (u'strength', 11)
# (u'responsible', 11)
# (u'asked', 11)
# (u'man', 11)
# (u'laws', 11)
# (u'fellow', 11)
# (u'information', 11)
# (u'foreign', 11)
# (u'others', 11)
# (u'used', 11)
# (u'comprehensive', 11)
# (u'retirement', 11)
# (u'faith', 11)
# (u'code', 11)
# (u'bills', 11)
# (u'times', 11)
# (u'succeed', 11)
# (u'walk', 11)
# (u'buy', 11)
# (u'stay', 11)
# (u'call', 10)
# (u'south', 10)
# (u'fix', 10)
# (u'yes', 10)
# (u'legislation', 10)
# (u'senate', 10)
# (u'increase', 10)
# (u'weapons', 10)
# (u'solve', 10)
# (u'coverage', 10)
# (u'far', 10)
# (u'known', 10)
# (u'reason', 10)
# (u'wages', 10)
# (u'least', 10)
# (u'nothing', 10)
# (u'problems', 10)
# (u'paying', 10)
# (u'poverty', 10)
# (u'receive', 10)
# (u'speaker', 10)
# (u'lost', 10)
# (u'north', 10)
# (u'tell', 10)
# (u'turn', 10)
# (u'safe', 10)
# (u'unemployment', 10)
# (u'basic', 10)
# (u'korea', 10)
# (u'helps', 10)
# (u'serious', 10)
# (u'asking', 10)
# (u'level', 10)
# (u'remember', 10)
# (u'rebuilding', 10)
# (u'infrastructure', 10)
# (u'violence', 10)
# (u'spirit', 10)
# (u'woman', 10)
# (u'worse', 10)
# (u'takes', 10)
# (u'minimum', 10)
# (u'coming', 10)
# (u'task', 10)
# (u'eliminate', 10)
# (u'terrorists', 10)
# (u'immigration', 10)
# (u'vice', 10)
# (u'restore', 10)
# (u'point', 10)
# (u'bringing', 9)
# (u'force', 9)
# (u'proposing', 9)
# (u'breaks', 9)
# (u'understand', 9)
# (u'billion', 9)
# (u'high-tech', 9)
# (u'achieve', 9)
# (u'talk', 9)
# (u"couldn't", 9)
# (u'overseas', 9)
# (u'past', 9)
# (u'none', 9)
# (u'simple', 9)
# (u'might', 9)
# (u'return', 9)
# (u'bigger', 9)
# (u'threats', 9)
# (u'moment', 9)
# (u'line', 9)
# (u'regulations', 9)
# (u'challenge', 9)
# (u'control', 9)
# (u'including', 9)
# (u'generations', 9)
# (u'burden', 9)
# (u'begun', 9)
# (u'compete', 9)
# (u'mr', 9)
# (u'trying', 9)
# (u'focus', 9)
# (u'standards', 9)
# (u'teacher', 9)
# (u'biden', 9)
# (u'allowed', 9)
# (u'thing', 9)
# (u'offer', 9)
# (u'later', 9)
# (u'tuition', 9)
# (u'broken', 9)
# (u'beyond', 9)
# (u'important', 9)
# (u'expect', 9)
# (u'number', 9)
# (u'mission', 9)
# (u'entrepreneurs', 9)
# (u'deserves', 9)
# (u'called', 9)
# (u'choose', 9)
# (u'greater', 9)
# (u'partnership', 9)
# (u'ones', 9)
# (u'employees', 8)
# (u'pursue', 8)
# (u'provide', 8)
# (u'wind', 8)
# (u"today's", 8)
# (u'anyone', 8)
# (u"who've", 8)
# (u'proposed', 8)
# (u'exports', 8)
# (u'depends', 8)
# (u'human', 8)
# (u'intend', 8)
# (u'depend', 8)
# (u'join', 8)
# (u'alone', 8)
# (u'policy', 8)
# (u'wealthiest', 8)
# (u'struggling', 8)
# (u'starting', 8)
# (u'decisions', 8)
# (u'ten', 8)
# (u'taken', 8)
# (u'remain', 8)
# (u"isn't", 8)
# (u'kind', 8)
# (u'hit', 8)
# (u'simply', 8)
# (u'high-speed', 8)
# (u'age', 8)
# (u'resources', 8)
# (u'universities', 8)
# (u'agenda', 8)
# (u'seniors', 8)
# (u'math', 8)
# (u'allow', 8)
# (u'words', 8)
# (u'biggest', 8)
# (u'needed', 8)
# (u'executive', 8)
# (u'trust', 8)
# (u'workforce', 8)
# (u'greatest', 8)
# (u'thanks', 8)
# (u'differences', 8)
# (u'sign', 8)
# (u'living', 8)
# (u'factory', 8)
# (u'follow', 8)
# (u'social', 8)
# (u'factories', 8)
# (u'diploma', 8)
# (u'twenty', 8)
# (u'hundred', 8)
# (u'obama', 8)
# (u'reward', 8)
# (u'him', 8)
# (u'creating', 8)
# (u'"we', 8)
# (u'pollution', 8)
# (u'peace', 8)
# (u'sanctions', 8)
# (u'debate', 8)
# (u'january', 8)
# (u'become', 8)
# (u'freedom', 8)
# (u'construction', 8)
# (u'else', 8)
# (u'brought', 7)
# (u'unit', 7)
# (u'very', 7)
# (u'service', 7)
# (u'begins', 7)
# (u'came', 7)
# (u'capacity', 7)
# (u'worker', 7)
# (u'advanced', 7)
# (u'hear', 7)
# (u'true', 7)
# (u'21st', 7)
# (u'says', 7)
# (u'love', 7)
# (u'sacrifice', 7)
# (u'lobbyists', 7)
# (u'white', 7)
# (u'saw', 7)
# (u'ways', 7)
# (u'borders', 7)
# (u'develop', 7)
# (u'renewable', 7)
# (u'accountable', 7)
# (u'europe', 7)
# (u'profits', 7)
# (u'dollar', 7)
# (u'opportunities', 7)
# (u'worst', 7)
# (u"i'll", 7)
# (u'town', 7)
# (u'taxpayer', 7)
# (u'funding', 7)
# (u'owners', 7)
# (u'feel', 7)
# (u'story', 7)
# (u'clear', 7)
# (u'barack', 7)
# (u'anything', 7)
# (u'competition', 7)
# (u'fewer', 7)
# (u'giving', 7)
# (u'led', 7)
# (u'standing', 7)
# (u'process', 7)
# (u'combat', 7)
# (u'hope', 7)
# (u'career', 7)
# (u'taking', 7)
# (u'add', 7)
# (u'taxpayers', 7)
# (u'roads', 7)
# (u'order', 7)
# (u"people's", 7)
# (u'john', 7)
# (u'improve', 7)
# (u'commission', 7)
# (u'"i', 7)
# (u'hand', 7)
# (u'gave', 7)
# (u'dignity', 7)
# (u'election', 7)
# (u'cory', 7)
# (u'proud', 7)
# (u'diplomacy', 7)
# (u'shared', 7)
# (u'thank', 7)
# (u'massive', 7)
# (u'knew', 7)
# (u'highest', 7)
# (u'promote', 7)
# (u'faster', 7)
# (u'includes', 7)
# (u'month', 7)
# (u'***', 7)
# (u'difference', 7)
# (u'streets', 7)
# (u'uniform', 7)
# (u'$1', 7)
# (u'close', 7)
# (u'spent', 7)
# (u'person', 7)
# (u'lose', 7)
# (u'goods', 7)
# (u'income', 7)
# (u'prepared', 7)
# (u'train', 7)
# (u'stock', 7)
# (u'six', 7)
# (u'hands', 7)
# (u'partners', 7)
# (u'earned', 7)
# (u'ability', 7)
# (u'deficits', 7)
# (u'parts', 7)
# (u'increased', 7)
# (u'rural', 7)
# (u'cause', 6)
# (u'red', 6)
# (u'second', 6)
# (u'asia', 6)
# (u'campaign', 6)
# (u'actions', 6)
# (u'third', 6)
# (u'break', 6)
# (u'went', 6)
# (u'priorities', 6)
# (u'economists', 6)
# (u'study', 6)
# (u'corporate', 6)
# (u'eight', 6)
# (u'high-quality', 6)
# (u'neighbors', 6)
# (u'hour', 6)
# (u'leave', 6)
# (u'water', 6)
# (u'thirty', 6)
# (u'wrong', 6)
# (u'efficient', 6)
# (u'price', 6)
# (u'mortgage', 6)
# (u'policies', 6)
# (u'speed', 6)
# (u"iran's", 6)
# (u'learning', 6)
# (u'rising', 6)
# (u'lot', 6)
# (u'technologies', 6)
# (u'wants', 6)
# (u'encourage', 6)
# (u'rate', 6)
# (u'consumers', 6)
# (u"haven't", 6)
# (u'ceo', 6)
# (u'major', 6)
# (u'sell', 6)
# (u'loopholes', 6)
# (u'sector', 6)
# (u'obligations', 6)
# (u'impact', 6)
# (u'political', 6)
# (u'plants', 6)
# (u'rid', 6)
# (u'doubling', 6)
# (u'medical', 6)
# (u'announcing', 6)
# (u'waiting', 6)
# (u'degree', 6)
# (u'named', 6)
# (u'powerful', 6)
# (u'quality', 6)
# (u'interests', 6)
# (u'unless', 6)
# (u'agreed', 6)
# (u'fear', 6)
# (u'hopeful', 6)
# (u'local', 6)
# (u'stories', 6)
# (u'almost', 6)
# (u'began', 6)
# (u'thought', 6)
# (u'prescription', 6)
# (u'ideals', 6)
# (u'billions', 6)
# (u'friends', 6)
# (u'worth', 6)
# (u'risk', 6)
# (u'hundreds', 6)
# (u'era', 6)
# (u'democratic', 6)
# (u'production', 6)
# (u'lasting', 6)
# (u'source', 6)
# (u'air', 6)
# (u'urge', 6)
# (u'denied', 6)
# (u'reducing', 6)
# (u'often', 6)
# (u'leading', 6)
# (u'michelle', 6)
# (u'internet', 6)
# (u'corporations', 6)
# (u'employers', 6)
# (u'show', 6)
# (u'carolina', 6)
# (u'someone', 6)
# (u'fully', 6)
# (u'manufacturers', 6)
# (u'complete', 6)
# (u'citizenship', 6)
# (u'fill', 6)
# (u'fall', 6)
# (u'found', 6)
# (u'gun', 6)
# (u'launch', 6)
# (u'partnerships', 6)
# (u'double', 6)
# (u'cleaner', 6)
# (u'institutions', 6)
# (u'strategy', 6)
# (u'hardworking', 6)
# (u'dime', 6)
# (u'demands', 6)
# (u"they've", 6)
# (u'something', 6)
# (u'courage', 6)
# (u'labor', 6)
# (u'auto', 6)
# (u'result', 6)
# (u'watching', 6)
# (u'destiny', 6)
# (u'agreements', 6)
# (u'waste', 6)
# (u'works', 6)
# (u'recognize', 6)
# (u'looking', 5)
# (u'changes', 5)
# (u'shores', 5)
# (u'meaningful', 5)
# (u'weeks', 5)
# (u'bank', 5)
# (u'medicaid', 5)
# (u'seek', 5)
# (u'letter', 5)
# (u'earn', 5)
# (u'affiliates', 5)
# (u'interest', 5)
# (u'launched', 5)
# (u'seven', 5)
# (u'kept', 5)
# (u'deal', 5)
# (u'negotiations', 5)
# (u'weakened', 5)
# (u'premiums', 5)
# (u'paychecks', 5)
# (u'proposals', 5)
# (u'educate', 5)
# (u'root', 5)
# (u'trucks', 5)
# (u'paid', 5)
# (u'knowing', 5)
# (u'cancer', 5)
# (u'insist', 5)
# (u'ordered', 5)
# (u'rebuild', 5)
# (u'wake', 5)
# (u'engineering', 5)
# (u'ship', 5)
# (u'food', 5)
# (u'status', 5)
# (u'running', 5)
# (u'mortgages', 5)
# (u'railroad', 5)
# (u'thousand', 5)
# (u'track', 5)
# (u'fiscal', 5)
# (u'investing', 5)
# (u'try', 5)
# (u'beginning', 5)
# (u'play', 5)
# (u'cover', 5)
# (u'wrote', 5)
# (u'recently', 5)
# (u'loan', 5)
# (u'along', 5)
# (u'towns', 5)
# (u'healthy', 5)
# (u'read', 5)
# (u'development', 5)
# (u'moving', 5)
# (u'mom', 5)
# (u'profitable', 5)
# (u'run', 5)
# (u'enduring', 5)
# (u'influence', 5)
# (u'putting', 5)
# (u'depression', 5)
# (u'safer', 5)
# (u'themselves', 5)
# (u'started', 5)
# (u'2011', 5)
# (u'special', 5)
# (u'defend', 5)
# (u'prepare', 5)
# (u'owner', 5)
# (u'battles', 5)
# (u'based', 5)
# (u'tape', 5)
# (u'neither', 5)
# (u'ends', 5)
# (u'deliver', 5)
# (u'passing', 5)
# (u'harder', 5)
# (u'fighting', 5)
# (u'whatever', 5)
# (u'reduction', 5)
# (u'sick', 5)
# (u'whose', 5)
# (u'teaching', 5)
# (u'govern', 5)
# (u'tired', 5)
# (u'changed', 5)
# (u'rescue', 5)
# (u'record', 5)
# (u'amid', 5)
# (u'keeps', 5)
# (u'side', 5)
# (u'foundation', 5)
# (u'brandon', 5)
# (u'materials', 5)
# (u'mother', 5)
# (u'adding', 5)
# (u'pays', 5)
# (u'fought', 5)
# (u'until', 5)
# (u'stake', 5)
# (u'felt', 5)
# (u'choice', 5)
# (u'expanding', 5)
# (u'quarter', 5)
# (u'opened', 5)
# (u'earlier', 5)
# (u'gives', 5)
# (u'russia', 5)
# (u'equipment', 5)
# (u'ground', 5)
# (u'finish', 5)
# (u'changing', 5)
# (u'renewed', 5)
# (u'kennedy', 5)
# (u'either', 5)
# (u'served', 5)
# (u'critical', 5)
# (u'quit', 5)
# (u'manufacturer', 5)
# (u'fraud', 5)
# (u'certain', 5)
# (u'graduate', 5)
# (u'civilians', 5)
# (u'debates', 5)
# (u'playing', 5)
# (u'25', 5)
# (u'determined', 5)
# (u'officers', 5)
# (u'meanwhile', 5)
# (u'cheaper', 5)
# (u'international', 5)
# (u'intelligence', 5)
# (u'incomes', 5)
# (u'threaten', 5)
# (u'fund', 5)
# (u'alliances', 5)
# (u'purpose', 5)
# (u'ourselves', 5)
# (u'agreement', 5)
# (u'fixing', 5)
# (u'required', 5)
# (u'enforce', 5)
# (u'cutting', 5)
# (u'individual', 5)
# (u'freeze', 5)
# (u"he's", 5)
# (u'carbon', 5)
# (u'respect', 5)
# (u'2014', 5)
# (u'gets', 5)
# (u'sources', 5)
# (u'entire', 5)
# (u"who's", 5)
# (u'desk', 5)
# (u'throughout', 5)
# (u'decline', 5)
# (u'space', 5)
# (u'talks', 4)
# (u're-start', 4)
# (u'word', 4)
# (u'attract', 4)
# (u'ordinary', 4)
# (u'rewarded', 4)
# (u'detroit', 4)
# (u'daughters', 4)
# (u'laid', 4)
# (u'safety', 4)
# (u'veto', 4)
# (u'creates', 4)
# (u'project', 4)
# (u'shape', 4)
# (u'cooperation', 4)
# (u'extend', 4)
# (u'initiative', 4)
# (u'website', 4)
# (u'experts', 4)
# (u'grown', 4)
# (u'governors', 4)
# (u'game', 4)
# (u'shoulder', 4)
# (u'specific', 4)
# (u'attacks', 4)
# (u'civil', 4)
# (u'launching', 4)
# (u'peninsula', 4)
# (u'tucson', 4)
# (u'leads', 4)
# (u'assistance', 4)
# (u'goes', 4)
# (u'wherever', 4)
# (u'sake', 4)
# (u'classroom', 4)
# (u'police', 4)
# (u'spur', 4)
# (u'nor', 4)
# (u'complicated', 4)
# (u'directly', 4)
# (u'message', 4)
# (u"here's", 4)
# (u'average', 4)
# (u'blame', 4)
# (u'engine', 4)
# (u'role', 4)
# (u'pockets', 4)
# (u'rescued', 4)
# (u'tv', 4)
# (u'learned', 4)
# (u'charge', 4)
# (u'hubs', 4)
# (u'plant', 4)
# (u'stopped', 4)
# (u'earns', 4)
# (u'upon', 4)
# (u'teach', 4)
# (u'fallen', 4)
# (u'convinced', 4)
# (u'achievement', 4)
# (u'justice', 4)
# (u'available', 4)
# (u'full-time', 4)
# (u'gay', 4)
# (u'governor', 4)
# (u'ready', 4)
# (u'doors', 4)
# (u'arrived', 4)
# (u'decision', 4)
# (u'connecting', 4)
# (u'question', 4)
# (u'planet', 4)
# (u'department', 4)
# (u'issues', 4)
# (u'continued', 4)
# (u'responsibilities', 4)
# (u'lines', 4)
# (u'preschool', 4)
# (u'globe', 4)
# (u'surely', 4)
# (u'quo', 4)
# (u'priority', 4)
# (u'painful', 4)
# (u'patients', 4)
# (u'border', 4)
# (u'fuel', 4)
# (u'meant', 4)
# (u'rein', 4)
# (u'tens', 4)
# (u'slowly', 4)
# (u'value', 4)
# (u'member', 4)
# (u'paycheck', 4)
# (u'weapon', 4)
# (u'domestic', 4)
# (u'aspirations', 4)
# (u'smart', 4)
# (u'export', 4)
# (u'rewarding', 4)
# (u'sustain', 4)
# (u'goal:', 4)
# (u'signed', 4)
# (u'girl', 4)
# (u'authority', 4)
# (u'rule', 4)
# (u'determination', 4)
# (u'direct', 4)
# (u'path', 4)
# (u'wars', 4)
# (u'homeowners', 4)
# (u'maintain', 4)
# (u'expectations', 4)
# (u'americans:', 4)
# (u'struggle', 4)
# (u'rewards', 4)
# (u'tells', 4)
# (u'though', 4)
# (u'enterprise', 4)
# (u'ending', 4)
# (u'announce', 4)
# (u'fields', 4)
# (u'independent', 4)
# (u'kid', 4)
# (u'aside', 4)
# (u'apart', 4)
# (u'core', 4)
# (u'graduates', 4)
# (u'east', 4)
# (u'failure', 4)
# (u'setting', 4)
# (u'brothers', 4)
# (u'regime', 4)
# (u'division', 4)
# (u'aggressively', 4)
# (u'supporting', 4)
# (u'shift', 4)
# (u'car', 4)
# (u'heard', 4)
# (u'huge', 4)
# (u'farmers', 4)
# (u'serving', 4)
# (u'smarter', 4)
# (u'transition', 4)
# (u'honest', 4)
# (u'city', 4)
# (u'cops', 4)
# (u'10', 4)
# (u'12', 4)
# (u'recover', 4)
# (u'potential', 4)
# (u'especially', 4)
# (u'drive', 4)
# (u'fifty', 4)
# (u'elected', 4)
# (u'concern', 4)
# (u'developing', 4)
# (u'summer', 4)
# (u'interested', 4)
# (u'mean', 4)
# (u'pull', 4)
# (u'gone', 4)
# (u'field', 4)
# (u'deeply', 4)
# (u'knows', 4)
# (u'learn', 4)
# (u'americas', 4)
# (u'held', 4)
# (u'committed', 4)
# (u'team', 4)
# (u"you'd", 4)
# (u'doctors', 4)
# (u'majority', 4)
# (u'relief', 4)
# (u'added', 4)
# (u'seize', 4)
# (u'fastest', 4)
# (u'during', 4)
# (u'became', 4)
# (u'$250,000', 4)
# (u'demand', 4)
# (u'clear:', 4)
# (u'networks', 4)
# (u'eager', 4)
# (u'confront', 4)
# (u'creation', 4)
# (u'urgent', 4)
# (u'towards', 4)
# (u'stable', 4)
# (u'practices', 4)
# (u'credits', 4)
# (u'leaving', 4)
# (u'defeat', 4)
# (u'danger', 4)
# (u'illegal', 4)
# (u'bridges', 4)
# (u'measure', 4)
# (u'jill', 4)
# (u'york', 4)
# (u'enforcement', 4)
# (u'providing', 4)
# (u'distinguished', 4)
# (u'son', 4)
# (u'strengthened', 4)
# (u'general', 4)
# (u'main', 4)
# (u'choices', 4)
# (u'barely', 4)
# (u'partner', 4)
# (u'effect', 4)
# (u'sets', 4)
# (u'payments', 4)
# (u'pressure', 4)
# (u'confident', 4)
# (u'incredible', 4)
# (u'lift', 4)
# (u'"the', 4)
# (u'saved', 3)
# (u'votes', 3)
# (u'electricity', 3)
# (u'master', 3)
# (u'straight', 3)
# (u'consistent', 3)
# (u'panama', 3)
# (u'above', 3)
# (u'california', 3)
# (u'reagan', 3)
# (u'hospital', 3)
# (u'hole', 3)
# (u'outdated', 3)
# (u'india', 3)
# (u'travel', 3)
# (u'modest', 3)
# (u'uninsured', 3)
# (u'decide', 3)
# (u'unemployed', 3)
# (u'laying', 3)
# (u'onto', 3)
# (u'ran', 3)
# (u'germany', 3)
# (u'consumed', 3)
# (u'tech', 3)
# (u'bomb', 3)
# (u'july', 3)
# (u'rich', 3)
# (u'lenders', 3)
# (u'respond', 3)
# (u'automakers', 3)
# (u'suggested', 3)
# (u'doubt:', 3)
# (u'innocent', 3)
# (u'rail', 3)
# (u'africa', 3)
# (u'usher', 3)
# (u'armed', 3)
# (u'raised', 3)
# (u'lowest', 3)
# (u'strongest', 3)
# (u'promises', 3)
# (u'israel', 3)
# (u'proven', 3)
# (u'test', 3)
# (u'acted', 3)
# (u'bullet', 3)
# (u'midst', 3)
# (u'father', 3)
# (u'advantage', 3)
# (u'groups', 3)
# (u'everybody', 3)
# (u'subsidies', 3)
# (u'millionaires', 3)
# (u'heroes', 3)
# (u'succeeded', 3)
# (u'cold', 3)
# (u'setbacks', 3)
# (u'ultimately', 3)
# (u'card', 3)
# (u'submit', 3)
# (u'carry', 3)
# (u'given', 3)
# (u'households', 3)
# (u'friend', 3)
# (u'15', 3)
# (u'effective', 3)
# (u'diplomatic', 3)
# (u'manufacture', 3)
# (u'contentious', 3)
# (u'turned', 3)
# (u'pain', 3)
# (u'senior', 3)
# (u'shot', 3)
# (u'proportion', 3)
# (u'black', 3)
# (u'encourages', 3)
# (u'region', 3)
# (u'personal', 3)
# (u'pennsylvania', 3)
# (u'preventing', 3)
# (u'thinking', 3)
# (u'lets', 3)
# (u'poised', 3)
# (u'grit', 3)
# (u'holding', 3)
# (u'early', 3)
# (u'lady', 3)
# (u'facing', 3)
# (u'burdens', 3)
# (u'pacific', 3)
# (u'legal', 3)
# (u'road', 3)
# (u'fast', 3)
# (u'bubble', 3)
# (u'strongly', 3)
# (u'syrian', 3)
# (u'tackle', 3)
# (u'messy', 3)
# (u'condition', 3)
# (u'independence', 3)
# (u'design', 3)
# (u'hours', 3)
# (u'amount', 3)
# (u'nine', 3)
# (u'accept', 3)
# (u'refuse', 3)
# (u'fundamental', 3)
# (u'feet', 3)
# (u'weight', 3)
# (u'labs', 3)
# (u'feed', 3)
# (u'colombia', 3)
# (u'compromise', 3)
# (u'vulnerable', 3)
# (u'severe', 3)
# (u'financing', 3)
# (u'doubled', 3)
# (u'conditions', 3)
# (u'9/11', 3)
# (u'sold', 3)
# (u"wouldn't", 3)
# (u'whole', 3)
# (u'ensures', 3)
# (u'monthly', 3)
# (u'meeting', 3)
# (u'empty', 3)
# (u'firefighters', 3)
# (u'prices', 3)
# (u'behavior', 3)
# (u'costly', 3)
# (u'decency', 3)
# (u'earmark', 3)
# (u'$10,000', 3)
# (u'competitive', 3)
# (u'questions', 3)
# (u'customers', 3)
# (u'march', 3)
# (u'showing', 3)
# (u'ignore', 3)
# (u'absolutely', 3)
# (u'broadband', 3)
# (u'blueprint', 3)
# (u'raising', 3)
# (u'employment', 3)
# (u'95%', 3)
# (u'breakthroughs', 3)
# (u'telling', 3)
# (u'world-class', 3)
# (u'fifteen', 3)
# (u'delay', 3)
# (u'buildings', 3)
# (u'ronald', 3)
# (u'1', 3)
# (u'truth', 3)
# (u'supports', 3)
# (u'blows', 3)
# (u'flag', 3)
# (u'bet', 3)
# (u'connected', 3)
# (u'deny', 3)
# (u"you'll", 3)
# (u'subsidizing', 3)
# (u'limits', 3)
# (u'tunisia', 3)
# (u'proposal', 3)
# (u'pre-k', 3)
# (u'moved', 3)
# (u'batteries', 3)
# (u'capabilities', 3)
# (u'equality', 3)
# (u'alive', 3)
# (u'avoid', 3)
# (u"generation's", 3)
# (u'puts', 3)
# (u'beat', 3)
# (u'cells', 3)
# (u'rubble', 3)
# (u'40', 3)
# (u'sandy', 3)
# (u'ceos', 3)
# (u'amanda', 3)
# (u'asian', 3)
# (u'pride', 3)
# (u'commerce', 3)
# (u'solution', 3)
# (u'met', 3)
# (u"i'd", 3)
# (u'guests', 3)
# (u'army', 3)
# (u'innovative', 3)
# (u'biofuels', 3)
# (u'counterterrorism', 3)
# (u'differently', 3)
# (u'easier', 3)
# (u'size', 3)
# (u'decent', 3)
# (u'spill', 3)
# (u'skeptical', 3)
# (u'engagement', 3)
# (u'collapse', 3)
# (u'immigrants', 3)
# (u'bridge', 3)
# (u'modern', 3)
# (u'strengthening', 3)
# (u'forced', 3)
# (u'layoffs', 3)
# (u'nobody', 3)
# (u'saying', 3)
# (u'unified', 3)
# (u'professionals', 3)
# (u"children's", 3)
# (u'18', 3)
# (u'secretary', 3)
# (u'institution', 3)
# (u'news', 3)
# (u'quickly', 3)
# (u'deeper', 3)
# (u'aid', 3)
# (u'opinions', 3)
# (u'wasteful', 3)
# (u'unnecessary', 3)
# (u'50', 3)
# (u'short-term', 3)
# (u'entrepreneur', 3)
# (u'1990s', 3)
# (u'payment', 3)
# (u'ford', 3)
# (u'prevents', 3)
# (u'enemies', 3)
# (u'hurt', 3)
# (u'milk', 3)
# (u'iraqi', 3)
# (u'revolution', 3)
# (u'dealing', 3)
# (u'constitution', 3)
# (u'upgrade', 3)
# (u'sending', 3)
# (u'ingenuity', 3)
# (u'productive', 3)
# (u'guarantee', 3)
# (u'pathway', 3)
# (u'produce', 3)
# (u'maybe', 3)
# (u'brain', 3)
# (u'equip', 3)
# (u'ours', 3)
# (u'happened', 3)
# (u'drilling', 3)
# (u'killed', 3)
# (u'advance', 3)
# (u'childhood', 3)
# (u'2', 3)
# (u'officials', 3)
# (u'mountain', 3)
# (u'allen', 3)
# (u'online', 3)
# (u'wonder', 3)
# (u'hardship', 3)
# (u'slow', 3)
# (u'truly', 3)
# (u'checks', 3)
# (u'cities', 3)
# (u'efficiency', 3)
# (u'senator', 3)
# (u'grants', 3)
# (u'consider', 3)
# (u'reaching', 3)
# (u'doctor', 3)
# (u'centuries', 3)
# (u'drives', 3)
# (u'pakistan', 3)
# (u'treatment', 3)
# (u'furniture', 3)
# (u'provided', 3)
# (u'lands', 3)
# (u'engage', 3)
# (u'summit', 3)
# (u'hard-working', 3)
# (u'fairness', 3)
# (u'winning', 3)
# (u'joined', 3)
# (u'scientists', 3)
# (u"nation's", 3)
# (u'shows', 3)
# (u'jackie', 3)
# (u'pushed', 3)
# (u'numbers', 3)
# (u'plans', 3)
# (u'coal', 3)
# (u'systems', 3)
# (u'propose', 3)
# (u'bryan', 3)
# (u'inequality', 3)
# (u'really', 3)
# (u'belief', 3)
# (u"year's", 3)
# (u'brave', 3)
# (u'several', 3)
# (u'selling', 3)
# (u'stands', 3)
# (u'sometimes', 3)
# (u'charged', 3)
# (u'resolve', 3)
# (u'probably', 3)
# (u'corruption', 3)
# (u'annual', 3)
# (u'elections', 3)
# (u'engineers', 3)
# (u'u.s', 3)
# (u"country's", 3)
# (u'historic', 3)
# (u'yemen', 3)
# (u'jeopardize', 3)
# (u'hated', 3)
# (u'transformation', 3)
# (u'extremism', 3)
# (u'repair', 3)
# (u'notion', 3)
# (u'results', 3)
# (u'wave', 3)
# (u'coalition', 3)
# (u'f', 3)
# (u'fee', 3)
# (u'doubt', 3)
# (u'bureaucracy', 3)
# (u'appointed', 3)
# (u'dropped', 3)
# (u'sit', 3)
# (u'struggles', 3)
# (u'lined', 3)
# (u'despite', 3)
# (u'brian', 3)
# (u'covered', 3)
# (u'thriving', 3)
# (u'privacy', 3)
# (u'overwhelming', 3)
# (u'gather', 3)
# (u'disease', 3)
# (u'newtown', 3)
# (u'supported', 3)
# (u'principal', 3)
# (u'arabian', 3)
# (u'inherited', 3)
# (u'areas', 3)
# (u'calling', 3)
# (u'contain', 3)
# (u'view', 3)
# (u'computer', 3)
# (u"qaeda's", 3)
# (u'opening', 3)
# (u'joe', 3)
# (u'otherwise', 3)
# (u'earning', 3)
# (u'permanent', 3)
# (u'terrorist', 3)
# (u'argue', 3)
# (u'center', 3)
# (u'protecting', 3)
# (u'unprecedented', 3)
# (u'siemens', 3)
# (u'page', 3)
# (u'leader', 3)
# (u'worthy', 3)
# (u'dangerous', 3)
# (u'this:', 3)
# (u'contribute', 3)
# (u'repeat', 3)
# (u'earmarks', 2)
# (u'emerged', 2)
# (u'vast', 2)
# (u'ladders', 2)
# (u'solid', 2)
# (u'bonuses', 2)
# (u"parents'", 2)
# (u'100', 2)
# (u'families;', 2)
# (u'moral', 2)
# (u'strike', 2)
# (u'plunged', 2)
# (u'involve', 2)
# (u'answer', 2)
# (u'beach', 2)
# (u'offshore', 2)
# (u'attracts', 2)
# (u'preventive', 2)
# (u'operations', 2)
# (u'school;', 2)
# (u'somewhere', 2)
# (u'overcome', 2)
# (u'affected', 2)
# (u'backgrounds', 2)
# (u'tyranny', 2)
# (u'filling', 2)
# (u'operatives', 2)
# (u'consolidate', 2)
# (u'trading', 2)
# (u"americans'", 2)
# (u'enormous', 2)
# (u'non-partisan', 2)
# (u'renew', 2)
# (u'philosophical', 2)
# (u'electronic', 2)
# (u'coverage;', 2)
# (u'negotiating', 2)
# (u'wasted', 2)
# (u'likely', 2)
# (u'willingness', 2)
# (u'mind', 2)
# (u'drought', 2)
# (u'competitors', 2)
# (u'consumer', 2)
# (u'tirelessly', 2)
# (u'asia-pacific', 2)
# (u'reinvented', 2)
# (u'watch', 2)
# (u'report', 2)
# (u'haiti', 2)
# (u'steal', 2)
# (u'decides', 2)
# (u'fail', 2)
# (u'discipline', 2)
# (u'loves', 2)
# (u'dedication', 2)
# (u'requests', 2)
# (u'peacefully', 2)
# (u'irresponsible', 2)
# (u'drugs', 2)
# (u'chile', 2)
# (u'near', 2)
# (u'ii', 2)
# (u'disappear', 2)
# (u'adversaries', 2)
# (u'realizing', 2)
# (u'backed', 2)
# (u'liberal', 2)
# (u'background', 2)
# (u'facts', 2)
# (u'match', 2)
# (u'birth', 2)
# (u'shadow', 2)
# (u'55', 2)
# (u'losing', 2)
# (u'post', 2)
# (u'plus', 2)
# (u'governance', 2)
# (u'balanced', 2)
# (u'rely', 2)
# (u'crowd', 2)
# (u'talents', 2)
# (u'inside', 2)
# (u'proved', 2)
# (u'invested', 2)
# (u"family's", 2)
# (u'landed', 2)
# (u'pet', 2)
# (u'invent', 2)
# (u'grateful', 2)
# (u'chair', 2)
# (u'first-class', 2)
# (u'environment', 2)
# (u'quick', 2)
# (u'trend', 2)
# (u'cyber', 2)
# (u'patient', 2)
# (u'debated', 2)
# (u'boost', 2)
# (u'institute', 2)
# (u'lowers', 2)
# (u'verge', 2)
# (u'visit', 2)
# (u'unwarranted', 2)
# (u'everywhere', 2)
# (u'cases', 2)
# (u'behalf', 2)
# (u'classrooms', 2)
# (u'gabby', 2)
# (u'write', 2)
# (u'lifting', 2)
# (u'wildfires', 2)
# (u'100,000', 2)
# (u'resource', 2)
# (u'term', 2)
# (u'attorneys', 2)
# (u'directing', 2)
# (u'demanding', 2)
# (u'promotion', 2)
# (u'saving', 2)
# (u'crossings', 2)
# (u'eyes', 2)
# (u'mostly', 2)
# (u'proving', 2)
# (u'eliminated', 2)
# (u'optimism', 2)
# (u'marines', 2)
# (u'addressing', 2)
# (u'investors', 2)
# (u'surgery', 2)
# (u'giffords', 2)
# (u'inspections', 2)
# (u'emphasis', 2)
# (u'bets', 2)
# (u'reforming', 2)
# (u'shop', 2)
# (u'remnants', 2)
# (u'deportation', 2)
# (u'congressional', 2)
# (u'$2', 2)
# (u'finishing', 2)
# (u'vision', 2)
# (u'declared', 2)
# (u'turbine', 2)
# (u'parent', 2)
# (u'20', 2)
# (u'regardless', 2)
# (u'deduction', 2)
# (u'hardest-hit', 2)
# (u'offered', 2)
# (u'case', 2)
# (u'newspaper', 2)
# (u'exist', 2)
# (u'drug', 2)
# (u'pad', 2)
# (u'nest', 2)
# (u'driven', 2)
# (u'kill', 2)
# (u'captured', 2)
# (u'asthma', 2)
# (u'seems', 2)
# (u'lender', 2)
# (u'plenty', 2)
# (u'careers', 2)
# (u'serves', 2)
# (u'market-based', 2)
# (u'classmates', 2)
# (u'restoring', 2)
# (u'assembly', 2)
# (u'sixty', 2)
# (u'central', 2)
# (u'boldly', 2)
# (u'shrinking', 2)
# (u'rallied', 2)
# (u'positioned', 2)
# (u'rebuilt', 2)
# (u'buying', 2)
# (u"wasn't", 2)
# (u'minneapolis', 2)
# (u"she'd", 2)
# (u'principled', 2)
# (u'poor', 2)
# (u'fuel-efficient', 2)
# (u'driving', 2)
# (u'odds', 2)
# (u'g-20', 2)
# (u'causes', 2)
# (u'pledged', 2)
# (u'dominated', 2)
# (u"they'll", 2)
# (u'steve', 2)
# (u'large', 2)
# (u'penalties', 2)
# (u'gi', 2)
# (u'certainly', 2)
# (u'answers', 2)
# (u'experience', 2)
# (u'streamline', 2)
# (u'common-sense', 2)
# (u'followed', 2)
# (u'trained', 2)
# (u'eye', 2)
# (u'homework', 2)
# (u'broke', 2)
# (u'protects', 2)
# (u'rather', 2)
# (u'educational', 2)
# (u'shore', 2)
# (u'egg', 2)
# (u'reminded', 2)
# (u'launchers', 2)
# (u'24', 2)
# (u'late', 2)
# (u'hurting', 2)
# (u'it:', 2)
# (u'tear', 2)
# (u'initiatives', 2)
# (u'robert', 2)
# (u'highway', 2)
# (u'storm', 2)
# (u'relationship', 2)
# (u'immediate', 2)
# (u'$4', 2)
# (u'treated', 2)
# (u'comrades', 2)
# (u'finding', 2)
# (u'citizens:', 2)
# (u'securing', 2)
# (u'stairs', 2)
# (u'relent', 2)
# (u'sustainable', 2)
# (u'declined', 2)
# (u'untouched', 2)
# (u'competent', 2)
# (u'forsyth', 2)
# (u'expensive', 2)
# (u'kathy', 2)
# (u'fire', 2)
# (u'uncertain', 2)
# (u'momentum', 2)
# (u'lawyers', 2)
# (u'grid', 2)
# (u'vigilant', 2)
# (u'violations', 2)
# (u'bin', 2)
# (u'suffering', 2)
# (u'stagnant', 2)
# (u'popular', 2)
# (u'slash', 2)
# (u'shale', 2)
# (u'graduation', 2)
# (u'missions:', 2)
# (u'$10.10', 2)
# (u'canal', 2)
# (u'opens', 2)
# (u'jewish', 2)
# (u'collapsed', 2)
# (u'deductions', 2)
# (u'hopes', 2)
# (u'mindful', 2)
# (u'themselves;', 2)
# (u'politicians', 2)
# (u'walked', 2)
# (u'2008', 2)
# (u'requires', 2)
# (u'highways', 2)
# (u'baby', 2)
# (u'contributions', 2)
# (u'uphold', 2)
# (u'torture', 2)
# (u'outside', 2)
# (u'miners', 2)
# (u'deals', 2)
# (u'obesity', 2)
# (u'locate', 2)
# (u'punishing', 2)
# (u'boots', 2)
# (u'video', 2)
# (u'download', 2)
# (u'plays', 2)
# (u'firms', 2)
# (u'youngest', 2)
# (u'announced', 2)
# (u'penalty', 2)
# (u'subsidized', 2)
# (u'reflects', 2)
# (u'account', 2)
# (u'founding', 2)
# (u'struggled', 2)
# (u'locked', 2)
# (u'waters', 2)
# (u'produced', 2)
# (u'meantime', 2)
# (u'degrees', 2)
# (u'dad', 2)
# (u'outlined', 2)
# (u'february', 2)
# (u'accounts', 2)
# (u'now:', 2)
# (u'80', 2)
# (u'repeat:', 2)
# (u'disclose', 2)
# (u'payroll', 2)
# (u'barriers', 2)
# (u'reversed', 2)
# (u'steel', 2)
# (u'false', 2)
# (u'korean', 2)
# (u'accountants', 2)
# (u'consequences', 2)
# (u'1,000', 2)
# (u'marriage', 2)
# (u'crumbling', 2)
# (u'michigan', 2)
# (u'bear', 2)
# (u'enlisting', 2)
# (u'extremists', 2)
# (u'preserve', 2)
# (u'closer', 2)
# (u'generations;', 2)
# (u'written', 2)
# (u'key', 2)
# (u'precious', 2)
# (u'minds', 2)
# (u'fulfilled', 2)
# (u'safely', 2)
# (u'together;', 2)
# (u'diplomats', 2)
# (u'opposition', 2)
# (u'welcomed', 2)
# (u'forms', 2)
# (u'faced', 2)
# (u'finished', 2)
# (u'deep', 2)
# (u'defining', 2)
# (u'frustrating', 2)
# (u'prosper', 2)
# (u'claimed', 2)
# (u'perhaps', 2)
# (u'unity', 2)
# (u'terrorism', 2)
# (u'taliban', 2)
# (u'moments', 2)
# (u'entering', 2)
# (u'skill', 2)
# (u'reasons', 2)
# (u'nato', 2)
# (u'miami', 2)
# (u'leaves', 2)
# (u'recognition', 2)
# (u'happens', 2)
# (u'focused', 2)
# (u'forgiven', 2)
# (u'burma', 2)
# (u'owe', 2)
# (u'creativity', 2)
# (u'limit', 2)
# (u'firm', 2)
# (u'universal', 2)
# (u'commander-in-chief', 2)
# (u'oak', 2)
# (u'reckless', 2)
# (u'facilities', 2)
# (u'marching', 2)
# (u'violate', 2)
# (u'penny', 2)
# (u'grueling', 2)
# (u'reinvent', 2)
# (u'andra', 2)
# (u'expanded', 2)
# (u'increasing', 2)
# (u'discrimination', 2)
# (u'pursuit', 2)
# (u'replace', 2)
# (u'total', 2)
# (u'criminals', 2)
# (u'brings', 2)
# (u'98', 2)
# (u'room', 2)
# (u'havens', 2)
# (u'aging', 2)
# (u'damage', 2)
# (u'raleigh', 2)
# (u'bucks', 2)
# (u'senators', 2)
# (u'benefited', 2)
# (u'japan', 2)
# (u'educating', 2)
# (u'hiring', 2)
# (u'represents', 2)
# (u'principals', 2)
# (u'victory', 2)
# (u'inventors', 2)
# (u'crimes', 2)
# (u'precisely', 2)
# (u'george', 2)
# (u'levels', 2)
# (u'tom', 2)
# (u'summon', 2)
# (u'target', 2)
# (u'classes', 2)
# (u'endure', 2)
# (u'talking', 2)
# (u'laden', 2)
# (u'isolated', 2)
# (u'upholding', 2)
# (u'luxury', 2)
# (u'$3,000', 2)
# (u'simplify', 2)
# (u'claims', 2)
# (u'treaty', 2)
# (u'enshrined', 2)
# (u'principle', 2)
# (u'voting', 2)
# (u'inspire', 2)
# (u'retire', 2)
# (u'busy', 2)
# (u'ties', 2)
# (u'defending', 2)
# (u'bay', 2)
# (u'large-scale', 2)
# (u'disaster', 2)
# (u'women;', 2)
# (u'boss', 2)
# (u'faces', 2)
# (u'pose', 2)
# (u'height', 2)
# (u'buffett', 2)
# (u'generals', 2)
# (u'doubts', 2)
# (u'voice', 2)
# (u'complex', 2)
# (u'sidelines', 2)
# (u'european', 2)
# (u'protected', 2)
# (u"john's", 2)
# (u'myra', 2)
# (u'unable', 2)
# (u'concerns', 2)
# (u'threatens', 2)
# (u'remind', 2)
# (u'night', 2)
# (u'rarely', 2)
# (u'battlefield', 2)
# (u'born', 2)
# (u'escape', 2)
# (u'bottom', 2)
# (u'trajectory', 2)
# (u'theirs', 2)
# (u'undocumented', 2)
# (u'steadily', 2)
# (u'palestinians', 2)
# (u'lowering', 2)
# (u'evidence', 2)
# (u'check', 2)
# (u'reality', 2)
# (u'digital', 2)
# (u'muslims', 2)
# (u'seeing', 2)
# (u'relieve', 2)
# (u'turns', 2)
# (u'democrat', 2)
# (u'settle', 2)
# (u'gut', 2)
# (u'somalia', 2)
# (u'options', 2)
# (u'muslim', 2)
# (u'understanding', 2)
# (u'roaring', 2)
# (u'fastest-growing', 2)
# (u'federally-funded', 2)
# (u'responsibly', 2)
# (u'1st', 2)
# (u'planted', 2)
# (u'scope', 2)
# (u'interstate', 2)
# (u'english', 2)
# (u'map', 2)
# (u'designed', 2)
# (u'indeed', 2)
# (u'farmer', 2)
# (u'finance', 2)
# (u'views', 2)
# (u'records', 2)
# (u'wealthy', 2)
# (u'rock', 2)
# (u'crushing', 2)
# (u'charlotte', 2)
# (u'defenses', 2)
# (u'ohio', 2)
# (u'concrete', 2)
# (u'flying', 2)
# (u'yourself', 2)
# (u'drove', 2)
# (u'rival', 2)
# (u'youngstown', 2)
# (u'argument', 2)
# (u'sat', 2)
# (u'performance', 2)
# (u'hardships', 2)
# (u'event', 2)
# (u'surplus', 2)
# (u'corner', 2)
# (u'floods', 2)
# (u'stockpiles', 2)
# (u'slashing', 2)
# (u'spring', 2)
# (u'talented', 2)
# (u'among', 2)
# (u'formed', 2)
# (u'protections', 2)
# (u'countless', 2)
# (u'endures', 2)
# (u'cast', 2)
# (u'promised', 2)
# (u'shifts', 2)
# (u'arguments', 2)
# (u'events', 2)
# (u'workplace', 2)
# (u'internet;', 2)
# (u'vacant', 2)
# (u'trains', 2)
# (u"you've", 2)
# (u'halfway', 2)
# (u'nick', 2)
# (u"everyone's", 2)
# (u'unfinished', 2)
# (u'rejoin', 2)
# (u'sharp', 2)
# (u'twelve', 2)
# (u'table', 2)
# (u'footing', 2)
# (u'moon', 2)
# (u'quitting', 2)
# (u'federally-financed', 2)
# (u'area', 2)
# (u'removing', 2)
# (u'low', 2)
# (u"child's", 2)
# (u'cabinet', 2)
# (u'ended', 2)
# (u'connect', 2)
# (u'moves', 2)
# (u'spends', 2)
# (u'open-ended', 2)
# (u'wounded', 2)
# (u'network', 2)
# (u'recklessness', 2)
# (u'forget', 2)
# (u'sitting', 2)
# (u'detention', 2)
# (u'renewal', 2)
# (u'mothers', 2)
# (u'beliefs', 2)
# (u'returned', 2)
# (u'darkness', 2)
# (u'circumstance', 2)
# (u'tragedy', 2)
# (u'houses', 2)
# (u'healthier', 2)
# (u"day's", 2)
# (u'requiring', 2)
# (u'generate', 2)
# (u'foundations', 2)
# (u'anxieties', 2)
# (u'mali', 2)
# (u'budgets', 2)
# (u'acts', 2)
# (u'reject', 2)
# (u'missions', 2)
# (u'response', 2)
# (u'overnight', 2)
# (u'actually', 2)
# (u'refinancing', 2)
# (u'seeking', 2)
# (u'framework', 2)
# (u'it;', 2)
# (u'redesign', 2)
# (u'courses', 2)
# (u'ports', 2)
# (u'mental', 2)
# (u'balance', 2)
# (u'extraordinary', 2)
# (u'imagine', 2)
# (u'earliest', 2)
# (u'broad-based', 2)
# (u'computers', 2)
# (u'syria', 2)
# (u'embraced', 2)
# (u'revive', 2)
# (u'finances', 2)
# (u'trapped', 2)
# (u'b', 2)
# (u'risks', 2)
# (u'toward', 2)
# (u'declare', 2)
# (u'risky', 2)
# (u'pre-existing', 2)
# (u'alike', 2)
# (u'transparent', 2)
# (u'remsburg', 2)
# (u'approved', 2)
# (u'omaha', 2)
# (u'affairs', 2)
# (u'failed', 2)
# (u'loved', 2)
# (u'gains', 2)
# (u'flowing', 2)
# (u"they'd", 2)
# (u'grew', 2)
# (u'guantanamo', 2)
# (u'remaining', 2)
# (u'supply', 2)
# (u'roofing', 2)
# (u'citizen', 2)
# (u'coalitions', 2)
# (u'bailouts', 2)
# (u'budged', 2)
# (u'itself', 2)
# (u'grant', 2)
# (u'belong', 2)
# (u'shuttered', 2)
# (u'yesterday', 2)
# (u'skyrocketing', 2)
# (u'organization', 2)
# (u'using', 2)
# (u'illusions', 2)
# (u'sputnik', 2)
# (u'guarantees', 2)
# (u'advocate', 2)
# (u'guide', 2)
# (u'google', 2)
# (u'religion', 2)
# (u'plots', 2)
# (u'resilience', 2)
# (u'bankruptcy', 2)
# (u'translate', 2)
# (u"tomorrow's", 2)
# (u'prosperity;', 2)
# (u'backs', 2)
# (u'excuses', 2)
# (u'desiline', 2)
# (u'elements', 2)
# (u'lend', 2)
# (u'rise', 2)
# (u'confusing', 2)
# (u'sides', 2)
# (u"she's", 2)
# (u'having', 2)
# (u'tested', 2)
# (u'conservative', 2)
# (u'centers', 2)
# (u'expelling', 2)
# (u'corrosive', 2)
# (u'cap', 2)
# (u'pledge', 2)
# (u'capital', 2)
# (u'chose', 2)
# (u'healing', 2)
# (u'invented', 2)
# (u'extreme', 2)
# (u"weren't", 2)
# (u'honor', 2)
# (u'apple', 2)
# (u'sons', 2)
# (u'missile', 2)
# (u'stabilized', 2)
# (u'lock', 2)
# (u'job-creating', 2)
# (u'hesitate', 2)
# (u'holds', 2)
# (u'rebounding', 2)
# (u'abuse', 2)
# (u'counter', 2)
# (u'preparing', 2)
# (u'alliance', 2)
# (u'firmly', 2)
# (u'2010', 2)
# (u'material', 2)
# (u'identified', 2)
# (u'70,000', 2)
# (u'upward', 2)
# (u'$100', 2)
# (u'twice', 2)
# (u'all-of-the-above', 2)
# (u'all-in', 2)
# (u'perfectly', 2)
# (u'final', 2)
# (u'exactly', 2)
# (u'discretionary', 2)
# (u'clearly', 2)
# (u'agency', 2)
# (u'issuing', 2)
# (u'deploy', 2)
# (u'homeowner', 2)
# (u'soldiers', 2)
# (u'winner', 2)
# (u'mayors', 2)
# (u'chicago', 2)
# (u'describes', 2)
# (u'constructing', 2)
# (u'bought', 2)
# (u'agencies', 2)
# (u'strides', 2)
# (u'assure', 2)
# (u'journey', 2)
# (u'acres', 2)
# (u'"i\'m', 2)
# (u'divisions', 2)
# (u'discoveries', 2)
# (u'va', 2)
# (u'negotiate', 2)
# (u'"they', 2)
# (u'usual', 2)
# (u'deposits', 2)
# (u'realize', 2)
# (u'crack', 2)
# (u'perpetual', 2)
# (u'simple:', 2)
# (u'boards', 2)
# (u'dependence', 2)
# (u'madame', 2)
# (u'preexisting', 2)
# (u'repeal', 2)
# (u'openings', 2)
# (u'additional', 2)
# (u'spread', 2)
# (u'extended', 2)
# (u'gain', 2)
# (u'official', 2)
# (u'placed', 2)
# (u'gaps', 2)
# (u'periods', 2)
# (u'commitments', 2)
# (u'details', 2)
# (u'afghans', 2)
# (u'inspiration', 2)
# (u'sleep', 1)
# (u'presents', 1)
# (u'unionized', 1)
# (u'try."', 1)
# (u'aurora', 1)
# (u'railways', 1)
# (u"robert's", 1)
# (u'conceive', 1)
# (u'enjoy', 1)
# (u'achievements', 1)
# (u'charter', 1)
# (u'tires', 1)
# (u'perfect', 1)
# (u'hide', 1)
# (u'hate', 1)
# (u'revolutionize', 1)
# (u'organs;', 1)
# (u'resilient', 1)
# (u'seeks', 1)
# (u'berlin;', 1)
# (u'evolving', 1)
# (u'governing', 1)
# (u'102', 1)
# (u'stresses', 1)
# (u'daughter', 1)
# (u'envoy', 1)
# (u'regulators', 1)
# (u'chrysler', 1)
# (u'great;', 1)
# (u'regulatory', 1)
# (u'romney', 1)
# (u'right:', 1)
# (u'enriching', 1)
# (u'nate', 1)
# (u'sticker', 1)
# (u'breathe', 1)
# (u"employees'", 1)
# (u'mired', 1)
# (u'successful', 1)
# (u'99', 1)
# (u'berlin', 1)
# (u'shelters', 1)
# (u'conflicts', 1)
# (u'97', 1)
# (u'ms', 1)
# (u"india's", 1)
# (u'disagreements;', 1)
# (u'cited', 1)
# (u'louisville', 1)
# (u'trusted', 1)
# (u'aching', 1)
# (u'lab', 1)
# (u'destined', 1)
# (u'types', 1)
# (u'attempt', 1)
# (u'appreciate', 1)
# (u'demars', 1)
# (u'perseveres;', 1)
# (u'london', 1)
# (u'drawdown', 1)
# (u'responsive', 1)
# (u'democracies', 1)
# (u'denver', 1)
# (u'destroyed', 1)
# (u'well-connected', 1)
# (u'widely', 1)
# (u'bans', 1)
# (u'prevented', 1)
# (u'caterpillar', 1)
# (u"administration's", 1)
# (u'confronting', 1)
# (u'reasonable', 1)
# (u'off-ramp', 1)
# (u'iran;', 1)
# (u'signing', 1)
# (u'250,000', 1)
# (u'navy', 1)
# (u'raid', 1)
# (u'399', 1)
# (u'extract', 1)
# (u'start:', 1)
# (u'reminding', 1)
# (u'americans?', 1)
# (u'americans;', 1)
# (u'crucial', 1)
# (u'flooded', 1)
# (u'medicine', 1)
# (u'disagreements', 1)
# (u'imported', 1)
# (u'turning', 1)
# (u'threatened', 1)
# (u'vets', 1)
# (u'deceptive', 1)
# (u'messages', 1)
# (u'oppose', 1)
# (u'daunting', 1)
# (u'grade', 1)
# (u'railroads', 1)
# (u'comforted', 1)
# (u'channels', 1)
# (u'neighborhood', 1)
# (u'thick', 1)
# (u'mercury', 1)
# (u'lawsuits', 1)
# (u'plentiful', 1)
# (u'thoughts', 1)
# (u'draft', 1)
# (u'grandchildren', 1)
# (u'nonpartisan', 1)
# (u'majorette', 1)
# (u'frankly', 1)
# (u'magnet', 1)
# (u'silly', 1)
# (u'speaking', 1)
# (u'd-day', 1)
# (u'yachts', 1)
# (u'selflessness', 1)
# (u'superstorm', 1)
# (u'flags', 1)
# (u'blue', 1)
# (u'bruce', 1)
# (u'automaker', 1)
# (u'excelling', 1)
# (u'stood', 1)
# (u'life,"', 1)
# (u'nonprofits', 1)
# (u'assisting', 1)
# (u'episode', 1)
# (u'richard', 1)
# (u'neighborhoods', 1)
# (u'flow', 1)
# (u"ty'sheoma", 1)
# (u'50-year', 1)
# (u'freak', 1)
# (u'meetings', 1)
# (u'aspires', 1)
# (u'colors', 1)
# (u'liberty', 1)
# (u'textbook;', 1)
# (u'dawn', 1)
# (u'unleashed', 1)
# (u'infiltrate', 1)
# (u'continuity', 1)
# (u'"mad', 1)
# (u'fossil', 1)
# (u'compounded', 1)
# (u'pocket', 1)
# (u'$10', 1)
# (u'dr', 1)
# (u'nurse', 1)
# (u'bar', 1)
# (u'release', 1)
# (u'men"', 1)
# (u'christian', 1)
# (u'fair?', 1)
# (u'brazil', 1)
# (u'grandmother', 1)
# (u"patients'", 1)
# (u'represent:', 1)
# (u'rolled', 1)
# (u'weak', 1)
# (u'33,000', 1)
# (u'stress', 1)
# (u'picking', 1)
# (u'ill', 1)
# (u'beacon', 1)
# (u'erupted', 1)
# (u'games', 1)
# (u'confronted', 1)
# (u'tone', 1)
# (u'1.6', 1)
# (u'epidemic', 1)
# (u'pregnancy', 1)
# (u'administrations', 1)
# (u'gratitude', 1)
# (u'targeting', 1)
# (u'asks', 1)
# (u'upside-down', 1)
# (u'way."', 1)
# (u'privilege', 1)
# (u"commonwealth's", 1)
# (u'prosperous', 1)
# (u"customers'", 1)
# (u'160', 1)
# (u'tide', 1)
# (u'exception', 1)
# (u'conviction', 1)
# (u'presidency', 1)
# (u'kentucky', 1)
# (u'ceilings', 1)
# (u'stopping', 1)
# (u'doha', 1)
# (u'defeated', 1)
# (u'mouse', 1)
# (u'damaged', 1)
# (u'soviets;', 1)
# (u'patent', 1)
# (u'beside', 1)
# (u'deficient', 1)
# (u'convictions', 1)
# (u'wheel', 1)
# (u'satellite', 1)
# (u'commonsense', 1)
# (u'marches', 1)
# (u'unyielding', 1)
# (u'graduations', 1)
# (u'skepticism', 1)
# (u'catalyzed', 1)
# (u'possessed', 1)
# (u'inherit', 1)
# (u'qualities', 1)
# (u'alabama', 1)
# (u'33', 1)
# (u'spurred', 1)
# (u'presume', 1)
# (u'fighters', 1)
# (u'incentive', 1)
# (u'buyers', 1)
# (u'candidate', 1)
# (u'transformed', 1)
# (u'taxes?', 1)
# (u"medicare's", 1)
# (u'low-income', 1)
# (u'survival', 1)
# (u'objective', 1)
# (u'cultural', 1)
# (u'imposed', 1)
# (u'desire', 1)
# (u'gift', 1)
# (u'57', 1)
# (u'orlando', 1)
# (u'new-found', 1)
# (u'pavement', 1)
# (u'attorney', 1)
# (u'frustrations', 1)
# (u'creed', 1)
# (u'"that\'s', 1)
# (u'handing', 1)
# (u'library', 1)
# (u'denies', 1)
# (u'shapes', 1)
# (u"harm's", 1)
# (u'contributing', 1)
# (u'tornado', 1)
# (u'embodies', 1)
# (u'offices', 1)
# (u'nineteen', 1)
# (u'participation', 1)
# (u'cash-strapped', 1)
# (u'shifting', 1)
# (u'copouts', 1)
# (u"al-qaeda's", 1)
# (u'super', 1)
# (u'degree."', 1)
# (u'dinner', 1)
# (u'horizon', 1)
# (u'slightly', 1)
# (u'automatically', 1)
# (u'managers', 1)
# (u'obtaining', 1)
# (u'beings', 1)
# (u'for?', 1)
# (u'coastal', 1)
# (u'device;', 1)
# (u'sunlight', 1)
# (u'music', 1)
# (u'shores?', 1)
# (u'form', 1)
# (u'depression;', 1)
# (u'$200', 1)
# (u'discourage', 1)
# (u'reset', 1)
# (u'attached', 1)
# (u'devices', 1)
# (u'better-positioned', 1)
# (u'separated', 1)
# (u'centrifuges', 1)
# (u'request', 1)
# (u'easy."', 1)
# (u'somebody', 1)
# (u'saltwater', 1)
# (u'fatherhood', 1)
# (u'awhile', 1)
# (u'sprint', 1)
# (u'looked', 1)
# (u'upheaval', 1)
# (u'chiefs', 1)
# (u'republic', 1)
# (u'ambitious', 1)
# (u'unwilling', 1)
# (u'phoenix', 1)
# (u'cyber-attacks', 1)
# (u'rolling', 1)
# (u'reorganization', 1)
# (u'assume', 1)
# (u'push', 1)
# (u'restored', 1)
# (u'managed', 1)
# (u'corps', 1)
# (u'rob', 1)
# (u'theaters', 1)
# (u'redouble', 1)
# (u'battle', 1)
# (u'rot', 1)
# (u'superpower', 1)
# (u'striving', 1)
# (u'contemplating', 1)
# (u'promoting', 1)
# (u'tampa', 1)
# (u'terror', 1)
# (u'suffered', 1)
# (u'oversight', 1)
# (u'neighbor;', 1)
# (u'refinance', 1)
# (u'keeping', 1)
# (u'congratulating', 1)
# (u'cook', 1)
# (u'trouble', 1)
# (u'philippines', 1)
# (u'structurally', 1)
# (u'poor;', 1)
# (u'speculation', 1)
# (u'dries', 1)
# (u'bulldozed', 1)
# (u'aggressive', 1)
# (u'substitute', 1)
# (u'adds', 1)
# (u'trivial', 1)
# (u'peels', 1)
# (u"patton's", 1)
# (u'falling', 1)
# (u'filled', 1)
# (u'explosion', 1)
# (u'mechanic', 1)
# (u'inauguration', 1)
# (u'expansion;', 1)
# (u'dissipated', 1)
# (u'share?', 1)
# (u'chemical', 1)
# (u'free."', 1)
# (u'bob', 1)
# (u'studies', 1)
# (u'reclaim', 1)
# (u'prefer', 1)
# (u'compare', 1)
# (u'morale', 1)
# (u'betraying', 1)
# (u'angry', 1)
# (u'wondering', 1)
# (u'candidates', 1)
# (u'household', 1)
# (u'chapter', 1)
# (u'organized', 1)
# (u'envelope', 1)
# (u'oregon', 1)
# (u'downtown', 1)
# (u'slogan', 1)
# (u'piles', 1)
# (u'originally', 1)
# (u'districts', 1)
# (u'hardest', 1)
# (u'regions', 1)
# (u'bites', 1)
# (u'spun', 1)
# (u'predict', 1)
# (u'kindness"', 1)
# (u'lieberman', 1)
# (u'future:', 1)
# (u'simpson-bowles', 1)
# (u'secured', 1)
# (u'contracts', 1)
# (u'sunday', 1)
# (u'fourth', 1)
# (u'laundry', 1)
# (u'southern', 1)
# (u'"expansion"', 1)
# (u'improving', 1)
# (u'revealed', 1)
# (u'pre-requisite', 1)
# (u'whenever', 1)
# (u'borrowing', 1)
# (u'instills', 1)
# (u'burmese', 1)
# (u'forebears', 1)
# (u'tutoring', 1)
# (u'foreclosure', 1)
# (u'stability', 1)
# (u'yearn', 1)
# (u'argued', 1)
# (u"dollars'", 1)
# (u'globalization', 1)
# (u"he'd", 1)
# (u'coaching', 1)
# (u'abusive', 1)
# (u'texas', 1)
# (u'year:', 1)
# (u'3', 1)
# (u'matches', 1)
# (u'sooner', 1)
# (u'toxic', 1)
# (u'conquer', 1)
# (u'twilight', 1)
# (u'pendleton', 1)
# (u'stabilize', 1)
# (u'possibilities', 1)
# (u'boehner', 1)
# (u'magazines', 1)
# (u'unlock', 1)
# (u'ready-to-be-filled', 1)
# (u'speculators', 1)
# (u'devastate', 1)
# (u'3rd', 1)
# (u'profit', 1)
# (u'oklahoma', 1)
# (u'abide', 1)
# (u'imperative', 1)
# (u'kent', 1)
# (u'$9.00', 1)
# (u'batteries;', 1)
# (u'possibility', 1)
# (u'obligation', 1)
# (u'weathered', 1)
# (u'surgeries', 1)
# (u'short-cuts', 1)
# (u'husband', 1)
# (u'routes', 1)
# (u'thirty-seven', 1)
# (u'indispensable', 1)
# (u'frequent', 1)
# (u'blind', 1)
# (u'soaring', 1)
# (u'automaker;', 1)
# (u'waned', 1)
# (u'reinvestment', 1)
# (u'returns', 1)
# (u'stifled', 1)
# (u'fraction', 1)
# (u'pittsburgh', 1)
# (u'elkhart', 1)
# (u'chute', 1)
# (u'"there', 1)
# (u'hillary', 1)
# (u'paper-thin', 1)
# (u'cards', 1)
# (u'start-ups', 1)
# (u'anger', 1)
# (u'offering', 1)
# (u'veteran', 1)
# (u'upgrading', 1)
# (u'interior', 1)
# (u'becoming', 1)
# (u'candidly', 1)
# (u'fails', 1)
# (u'importantly', 1)
# (u'sheets', 1)
# (u'sequester,"', 1)
# (u'wireless', 1)
# (u'steadfast', 1)
# (u'flawlessly', 1)
# (u'heat', 1)
# (u'defeating', 1)
# (u'menchu', 1)
# (u'easy,"', 1)
# (u"isn't;", 1)
# (u'soviets', 1)
# (u"father's", 1)
# (u'gulf', 1)
# (u'september', 1)
# (u'tears', 1)
# (u'deployed', 1)
# (u'neighborsi', 1)
# (u'energetx', 1)
# (u'hostage', 1)
# (u'recruiters', 1)
# (u'partnered', 1)
# (u'storm;', 1)
# (u'joked', 1)
# (u'sabotage', 1)
# (u'yield', 1)
# (u'dough', 1)
# (u'violated', 1)
# (u'larding', 1)
# (u'all."', 1)
# (u'company."', 1)
# (u'review', 1)
# (u'mission:', 1)
# (u'second-place', 1)
# (u'recedes', 1)
# (u'coma', 1)
# (u'spark', 1)
# (u'jobi', 1)
# (u'dates', 1)
# (u'22', 1)
# (u'libya', 1)
# (u'gimmicks', 1)
# (u'brinksmanship', 1)
# (u'expression', 1)
# (u'hezbollah', 1)
# (u'duty', 1)
# (u'stretches', 1)
# (u'bricks', 1)
# (u'28', 1)
# (u'hybrids', 1)
# (u'pundits', 1)
# (u'cancel', 1)
# (u'allies;', 1)
# (u'caring', 1)
# (u'egypt;', 1)
# (u'stretch', 1)
# (u'informed', 1)
# (u'universities;', 1)
# (u'deposited', 1)
# (u'partisanship', 1)
# (u'500', 1)
# (u'shopping', 1)
# (u'graveyard', 1)
# (u'starters', 1)
# (u'unsafe', 1)
# (u'wounds', 1)
# (u'highly-skilled', 1)
# (u'chance."', 1)
# (u'hidden', 1)
# (u'worshiping', 1)
# (u'ally', 1)
# (u'endured', 1)
# (u'conferences', 1)
# (u'engaged', 1)
# (u'couples', 1)
# (u'embrace', 1)
# (u'iowa', 1)
# (u'worry', 1)
# (u'veterans?', 1)
# (u'bowl', 1)
# (u'admit', 1)
# (u'pan', 1)
# (u'closest', 1)
# (u'applaud', 1)
# (u'driver', 1)
# (u'"something', 1)
# (u'consensus', 1)
# (u'high-paying', 1)
# (u'relies', 1)
# (u'constitutional', 1)
# (u'bang', 1)
# (u'model', 1)
# (u'handouts', 1)
# (u'77', 1)
# (u'sputters', 1)
# (u'excel', 1)
# (u'ninth', 1)
# (u'sweeping', 1)
# (u'violent', 1)
# (u'touch', 1)
# (u'blow', 1)
# (u'myself."', 1)
# (u'pile', 1)
# (u'versa', 1)
# (u'reformed', 1)
# (u'disrupt', 1)
# (u'tuesday', 1)
# (u'shadows', 1)
# (u'kills', 1)
# (u'outsource', 1)
# (u'traffic', 1)
# (u'listening', 1)
# (u'dare', 1)
# (u'401ks', 1)
# (u'benefit', 1)
# (u'farthest-reaching', 1)
# (u'booming', 1)
# (u'passions', 1)
# (u'sudan', 1)
# (u'provides', 1)
# (u'"living', 1)
# (u'seconds', 1)
# (u'prosecution', 1)
# (u'equivalent', 1)
# (u'strained', 1)
# (u'dictators', 1)
# (u'control;', 1)
# (u'conducting', 1)
# (u'favorite', 1)
# (u'practical', 1)
# (u'tremendous', 1)
# (u'burning', 1)
# (u'teamwork', 1)
# (u'training;', 1)
# (u'determine', 1)
# (u'elementary', 1)
# (u'nave', 1)
# (u'valuable', 1)
# (u'stark', 1)
# (u'deteriorating', 1)
# (u'dictator', 1)
# (u'decisive', 1)
# (u'drug-resistant', 1)
# (u'chats', 1)
# (u'deepened', 1)
# (u'lobbyists;', 1)
# (u'strikes', 1)
# (u'spilled', 1)
# (u'america!"', 1)
# (u'builders', 1)
# (u'enriched', 1)
# (u'naysayers', 1)
# (u"kentucky's", 1)
# (u'"fix-it-first"', 1)
# (u'deterrent', 1)
# (u'proudest', 1)
# (u'payday', 1)
# (u'retiring', 1)
# (u'vocational', 1)
# (u'misfortune', 1)
# (u'waving', 1)
# (u"israel's", 1)
# (u'remote', 1)
# (u'calls', 1)
# (u'scranton', 1)
# (u'$30', 1)
# (u'resale', 1)
# (u'repay', 1)
# (u'mass', 1)
# (u'legislatures', 1)
# (u'chinese', 1)
# (u'fifty-one', 1)
# (u'washed', 1)
# (u'forbidden', 1)
# (u'founded', 1)
# (u'deadline', 1)
# (u'cincinnati', 1)
# (u"taliban's", 1)
# (u'remarkable', 1)
# (u'dairy', 1)
# (u'lawmakers', 1)
# (u'midwest', 1)
# (u'sound', 1)
# (u'ticked', 1)
# (u'cause;', 1)
# (u'awful', 1)
# (u'dictatorship', 1)
# (u'stimulus', 1)
# (u'celebrity', 1)
# (u'list', 1)
# (u'bankrolled', 1)
# (u'pettiness', 1)
# (u're-finance', 1)
# (u'settled', 1)
# (u'wisconsin', 1)
# (u'thread;', 1)
# (u'conscience', 1)
# (u'him:', 1)
# (u'15,000', 1)
# (u'suu', 1)
# (u'necessary;', 1)
# (u'multinational', 1)
# (u'gridlocked', 1)
# (u'tracks', 1)
# (u'grudges', 1)
# (u'taxpayer-subsidies', 1)
# (u'title:', 1)
# (u'equations', 1)
# (u'houser', 1)
# (u'prosecutors', 1)
# (u'hampering', 1)
# (u'inspired', 1)
# (u'allows', 1)
# (u'post-partisan', 1)
# (u'skyrocket', 1)
# (u'tax-free', 1)
# (u'partnering', 1)
# (u'transit', 1)
# (u'neighbors,"', 1)
# (u'color', 1)
# (u'establish', 1)
# (u'legislator', 1)
# ...
# (u'mexico', 1)
# (u'honorable', 1)
# (u'dictate', 1)
# (u'ambition', 1)
# (u'expenses', 1)
# (u'taunts', 1)
# (u'eighteen', 1)
# (u'clinging', 1)
# (u'cleo', 1)
# (u'harmony', 1)
# (u'harming', 1)
# (u'destruction;', 1)
# (u'pick', 1)
# (u'pioneers', 1)
# (u'failing', 1)
# (u'hearts', 1)
# (u'smoked', 1)
# (u'yours', 1)
# (u"she'll", 1)
# (u'graded', 1)
# (u'unfair', 1)
# (u'year-old', 1)
# (u'plug-in', 1)
# (u'divide', 1)
# (u'advancement', 1)
# (u'wright', 1)
# (u'teenager', 1)
# (u'prison', 1)
# (u'spikes', 1)
# (u'gregg', 1)
# (u'advances', 1)
# (u'roadside', 1)
# (u'allowance', 1)
# (u'fact:', 1)
# (u'ago:', 1)
# (u'cape', 1)
# (u'highly', 1)
# (u'performing', 1)
# (u'officer', 1)
# (u'states:', 1)
# (u'working-class', 1)
# (u'creek', 1)
# (u'somehow', 1)
# (u'hoover', 1)
# (u'cede', 1)
# (u'anniversaries', 1)
# (u'self-healing', 1)
# (u'cordray', 1)
# (u'individuals', 1)
# (u'newtons', 1)
# (u'christmas', 1)
# (u'bold', 1)
# (u'devastation', 1)
# (u'predicting', 1)
# (u'provocations', 1)
# (u'chilean', 1)
# (u'banker', 1)
# (u'commit', 1)
# (u'facility', 1)
# (u'bound', 1)
# (u'arms', 1)
# (u'raises', 1)
# (u'money."', 1)
# (u'cleared', 1)
# (u're-litigating', 1)
# (u'transform', 1)
# (u'pay-as-you-go', 1)
# (u'boom', 1)
# (u'"none', 1)
# (u'faring', 1)
# (u'apprenticeships', 1)
# (u'sustained', 1)
# (u'removed', 1)
# (u'responding', 1)
# (u'builds', 1)
# (u'understood', 1)
# (u'wait?', 1)
# (u'bargain', 1)
# (u'crystal', 1)
# (u'anew', 1)
# (u'panels', 1)
# (u'90%', 1)
# (u'150', 1)
# (u'proves', 1)
# (u'revitalize', 1)
# (u'enlist', 1)
# (u'constructed', 1)
# (u'rapidly-changing', 1)
# (u'tie', 1)
# (u'roll', 1)
# (u'subsidize', 1)
# (u'permitting', 1)
# (u'describe', 1)
# (u'utilities', 1)
# (u'phony', 1)
# (u'scores', 1)
# (u'transfers', 1)
# (u'derail', 1)
# (u'abraham', 1)
# (u'globe:', 1)
# (u'vigorously', 1)
# (u'gutting', 1)
# (u'overdue', 1)
# (u'mile', 1)
# (u'bomber', 1)
# (u'proposal:', 1)
# (u'pell', 1)
# (u'april', 1)
# (u'accomplish', 1)
# (u'supplies', 1)
# (u'good-paying', 1)
# (u'billionaire', 1)
# (u'child;', 1)
# (u'application', 1)
# (u"sana'a", 1)
# (u'responders', 1)
# (u'impressive', 1)
# (u'embarrassment', 1)
# (u'solved', 1)
# (u'shelley', 1)
# (u'unclogging', 1)
# (u'playbook', 1)
# (u'verifiable', 1)
# (u'tougher', 1)
# (u'obsolete', 1)
# (u'notice:', 1)
# (u'bacteria', 1)
# (u'celebrated', 1)
# (u'brink', 1)
# (u'transcontinental', 1)
# (u'staff', 1)
# (u'temperatures', 1)
# (u'burn', 1)
# (u"april's", 1)
# (u'revenues', 1)
# (u'share:', 1)
# (u'trial', 1)
# (u'ineffective', 1)
# (u'all-out', 1)
# (u'emerge', 1)
# (u'rio;', 1)
# (u'bloody', 1)
# (u'"my', 1)
# (u'ritterby', 1)
# (u'prove', 1)
# (u'lieutenants', 1)
# (u'imaginations', 1)
# (u'sharing', 1)
# (u'fine-tuned', 1)
# (u'treasury', 1)
# (u'three-', 1)
# (u'virtue', 1)
# (u'easiest', 1)
# (u'american-made', 1)
# (u'dialed', 1)
# (u'ibm', 1)
# (u'pretend', 1)
# (u'schedule', 1)
# (u'judd', 1)
# (u'printing', 1)
# (u'slows', 1)
# (u'performed', 1)
# (u'mismanagement', 1)
# (u'invest;', 1)
# (u'vital', 1)
# (u'latino;', 1)
# (u'broad', 1)
# (u'bethea', 1)
# (u'crashed', 1)
# (u'apprenticeship', 1)
# (u'destructive', 1)
# (u'$40', 1)
# (u'gap', 1)
# (u'speak;', 1)
# (u'secure;', 1)
# (u'unleash', 1)
# (u'invests', 1)
# (u'enemies;', 1)
# (u'howard', 1)
# (u'insurgency', 1)
# (u'unacceptable', 1)
# (u'blocked', 1)
# (u'terrible,"', 1)
# (u'acknowledge', 1)
# (u'education;', 1)
# (u'surveillance', 1)
# (u'offers', 1)
# (u'visiting', 1)
# (u'gate', 1)
# (u'kids;', 1)
# (u"syria's", 1)
# (u're-fighting', 1)
# (u'reckoning', 1)
# (u'possess', 1)
# (u'name', 1)
# (u'lies', 1)
# (u'james', 1)
# (u'drop', 1)
# (u'decade"', 1)
# (u'establishing', 1)
# (u'rangers', 1)
# (u'el', 1)
# (u'supplant', 1)
# (u'bio-terrorism', 1)
# (u'risk-taker', 1)
# (u'teams', 1)
# (u'self-government', 1)
# (u'seoul', 1)
# (u'infuriated', 1)
# (u'bailout', 1)
# (u'viable', 1)
# (u'inaction', 1)
# (u'treatments', 1)
# (u'dig', 1)
# (u'challenge:', 1)
# (u'progress."', 1)
# (u'inevitable', 1)
# (u'withfarmers', 1)
# (u'pandemic', 1)
# (u'turf', 1)
# (u'entrusted', 1)
# (u'sanchez', 1)
# (u'occupations', 1)
# (u'waves', 1)
# (u'occupy', 1)
# (u'crisis,"', 1)
# (u'legally', 1)
# (u'inefficient', 1)
# (u'out-innovate', 1)
# (u'population', 1)
# (u'unfortunately', 1)
# (u'crossroads', 1)
# (u'bag', 1)
# (u'wins', 1)
# (u'future."', 1)
# (u'outcome', 1)
# (u'declares', 1)
# (u'illness', 1)
# (u'san', 1)
# (u'craig', 1)
# (u'eats', 1)
# (u'buried', 1)
# (u'refighting', 1)
# (u'bashing', 1)
# (u'warriors', 1)
# (u'600,000', 1)
# (u'200', 1)
# (u'investigations', 1)
# (u'cairo;', 1)
# (u'visitors', 1)
# (u'fcc', 1)
# (u'idea?', 1)
# (u'operate', 1)
# (u'31st', 1)
# (u'not:', 1)
# (u'ninety-eight', 1)
# (u'clearing', 1)
# (u'turnover', 1)
# (u'deployments', 1)
# (u'honors', 1)
# (u'essence', 1)
# (u'factories;', 1)
# (u'assistant', 1)
# (u'replaces', 1)
# (u'scorekeeper', 1)
# (u'miles', 1)
# (u'high-powered', 1)
# (u'honesty', 1)
# (u'burst', 1)
# (u'job:', 1)
# (u'driveways', 1)
# (u'seal', 1)
# (u'generosity', 1)
# (u'outsourcing', 1)
# (u'mayor', 1)
# (u'import', 1)
# (u'homebuyers', 1)
# (u'august', 1)
# (u'concentrate', 1)
# (u'nationality', 1)
# (u'safeguard', 1)
# (u'quiet', 1)
# (u'compound;', 1)
# (u'3.5', 1)
# (u'disappointment', 1)
# (u'nearby', 1)
# (u'fiasco?', 1)
# (u'robotics', 1)
# (u'period', 1)
# (u'mccain', 1)
# (u'warriors;', 1)
# (u'moreover', 1)
# (u'poll', 1)
# (u'punishes', 1)
# (u'teddy', 1)
# (u'west', 1)
# (u'mark', 1)
# (u"lock's", 1)
# (u'peaceful', 1)
# (u'helicopter', 1)
# (u'fig', 1)
# (u're-financing', 1)
# (u'realities', 1)
# (u'predicament', 1)
# (u'worried', 1)
# (u'care;', 1)
# (u'pizza', 1)
# (u'promising', 1)
# (u'investigating', 1)
# (u'enriches', 1)
# (u'orientation', 1)
# (u'secondary', 1)
# (u'hills', 1)
# (u'according', 1)
# (u'strain', 1)
# (u'wisely', 1)
# (u'fame', 1)
# (u'intense', 1)
# (u'revolutions', 1)
# (u'harsh', 1)
# (u'$20', 1)
# (u'it."', 1)
# (u'runaround', 1)
# (u'document', 1)
# (u'boosted', 1)
# (u'drain', 1)
# (u'u.s.a!"', 1)
# (u'congressmen', 1)
# (u'2005', 1)
# (u'laboratories', 1)
# (u'gangs', 1)
# (u'adjustments', 1)
# (u'safeguards', 1)
# (u'secretaries;', 1)
# (u'summed', 1)
# (u'guides', 1)
# (u'supercomputers', 1)
# (u'quitters', 1)
# (u'leaner', 1)
# (u'preference', 1)
# (u'tight-knit', 1)
# (u'birthdays', 1)
# (u'intel', 1)
# (u'tuition;', 1)
# (u'rivals', 1)
# (u'shrink', 1)
# (u'curriculums', 1)
# (u'reduced', 1)
# (u'classified', 1)
# (u'jews', 1)
# (u'exposed', 1)
# (u'cynicism', 1)
# (u'scholarships', 1)
# (u'freer', 1)
# (u'accessing', 1)
# (u'scientific', 1)
# (u'industrialized', 1)
# (u'meets', 1)
# (u'pastors', 1)
# (u'inherent', 1)
# (u'devising', 1)
# (u'stations', 1)
# (u'factors', 1)
# (u'escalating', 1)
# (u'up."', 1)
# (u'harness', 1)
# (u'gary', 1)
# (u'watchdog', 1)
# (u'happening', 1)
# (u'legacy', 1)
# (u'philadelphia', 1)
# (u'meals', 1)
# (u'dreaming', 1)
# (u'strict', 1)
# (u'treat', 1)
# (u'media', 1)
# (u'things."', 1)
# (u'signs', 1)
# (u'tranquility', 1)
# (u'dangers', 1)
# (u'pleased', 1)
# (u'land', 1)
# (u'cycle', 1)
# (u'billionaires', 1)
# (u'year-olds', 1)
# (u'preside', 1)
# (u'emissions', 1)
# (u'abuses', 1)
# (u'trips', 1)
# (u'vehicles', 1)
# (u'research;', 1)
# (u'panels;', 1)
# (u'imagination', 1)
# (u'walks', 1)
# (u'orrin', 1)
# (u'credibility', 1)
# (u'commutes', 1)
# (u'underwater', 1)
# (u'forcing', 1)
# (u"president's", 1)
# (u'fueling', 1)
# (u'fresh', 1)
# (u'stocks', 1)
# (u'arsenals', 1)
# (u'wife', 1)
# (u'bystander', 1)
# (u'stockpile', 1)
# (u'numbing', 1)
# (u'belts', 1)
# (u'strings', 1)
# (u'refused', 1)
# (u'caused', 1)
# (u'bull', 1)
# (u'back?', 1)
# (u'costco', 1)
# (u'homelessness', 1)
# (u'pilot', 1)
# (u'smartphones', 1)
# (u'grandfather', 1)
# (u'reaffirming', 1)
# (u'sank', 1)
# (u'quicker', 1)
# (u'on-the-job', 1)
# (u'arizona', 1)
# (u'quicken', 1)
# (u'clock', 1)
# (u'anniversary', 1)
# (u'self-government;', 1)
# (u'prevailed', 1)
# (u'movement', 1)
# (u'turmoil', 1)
# (u'reverses', 1)
# (u'lack', 1)
# (u'combating', 1)
# (u'andrews', 1)
# (u'prior', 1)
# (u"would've", 1)
# (u'narrow', 1)
# (u'inspires', 1)
# (u'scraping', 1)
# (u'65th', 1)
# (u'boosting', 1)
# (u'rises', 1)
# (u'flat', 1)
# (u'openly;', 1)
# (u'stolen', 1)
# (u'excuse', 1)
# (u'particular', 1)
# (u'installing', 1)
# (u'sudden', 1)
# (u'greeted', 1)
# (u'galesburg', 1)
# (u'stubborn', 1)
# (u'challenging', 1)
# (u'prompting', 1)
# (u'lightweight', 1)
# (u'fiercely', 1)
# (u'gallon', 1)
# (u'sikh', 1)
# (u'longest', 1)
# (u'voted."', 1)
# (u'counter-terrorism', 1)
# (u'mapping', 1)
# (u'pension', 1)
# (u'fascism', 1)
# (u'disable', 1)
# (u'blood', 1)
# (u'act;', 1)
# (u'rocketed', 1)
# (u'finalized', 1)
# (u'developed', 1)
# (u'industrial', 1)
# (u'milwaukee', 1)
# (u'suffer', 1)
# (u'27', 1)
# (u'detainee', 1)
# (u'solving', 1)
# (u'2%', 1)
# (u'hiring;', 1)
# (u'cool', 1)
# (u'believed:', 1)
# (u'complain', 1)
# (u'wash', 1)
# (u'die', 1)
# (u'investigators', 1)
# (u'needless', 1)
# (u'house;', 1)
# (u'missed', 1)
# (u'projected', 1)
# (u'adhere', 1)
# (u'protectionism', 1)
# (u'drifting', 1)
# (u'base', 1)
# (u'brightest', 1)
# (u'"college', 1)
# (u'cheering', 1)
# (u'reemployment', 1)
# (u'empowering', 1)
# (u'that."', 1)
# (u'fees', 1)
# (u'stage', 1)
# (u'temperature', 1)
# (u'paint', 1)
# (u'automobile', 1)
# (u'swipe', 1)
# (u'spouse', 1)
# (u'parent/teacher', 1)
# (u'station', 1)
# (u'seeker', 1)
# (u'begrudge', 1)
# (u'gps', 1)
# (u'option', 1)
# (u'convinces', 1)
# (u'discover', 1)
# (u'$3', 1)
# (u'dam', 1)
# (u'iranian', 1)
# (u'offender', 1)
# (u'uniforms', 1)
# (u'imports', 1)
# (u'hire:', 1)
# (u'substantial', 1)
# (u'performance;', 1)
# (u'nights', 1)
# (u'drapes', 1)
# (u'client', 1)
# (u'beshear', 1)
# (u'flexibility:', 1)
# (u'electric', 1)
# (u'swiftly', 1)
# (u'affordability', 1)
# (u'hired', 1)
# (u'72', 1)
# (u'devastated', 1)
# (u'2nd', 1)
# (u'joining', 1)
# (u'rule:', 1)
# (u'commissions', 1)
# (u'league', 1)
# (u'session', 1)
# (u'efforts:', 1)
# (u'gravest', 1)
# (u'philanthropists', 1)
# (u'heavily', 1)
# (u'shingles', 1)
# (u'captures', 1)
# (u'8', 1)
# (u'crippling', 1)
# (u'coincidence', 1)
# (u'employer', 1)
# (u'locating', 1)
# (u'carrying', 1)
# (u'culture', 1)
# (u'encouraged."', 1)
# (u'repairs', 1)
# (u'years;', 1)
# (u'$2,500', 1)
# (u'guinea', 1)
# (u'currently', 1)
# (u'out;', 1)
# (u"other's", 1)
# (u'supposed', 1)
# (u'candor', 1)
# (u'attention', 1)
# (u'readying', 1)
# (u'feeling', 1)
# (u'reverse', 1)
# (u'crime', 1)
# (u'riddled', 1)
# (u'bond', 1)
# (u'danced', 1)
# (u'allegiance', 1)
# (u'$2.5', 1)
# (u'tennessee', 1)
# (u'church', 1)
# (u'improvement', 1)
# (u'belt', 1)
# (u'acceptance', 1)
# (u'whom', 1)
# (u'dropping', 1)
# (u'there;', 1)
# (u'lived', 1)
# (u'consume', 1)
# (u'boy', 1)
# (u'mine', 1)
# (u'afraid,"', 1)
# (u'extracted', 1)
# (u'equivocation', 1)
# (u'judicial', 1)
# (u'income;', 1)
# (u'pace', 1)
# (u'harkin', 1)
# (u'fight;', 1)
# (u'30', 1)
# (u'rancor', 1)
# (u'fast-changing', 1)
# (u're-design', 1)
# (u'virtually', 1)
# (u'devised', 1)
# (u'tragedies', 1)
# (u'contractors', 1)
# (u'robust', 1)
# (u'recent', 1)
# (u'priced', 1)
# (u'people;', 1)
# (u'eviction;', 1)
# (u'deployment', 1)
# (u'reliance', 1)
# (u'continent', 1)
# (u'extra', 1)
# (u'presidents', 1)
# (u'nasa', 1)
# (u'wives', 1)
# (u'matters', 1)
# (u'question:', 1)
# (u'knock', 1)
# (u'relied', 1)
# (u'$14,500', 1)
# (u'associate', 1)
# (u'strife', 1)
# (u'400,000', 1)
# (u'parade', 1)
# (u'34,000', 1)
# (u'delivered', 1)
# (u'scale', 1)
# (u'affects', 1)
# (u'shall', 1)
# (u'efficiencies', 1)
# (u'temple', 1)
# (u'made."', 1)
# (u'sixteen', 1)
# (u'rebates', 1)
# (u'"lost', 1)
# (u'secretary;', 1)
# (u'nowhere', 1)
# (u'wealth', 1)
# (u'surrender', 1)
# (u'ordeal', 1)
# (u'dwight', 1)
# (u'colorado', 1)
# (u'repaid', 1)
# (u'statistics', 1)
# (u'eleven', 1)
# (u'accountability', 1)
# (u'harnesses', 1)
# (u'abess', 1)
# (u'opponent', 1)
# (u'himself', 1)
# (u'murphy', 1)
# (u'boys', 1)
# (u'homeownership', 1)
# (u"hasn't", 1)
# (u'historically', 1)
# (u'clear-eyed', 1)
# (u'strong;', 1)
# (u'adults', 1)
# (u'likewise', 1)
# (u'cleveland', 1)
# (u'living?', 1)
# (u'divisive', 1)
# (u'cure', 1)
# (u'rehab', 1)
# (u'independents', 1)
# (u'genome', 1)
# (u'outsourced', 1)
# (u'explaining', 1)
# (u'kansas', 1)
# (u'reach:', 1)
# (u'fisher', 1)
# (u'worsened', 1)
# (u'suffers', 1)
# (u'yardsticks', 1)
# (u'bankers', 1)
# (u'eased', 1)
# (u'hard;', 1)
# (u'2007', 1)
# (u'enrolled', 1)
# (u'2009', 1)
# (u'inventions', 1)
# (u'hunger', 1)
# (u'crisis;', 1)
# (u'hiv/aids', 1)
# (u'differing', 1)
# (u'dramatically', 1)
# (u'confirmation', 1)
# (u'organizations', 1)
# (u'afghanistan;', 1)
# (u'mastering', 1)
# (u'assad', 1)
# (u'p-tech', 1)
# (u'severely', 1)
# (u'tokyo', 1)
# (u'dealt', 1)
# (u'someday', 1)
# (u'educators', 1)
# (u'safe;', 1)
# (u'click', 1)
# (u'victor', 1)
# (u'campuses', 1)
# (u'equipping', 1)
# (u'out-compete', 1)
# (u'five-year', 1)
# (u'relocate', 1)
# (u'ammunition', 1)
# (u'3d', 1)
# (u'focuses', 1)
# (u'leg', 1)
# (u'punch', 1)
# (u"history's", 1)
# (u'decimated', 1)
# (u'arrive', 1)
# (u'involved', 1)
# (u'larger', 1)
# (u'no-bid', 1)
# (u'expire', 1)
# (u'bookkeeping', 1)
# (u'fulfill', 1)
# (u'balances', 1)
# (u'manage', 1)
# (u'surpluses', 1)
# (u'names', 1)
# (u'apply', 1)
# (u'all-time', 1)
# (u'lifts', 1)
# (u'savings:', 1)
# (u'face-to-face', 1)
# (u'panel', 1)
# (u'curricula', 1)
# (u'seals', 1)
# (u'becomes', 1)
# (u'torn', 1)
# (u'governments', 1)
# (u'saddle', 1)
# (u'anywhere', 1)
# (u'aids-free', 1)
# (u'weaker', 1)
# (u'providers', 1)
# (u'effectively', 1)
# (u'reserves', 1)
# (u'surge', 1)
# (u'native', 1)
# (u'located', 1)
# (u'counterfeit', 1)
# (u'express', 1)
# (u'aspiring', 1)
# (u'battered', 1)
# (u'underway', 1)
# (u'jumpstart', 1)
# (u'resent', 1)
# (u'proliferation;', 1)
# (u'readiness', 1)
# (u'majorities', 1)
# (u'hold?', 1)
# (u'light', 1)
# (u'physician', 1)
# (u'stamped', 1)
# (u'manufactured', 1)
# (u'encouraged', 1)
# (u'giveaways', 1)
# (u'looks', 1)
# (u'lifeblood', 1)
# (u'unchecked', 1)
# (u'ourselves."', 1)
# (u'world?', 1)
# (u'prudent', 1)
# (u'2012', 1)
# (u'campaigned', 1)
# (u'disrupted', 1)
# (u'conrad', 1)
# (u'personally', 1)
# (u'speaks', 1)
# (u'by;', 1)
# (u'profound', 1)
# (u'warned', 1)
# (u'covering', 1)
# (u'trimmed', 1)
# (u'magnitude', 1)
# (u'experienced', 1)
# (u'lie', 1)
# (u'society', 1)
# (u'books', 1)
# (u'thirteen', 1)
# (u'task,"', 1)
# (u'sovereign', 1)
# (u'chaos', 1)
# (u'obsess', 1)
# (u"michelle's", 1)
# (u'caregivers', 1)
# (u'applications', 1)
# (u'backwards', 1)
# (u'islamic', 1)
# (u'determining', 1)
# (u'rushed', 1)
# (u'conversation', 1)
# (u'tack', 1)
# (u'resumes', 1)
# (u'retail', 1)
# (u'finest', 1)
# (u'succeeds', 1)
# (u'scene', 1)
# (u'reached', 1)
# (u'economy;', 1)
# (u'65%', 1)
# (u'sergeant', 1)
# (u'bone-tired', 1)
# (u'ira', 1)
# (u'punish', 1)
# (u'tuck', 1)
# (u'lightening', 1)
# (u'warfare', 1)
# (u'shrapnel', 1)
# (u'isolation', 1)
# (u'infectious', 1)
# (u'6th', 1)
# (u'visited', 1)
# (u'1.5', 1)
# (u'unlikely', 1)
# (u'chambers', 1)
# (u'documents', 1)
# (u'quitters."', 1)
# (u'arm', 1)
# (u'rejects', 1)
# (u'bus', 1)
# (u'latino', 1)
# (u'toughest', 1)
# (u'regard', 1)
# (u'intentions', 1)
# (u'so-called', 1)
# (u'reignite', 1)
# (u'movie', 1)
# (u'occasion', 1)
# (u'anyway', 1)
# (u'specializes', 1)
# (u'wear', 1)
# (u'pause', 1)
# (u'knowledge', 1)
# (u'few;', 1)
# (u'entities', 1)
# (u'112th', 1)
# (u'yourselves', 1)
# (u'employed', 1)
# (u'god-given', 1)
# (u'prosecute', 1)
# (u'toledo', 1)
# (u'stripes', 1)
# (u'joint', 1)
# (u'exchanges', 1)
# (u'goods;', 1)
# (u'shaping', 1)
# (u'sowing', 1)
# (u'tightening', 1)
# (u'situation', 1)
# (u'frustrates', 1)
# (u'convince', 1)
# (u'routine', 1)
# (u'warren', 1)
# (u'"nothing', 1)
# (u"system's", 1)
# (u'demonstrate', 1)
# (u'impoverished', 1)
# (u'praying', 1)
# (u'restrictions', 1)
# (u'freely', 1)
# (u'well-qualified', 1)
# (u'deter', 1)
# (u'jim', 1)
# (u'changing;', 1)
# (u'out-teach', 1)
# (u'revamp', 1)
# (u'pouring', 1)
# (u'hindu', 1)
# (u'arbitrary', 1)
# (u'2001', 1)
# (u'u.s.a.!', 1)
# (u'received', 1)
# (u'qadhafi', 1)
# (u'1200', 1)
# (u'ensuring', 1)
# (u'volunteer', 1)
# (u'pictures', 1)
# (u'will"', 1)
# (u'carved', 1)
# (u'delaying', 1)
# (u'lifetime', 1)
# (u'sits', 1)
# (u'insourcing', 1)
# (u'morning', 1)
# (u'chants', 1)
# (u'microsoft', 1)
# (u'autoworker', 1)
# (u'selfish', 1)
# (u'drink', 1)
# (u'authors', 1)
# (u'discouraged', 1)
# (u'lobby', 1)
# (u'doubtful;', 1)
# (u'modeled', 1)
# (u'stranglehold', 1)
# (u'gutted', 1)
# (u'position', 1)
# (u'drawing', 1)
# (u'restructure', 1)
# (u'mandate', 1)
# (u'obtain', 1)
# (u'forty-four', 1)
# (u'trans-pacific', 1)
# (u'seats', 1)
# (u'keen', 1)
# (u'work-study', 1)
# (u'work;', 1)
# (u'attractive', 1)
# (u'destroy', 1)
# (u'policy-making', 1)
# (u'recovery.gov', 1)
# (u'whims', 1)
# (u'immediately', 1)
# (u'"but', 1)
# (u'roofers', 1)
# (u'exploiting', 1)
# (u'scares', 1)
# (u'disrupting', 1)
# (u'"what', 1)
# (u'merge', 1)
# (u'leak', 1)
# (u'favors', 1)
# (u'e-mail', 1)
# (u'before;', 1)
# (u'lags', 1)
# (u'noise', 1)
# (u'real-world', 1)
# (u'paper', 1)
# (u'petty', 1)
# (u'overloaded', 1)
# (u'noisy', 1)
# (u'seeds', 1)
# (u'insider', 1)
# (u'recognizes', 1)
# (u'software', 1)
# (u'unsustainable', 1)
# (u'tight', 1)
# (u'weather', 1)
# (u'mere', 1)
# (u'transfer', 1)
# (u'noticed', 1)
# (u'airline', 1)
# (u'maze', 1)
# (u'double-down', 1)
# (u'funds', 1)
# (u'agrees', 1)
# (u'reminds', 1)
# (u'preventable', 1)
# (u'apollo', 1)
# (u'eat', 1)
# (u'misty', 1)
# (u'flip', 1)
# (u'retool', 1)
# (u'200,000', 1)
# (u'diligently', 1)
# (u'reason:', 1)
# (u'ribbon-cuttings', 1)
# (u'campus', 1)
# (u'compared', 1)
# (u'illinois', 1)
# (u'long-time', 1)
# (u'conclusion', 1)
# (u'bailing', 1)
# (u'pathways', 1)
# (u'mistakes;', 1)
# (u'stumble;', 1)
# (u'biotechnology', 1)
# (u'retirees', 1)

# %%
word_count_gwb_clean = word_count_gwb.filter(lambda x: x[0] not in common_words)
word_count_gwb_clean.count()
for x in word_count_gwb_clean.sortBy(lambda x: x[1],ascending=False).take(15):
    print x
# Out:
# (u'', 704)
# (u'america', 207)
# (u'people', 158)
# (u'must', 153)
# (u'world', 131)
# (u'country', 108)
# (u'american', 104)
# (u'americans', 99)
# (u'congress', 99)
# (u'security', 98)
# (u'help', 90)
# (u'nation', 88)
# (u'terrorists', 83)
# (u'iraq', 80)
# (u'freedom', 79)

# %%
word_count_wjc_clean = word_count_wjc.filter(lambda x: x[0] not in common_words)
word_count_wjc_clean.count()
for x in word_count_wjc_clean.sortBy(lambda x: x[1],ascending=False).take(15):
    print x
# Out:
# (u'', 1046)
# (u'must', 289)
# (u'people', 266)
# (u'work', 194)
# (u'america', 188)
# (u'years', 176)
# (u'children', 153)
# (u'americans', 152)
# (u'congress', 147)
# (u'american', 136)
# (u'help', 117)
# (u'care', 116)
# (u'world', 108)
# (u'health', 102)
# (u'tonight', 98)

# %%
word_count_jfk_clean = word_count_wjc.filter(lambda x: x[0] not in common_words)
word_count_jfk_clean.count()
for x in word_count_jfk_clean.sortBy(lambda x: x[1],ascending=False).take(15):
    print x
# Out:
# (u'', 1046)
# (u'must', 289)
# (u'people', 266)
# (u'work', 194)
# (u'america', 188)
# (u'years', 176)
# (u'children', 153)
# (u'americans', 152)
# (u'congress', 147)
# (u'american', 136)
# (u'help', 117)
# (u'care', 116)
# (u'world', 108)
# (u'health', 102)
# (u'tonight', 98)

# %%
word_count_fdr_clean = word_count_fdr.filter(lambda x: x[0] not in common_words)
word_count_fdr_clean.count()
for x in word_count_fdr_clean.sortBy(lambda x: x[1],ascending=False).take(15):
    print x
# Out:
# (u'', 980)
# (u'war', 238)
# (u'world', 167)
# (u'must', 161)
# (u'government', 154)
# (u'people', 141)
# (u'national', 130)
# (u'other', 124)
# (u'nation', 122)
# (u'nations', 111)
# (u'peace', 111)
# (u'united', 106)
# (u'congress', 105)
# (u'american', 97)
# (u'many', 94)

# %%
word_count_al_clean = word_count_al.filter(lambda x: x[0] not in common_words)
word_count_al_clean.count()
for x in word_count_al_clean.sortBy(lambda x: x[1],ascending=False).take(15):
    print x
# Out:
# (u'', 317)
# (u'states', 148)
# (u'upon', 84)
# (u'united', 81)
# (u'any', 79)
# (u'congress', 77)
# (u'government', 73)
# (u'people', 70)
# (u'other', 69)
# (u'war', 64)
# (u'country', 62)
# (u'great', 61)
# (u'union', 53)
# (u'shall', 53)
# (u'time', 51)

# %%
word_count_gw_clean = word_count_gw.filter(lambda x: x[0] not in common_words)
word_count_gw_clean.count()
for x in word_count_gw_clean.sortBy(lambda x: x[1],ascending=False).take(15):
    print x
# Out:
# (u'', 241)
# (u'states', 91)
# (u'united', 86)
# (u'public', 54)
# (u'your', 47)
# (u'government', 47)
# (u'made', 39)
# (u'upon', 38)
# (u'my', 37)
# (u'other', 37)
# (u'citizens', 33)
# (u'state', 32)
# (u'country', 31)
# (u'shall', 30)
# (u'peace', 30)

# %%
for x in word_count_fdr_clean.subtractByKey(word_count_bo_clean).sortBy(lambda x: x[1],ascending=False).take(15):
    print x
# Out:
# (u'present', 39)
# (u'japanese', 36)
# (u'therefore', 31)
# (u'essential', 31)
# (u'enemy', 24)
# (u'1942', 22)
# (u'methods', 21)
# (u'adequate', 21)
# (u'principles', 20)
# (u'peoples', 20)
# (u'1933', 19)
# (u'however', 19)
# (u'objectives', 19)
# (u'agriculture', 18)
# (u'civilization', 18)

# %%
for x in word_count_bo_clean.subtractByKey(word_count_fdr_clean).sortBy(lambda x: x[1],ascending=False).take(15):
    print x
# Out:
# (u'energy', 87)
# (u'tonight', 84)
# (u'businesses', 69)
# (u'college', 40)
# (u'schools', 36)
# (u'students', 27)
# (u'oil', 26)
# (u'kids', 25)
# (u'republicans', 25)
# (u'innovation', 24)
# (u'gas', 23)
# (u'democrats', 23)
# (u'research', 22)
# (u'nuclear', 21)
# (u'technology', 20)

# %%
for x in word_count_bo_clean.subtractByKey(word_count_wjc_clean).sortBy(lambda x: x[1],ascending=False).take(15):
    print x
# Out:
# (u'oil', 26)
# (u'manufacturing', 19)
# (u'afghanistan', 18)
# (u'al', 15)
# (u'afghan', 15)
# (u'iran', 12)
# (u'solar', 12)
# (u'qaeda', 12)
# (u'code', 11)
# (u'rebuilding', 10)
# (u'worse', 10)
# (u'infrastructure', 10)
# (u'biden', 9)
# (u'breaks', 9)
# (u'high-speed', 8)

# %%
for x in word_count_bo_clean.subtractByKey(word_count_gwb_clean).sortBy(lambda x: x[1],ascending=False).take(15):
    print x
# Out:
# (u'banks', 22)
# (u'industry', 20)
# (u'trillion', 17)
# (u'middle-class', 13)
# (u'wage', 12)
# (u'class', 12)
# (u'forge', 11)
# (u'lay', 11)
# (u'lending', 11)
# (u'walk', 11)
# (u'helps', 10)
# (u'restore', 10)
# (u'minimum', 10)
# (u'high-tech', 9)
# (u'biden', 9)

# %%
for x in word_count_bo_clean.subtractByKey(word_count_gw_clean).sortBy(lambda x: x[1],ascending=False).take(15):
    print x
# Out:
# (u'jobs', 148)
# (u'america', 131)
# (u'americans', 105)
# (u'tonight', 84)
# (u'help', 81)
# (u'businesses', 69)
# (u'health', 55)
# (u'back', 53)
# (u'job', 51)
# (u'reform', 51)
# (u'deficit', 48)
# (u'down', 47)
# (u'college', 40)
# (u'today', 40)
# (u"can't", 39)

# %%
for x in word_count_bo_clean.subtractByKey(word_count_al_clean).sortBy(lambda x: x[1],ascending=False).collect():
    print x
# Out:
# (u'jobs', 148)
# (u'tonight', 84)
# (u'businesses', 69)
# (u'families', 56)
# (u'job', 51)
# (u'deficit', 48)
# (u'college', 40)
# (u'today', 40)
# (u"can't", 39)
# (u'schools', 36)
# (u'million', 36)
# (u'workers', 35)
# (u'clean', 35)
# (u'hard', 32)
# (u'budget', 30)
# (u'lead', 28)
# (u'bill', 28)
# (u'cuts', 28)
# (u"america's", 28)
# (u'students', 27)
# (u'invest', 26)
# (u'finally', 26)
# (u'oil', 26)
# (u'afford', 25)
# (u'young', 25)
# (u'kids', 25)
# (u'cannot', 25)
# (u'republicans', 25)
# (u'values', 24)
# (u'spending', 24)
# (u'leaders', 24)
# (u'recovery', 24)
# (u'innovation', 24)
# (u'gas', 23)
# (u'took', 23)
# (u'democrats', 23)
# (u'percent', 22)
# (u'insurance', 22)
# (u'costs', 22)
# (u'research', 22)
# (u'nuclear', 21)
# (u'economic', 21)
# (u'technology', 20)
# (u'recession', 20)
# (u'investments', 20)
# (u'company', 20)
# (u'chamber', 19)
# (u'start', 19)
# (u'decade', 19)
# (u'child', 19)
# (u'manufacturing', 19)
# (u'afghanistan', 18)
# (u'goal', 18)
# (u'stronger', 17)
# (u'decades', 17)
# (u'rules', 17)
# (u'building', 17)
# (u'programs', 17)
# (u'trillion', 17)
# (u'stop', 16)
# (u'around', 16)
# (u'big', 16)
# (u'deserve', 16)
# (u'commitment', 16)
# (u'colleges', 16)
# (u'dollars', 16)
# (u'ahead', 16)
# (u'behind', 16)
# (u'housing', 16)
# (u"aren't", 16)
# (u'global', 16)
# (u'iraq', 16)
# (u'skills', 15)
# (u'challenges', 15)
# (u'helping', 15)
# (u'strengthen', 15)
# (u"won't", 15)
# (u'teachers', 15)
# (u'grow', 15)
# (u'investment', 15)
# (u'idea', 15)
# (u'al', 15)
# (u'worked', 15)
# (u"there's", 15)
# (u'leadership', 15)
# (u'bipartisan', 15)
# (u'program', 15)
# (u'afghan', 15)
# (u'medicare', 14)
# (u'helped', 14)
# (u'dream', 14)
# (u'parents', 14)
# (u'makes', 14)
# (u'rest', 14)
# (u'student', 14)
# (u'reforms', 14)
# (u'street', 14)
# (u'everyone', 14)
# (u'getting', 14)
# (u'veterans', 13)
# (u'middle-class', 13)
# (u'real', 13)
# (u'week', 13)
# (u"world's", 13)
# (u'tomorrow', 13)
# (u'everything', 13)
# (u'ideas', 13)
# (u'middle', 13)
# (u'spend', 13)
# (u"you're", 13)
# (u'top', 13)
# (u'savings', 13)
# (u'problem', 13)
# (u'going', 13)
# (u'wage', 12)
# (u'iran', 12)
# (u'long-term', 12)
# (u'allies', 12)
# (u'cars', 12)
# (u'politics', 12)
# (u'dreams', 12)
# (u'solar', 12)
# (u'happen', 12)
# (u'told', 12)
# (u'speak', 12)
# (u'wait', 12)
# (u'qaeda', 12)
# (u'folks', 11)
# (u'tough', 11)
# (u'industries', 11)
# (u'ensure', 11)
# (u'incentives', 11)
# (u'affordable', 11)
# (u'forge', 11)
# (u'markets', 11)
# (u'got', 11)
# (u'asked', 11)
# (u'lending', 11)
# (u'threat', 11)
# (u'lower', 11)
# (u'democracy', 11)
# (u'code', 11)
# (u'bills', 11)
# (u'fellow', 11)
# (u'weapons', 10)
# (u'solve', 10)
# (u'problems', 10)
# (u'poverty', 10)
# (u'speaker', 10)
# (u'tell', 10)
# (u'remember', 10)
# (u'rebuilding', 10)
# (u'eliminate', 10)
# (u'helps', 10)
# (u'yes', 10)
# (u'coverage', 10)
# (u'basic', 10)
# (u'unemployment', 10)
# (u'level', 10)
# (u'infrastructure', 10)
# (u'woman', 10)
# (u'minimum', 10)
# (u'korea', 10)
# (u'terrorists', 10)
# (u'vice', 10)
# (u'billion', 9)
# (u'high-tech', 9)
# (u'threats', 9)
# (u'compete', 9)
# (u'biden', 9)
# (u'focus', 9)
# (u'teacher', 9)
# (u'mission', 9)
# (u'entrepreneurs', 9)
# (u'breaks', 9)
# (u'talk', 9)
# (u"couldn't", 9)
# (u'overseas', 9)
# (u'bigger', 9)
# (u'challenge', 9)
# (u'achieve', 9)
# (u'begun', 9)
# (u'trying', 9)
# (u'offer', 9)
# (u'standards', 9)
# (u'tuition', 9)
# (u'partnership', 9)
# (u'intend', 8)
# (u'high-speed', 8)
# (u'anyone', 8)
# (u'hit', 8)
# (u'decisions', 8)
# (u'universities', 8)
# (u'biggest', 8)
# (u'starting', 8)
# (u'workforce', 8)
# (u'thanks', 8)
# (u'debate', 8)
# (u'factory', 8)
# (u'diploma', 8)
# (u'"we', 8)
# (u'employees', 8)
# (u"who've", 8)
# (u'exports', 8)
# (u'wind', 8)
# (u'math', 8)
# (u'wealthiest', 8)
# (u'ten', 8)
# (u"today's", 8)
# (u"isn't", 8)
# (u'agenda', 8)
# (u'sanctions', 8)
# (u'sign', 8)
# (u'factories', 8)
# (u'obama', 8)
# (u'reward', 8)
# (u'pollution', 8)
# (u'says', 7)
# (u'love', 7)
# (u'worst', 7)
# (u"i'll", 7)
# (u'town', 7)
# (u'funding', 7)
# (u'barack', 7)
# (u'standing', 7)
# (u'taxpayers', 7)
# (u'worker', 7)
# (u'cory', 7)
# (u'dignity', 7)
# (u'shared', 7)
# (u'thank', 7)
# (u'massive', 7)
# (u'"i', 7)
# (u'spent', 7)
# (u'partners', 7)
# (u'deficits', 7)
# (u'rural', 7)
# (u'unit', 7)
# (u'21st', 7)
# (u'lobbyists', 7)
# (u'renewable', 7)
# (u'competition', 7)
# (u'opportunities', 7)
# (u'taxpayer', 7)
# (u'story', 7)
# (u'accountable', 7)
# (u'fewer', 7)
# (u'combat', 7)
# (u'john', 7)
# (u'knew', 7)
# (u'diplomacy', 7)
# (u'proud', 7)
# (u'streets', 7)
# (u'$1', 7)
# (u'goods', 7)
# (u'train', 7)
# (u'stock', 7)
# (u'corporate', 6)
# (u'high-quality', 6)
# (u'efficient', 6)
# (u'speed', 6)
# (u'rising', 6)
# (u'sell', 6)
# (u'sector', 6)
# (u'impact', 6)
# (u'prescription', 6)
# (u'ceo', 6)
# (u"iran's", 6)
# (u'powerful', 6)
# (u'quality', 6)
# (u'ideals', 6)
# (u'stories', 6)
# (u'era', 6)
# (u'risk', 6)
# (u'corporations', 6)
# (u'gun', 6)
# (u'urge', 6)
# (u'michelle', 6)
# (u'agreements', 6)
# (u'citizenship', 6)
# (u'cleaner', 6)
# (u"they've", 6)
# (u'auto', 6)
# (u'destiny', 6)
# (u'campaign', 6)
# (u'went', 6)
# (u'priorities', 6)
# (u'medical', 6)
# (u'study', 6)
# (u'mortgage', 6)
# (u'actions', 6)
# (u"haven't", 6)
# (u'policies', 6)
# (u'learning', 6)
# (u'technologies', 6)
# (u'encourage', 6)
# (u'consumers', 6)
# (u'economists', 6)
# (u'hour', 6)
# (u'major', 6)
# (u'loopholes', 6)
# (u'thirty', 6)
# (u'rid', 6)
# (u'doubling', 6)
# (u'waiting', 6)
# (u'announcing', 6)
# (u'red', 6)
# (u'billions', 6)
# (u'hundreds', 6)
# (u'democratic', 6)
# (u'air', 6)
# (u'reducing', 6)
# (u'watching', 6)
# (u'internet', 6)
# (u'manufacturers', 6)
# (u'employers', 6)
# (u'fall', 6)
# (u'someone', 6)
# (u'partnerships', 6)
# (u'strategy', 6)
# (u'hardworking', 6)
# (u'dime', 6)
# (u'courage', 6)
# (u'launch', 6)
# (u'root', 5)
# (u'meaningful', 5)
# (u'medicaid', 5)
# (u'track', 5)
# (u'knowing', 5)
# (u'paychecks', 5)
# (u'healthy', 5)
# (u'ordered', 5)
# (u'wake', 5)
# (u'status', 5)
# (u'mortgages', 5)
# (u'tape', 5)
# (u'food', 5)
# (u'proposals', 5)
# (u'read', 5)
# (u'try', 5)
# (u'started', 5)
# (u'owner', 5)
# (u'2011', 5)
# (u'teaching', 5)
# (u'rescue', 5)
# (u'foundation', 5)
# (u'pays', 5)
# (u'expanding', 5)
# (u'equipment', 5)
# (u'quit', 5)
# (u'debates', 5)
# (u'playing', 5)
# (u'enforce', 5)
# (u'fixing', 5)
# (u'record', 5)
# (u'carbon', 5)
# (u'2014', 5)
# (u'decline', 5)
# (u'threaten', 5)
# (u'affiliates', 5)
# (u'weeks', 5)
# (u'bank', 5)
# (u'thousand', 5)
# (u'earn', 5)
# (u'launched', 5)
# (u'deal', 5)
# (u'weakened', 5)
# (u'educate', 5)
# (u'trucks', 5)
# (u'cancer', 5)
# (u'insist', 5)
# (u'rebuild', 5)
# (u'mom', 5)
# (u'prepare', 5)
# (u'premiums', 5)
# (u'play', 5)
# (u'wrote', 5)
# (u'towns', 5)
# (u'engineering', 5)
# (u'depression', 5)
# (u'battles', 5)
# (u'ends', 5)
# (u'sick', 5)
# (u'tired', 5)
# (u'govern', 5)
# (u'brandon', 5)
# (u'space', 5)
# (u"he's", 5)
# (u'keeps', 5)
# (u'stake', 5)
# (u'mother', 5)
# (u'kennedy', 5)
# (u'critical', 5)
# (u'earlier', 5)
# (u'manufacturer', 5)
# (u'fraud', 5)
# (u'civilians', 5)
# (u'finish', 5)
# (u'meanwhile', 5)
# (u'alliances', 5)
# (u'desk', 5)
# (u'cheaper', 5)
# (u'cutting', 5)
# (u'individual', 5)
# (u'freeze', 5)
# (u'gets', 5)
# (u'graduate', 5)
# (u"who's", 5)
# (u'talks', 4)
# (u'complicated', 4)
# (u're-start', 4)
# (u'attract', 4)
# (u'veto', 4)
# (u'creates', 4)
# (u'initiative', 4)
# (u'spur', 4)
# (u'website', 4)
# (u'experts', 4)
# (u'shoulder', 4)
# (u'specific', 4)
# (u'attacks', 4)
# (u'leads', 4)
# (u'sake', 4)
# (u'meant', 4)
# (u'classroom', 4)
# (u'peninsula', 4)
# (u'planet', 4)
# (u'blame', 4)
# (u'role', 4)
# (u'engine', 4)
# (u'tv', 4)
# (u'earns', 4)
# (u'stopped', 4)
# (u'convinced', 4)
# (u'slowly', 4)
# (u'priority', 4)
# (u'governors', 4)
# (u'police', 4)
# (u'hubs', 4)
# (u'member', 4)
# (u'aspirations', 4)
# (u'export', 4)
# (u'goal:', 4)
# (u'summer', 4)
# (u'path', 4)
# (u'tells', 4)
# (u'announce', 4)
# (u'fields', 4)
# (u'eager', 4)
# (u'core', 4)
# (u'brothers', 4)
# (u'aggressively', 4)
# (u'supporting', 4)
# (u'shift', 4)
# (u'car', 4)
# (u'strengthened', 4)
# (u'cops', 4)
# (u'10', 4)
# (u'elected', 4)
# (u'pull', 4)
# (u"you'd", 4)
# (u'$250,000', 4)
# (u'clear:', 4)
# (u'failure', 4)
# (u'networks', 4)
# (u'credits', 4)
# (u'illegal', 4)
# (u'fastest', 4)
# (u'distinguished', 4)
# (u'partner', 4)
# (u'smarter', 4)
# (u'detroit', 4)
# (u'patients', 4)
# (u'cooperation', 4)
# (u'launching', 4)
# (u'tucson', 4)
# (u'goes', 4)
# (u'girl', 4)
# (u"here's", 4)
# (u'rewarded', 4)
# (u'learned', 4)
# (u'plant', 4)
# (u'teach', 4)
# (u'achievement', 4)
# (u'full-time', 4)
# (u'gay', 4)
# (u'daughters', 4)
# (u'doors', 4)
# (u'game', 4)
# (u'rescued', 4)
# (u'pockets', 4)
# (u'preschool', 4)
# (u'globe', 4)
# (u'quo', 4)
# (u'painful', 4)
# (u'rein', 4)
# (u'paycheck', 4)
# (u'weapon', 4)
# (u'smart', 4)
# (u'rewarding', 4)
# (u'homeowners', 4)
# (u'americans:', 4)
# (u'rewards', 4)
# (u'apart', 4)
# (u'towards', 4)
# (u'setting', 4)
# (u'regime', 4)
# (u'team', 4)
# (u'incredible', 4)
# (u'serving', 4)
# (u'transition', 4)
# (u'honest', 4)
# (u'recover', 4)
# (u'potential', 4)
# (u'farmers', 4)
# (u'developing', 4)
# (u'graduates', 4)
# (u'americas', 4)
# (u'doctors', 4)
# (u'seize', 4)
# (u'became', 4)
# (u'stable', 4)
# (u'practices', 4)
# (u'kid', 4)
# (u'jill', 4)
# (u'son', 4)
# (u'choices', 4)
# (u'barely', 4)
# (u'sets', 4)
# (u'"the', 4)
# (u'lift', 4)
# (u'saved', 3)
# (u'electricity', 3)
# (u'reagan', 3)
# (u'outdated', 3)
# (u'india', 3)
# (u'uninsured', 3)
# (u'households', 3)
# (u'master', 3)
# (u'$10,000', 3)
# (u'bomb', 3)
# (u'automakers', 3)
# (u'rail', 3)
# (u'usher', 3)
# (u'moved', 3)
# (u'broadband', 3)
# (u'father', 3)
# (u'everybody', 3)
# (u'millionaires', 3)
# (u'setbacks', 3)
# (u'employment', 3)
# (u'equality', 3)
# (u'amanda', 3)
# (u'15', 3)
# (u'blueprint', 3)
# (u'contentious', 3)
# (u'turned', 3)
# (u'pain', 3)
# (u'shot', 3)
# (u'encourages', 3)
# (u'thinking', 3)
# (u'tunisia', 3)
# (u'grit', 3)
# (u'facing', 3)
# (u'bubble', 3)
# (u'syrian', 3)
# (u'ronald', 3)
# (u'messy', 3)
# (u'hours', 3)
# (u'labs', 3)
# (u'onto', 3)
# (u'feed', 3)
# (u'feet', 3)
# (u'ran', 3)
# (u'costly', 3)
# (u'earmark', 3)
# (u'lady', 3)
# (u'ignore', 3)
# (u'absolutely', 3)
# (u'germany', 3)
# (u'manufacture', 3)
# (u'monthly', 3)
# (u'tech', 3)
# (u'95%', 3)
# (u'telling', 3)
# (u'world-class', 3)
# (u'fifteen', 3)
# (u"generation's", 3)
# (u'beat', 3)
# (u'rubble', 3)
# (u'tackle', 3)
# (u'asian', 3)
# (u'solution', 3)
# (u'guests', 3)
# (u'biofuels', 3)
# (u'differently', 3)
# (u'extremism', 3)
# (u'collapse', 3)
# (u'bridge', 3)
# (u'professionals', 3)
# (u'18', 3)
# (u'news', 3)
# (u'deeper', 3)
# (u'unified', 3)
# (u'skeptical', 3)
# (u'unnecessary', 3)
# (u'50', 3)
# (u'1990s', 3)
# (u'prevents', 3)
# (u'decent', 3)
# (u'milk', 3)
# (u'iraqi', 3)
# (u'dropped', 3)
# (u'pathway', 3)
# (u'brain', 3)
# (u'equip', 3)
# (u'drilling', 3)
# (u'childhood', 3)
# (u'mountain', 3)
# (u'allen', 3)
# (u'checks', 3)
# (u'senator', 3)
# (u'centuries', 3)
# (u'drives', 3)
# (u'pakistan', 3)
# (u'treatment', 3)
# (u'hard-working', 3)
# (u'joined', 3)
# (u'jackie', 3)
# (u'coalition', 3)
# (u'pushed', 3)
# (u'plans', 3)
# (u'bryan', 3)
# (u'entrepreneur', 3)
# (u'stands', 3)
# (u'corruption', 3)
# (u'hardship', 3)
# (u'hated', 3)
# (u'transformation', 3)
# (u"children's", 3)
# (u'notion', 3)
# (u'bureaucracy', 3)
# (u'brian', 3)
# (u'covered', 3)
# (u'thriving', 3)
# (u'maybe', 3)
# (u'joe', 3)
# (u'earning', 3)
# (u'center', 3)
# (u'siemens', 3)
# (u'page', 3)
# (u'newtown', 3)
# (u'consistent', 3)
# (u'panama', 3)
# (u'behavior', 3)
# (u'hospital', 3)
# (u'hole', 3)
# (u'travel', 3)
# (u'modest', 3)
# (u'unemployed', 3)
# (u'innocent', 3)
# (u'rich', 3)
# (u'lenders', 3)
# (u'doubt:', 3)
# (u'raised', 3)
# (u'strongest', 3)
# (u'proven', 3)
# (u'bullet', 3)
# (u'groups', 3)
# (u'subsidies', 3)
# (u'heroes', 3)
# (u'succeeded', 3)
# (u'card', 3)
# (u'friend', 3)
# (u'senior', 3)
# (u'lets', 3)
# (u'poised', 3)
# (u'9/11', 3)
# (u'israel', 3)
# (u'refuse', 3)
# (u'fundamental', 3)
# (u'vulnerable', 3)
# (u'financing', 3)
# (u'doubled', 3)
# (u"wouldn't", 3)
# (u'ensures', 3)
# (u'empty', 3)
# (u'firefighters', 3)
# (u'decency', 3)
# (u'competitive', 3)
# (u'customers', 3)
# (u'fast', 3)
# (u'alive', 3)
# (u'consumed', 3)
# (u'proposal', 3)
# (u'buildings', 3)
# (u'blows', 3)
# (u'bet', 3)
# (u'deny', 3)
# (u"you'll", 3)
# (u'subsidizing', 3)
# (u'pre-k', 3)
# (u'batteries', 3)
# (u'capabilities', 3)
# (u'breakthroughs', 3)
# (u'puts', 3)
# (u'cells', 3)
# (u'40', 3)
# (u'sandy', 3)
# (u'ceos', 3)
# (u'short-term', 3)
# (u"i'd", 3)
# (u'innovative', 3)
# (u'counterterrorism', 3)
# (u'u.s', 3)
# (u'engagement', 3)
# (u'layoffs', 3)
# (u'upgrade', 3)
# (u'ford', 3)
# (u'strengthening', 3)
# (u'hurt', 3)
# (u'ingenuity', 3)
# (u'arabian', 3)
# (u'productive', 3)
# (u'happened', 3)
# (u'truly', 3)
# (u'online', 3)
# (u'slow', 3)
# (u'brave', 3)
# (u'cities', 3)
# (u'argue', 3)
# (u'doctor', 3)
# (u'furniture', 3)
# (u'wasteful', 3)
# (u'fairness', 3)
# (u'winning', 3)
# (u'scientists', 3)
# (u"nation's", 3)
# (u'yemen', 3)
# (u'inequality', 3)
# (u"year's", 3)
# (u'selling', 3)
# (u'resolve', 3)
# (u'engage', 3)
# (u'despite', 3)
# (u'jeopardize', 3)
# (u'summit', 3)
# (u'computer', 3)
# (u'wave', 3)
# (u'fee', 3)
# (u'f', 3)
# (u'sit', 3)
# (u'lined', 3)
# (u'spill', 3)
# (u'privacy', 3)
# (u'overwhelming', 3)
# (u'gather', 3)
# (u'inherited', 3)
# (u'areas', 3)
# (u'officials', 3)
# (u"qaeda's", 3)
# (u'wonder', 3)
# (u'terrorist', 3)
# (u'historic', 3)
# (u'quickly', 3)
# (u'this:', 3)
# (u'ladders', 2)
# (u'solid', 2)
# (u'disclose', 2)
# (u'strike', 2)
# (u'plunged', 2)
# (u'beach', 2)
# (u'welcomed', 2)
# (u'school;', 2)
# (u'backgrounds', 2)
# (u'operatives', 2)
# (u'consolidate', 2)
# (u'trading', 2)
# (u'classmates', 2)
# (u'streamline', 2)
# (u'electronic', 2)
# (u'coverage;', 2)
# (u'wasted', 2)
# (u'consumer', 2)
# (u'asia-pacific', 2)
# (u'steel', 2)
# (u'watch', 2)
# (u'decides', 2)
# (u'dedication', 2)
# (u'tyranny', 2)
# (u'drugs', 2)
# (u'ii', 2)
# (u'55', 2)
# (u'losing', 2)
# (u'balanced', 2)
# (u'invested', 2)
# (u'environment', 2)
# (u'locked', 2)
# (u'quick', 2)
# (u'trend', 2)
# (u'boost', 2)
# (u'lowers', 2)
# (u'visit', 2)
# (u'gabby', 2)
# (u'crumbling', 2)
# (u'plus', 2)
# (u'backed', 2)
# (u'directing', 2)
# (u'lawyers', 2)
# (u'giffords', 2)
# (u'bets', 2)
# (u'egg', 2)
# (u'shop', 2)
# (u'$2', 2)
# (u'deduction', 2)
# (u'newspaper', 2)
# (u'pad', 2)
# (u'themselves;', 2)
# (u'kill', 2)
# (u'asthma', 2)
# (u'lender', 2)
# (u'assembly', 2)
# (u'central', 2)
# (u'shrinking', 2)
# (u'rallied', 2)
# (u"wasn't", 2)
# (u'poor', 2)
# (u'fuel-efficient', 2)
# (u'regardless', 2)
# (u'steve', 2)
# (u'frustrating', 2)
# (u'eye', 2)
# (u'oak', 2)
# (u'faced', 2)
# (u'protects', 2)
# (u'remnants', 2)
# (u'reminded', 2)
# (u'24', 2)
# (u'20', 2)
# (u'it:', 2)
# (u'positioned', 2)
# (u'stairs', 2)
# (u'treated', 2)
# (u'comrades', 2)
# (u'finding', 2)
# (u'sustainable', 2)
# (u'marriage', 2)
# (u'untouched', 2)
# (u'institute', 2)
# (u'somewhere', 2)
# (u'grid', 2)
# (u'vigilant', 2)
# (u'bin', 2)
# (u'stagnant', 2)
# (u'pet', 2)
# (u'patient', 2)
# (u'jewish', 2)
# (u'unwarranted', 2)
# (u'highways', 2)
# (u'contributions', 2)
# (u'deals', 2)
# (u'locate', 2)
# (u'punishing', 2)
# (u'video', 2)
# (u'download', 2)
# (u'plays', 2)
# (u'youngest', 2)
# (u'baby', 2)
# (u'founding', 2)
# (u'meantime', 2)
# (u'defining', 2)
# (u'dad', 2)
# (u'payroll', 2)
# (u'steal', 2)
# (u'barriers', 2)
# (u'non-partisan', 2)
# (u'accountants', 2)
# (u'missions:', 2)
# (u'closer', 2)
# (u'generations;', 2)
# (u'fulfilled', 2)
# (u'together;', 2)
# (u'diplomats', 2)
# (u'taliban', 2)
# (u'moments', 2)
# (u'nato', 2)
# (u'attorneys', 2)
# (u'miami', 2)
# (u'happens', 2)
# (u'focused', 2)
# (u'forgiven', 2)
# (u'burma', 2)
# (u'creativity', 2)
# (u'kathy', 2)
# (u'commander-in-chief', 2)
# (u'write', 2)
# (u'violate', 2)
# (u'grueling', 2)
# (u'andra', 2)
# (u'pursuit', 2)
# (u'guide', 2)
# (u'brings', 2)
# (u'98', 2)
# (u'excuses', 2)
# (u'aging', 2)
# (u'raleigh', 2)
# (u'senators', 2)
# (u'shuttered', 2)
# (u'educating', 2)
# (u'represents', 2)
# (u'network', 2)
# (u'target', 2)
# (u'endure', 2)
# (u'talking', 2)
# (u'concrete', 2)
# (u'luxury', 2)
# (u'$3,000', 2)
# (u'simplify', 2)
# (u'enshrined', 2)
# (u'inspire', 2)
# (u'discretionary', 2)
# (u'anxieties', 2)
# (u'disaster', 2)
# (u'options', 2)
# (u'threatens', 2)
# (u'remind', 2)
# (u'battlefield', 2)
# (u'theirs', 2)
# (u'undocumented', 2)
# (u'lowering', 2)
# (u'wounded', 2)
# (u'turns', 2)
# (u'somalia', 2)
# (u'federally-funded', 2)
# (u'seeing', 2)
# (u'indeed', 2)
# (u'damage', 2)
# (u'remsburg', 2)
# (u'finance', 2)
# (u'records', 2)
# (u'george', 2)
# (u'response', 2)
# (u'youngstown', 2)
# (u'overnight', 2)
# (u'performance', 2)
# (u'hardships', 2)
# (u'commitments', 2)
# (u'corner', 2)
# (u'refinancing', 2)
# (u'floods', 2)
# (u'slashing', 2)
# (u'talented', 2)
# (u'strides', 2)
# (u'workplace', 2)
# (u'missions', 2)
# (u'shifts', 2)
# (u"you've", 2)
# (u'nick', 2)
# (u'rejoin', 2)
# (u'twelve', 2)
# (u'quitting', 2)
# (u'trajectory', 2)
# (u'ended', 2)
# (u'spends', 2)
# (u'open-ended', 2)
# (u"she's", 2)
# (u'returned', 2)
# (u'darkness', 2)
# (u'tragedy', 2)
# (u'myra', 2)
# (u"day's", 2)
# (u'generate', 2)
# (u'foundations', 2)
# (u'budgets', 2)
# (u'bucks', 2)
# (u'it;', 2)
# (u'courses', 2)
# (u'mental', 2)
# (u'democrat', 2)
# (u'broad-based', 2)
# (u'syria', 2)
# (u'discrimination', 2)
# (u'risks', 2)
# (u'gains', 2)
# (u"they'd", 2)
# (u'guantanamo', 2)
# (u'charlotte', 2)
# (u'deposits', 2)
# (u'roofing', 2)
# (u'coalitions', 2)
# (u'budged', 2)
# (u'yesterday', 2)
# (u'skyrocketing', 2)
# (u'redesign', 2)
# (u'illusions', 2)
# (u'upholding', 2)
# (u'religion', 2)
# (u'plots', 2)
# (u'resilience', 2)
# (u"tomorrow's", 2)
# (u'prosperity;', 2)
# (u'backs', 2)
# (u'centers', 2)
# (u'rebounding', 2)
# (u'havens', 2)
# (u'chose', 2)
# (u'healing', 2)
# (u"weren't", 2)
# (u'apple', 2)
# (u'lock', 2)
# (u'dependence', 2)
# (u'hesitate', 2)
# (u'ties', 2)
# (u'2010', 2)
# (u'transparent', 2)
# (u'identified', 2)
# (u'$100', 2)
# (u'rival', 2)
# (u'all-in', 2)
# (u'fastest-growing', 2)
# (u'loved', 2)
# (u'mayors', 2)
# (u'hiring', 2)
# (u'agencies', 2)
# (u'beliefs', 2)
# (u'va', 2)
# (u'"they', 2)
# (u'boards', 2)
# (u'using', 2)
# (u'earmarks', 2)
# (u'emerged', 2)
# (u'minneapolis', 2)
# (u'announced', 2)
# (u'bonuses', 2)
# (u'momentum', 2)
# (u'principled', 2)
# (u'offshore', 2)
# (u'demanding', 2)
# (u'attracts', 2)
# (u'preventive', 2)
# (u'reforming', 2)
# (u'filling', 2)
# (u'first-class', 2)
# (u'driving', 2)
# (u"americans'", 2)
# (u'enormous', 2)
# (u'drought', 2)
# (u'competitors', 2)
# (u'tirelessly', 2)
# (u'reinvented', 2)
# (u'requests', 2)
# (u'irresponsible', 2)
# (u'adversaries', 2)
# (u'realizing', 2)
# (u'birth', 2)
# (u'match', 2)
# (u'background', 2)
# (u'shadow', 2)
# (u'entering', 2)
# (u'post', 2)
# (u'governance', 2)
# (u'crowd', 2)
# (u'inside', 2)
# (u'talents', 2)
# (u'invent', 2)
# (u'chair', 2)
# (u'launchers', 2)
# (u'cyber', 2)
# (u'verge', 2)
# (u'classrooms', 2)
# (u'graduation', 2)
# (u'lifting', 2)
# (u'wildfires', 2)
# (u'term', 2)
# (u'vision', 2)
# (u'promotion', 2)
# (u'crossings', 2)
# (u'eyes', 2)
# (u'mostly', 2)
# (u'eliminated', 2)
# (u'optimism', 2)
# (u'marines', 2)
# (u'addressing', 2)
# (u'investors', 2)
# (u'surgery', 2)
# (u'emphasis', 2)
# (u'finishing', 2)
# (u'parent', 2)
# (u'mindful', 2)
# (u'rebuilt', 2)
# (u'minds', 2)
# (u'nest', 2)
# (u'careers', 2)
# (u'serves', 2)
# (u'market-based', 2)
# (u'buying', 2)
# (u'deep', 2)
# (u"she'd", 2)
# (u'2008', 2)
# (u'odds', 2)
# (u'g-20', 2)
# (u'pledged', 2)
# (u'highway', 2)
# (u'penalties', 2)
# (u'answers', 2)
# (u'common-sense', 2)
# (u'trained', 2)
# (u'homework', 2)
# (u"family's", 2)
# (u'broke', 2)
# (u'renew', 2)
# (u'hurting', 2)
# (u'philosophical', 2)
# (u'inspections', 2)
# (u'initiatives', 2)
# (u'walked', 2)
# (u'robert', 2)
# (u"they'll", 2)
# (u'citizens:', 2)
# (u'negotiating', 2)
# (u'$4', 2)
# (u'relent', 2)
# (u'forsyth', 2)
# (u'expensive', 2)
# (u'willingness', 2)
# (u"parents'", 2)
# (u'violations', 2)
# (u'slash', 2)
# (u'shale', 2)
# (u'plenty', 2)
# (u'$10.10', 2)
# (u'collapsed', 2)
# (u'deductions', 2)
# (u'hardest-hit', 2)
# (u'turbine', 2)
# (u'gi', 2)
# (u'uphold', 2)
# (u'torture', 2)
# (u'miners', 2)
# (u'obesity', 2)
# (u'boots', 2)
# (u'firms', 2)
# (u'subsidized', 2)
# (u'reflects', 2)
# (u'educational', 2)
# (u'struggled', 2)
# (u'haiti', 2)
# (u'landed', 2)
# (u'outlined', 2)
# (u'now:', 2)
# (u'families;', 2)
# (u'reversed', 2)
# (u'loves', 2)
# (u'korean', 2)
# (u'enlisting', 2)
# (u'extremists', 2)
# (u'key', 2)
# (u'drug', 2)
# (u'finished', 2)
# (u'prosper', 2)
# (u'unity', 2)
# (u'terrorism', 2)
# (u'skill', 2)
# (u'reckless', 2)
# (u'marching', 2)
# (u'protections', 2)
# (u'penny', 2)
# (u'reinvent', 2)
# (u'criminals', 2)
# (u'sidelines', 2)
# (u'inventors', 2)
# (u'crimes', 2)
# (u'laden', 2)
# (u'busy', 2)
# (u'faces', 2)
# (u'pose', 2)
# (u'buffett', 2)
# (u'generals', 2)
# (u'doubts', 2)
# (u'principals', 2)
# (u'openings', 2)
# (u'replace', 2)
# (u'bottom', 2)
# (u'alliance', 2)
# (u'trains', 2)
# (u'retire', 2)
# (u'wealthy', 2)
# (u'reality', 2)
# (u'federally-financed', 2)
# (u'settle', 2)
# (u'muslim', 2)
# (u'understanding', 2)
# (u'roaring', 2)
# (u'flying', 2)
# (u'cap', 2)
# (u'palestinians', 2)
# (u'farmer', 2)
# (u'rock', 2)
# (u'benefited', 2)
# (u'yourself', 2)
# (u'drove', 2)
# (u'sat', 2)
# (u'interstate', 2)
# (u'stockpiles', 2)
# (u'repeal', 2)
# (u'internet;', 2)
# (u'vacant', 2)
# (u'halfway', 2)
# (u"everyone's", 2)
# (u'digital', 2)
# (u'conservative', 2)
# (u'area', 2)
# (u"child's", 2)
# (u'cabinet', 2)
# (u'moves', 2)
# (u'recklessness', 2)
# (u'countless', 2)
# (u'sitting', 2)
# (u'healthier', 2)
# (u"john's", 2)
# (u'afghans', 2)
# (u'mali', 2)
# (u'computers', 2)
# (u'gut', 2)
# (u'trapped', 2)
# (u'tom', 2)
# (u'risky', 2)
# (u'pre-existing', 2)
# (u'relieve', 2)
# (u'responsibly', 2)
# (u'gaps', 2)
# (u'crushing', 2)
# (u'large-scale', 2)
# (u'describes', 2)
# (u'crack', 2)
# (u'bailouts', 2)
# (u'levels', 2)
# (u'sputnik', 2)
# (u'guarantees', 2)
# (u'advocate', 2)
# (u'google', 2)
# (u'rarely', 2)
# (u'women;', 2)
# (u'muslims', 2)
# (u'bankruptcy', 2)
# (u'renewal', 2)
# (u'translate', 2)
# (u'simple:', 2)
# (u'desiline', 2)
# (u'lend', 2)
# (u'confusing', 2)
# (u'night', 2)
# (u'moon', 2)
# (u'expelling', 2)
# (u'corrosive', 2)
# (u'invented', 2)
# (u'issuing', 2)
# (u'missile', 2)
# (u'stabilized', 2)
# (u'job-creating', 2)
# (u'madame', 2)
# (u'holds', 2)
# (u'counter', 2)
# (u'70,000', 2)
# (u'upward', 2)
# (u'all-of-the-above', 2)
# (u'agency', 2)
# (u'concerns', 2)
# (u'deploy', 2)
# (u'homeowner', 2)
# (u'winner', 2)
# (u'planted', 2)
# (u'summon', 2)
# (u'bought', 2)
# (u'boss', 2)
# (u'journey', 2)
# (u'"i\'m', 2)
# (u'height', 2)
# (u'preexisting', 2)
# (u'spread', 2)
# (u'inspiration', 2)
# (u'sleep', 1)
# (u'list', 1)
# (u'tires', 1)
# (u'hide', 1)
# (u'hate', 1)
# (u'revolutionize', 1)
# (u'resilient', 1)
# (u'ceilings', 1)
# (u'berlin;', 1)
# (u'stresses', 1)
# (u'daughter', 1)
# (u'envoy', 1)
# (u'inner-cities', 1)
# (u'breathe', 1)
# (u"employees'", 1)
# (u'99', 1)
# (u"india's", 1)
# (u'appreciate', 1)
# (u'demars', 1)
# (u'responsive', 1)
# (u'democracies', 1)
# (u"patton's", 1)
# (u"administration's", 1)
# (u'convictions', 1)
# (u'deficient', 1)
# (u'off-ramp', 1)
# (u'extract', 1)
# (u'start:', 1)
# (u'reminding', 1)
# (u'crucial', 1)
# (u'flooded', 1)
# (u'medicine', 1)
# (u'sadly', 1)
# (u'messages', 1)
# (u'bears', 1)
# (u'daunting', 1)
# (u're-finance', 1)
# (u'mercury', 1)
# (u'plentiful', 1)
# (u'nonpartisan', 1)
# (u'majorette', 1)
# (u'silly', 1)
# (u'd-day', 1)
# (u'selflessness', 1)
# (u'blue', 1)
# (u'bruce', 1)
# (u'translator', 1)
# (u'imported', 1)
# (u'nonprofits', 1)
# (u'episode', 1)
# (u'textbook;', 1)
# (u'pocket', 1)
# (u'$10', 1)
# (u'bar', 1)
# (u'automatic', 1)
# (u'brazil', 1)
# (u'draws', 1)
# (u'grandmother', 1)
# (u"patients'", 1)
# (u'rolled', 1)
# (u'weak', 1)
# (u'33,000', 1)
# (u'games', 1)
# (u'confronted', 1)
# (u'102', 1)
# (u'pregnancy', 1)
# (u'regenerate', 1)
# (u'way."', 1)
# (u'transformed', 1)
# (u"customers'", 1)
# (u'160', 1)
# (u'stopping', 1)
# (u'disagreements;', 1)
# (u'mouse', 1)
# (u'worshiping', 1)
# (u'soviets;', 1)
# (u'beside', 1)
# (u'yearns', 1)
# (u'confronting', 1)
# (u'wheel', 1)
# (u'raid', 1)
# (u'graduations', 1)
# (u'striving', 1)
# (u'33', 1)
# (u"commonwealth's", 1)
# (u'taxes?', 1)
# (u"medicare's", 1)
# (u'low-income', 1)
# (u'objective', 1)
# (u'new-found', 1)
# (u'orlando', 1)
# (u'sends', 1)
# (u'"that\'s', 1)
# (u'denies', 1)
# (u'shapes', 1)
# (u'contributing', 1)
# (u'shifting', 1)
# (u'super', 1)
# (u'degree."', 1)
# (u'slightly', 1)
# (u'managers', 1)
# (u'for?', 1)
# (u'music', 1)
# (u'wireless', 1)
# (u'reset', 1)
# (u'better-positioned', 1)
# (u'separated', 1)
# (u'easy."', 1)
# (u'saltwater', 1)
# (u'looked', 1)
# (u'upheaval', 1)
# (u'excel', 1)
# (u'warehouse', 1)
# (u'rolling', 1)
# (u'reorganization', 1)
# (u'push', 1)
# (u'managed', 1)
# (u'redouble', 1)
# (u'rot', 1)
# (u'promoting', 1)
# (u'terror', 1)
# (u'neighbor;', 1)
# (u'cook', 1)
# (u'bulldozed', 1)
# (u'adds', 1)
# (u'free."', 1)
# (u'studies', 1)
# (u'prefer', 1)
# (u'morale', 1)
# (u'betraying', 1)
# (u'50-year', 1)
# (u'chapter', 1)
# (u'envelope', 1)
# (u'downtown', 1)
# (u'slogan', 1)
# (u'districts', 1)
# (u'bites', 1)
# (u'lobbying', 1)
# (u'simpson-bowles', 1)
# (u'laundry', 1)
# (u'revealed', 1)
# (u'borrowing', 1)
# (u'instills', 1)
# (u'truck', 1)
# (u'tutoring', 1)
# (u'argued', 1)
# (u'group', 1)
# (u"dollars'", 1)
# (u'procedures', 1)
# (u"he'd", 1)
# (u'matches', 1)
# (u'toxic', 1)
# (u'conquer', 1)
# (u'storm;', 1)
# (u'twilight', 1)
# (u'possibilities', 1)
# (u'magazines', 1)
# (u'ready-to-be-filled', 1)
# (u'profit', 1)
# (u'$9.00', 1)
# (u'routes', 1)
# (u'automaker;', 1)
# (u'waned', 1)
# (u'reinvestment', 1)
# (u'stifled', 1)
# (u'pittsburgh', 1)
# (u'paper-thin', 1)
# (u'cards', 1)
# (u'start-ups', 1)
# (u'anger', 1)
# (u'isolate', 1)
# (u'candidly', 1)
# (u'importantly', 1)
# (u'menchu', 1)
# (u"isn't;", 1)
# (u'disabilities;', 1)
# (u'perseveres;', 1)
# (u'neighborsi', 1)
# (u'energetx', 1)
# (u'hostage', 1)
# (u'recruiters', 1)
# (u'partnered', 1)
# (u'sabotage', 1)
# (u'dough', 1)
# (u"steve's", 1)
# (u'all."', 1)
# (u'mission:', 1)
# (u"father's", 1)
# (u'bump', 1)
# (u'coma', 1)
# (u'gimmicks', 1)
# (u'represent:', 1)
# (u'expression', 1)
# (u'handouts', 1)
# (u'bricks', 1)
# (u'pundits', 1)
# (u'cancel', 1)
# (u'tornado', 1)
# (u'caring', 1)
# (u'stretch', 1)
# (u'partisanship', 1)
# (u'shopping', 1)
# (u'starters', 1)
# (u'unsafe', 1)
# (u'highly-skilled', 1)
# (u'chance."', 1)
# (u'fair?', 1)
# (u'couples', 1)
# (u'embrace', 1)
# (u'bowl', 1)
# (u'great;', 1)
# (u'structurally', 1)
# (u'cheers', 1)
# (u'"something', 1)
# (u'consensus', 1)
# (u'high-paying', 1)
# (u'relies', 1)
# (u'60,000', 1)
# (u'candidates', 1)
# (u'77', 1)
# (u'blow', 1)
# (u'pile', 1)
# (u'disrupt', 1)
# (u'shadows', 1)
# (u'correcting', 1)
# (u'farthest-reaching', 1)
# (u'obstruct', 1)
# (u'booming', 1)
# (u'"nation', 1)
# (u'sudan', 1)
# (u'seconds', 1)
# (u'strained', 1)
# (u'assemble', 1)
# (u'favorite', 1)
# (u'tremendous', 1)
# (u'unused', 1)
# (u'training;', 1)
# (u'elementary', 1)
# (u'nave', 1)
# (u'deteriorating', 1)
# (u'dictator', 1)
# (u'white;', 1)
# (u'deepened', 1)
# (u'lobbyists;', 1)
# (u'america!"', 1)
# (u'builders', 1)
# (u'enriched', 1)
# (u'waving', 1)
# (u'remote', 1)
# (u'scranton', 1)
# (u'resale', 1)
# (u'mass', 1)
# (u'fifty-one', 1)
# (u'washed', 1)
# (u'founded', 1)
# (u'deadline', 1)
# (u'cincinnati', 1)
# (u"taliban's", 1)
# (u'commonsense', 1)
# (u'dairy', 1)
# (u'midwest', 1)
# (u'awful', 1)
# (u'stimulus', 1)
# (u'neighborhood', 1)
# (u'thread;', 1)
# (u'conscience', 1)
# (u'15,000', 1)
# (u'multinational', 1)
# (u'rigged', 1)
# (u'grudges', 1)
# (u'taxpayer-subsidies', 1)
# (u'equations', 1)
# (u'prosecutors', 1)
# (u'allows', 1)
# (u'post-partisan', 1)
# (u'vets', 1)
# (u'partnering', 1)
# (u'neighbors,"', 1)
# (u'up?"', 1)
# (u'tunis', 1)
# (u'teen', 1)
# (u'waterways', 1)
# (u'globe;', 1)
# (u'nineteen', 1)
# (u'oversight', 1)
# (u'rodriguez', 1)
# (u'wished', 1)
# (u'bank;', 1)
# (u'oppose', 1)
# (u'consequence', 1)
# (u'anti-poverty', 1)
# (u'pat', 1)
# (u'number:', 1)
# (u'forty-something', 1)
# (u'american."', 1)
# (u'"are', 1)
# (u'avenue', 1)
# (u'pray', 1)
# (u'28', 1)
# (u'founders', 1)
# (u'colleague', 1)
# (u'consign', 1)
# (u'sweeping', 1)
# (u'war-era', 1)
# (u'truths', 1)
# (u'barrels', 1)
# (u'randolph', 1)
# (u'magnet', 1)
# (u'houser', 1)
# (u'testament', 1)
# (u'undoes', 1)
# (u'bleeding', 1)
# (u'piedmont', 1)
# (u'pipelines', 1)
# (u'"made', 1)
# (u'typhoon', 1)
# (u'usa."', 1)
# (u'2020', 1)
# (u'unafraid', 1)
# (u'lit', 1)
# (u'lip', 1)
# (u'graduating', 1)
# (u'macs', 1)
# (u'park', 1)
# (u'depths', 1)
# (u'storefronts', 1)
# (u'measured', 1)
# (u'cobra;', 1)
# (u'carefully', 1)
# (u'stores', 1)
# (u'peels', 1)
# (u'devastate', 1)
# (u'well-off', 1)
# (u'art', 1)
# (u'startup', 1)
# (u'explosion', 1)
# (u'please', 1)
# (u'mattered', 1)
# (u'targeted', 1)
# (u'hardest-working', 1)
# (u'secrets', 1)
# (u'battery', 1)
# (u'senseless', 1)
# (u'pr', 1)
# (u'pendleton', 1)
# (u'collected', 1)
# (u'formative', 1)
# (u'scorecard"', 1)
# (u'creed;', 1)
# (u'frozen', 1)
# (u'admire', 1)
# (u'cents', 1)
# (u'motors', 1)
# (u'three-quarters', 1)
# (u'anguish', 1)
# (u"germany's", 1)
# (u'160,000', 1)
# (u'bonus', 1)
# (u'achievement."', 1)
# (u'flags', 1)
# (u'constitution:', 1)
# (u'places;', 1)
# (u'vests', 1)
# (u'unstable', 1)
# (u'saddled', 1)
# (u'well-connected', 1)
# (u'depression;', 1)
# (u'extremist', 1)
# (u'fanfare', 1)
# (u"china's", 1)
# (u'salmon', 1)
# (u'example:', 1)
# (u'shine', 1)
# (u'excelling', 1)
# (u'drama', 1)
# (u'forget:', 1)
# (u'clinton', 1)
# (u'stitched', 1)
# (u'osama', 1)
# (u'contributor', 1)
# (u'pentagon', 1)
# (u'gridlocked', 1)
# (u'batteries;', 1)
# (u'hands-on', 1)
# (u'company."', 1)
# (u'windows', 1)
# (u'decency;', 1)
# (u'boomers', 1)
# (u"town's", 1)
# (u'lost;', 1)
# (u'facebook', 1)
# (u'$400', 1)
# (u'uranium', 1)
# (u'prosecution', 1)
# (u'fear;', 1)
# (u'turbines', 1)
# (u'rigid', 1)
# (u'posturing', 1)
# (u'groceries', 1)
# (u'reductions', 1)
# (u'proctor', 1)
# (u'blacksburg', 1)
# (u'pristine', 1)
# (u'election-year', 1)
# (u'ukraine', 1)
# (u'talent', 1)
# (u'technical', 1)
# (u'deterrents', 1)
# (u'"thank', 1)
# (u'predict', 1)
# (u'israelis', 1)
# (u'insists', 1)
# (u'continuity', 1)
# (u'catalyzed', 1)
# (u'unites', 1)
# (u'purpose:', 1)
# (u'farm', 1)
# (u'writ', 1)
# (u'gunman', 1)
# (u'chosen', 1)
# (u'dr', 1)
# (u'2015', 1)
# (u'front', 1)
# (u'airports', 1)
# (u'shaking', 1)
# (u'most:', 1)
# (u'pat-down', 1)
# (u'700', 1)
# (u'sexual', 1)
# (u'regulatory', 1)
# (u'shaken;', 1)
# (u'achievements', 1)
# (u'release', 1)
# (u'shun', 1)
# (u'barkeeper', 1)
# (u'repairing', 1)
# (u'halted', 1)
# (u'surgeries', 1)
# (u'deceptive', 1)
# (u'data', 1)
# (u'wrapped', 1)
# (u'herself', 1)
# (u'"mad', 1)
# (u'"god', 1)
# (u'chats', 1)
# (u'tide', 1)
# (u'necessities', 1)
# (u'ready-to-work', 1)
# (u'mills', 1)
# (u'mailed', 1)
# (u'trivial', 1)
# (u'litigation', 1)
# (u'expansion;', 1)
# (u'spun', 1)
# (u'tactics', 1)
# (u'chips', 1)
# (u'"if', 1)
# (u'dillon', 1)
# (u'upgrading', 1)
# (u'droughts', 1)
# (u'frustrated', 1)
# (u'ethic', 1)
# (u'him:', 1)
# (u'swift', 1)
# (u'300,000', 1)
# (u'vaccines', 1)
# (u'packaging', 1)
# (u'8-year', 1)
# (u'teamwork', 1)
# (u'freak', 1)
# (u'overwhelmingly', 1)
# (u'consequential', 1)
# (u'laser', 1)
# (u'fearful', 1)
# (u'friend;', 1)
# (u'hampering', 1)
# (u'weighed', 1)
# (u'malls', 1)
# (u'enriching', 1)
# (u'productivity', 1)
# (u'moms', 1)
# (u'disagree', 1)
# (u'sisters', 1)
# (u'breaks?', 1)
# (u'soviet', 1)
# (u'excessive', 1)
# (u'hadiya', 1)
# (u'twenty-three', 1)
# (u'run-down', 1)
# (u'greensburg', 1)
# (u'dwindle', 1)
# (u'moment;', 1)
# (u'driver', 1)
# (u'ballot', 1)
# (u'hurricane', 1)
# (u'passion', 1)
# (u'hinder', 1)
# (u'murderer', 1)
# (u'prohibited', 1)
# (u'targeting', 1)
# (u'gained', 1)
# (u'stamp', 1)
# (u'solar;', 1)
# (u'highs;', 1)
# (u'iron-clad', 1)
# (u'upside-down', 1)
# (u'ridge', 1)
# (u'frustrations', 1)
# (u'firefighter', 1)
# (u'achievement;', 1)
# (u'function', 1)
# (u'governmentour', 1)
# (u'wealthier', 1)
# (u'count', 1)
# (u'breakthrough', 1)
# (u'minutes', 1)
# (u'rightly', 1)
# (u'nurses', 1)
# (u'romney', 1)
# (u"romney's", 1)
# (u're-tooled', 1)
# (u'identities', 1)
# (u'rumors', 1)
# (u'tenth', 1)
# (u'myself."', 1)
# (u'cashed', 1)
# (u'contracts', 1)
# (u'star', 1)
# (u'inescapable', 1)
# (u'risked', 1)
# (u"hadiya's", 1)
# (u'cynical?', 1)
# (u"jackie's", 1)
# (u'obstruction', 1)
# (u'ritterby', 1)
# (u'crises', 1)
# (u'unpopular', 1)
# (u'rancorous', 1)
# (u'honorable', 1)
# (u"yesterday's", 1)
# (u'miller', 1)
# (u'surrounding', 1)
# (u'nation-building', 1)
# (u'[on]', 1)
# (u'supplies', 1)
# (u'state-of-the', 1)
# (u'$140', 1)
# (u'golden', 1)
# (u'servicemen', 1)
# (u'plot', 1)
# (u'spoke', 1)
# (u'best-selling', 1)
# (u'apprenticeships', 1)
# (u'90', 1)
# (u'rangoon', 1)
# (u'taunts', 1)
# (u'movies', 1)
# (u'clinging', 1)
# (u'that."', 1)
# (u'reviewing', 1)
# (u'verify', 1)
# (u'gate', 1)
# (u'badly', 1)
# (u'haven', 1)
# (u'typed', 1)
# (u'disease;', 1)
# (u'outsized', 1)
# (u'stalemate', 1)
# (u'investment;', 1)
# (u'enrich', 1)
# (u'intimidation', 1)
# (u'2,000-foot', 1)
# (u'dumping', 1)
# (u'forty', 1)
# (u'counter-terrorism', 1)
# (u'saluting', 1)
# (u'wash', 1)
# (u'pioneers', 1)
# (u'urban', 1)
# (u'hike', 1)
# (u'spectrum', 1)
# (u'purchases', 1)
# (u'bridges;', 1)
# (u'responded', 1)
# (u'solutions', 1)
# (u'graded', 1)
# (u'lightening', 1)
# (u'out-educate', 1)
# (u'infectious', 1)
# (u'brothers;', 1)
# (u'rehab', 1)
# (u'$60', 1)
# (u'wean', 1)
# (u'admirals', 1)
# (u'foes', 1)
# (u'policy-making', 1)
# (u'physician', 1)
# (u'anchor', 1)
# (u'runaround', 1)
# (u'cleo', 1)
# (u'harming', 1)
# (u'differing', 1)
# (u'fact:', 1)
# (u'yours', 1)
# (u'unfair', 1)
# (u'hills', 1)
# (u'wright', 1)
# (u'teenager', 1)
# (u'advances', 1)
# (u'cape', 1)
# (u'rio;', 1)
# (u'creek', 1)
# (u'200', 1)
# (u'cede', 1)
# (u'american-made', 1)
# (u'christmas', 1)
# (u'bold', 1)
# (u'devastation', 1)
# (u'provocations', 1)
# (u'rent', 1)
# (u'banker', 1)
# (u'ranger', 1)
# (u're-litigating', 1)
# (u'sovereign', 1)
# (u'"none', 1)
# (u'idea?', 1)
# (u'31st', 1)
# (u'builds', 1)
# (u'bargain', 1)
# (u'crystal', 1)
# (u'accelerate', 1)
# (u'150', 1)
# (u'revitalize', 1)
# (u'rapidly-changing', 1)
# (u'tie', 1)
# (u'shrink', 1)
# (u'subsidize', 1)
# (u'phony', 1)
# (u'happening', 1)
# (u'globe:', 1)
# (u'on-the-job', 1)
# (u'proposal:', 1)
# (u'pell', 1)
# (u'billionaire', 1)
# (u"sana'a", 1)
# (u'impressive', 1)
# (u'solved', 1)
# (u'verifiable', 1)
# (u'obsolete', 1)
# (u'installing', 1)
# (u'transcontinental', 1)
# (u'temperatures', 1)
# (u"april's", 1)
# (u'emerge', 1)
# (u'lieutenants', 1)
# (u'intense', 1)
# (u'easiest', 1)
# (u'organizations', 1)
# (u'ibm', 1)
# (u'10,000', 1)
# (u'gallon', 1)
# (u'giveaways', 1)
# (u'invest;', 1)
# (u'crashed', 1)
# (u'apprenticeship', 1)
# (u'6th', 1)
# (u'secure;', 1)
# (u'invests', 1)
# (u'unacceptable', 1)
# (u'terrible,"', 1)
# (u'devastated', 1)
# (u"syria's", 1)
# (u'bound', 1)
# (u're-fighting', 1)
# (u'name', 1)
# (u'james', 1)
# (u'decade"', 1)
# (u'rangers', 1)
# (u'raises', 1)
# (u'el', 1)
# (u'risk-taker', 1)
# (u'self-government', 1)
# (u'seoul', 1)
# (u'viable', 1)
# (u'treatments', 1)
# (u'challenge:', 1)
# (u'pandemic', 1)
# (u'turf', 1)
# (u'sanchez', 1)
# (u'transform', 1)
# (u'occupy', 1)
# (u'legally', 1)
# (u'inefficient', 1)
# (u'unfortunately', 1)
# (u'scraping', 1)
# (u'wins', 1)
# (u'future."', 1)
# (u'declares', 1)
# (u'craig', 1)
# (u'buried', 1)
# (u'bashing', 1)
# (u'warriors', 1)
# (u'600,000', 1)
# (u'visitors', 1)
# (u'assistant', 1)
# (u'honesty', 1)
# (u'job:', 1)
# (u"hasn't", 1)
# (u'generosity', 1)
# (u'outsourcing', 1)
# (u'mayor', 1)
# (u'import', 1)
# (u'nationality', 1)
# (u'warriors;', 1)
# (u"lock's", 1)
# (u'helicopter', 1)
# (u'fig', 1)
# (u'predicament', 1)
# (u'curricula', 1)
# (u'orientation', 1)
# (u'strain', 1)
# (u'fame', 1)
# (u'harsh', 1)
# (u'disappointment', 1)
# (u'boosted', 1)
# (u'u.s.a!"', 1)
# (u'gates', 1)
# (u'efforts:', 1)
# (u'secretaries;', 1)
# (u'eisenhower', 1)
# (u'quitters', 1)
# (u'preference', 1)
# (u'intel', 1)
# (u'roll', 1)
# (u'jews', 1)
# (u'mistrust', 1)
# (u'freer', 1)
# (u'manufactured', 1)
# (u'utilities', 1)
# (u'pastors', 1)
# (u'airline', 1)
# (u'transfers', 1)
# (u'watchdog', 1)
# (u'philadelphia', 1)
# (u'media', 1)
# (u'worsened', 1)
# (u'tranquility', 1)
# (u'billionaires', 1)
# (u'preside', 1)
# (u'emissions', 1)
# (u'trips', 1)
# (u'1200', 1)
# (u'imagination', 1)
# (u'carved', 1)
# (u'lifetime', 1)
# (u'selfish', 1)
# (u'allentown', 1)
# (u"president's", 1)
# (u'message:', 1)
# (u'arsenals', 1)
# (u'bystander', 1)
# (u'numbing', 1)
# (u'strings', 1)
# (u'realities', 1)
# (u'reaffirming', 1)
# (u'sank', 1)
# (u'anniversary', 1)
# (u'self-government;', 1)
# (u'prevailed', 1)
# (u'turmoil', 1)
# (u'combating', 1)
# (u'andrews', 1)
# (u'investigating', 1)
# (u"would've", 1)
# (u'crisis;', 1)
# (u'hiv/aids', 1)
# (u'flat', 1)
# (u'stubborn', 1)
# (u'challenging', 1)
# (u'sikh', 1)
# (u'mapping', 1)
# (u'fascism', 1)
# (u'crisis,"', 1)
# (u'eats', 1)
# (u'$20', 1)
# (u'essence', 1)
# (u'milwaukee', 1)
# (u'2%', 1)
# (u'hiring;', 1)
# (u'severely', 1)
# (u'complain', 1)
# (u'hook', 1)
# (u'die', 1)
# (u'inherent', 1)
# (u'house;', 1)
# (u'missed', 1)
# (u'projected', 1)
# (u'brightest', 1)
# (u'unclogging', 1)
# (u'"college', 1)
# (u'cheering', 1)
# (u'reemployment', 1)
# (u'empowering', 1)
# (u'temperature', 1)
# (u'paint', 1)
# (u'automobile', 1)
# (u'parent/teacher', 1)
# (u'option', 1)
# (u'discover', 1)
# (u'$3', 1)
# (u'dam', 1)
# (u'imports', 1)
# (u'hire:', 1)
# (u'performance;', 1)
# (u'honors', 1)
# (u'beshear', 1)
# (u'flexibility:', 1)
# (u'congressmen', 1)
# (u'electric', 1)
# (u'microsoft', 1)
# (u'rule:', 1)
# (u'gangs', 1)
# (u'philanthropists', 1)
# (u'work-study', 1)
# (u'brink', 1)
# (u'longest', 1)
# (u'crippling', 1)
# (u'guinea', 1)
# (u'gravest', 1)
# (u'chambers', 1)
# (u'arm', 1)
# (u'repairs', 1)
# (u'$2,500', 1)
# (u'pictures', 1)
# (u'league', 1)
# (u'reverse', 1)
# (u'riddled', 1)
# (u'good-paying', 1)
# (u'shingles', 1)
# (u'preventable', 1)
# (u'consume', 1)
# (u'boy', 1)
# (u'mine', 1)
# (u'extracted', 1)
# (u'all-time', 1)
# (u'pace', 1)
# (u'how?', 1)
# (u'virtually', 1)
# (u'lie', 1)
# (u'robust', 1)
# (u'all-out', 1)
# (u'down-payment', 1)
# (u'shouting', 1)
# (u'knock', 1)
# (u'$14,500', 1)
# (u'parade', 1)
# (u'pay-as-you-go', 1)
# (u'affects', 1)
# (u'temple', 1)
# (u'affordability', 1)
# (u'"lost', 1)
# (u'nowhere', 1)
# (u'dwight', 1)
# (u'72', 1)
# (u'imaginations', 1)
# (u'harnesses', 1)
# (u'abess', 1)
# (u'boys', 1)
# (u'homeownership', 1)
# (u'driveways', 1)
# (u'adults', 1)
# (u'living?', 1)
# (u'divisive', 1)
# (u'independents', 1)
# (u'buck', 1)
# (u'genome', 1)
# (u'explaining', 1)
# (u'fisher', 1)
# (u'meals', 1)
# (u'back?', 1)
# (u'yardsticks', 1)
# (u'bankers', 1)
# (u'2007', 1)
# (u'leak', 1)
# (u'fresh', 1)
# (u'flexible', 1)
# (u'dramatically', 1)
# (u'afghanistan;', 1)
# (u'assad', 1)
# (u'someday', 1)
# (u'click', 1)
# (u'industrialized', 1)
# (u'relocate', 1)
# (u'punch', 1)
# (u'fulfill', 1)
# (u'no-bid', 1)
# (u'presidents', 1)
# (u'savings:', 1)
# (u'historically', 1)
# (u'touched', 1)
# (u'aids-free', 1)
# (u'battered', 1)
# (u'effectively', 1)
# (u'stamped', 1)
# (u'mismanagement', 1)
# (u'looks', 1)
# (u'unchecked', 1)
# (u'underwater', 1)
# (u'world?', 1)
# (u'disrupted', 1)
# (u'by;', 1)
# (u'warned', 1)
# (u'merge', 1)
# (u'thirteen', 1)
# (u'cairo;', 1)
# (u'bag', 1)
# (u'chaos', 1)
# (u'islamic', 1)
# (u'determining', 1)
# (u'conversation', 1)
# (u'scene', 1)
# (u'jumpstart', 1)
# (u'sergeant', 1)
# (u'bone-tired', 1)
# (u'punish', 1)
# (u'isolation', 1)
# (u'1.5', 1)
# (u'encouraged."', 1)
# (u'funds', 1)
# (u'intentions', 1)
# (u'reignite', 1)
# (u'movie', 1)
# (u'anyway', 1)
# (u'playbook', 1)
# (u'agrees', 1)
# (u'few;', 1)
# (u'entities', 1)
# (u'112th', 1)
# (u"troops'", 1)
# (u'prosecute', 1)
# (u'stripes', 1)
# (u'ira', 1)
# (u'sowing', 1)
# (u'tightening', 1)
# (u'withstand', 1)
# (u'clearing', 1)
# (u'"nothing', 1)
# (u"system's", 1)
# (u'200,000', 1)
# (u'wear', 1)
# (u'out-teach', 1)
# (u'revamp', 1)
# (u'pouring', 1)
# (u'hindu', 1)
# (u'treat', 1)
# (u'biomedical', 1)
# (u'sacrificing', 1)
# (u'insourcing', 1)
# (u'bacteria', 1)
# (u'chants', 1)
# (u'autoworker', 1)
# (u'lobby', 1)
# (u'stranglehold', 1)
# (u'gutted', 1)
# (u'credibility', 1)
# (u'drawing', 1)
# (u'restructure', 1)
# (u'trans-pacific', 1)
# (u'keen', 1)
# (u'danced', 1)
# (u'tight', 1)
# (u'$2.5', 1)
# (u'attractive', 1)
# (u'roofers', 1)
# (u'exploiting', 1)
# (u'made."', 1)
# (u'scares', 1)
# (u'"what', 1)
# (u'trimmed', 1)
# (u'e-mail', 1)
# (u'real-world', 1)
# (u"michelle's", 1)
# (u'insider', 1)
# (u'recognizes', 1)
# (u'unsustainable', 1)
# (u'rivals', 1)
# (u'inspires', 1)
# (u'maze', 1)
# (u'bus', 1)
# (u'reminds', 1)
# (u'eat', 1)
# (u'misty', 1)
# (u'flip', 1)
# (u'notice:', 1)
# (u'changing;', 1)
# (u'reason:', 1)
# (u'ribbon-cuttings', 1)
# (u'campus', 1)
# (u'boom', 1)
# (u'long-time', 1)
# (u'pathways', 1)
# (u'biotechnology', 1)
# (u'stumble;', 1)
# (u'retirees', 1)
# (u'unionized', 1)
# (u'try."', 1)
# (u'aurora', 1)
# (u"robert's", 1)
# (u'presidency', 1)
# (u'conceive', 1)
# (u'charter', 1)
# (u'organs;', 1)
# (u'seeks', 1)
# (u'evolving', 1)
# (u'governing', 1)
# (u'completely', 1)
# (u'chrysler', 1)
# (u'cutting-edge', 1)
# (u'right:', 1)
# (u'mired', 1)
# (u'berlin', 1)
# (u'shelters', 1)
# (u'tampa', 1)
# (u'mechanic', 1)
# (u'household', 1)
# (u'globalization', 1)
# (u'aching', 1)
# (u'damaged', 1)
# (u'destined', 1)
# (u'types', 1)
# (u'builders."', 1)
# (u'cause;', 1)
# (u'drawdown', 1)
# (u'widely', 1)
# (u'bans', 1)
# (u'caterpillar', 1)
# (u'iran;', 1)
# (u'signing', 1)
# (u'drug-resistant', 1)
# (u'tempting', 1)
# (u'comforted', 1)
# (u'nation:', 1)
# (u'grandchildren', 1)
# (u'frankly', 1)
# (u'booming;', 1)
# (u'yachts', 1)
# (u'superstorm', 1)
# (u'automaker', 1)
# (u'neighborhoods', 1)
# (u'people:', 1)
# (u'incomplete', 1)
# (u'meetings', 1)
# (u'spurred', 1)
# (u'aspires', 1)
# (u'americans?', 1)
# (u'reaffirm', 1)
# (u'infiltrate', 1)
# (u'fossil', 1)
# (u'compounded', 1)
# (u'contentious;', 1)
# (u'nurse', 1)
# (u'men"', 1)
# (u'malpractice', 1)
# (u'stress', 1)
# (u'drew', 1)
# (u'ill', 1)
# (u'tracks', 1)
# (u'epidemic', 1)
# (u'administrations', 1)
# (u'stadium', 1)
# (u'homeland', 1)
# (u'exception', 1)
# (u'conviction', 1)
# (u'doha', 1)
# (u'sticker', 1)
# (u'defeated', 1)
# (u'satellite', 1)
# (u'marches', 1)
# (u'unyielding', 1)
# (u'skepticism', 1)
# (u'thoughts', 1)
# (u'possessed', 1)
# (u'inherit', 1)
# (u'qualities', 1)
# (u'alabama', 1)
# (u'fighters', 1)
# (u'purchasing', 1)
# (u'buyers', 1)
# (u'survival', 1)
# (u'cultural', 1)
# (u'gift', 1)
# (u'57', 1)
# (u'pavement', 1)
# (u'attorney', 1)
# (u'creed', 1)
# (u"harm's", 1)
# (u'embodies', 1)
# (u'participation', 1)
# (u'cash-strapped', 1)
# (u'copouts', 1)
# (u"al-qaeda's", 1)
# (u'dinner', 1)
# (u'horizon', 1)
# (u'automatically', 1)
# (u'jet', 1)
# (u'coastal', 1)
# (u'weathered', 1)
# (u'sunlight', 1)
# (u'fraction', 1)
# (u'shores?', 1)
# (u'$200', 1)
# (u'discourage', 1)
# (u'heat', 1)
# (u'disagreements', 1)
# (u'devices', 1)
# (u'centrifuges', 1)
# (u'flaw', 1)
# (u'fatherhood', 1)
# (u'ambitious', 1)
# (u'phoenix', 1)
# (u'cyber-attacks', 1)
# (u'trouble', 1)
# (u'leonard', 1)
# (u'rob', 1)
# (u'theaters', 1)
# (u'superpower', 1)
# (u'97', 1)
# (u'refinance', 1)
# (u'keeping', 1)
# (u'congratulating', 1)
# (u'philippines', 1)
# (u'poor;', 1)
# (u'speculation', 1)
# (u'dries', 1)
# (u'aggressive', 1)
# (u'falling', 1)
# (u'ms', 1)
# (u'inauguration', 1)
# (u'dissipated', 1)
# (u'share?', 1)
# (u'reclaim', 1)
# (u'$1,500', 1)
# (u'life,"', 1)
# (u'angry', 1)
# (u'wondering', 1)
# (u'cited', 1)
# (u'criteria:', 1)
# (u'piles', 1)
# (u'originally', 1)
# (u'hardest', 1)
# (u'kindness"', 1)
# (u'future:', 1)
# (u'sunday', 1)
# (u'fourth', 1)
# (u'"expansion"', 1)
# (u'pre-requisite', 1)
# (u'burmese', 1)
# (u'forebears', 1)
# (u'foreclosure', 1)
# (u'yearn', 1)
# (u'louisville', 1)
# (u'coaching', 1)
# (u'stabilize', 1)
# (u'beings', 1)
# (u'boehner', 1)
# (u'unlock', 1)
# (u'speculators', 1)
# (u'3rd', 1)
# (u'oklahoma', 1)
# (u'kent', 1)
# (u'possibility', 1)
# (u'lab', 1)
# (u'device;', 1)
# (u'short-cuts', 1)
# (u'waver', 1)
# (u'soaring', 1)
# (u'sheer', 1)
# (u'elkhart', 1)
# (u'chute', 1)
# (u'"there', 1)
# (u'hillary', 1)
# (u'veteran', 1)
# (u'tractorsgrocery', 1)
# (u'sheets', 1)
# (u'sequester,"', 1)
# (u'flawlessly', 1)
# (u'defeating', 1)
# (u'easy,"', 1)
# (u'pump', 1)
# (u'soviets', 1)
# (u'second-place', 1)
# (u'tears', 1)
# (u'deployed', 1)
# (u'joked', 1)
# (u'violated', 1)
# (u'larding', 1)
# (u'steadfast', 1)
# (u'recedes', 1)
# (u'spark', 1)
# (u'jobi', 1)
# (u'libya', 1)
# (u'brinksmanship', 1)
# (u'hezbollah', 1)
# (u'stretches', 1)
# (u'hybrids', 1)
# (u'denver', 1)
# (u'allies;', 1)
# (u'handing', 1)
# (u'universities;', 1)
# (u'500', 1)
# (u'graveyard', 1)
# (u'subjecting', 1)
# (u'hidden', 1)
# (u'pettiness', 1)
# (u'endured', 1)
# (u'conferences', 1)
# (u'worry', 1)
# (u'veterans?', 1)
# (u'revitalized', 1)
# (u'closest', 1)
# (u'bang', 1)
# (u'model', 1)
# (u'sputters', 1)
# (u'versa', 1)
# (u'tuesday', 1)
# (u'kills', 1)
# (u'outsource', 1)
# (u'401ks', 1)
# (u'passions', 1)
# (u'stops', 1)
# (u'"living', 1)
# (u'equivalent', 1)
# (u'dictators', 1)
# (u'conducting', 1)
# (u'neighbor', 1)
# (u'burning', 1)
# (u'stark', 1)
# (u'stars', 1)
# (u'decisive', 1)
# (u'250,000', 1)
# (u'strikes', 1)
# (u'hottest', 1)
# (u'rush', 1)
# (u'naysayers', 1)
# (u"kentucky's", 1)
# (u'"fix-it-first"', 1)
# (u'frustrated;', 1)
# (u'bob', 1)
# (u'deterrent', 1)
# (u'dawn', 1)
# (u'proudest', 1)
# (u'payday', 1)
# (u'vocational', 1)
# (u'misfortune', 1)
# (u'americans;', 1)
# (u'calls', 1)
# (u'$30', 1)
# (u'repay', 1)
# (u'chinese', 1)
# (u'forbidden', 1)
# (u'lawmakers', 1)
# (u'ticked', 1)
# (u'dictatorship', 1)
# (u'celebrity', 1)
# (u'bankrolled', 1)
# (u'suu', 1)
# (u'necessary;', 1)
# (u'title:', 1)
# (u'inspired', 1)
# (u'skyrocket', 1)
# (u'tax-free', 1)
# (u'legislator', 1)
# (u'wiped', 1)
# (u'opportunity."', 1)
# (u'incentive', 1)
# (u're-finances', 1)
# (u'equation', 1)
# (u'roosevelt', 1)
# (u'evolved', 1)
# (u'compare', 1)
# (u'airplane', 1)
# (u'sacred', 1)
# (u'gravitate', 1)
# (u'reestablishing', 1)
# (u'"it', 1)
# (u'egypt;', 1)
# (u'26', 1)
# (u'fears;', 1)
# (u'handheld', 1)
# (u'absence', 1)
# (u'messes', 1)
# (u'ally', 1)
# (u'walls', 1)
# (u'imprisoned', 1)
# (u'frivolous', 1)
# (u'pirated', 1)
# (u'thick', 1)
# (u'america:', 1)
# (u'publish', 1)
# (u'salute', 1)
# (u'enforcing', 1)
# (u'guess', 1)
# (u'lawsuits', 1)
# (u'slipped', 1)
# (u'olympic', 1)
# (u'fancy', 1)
# (u'guaranteeing', 1)
# (u'enact', 1)
# (u'recovered', 1)
# (u'erupted', 1)
# (u'$8', 1)
# (u'stirs', 1)
# (u'stale', 1)
# (u'newborns', 1)
# (u'meltdown', 1)
# (u'zero', 1)
# (u'self', 1)
# (u'significant', 1)
# (u'headlines', 1)
# (u'from;', 1)
# (u'pretty', 1)
# (u'strongholds', 1)
# (u'ferret', 1)
# (u'ninth', 1)
# (u'pretending', 1)
# (u'restart', 1)
# (u'horse-trading', 1)
# (u'surpass', 1)
# (u'dump', 1)
# (u'remembered."', 1)
# (u'years:', 1)
# (u'135,000', 1)
# (u'thrive', 1)
# (u'liked', 1)
# (u'hackers', 1)
# (u'prosecuting', 1)
# (u'volunteered', 1)
# (u'secret', 1)
# (u'500,000', 1)
# (u'reformed', 1)
# (u'fate', 1)
# (u'ideologies', 1)
# (u'2035', 1)
# (u'uncertain;', 1)
# (u'shirk', 1)
# (u'climb', 1)
# (u'urgency', 1)
# (u"ty'sheoma", 1)
# (u'staffing', 1)
# (u'repealing', 1)
# (u'alternative', 1)
# (u'us,"', 1)
# (u'offices;', 1)
# (u'crying', 1)
# (u'emergency', 1)
# (u'entrenched', 1)
# (u'jobs?', 1)
# (u'collective', 1)
# (u'd.c', 1)
# (u'fathers', 1)
# (u'trends', 1)
# (u'sprint', 1)
# (u'societycare', 1)
# (u'first-time', 1)
# (u'fed', 1)
# (u'deserved', 1)
# (u'completing', 1)
# (u'brooklyn', 1)
# (u'lieberman', 1)
# (u'range', 1)
# (u'adversity', 1)
# (u'abusive', 1)
# (u'floodgates', 1)
# (u'lesson', 1)
# (u'entitlement', 1)
# (u'handles', 1)
# (u'pounded', 1)
# (u'assisting', 1)
# (u'newer', 1)
# (u'revitalizing', 1)
# (u'listening', 1)
# (u'reportedly', 1)
# (u'develops', 1)
# (u"israel's", 1)
# (u'salaries', 1)
# (u'broader', 1)
# (u'excluded', 1)
# (u'longest-serving', 1)
# (u'polling', 1)
# (u'ripped', 1)
# (u'uncomfortable', 1)
# (u'edison', 1)
# (u'drill', 1)
# (u'gathered', 1)
# (u'packing', 1)
# (u'passion;', 1)
# (u'will."', 1)
# (u'once-shuttered', 1)
# (u'residents', 1)
# (u'black-and-white', 1)
# (u'kyi', 1)
# (u'usa', 1)
# (u'unleashed', 1)
# (u'assuring', 1)
# (u'chip', 1)
# (u'prized', 1)
# (u'fail."', 1)
# (u'"to', 1)
# (u'"d."', 1)
# (u'servants', 1)
# (u'slip', 1)
# (u'cyber-threats', 1)
# (u'tied', 1)
# (u'realized', 1)
# (u'memorize', 1)
# (u'unsolved', 1)
# (u'rubio', 1)
# (u'stalled', 1)
# (u'2013', 1)
# (u'violating', 1)
# (u'university', 1)
# (u'related', 1)
# (u'highs', 1)
# (u'shut', 1)
# (u'undo', 1)
# (u'regulators', 1)
# (u'four-hour', 1)
# (u'cynical', 1)
# (u'scrambling', 1)
# (u'chemicals', 1)
# (u'1.6', 1)
# (u"alzheimer's;", 1)
# (u'dishes', 1)
# (u'hesitations', 1)
# (u'fuels', 1)
# (u'collaboration', 1)
# (u'envy', 1)
# (u'controls', 1)
# (u'control;', 1)
# (u'shedding', 1)
# (u'asks', 1)
# (u'nationwide', 1)
# (u'declining', 1)
# (u'hits', 1)
# (u'"now', 1)
# (u'"u.s.a.!', 1)
# (u'outgunned', 1)
# (u'picking', 1)
# (u'choice:', 1)
# (u'window', 1)
# (u"bush's", 1)
# (u'verizon', 1)
# (u'out-build', 1)
# (u'wartime', 1)
# (u'180,000', 1)
# (u'liberal;', 1)
# (u'bray', 1)
# (u'ripe', 1)
# (u'inspector', 1)
# (u'year:', 1)
# (u'tripoli', 1)
# (u'digging', 1)
# (u'though:', 1)
# (u'elyria', 1)
# (u'steals', 1)
# (u'patrols', 1)
# (u'test;', 1)
# (u'rocked', 1)
# (u'bottom:', 1)
# (u'399', 1)
# (u'clerksthey', 1)
# (u'lower-wage', 1)
# (u'nate', 1)
# (u'mistake:', 1)
# (u'heed', 1)
# (u'rotc', 1)
# (u'backlog', 1)
# (u'grids', 1)
# (u'library', 1)
# (u"school's", 1)
# (u'grinding', 1)
# (u'bureaucratic', 1)
# (u'across-the-board', 1)
# (u'murdered', 1)
# (u'schoolyard', 1)
# (u'choked', 1)
# (u'throng', 1)
# (u'spilled', 1)
# (u'tighter', 1)
# (u'beacon', 1)
# (u'prospects', 1)
# (u'cyberattacks', 1)
# (u'overlapping', 1)
# (u'africa;', 1)
# (u'urging', 1)
# (u'top-down', 1)
# (u'skies', 1)
# (u'dropout', 1)
# (u'bundle', 1)
# (u'christians', 1)
# (u'richard', 1)
# (u'transitions', 1)
# (u'personally', 1)
# (u'hanging', 1)
# (u'oldest', 1)
# (u'four-year', 1)
# (u'seals', 1)
# (u'piling', 1)
# (u'others;', 1)
# (u'spouses', 1)
# (u'growth?', 1)
# (u'deaths;', 1)
# (u'mobility', 1)
# (u'opponents', 1)
# (u'edward', 1)
# (u'separates', 1)
# (u'$40', 1)
# (u'eighteen', 1)
# (u're-imagined', 1)
# (u'recovers', 1)
# (u'faulty', 1)
# (u'pizza', 1)
# (u'regional', 1)
# (u'fragile', 1)
# (u'anti-fraud', 1)
# (u'resumes', 1)
# (u'exporters', 1)
# (u'permits', 1)
# (u'sixteen', 1)
# (u'convinces', 1)
# (u'correctional', 1)
# (u'decision-making', 1)
# (u'65%', 1)
# (u'boosting', 1)
# (u'"this', 1)
# (u'hearing', 1)
# (u'floors', 1)
# (u'drones', 1)
# (u'rated', 1)
# (u'nation;', 1)
# (u'bailout', 1)
# (u'anniversaries', 1)
# (u'pretend', 1)
# (u'hatch', 1)
# (u'aung', 1)
# (u'clock', 1)
# (u'hunger', 1)
# (u'pick', 1)
# (u'debt;', 1)
# (u'covering', 1)
# (u'task,"', 1)
# (u'triumphed', 1)
# (u'plug-in', 1)
# (u'blameless', 1)
# (u'soranno', 1)
# (u'discovery', 1)
# (u'$5,000', 1)
# (u'accident', 1)
# (u'decades:', 1)
# (u'refighting', 1)
# (u'eradicate', 1)
# (u'enterprise;', 1)
# (u'2nd', 1)
# (u'education;', 1)
# (u'wait?', 1)
# (u'dozens', 1)
# (u'equivocation', 1)
# (u'transatlantic', 1)
# (u'$2000', 1)
# (u'impoverished', 1)
# (u'responding', 1)
# (u'destruction;', 1)
# (u'greeted', 1)
# (u'failing', 1)
# (u'differences;', 1)
# (u'smoked', 1)
# (u"she'll", 1)
# (u'year-old', 1)
# (u'prison', 1)
# (u'spikes', 1)
# (u'gregg', 1)
# (u'roadside', 1)
# (u'ago:', 1)
# (u'arbitrary', 1)
# (u'working-class', 1)
# (u'progress."', 1)
# (u'u.s.a.!', 1)
# (u'cordray', 1)
# (u'burn', 1)
# (u'it."', 1)
# (u'gloss', 1)
# (u'balances', 1)
# (u'bio-terrorism', 1)
# (u'money."', 1)
# (u'lags', 1)
# (u'faring', 1)
# (u'marchers', 1)
# (u'high-powered', 1)
# (u'3.5', 1)
# (u'nearby', 1)
# (u'panels', 1)
# (u'90%', 1)
# (u'trust;', 1)
# (u'permitting', 1)
# (u'fiercely', 1)
# (u'scale', 1)
# (u'scores', 1)
# (u'derail', 1)
# (u'gutting', 1)
# (u'overdue', 1)
# (u'apollo', 1)
# (u'aligned', 1)
# (u'withfarmers', 1)
# (u'child;', 1)
# (u'responders', 1)
# (u'dig', 1)
# (u'"my', 1)
# (u'tougher', 1)
# (u'celebrated', 1)
# (u'predicting', 1)
# (u'agribusinesses', 1)
# (u'extra', 1)
# (u'shelley', 1)
# (u'insurgency', 1)
# (u'fine-tuned', 1)
# (u'three-', 1)
# (u'dialed', 1)
# (u'judd', 1)
# (u'printing', 1)
# (u'five-year', 1)
# (u'bethea', 1)
# (u'destructive', 1)
# (u'speak;', 1)
# (u'unleash', 1)
# (u'enemies;', 1)
# (u'blocked', 1)
# (u'jim', 1)
# (u'civilian', 1)
# (u'speeding', 1)
# (u'drop', 1)
# (u'supplant', 1)
# (u'teams', 1)
# (u'factors', 1)
# (u'mistakes;', 1)
# (u'entrusted', 1)
# (u'waves', 1)
# (u'stocks', 1)
# (u'out-innovate', 1)
# (u'crossroads', 1)
# (u'outcome', 1)
# (u'illness', 1)
# (u'hard-hit', 1)
# (u'encouraged', 1)
# (u'investigations', 1)
# (u'fcc', 1)
# (u'operate', 1)
# (u'not:', 1)
# (u'deployments', 1)
# (u'hoover', 1)
# (u'factories;', 1)
# (u'replaces', 1)
# (u'secondary', 1)
# (u'worried', 1)
# (u'burst', 1)
# (u'seal', 1)
# (u'homebuyers', 1)
# (u'concentrate', 1)
# (u'tuck', 1)
# (u'flipped', 1)
# (u'allowance', 1)
# (u'fiasco?', 1)
# (u'mandate', 1)
# (u'robotics', 1)
# (u'mccain', 1)
# (u'poll', 1)
# (u'noisy', 1)
# (u'punishes', 1)
# (u'howard', 1)
# (u're-financing', 1)
# (u'standard', 1)
# (u'pilot', 1)
# (u'care;', 1)
# (u'cure', 1)
# (u'promising', 1)
# (u'enriches', 1)
# (u'compound;', 1)
# (u'revolutions', 1)
# (u'surveillance', 1)
# (u'drain', 1)
# (u'laboratories', 1)
# (u'fueling', 1)
# (u'safeguards', 1)
# (u'summed', 1)
# (u'supercomputers', 1)
# (u'rises', 1)
# (u'leaner', 1)
# (u'birthdays', 1)
# (u'tuition;', 1)
# (u'curriculums', 1)
# (u'sleepless', 1)
# (u'tragedies', 1)
# (u'"but', 1)
# (u'scholarships', 1)
# (u'accessing', 1)
# (u'georgia', 1)
# (u'stations', 1)
# (u'escalating', 1)
# (u'teddy', 1)
# (u'decimated', 1)
# (u'up."', 1)
# (u'newtons', 1)
# (u'gary', 1)
# (u'legacy', 1)
# (u'dreaming', 1)
# (u'things."', 1)
# (u'petty', 1)
# (u'cycle', 1)
# (u'costco', 1)
# (u'god-given', 1)
# (u'year-olds', 1)
# (u'abuses', 1)
# (u'vehicles', 1)
# (u'research;', 1)
# (u'describe', 1)
# (u'estiven', 1)
# (u'walks', 1)
# (u'orrin', 1)
# (u'smartphones', 1)
# (u'2001', 1)
# (u'forcing', 1)
# (u'enrolled', 1)
# (u'stockpile', 1)
# (u'refused', 1)
# (u'adhere', 1)
# (u'grandfather', 1)
# (u'quicker', 1)
# (u'quicken', 1)
# (u'bomber', 1)
# (u'witnessed', 1)
# (u'associate', 1)
# (u'movement', 1)
# (u'65th', 1)
# (u'wanted', 1)
# (u'openly;', 1)
# (u'scorekeeper', 1)
# (u'offender', 1)
# (u'shelves', 1)
# (u'prompting', 1)
# (u'voted."', 1)
# (u'wisely', 1)
# (u'ninety-eight', 1)
# (u'disable', 1)
# (u'act;', 1)
# (u'turnover', 1)
# (u'rocketed', 1)
# (u'finalized', 1)
# (u'27', 1)
# (u'detainee', 1)
# (u'solving', 1)
# (u'cool', 1)
# (u'investigators', 1)
# (u'needless', 1)
# (u'base', 1)
# (u'rejects', 1)
# (u'talked', 1)
# (u'protectionism', 1)
# (u'errors', 1)
# (u'swipe', 1)
# (u'station', 1)
# (u'seeker', 1)
# (u'begrudge', 1)
# (u'gps', 1)
# (u'iranian', 1)
# (u'uniforms', 1)
# (u'harkin', 1)
# (u'nights', 1)
# (u'drapes', 1)
# (u'client', 1)
# (u'lifts', 1)
# (u'swiftly', 1)
# (u'campuses', 1)
# (u'joining', 1)
# (u'authors', 1)
# (u'heavily', 1)
# (u'express', 1)
# (u'resent', 1)
# (u'devising', 1)
# (u'locating', 1)
# (u'years;', 1)
# (u'visiting', 1)
# (u'leg', 1)
# (u'toledo', 1)
# (u"other's", 1)
# (u'inaction', 1)
# (u'crime', 1)
# (u'larger;', 1)
# (u'coincidence', 1)
# (u'church', 1)
# (u'belt', 1)
# (u'cheapest', 1)
# (u'there;', 1)
# (u'swifter', 1)
# (u'stolen', 1)
# (u'share:', 1)
# (u'income;', 1)
# (u'fight;', 1)
# (u'rancor', 1)
# (u'fast-changing', 1)
# (u're-design', 1)
# (u'ineffective', 1)
# (u'dozen', 1)
# (u'contractors', 1)
# (u'priced', 1)
# (u'edge', 1)
# (u'people;', 1)
# (u'eviction;', 1)
# (u'praying', 1)
# (u'nasa', 1)
# (u'wives', 1)
# (u'question:', 1)
# (u'forty-four', 1)
# (u'400,000', 1)
# (u'harness', 1)
# (u'rebates', 1)
# (u'secretary;', 1)
# (u'ordeal', 1)
# (u'repaid', 1)
# (u'morning', 1)
# (u'accountability', 1)
# (u'opponent', 1)
# (u'murphy', 1)
# (u'classified', 1)
# (u'clear-eyed', 1)
# (u'strong;', 1)
# (u'candor', 1)
# (u'sharing', 1)
# (u'outsourced', 1)
# (u'inventions', 1)
# (u'suffers', 1)
# (u'eased', 1)
# (u'2005', 1)
# (u'2009', 1)
# (u'confirmation', 1)
# (u'mastering', 1)
# (u'p-tech', 1)
# (u'believed:', 1)
# (u'tokyo', 1)
# (u'dealt', 1)
# (u'overloaded', 1)
# (u'educators', 1)
# (u'safe;', 1)
# (u'victor', 1)
# (u'out-compete', 1)
# (u'ammunition', 1)
# (u'focuses', 1)
# (u"history's", 1)
# (u'arrive', 1)
# (u'bookkeeping', 1)
# (u'payoffs', 1)
# (u'manage', 1)
# (u'surpluses', 1)
# (u'face-to-face', 1)
# (u'panel', 1)
# (u'saddle', 1)
# (u'weaker', 1)
# (u'providers', 1)
# (u'reserves', 1)
# (u'counterfeit', 1)
# (u'self-healing', 1)
# (u'aspiring', 1)
# (u'underway', 1)
# (u'proliferation;', 1)
# (u'majorities', 1)
# (u'hold?', 1)
# (u'lifeblood', 1)
# (u'warren', 1)
# (u'2012', 1)
# (u'campaigned', 1)
# (u'speaks', 1)
# (u'obsess', 1)
# (u'caregivers', 1)
# (u'backwards', 1)
# (u'tack', 1)
# (u'homelessness', 1)
# (u'retail', 1)
# (u'finest', 1)
# (u'succeeds', 1)
# (u'facility', 1)
# (u'economy;', 1)
# (u'drifting', 1)
# (u'shrapnel', 1)
# (u'hard;', 1)
# (u'dictate', 1)
# (u'quitters."', 1)
# (u'contact', 1)
# (u'latino', 1)
# (u'toughest', 1)
# (u'enlist', 1)
# (u'currently', 1)
# (u'specializes', 1)
# (u'staff', 1)
# (u'pause', 1)
# (u'employer', 1)
# (u'slows', 1)
# (u'latino;', 1)
# (u'goods;', 1)
# (u'belts', 1)
# (u'frustrates', 1)
# (u'routine', 1)
# (u'ourselves."', 1)
# (u'well-qualified', 1)
# (u'deter', 1)
# (u'readying', 1)
# (u'tight-knit', 1)
# (u'cynicism', 1)
# (u'panels;', 1)
# (u'commutes', 1)
# (u'qadhafi', 1)
# (u'ensuring', 1)
# (u'bull', 1)
# (u'volunteer', 1)
# (u'will"', 1)
# (u'lightweight', 1)
# (u'sits', 1)
# (u'efficiencies', 1)
# (u'kids;', 1)
# (u'drink', 1)
# (u'discouraged', 1)
# (u'whims', 1)
# (u'expense', 1)
# (u'doubtful;', 1)
# (u'modeled', 1)
# (u'fever', 1)
# (u'less;', 1)
# (u'seats', 1)
# (u'work;', 1)
# (u'recovery.gov', 1)
# (u'deployment', 1)
# (u'afraid,"', 1)
# (u'out;', 1)
# (u'conrad', 1)
# (u'cleveland', 1)
# (u'disrupting', 1)
# (u'before;', 1)
# (u'noise', 1)
# (u'expire', 1)
# (u'stage', 1)
# (u'surge', 1)
# (u'software', 1)
# (u'weather', 1)
# (u'spouse', 1)
# (u'rushed', 1)
# (u'dropping', 1)
# (u'double-down', 1)
# (u'retool', 1)
# (u'convince', 1)
# (u'reach:', 1)
# (u'conclusion', 1)
# (u'adjustments', 1)
# (u'coburn', 1)
# (u'bailing', 1)
# (u'accomplish', 1)
# (u'infuriated', 1)
# (u'galesburg', 1)

# %%
for x in word_count_wjc_clean.subtractByKey(word_count_al_clean).sortBy(lambda x: x[1],ascending=False).collect():
    print x
# Out:
# (u'tonight', 98)
# (u'families', 82)
# (u'budget', 77)
# (u'challenge', 76)
# (u'parents', 70)
# (u'schools', 66)
# (u'jobs', 66)
# (u'child', 65)
# (u'million', 64)
# (u'today', 60)
# (u'crime', 60)
# (u'21st', 58)
# (u'college', 54)
# (u'thank', 47)
# (u'bill', 47)
# (u'job', 46)
# (u'hard', 42)
# (u"america's", 41)
# (u'bipartisan', 40)
# (u'insurance', 39)
# (u'medicare', 38)
# (u'economic', 37)
# (u'fellow', 37)
# (u'teachers', 36)
# (u'workers', 36)
# (u'democracy', 36)
# (u'young', 35)
# (u'businesses', 34)
# (u'percent', 34)
# (u"can't", 34)
# (u'billion', 33)
# (u'weapons', 33)
# (u'deficit', 33)
# (u'start', 32)
# (u'around', 31)
# (u'nuclear', 31)
# (u'stop', 30)
# (u'global', 30)
# (u'proud', 30)
# (u'programs', 29)
# (u'going', 29)
# (u'leadership', 29)
# (u'strengthen', 28)
# (u'standards', 28)
# (u'drugs', 27)
# (u'cannot', 27)
# (u'cuts', 27)
# (u'police', 26)
# (u'middle', 26)
# (u'worked', 26)
# (u'medical', 26)
# (u'values', 25)
# (u'program', 25)
# (u'environment', 24)
# (u'markets', 24)
# (u'spending', 24)
# (u'students', 23)
# (u'quality', 23)
# (u'got', 23)
# (u'tell', 23)
# (u'vice', 23)
# (u'lead', 22)
# (u'balanced', 21)
# (u'technology', 21)
# (u'leaders', 21)
# (u'challenges', 20)
# (u'helped', 20)
# (u'coverage', 20)
# (u'problem', 20)
# (u'initiative', 19)
# (u'helping', 19)
# (u'chamber', 19)
# (u'record', 19)
# (u'renew', 19)
# (u'building', 18)
# (u'real', 18)
# (u'poverty', 18)
# (u'stronger', 18)
# (u"world's", 18)
# (u'big', 18)
# (u'commitment', 18)
# (u'streets', 18)
# (u'historic', 18)
# (u'affordable', 17)
# (u'invest', 17)
# (u'campaign', 17)
# (u'drug', 17)
# (u'internet', 17)
# (u'finish', 17)
# (u'ban', 16)
# (u'investment', 16)
# (u"you're", 16)
# (u'ahead', 16)
# (u'incentives', 15)
# (u'speaker', 15)
# (u'poor', 15)
# (u'era', 15)
# (u'took', 15)
# (u"children's", 15)
# (u'gun', 15)
# (u'remember', 15)
# (u'thousand', 15)
# (u'kids', 15)
# (u"i'd", 15)
# (u'democratic', 15)
# (u'research', 15)
# (u'areas', 15)
# (u'skills', 14)
# (u'wage', 14)
# (u'lady', 14)
# (u'covenant', 14)
# (u'thanks', 14)
# (u'50', 14)
# (u'ideas', 14)
# (u'goal', 14)
# (u'1993', 14)
# (u'neighborhoods', 14)
# (u'finally', 14)
# (u'learning', 14)
# (u'opportunities', 14)
# (u'teach', 14)
# (u'clean', 14)
# (u'2000', 14)
# (u'millennium', 13)
# (u'sector', 13)
# (u'read', 13)
# (u'tough', 13)
# (u'nato', 13)
# (u'idea', 13)
# (u'illegal', 13)
# (u'savings', 13)
# (u"nation's", 13)
# (u'smaller', 13)
# (u'religious', 12)
# (u'20', 12)
# (u'role', 12)
# (u'allies', 12)
# (u'grow', 12)
# (u'10', 12)
# (u'brady', 12)
# (u'$', 12)
# (u'partners', 12)
# (u'parent', 12)
# (u'prepare', 12)
# (u'behind', 12)
# (u'achieve', 12)
# (u'air', 12)
# (u'unemployment', 12)
# (u'scientists', 12)
# (u'everyone', 12)
# (u'reward', 12)
# (u'teen', 11)
# (u'everybody', 11)
# (u'classroom', 11)
# (u'problems', 11)
# (u'moved', 11)
# (u'investments', 11)
# (u'everything', 11)
# (u'americorps', 11)
# (u'environmental', 11)
# (u'rural', 11)
# (u'bosnia', 11)
# (u'richard', 11)
# (u'technologies', 11)
# (u'lower', 11)
# (u'korea', 11)
# (u'space', 11)
# (u'truly', 11)
# (u'minimum', 11)
# (u'basic', 11)
# (u'15', 10)
# (u'threats', 10)
# (u'long-term', 10)
# (u"won't", 10)
# (u'risk', 10)
# (u'finance', 10)
# (u'urge', 10)
# (u'bureaucracy', 10)
# (u'lifetime', 10)
# (u'democrats', 10)
# (u'math', 10)
# (u'earn', 10)
# (u'proposal', 10)
# (u'criminals', 10)
# (u'costs', 10)
# (u'row', 10)
# (u'terrorists', 10)
# (u'saved', 9)
# (u'ensure', 9)
# (u'rising', 9)
# (u'terror', 9)
# (u'dream', 9)
# (u'stopped', 9)
# (u'funding', 9)
# (u'barriers', 9)
# (u'gangs', 9)
# (u'gore', 9)
# (u'mission', 9)
# (u'supporting', 9)
# (u"she's", 9)
# (u'goals', 9)
# (u'exports', 9)
# (u'empowerment', 9)
# (u'fourth', 9)
# (u'talk', 9)
# (u'rest', 9)
# (u'empower', 9)
# (u"today's", 9)
# (u'fundamental', 9)
# (u'initiatives', 9)
# (u'prevention', 9)
# (u'decade', 9)
# (u'tobacco', 9)
# (u'student', 9)
# (u'sick', 9)
# (u'lift', 9)
# (u'farmers', 9)
# (u'cities', 9)
# (u'fall', 9)
# (u'became', 9)
# (u'strategy', 9)
# (u'partnership', 9)
# (u'choices', 9)
# (u'getting', 9)
# (u'toxic', 8)
# (u'districts', 8)
# (u'william', 8)
# (u'solve', 8)
# (u'hours', 8)
# (u'protects', 8)
# (u'powerful', 8)
# (u'announce', 8)
# (u'asked', 8)
# (u'politics', 8)
# (u'decline', 8)
# (u'enforce', 8)
# (u'using', 8)
# (u'dreams', 8)
# (u'deal', 8)
# (u'groups', 8)
# (u'lobbyists', 8)
# (u'cancer', 8)
# (u'buying', 8)
# (u'keeping', 8)
# (u'threat', 8)
# (u'housing', 8)
# (u'told', 8)
# (u"there's", 8)
# (u'republicans', 8)
# (u'scores', 8)
# (u'tuition', 8)
# (u'crimes', 8)
# (u'decisions', 7)
# (u'middle-class', 7)
# (u'60', 7)
# (u"i'll", 7)
# (u'prescription', 7)
# (u'clinton', 7)
# (u'makes', 7)
# (u'folks', 7)
# (u'farm', 7)
# (u'decades', 7)
# (u'voted', 7)
# (u'teaching', 7)
# (u'churches', 7)
# (u'bridge', 7)
# (u'economies', 7)
# (u'greenhouse', 7)
# (u'expanding', 7)
# (u'records', 7)
# (u'tomorrow', 7)
# (u'senator', 7)
# (u'summer', 7)
# (u'agreements', 7)
# (u'media', 7)
# (u'plans', 7)
# (u'cleaner', 7)
# (u'teacher', 7)
# (u'treatment', 7)
# (u'adults', 7)
# (u'literally', 7)
# (u'dramatically', 7)
# (u'citizenship', 7)
# (u'discrimination', 7)
# (u'funds', 7)
# (u'charter', 7)
# (u'hospital', 7)
# (u'encourage', 7)
# (u'yes', 7)
# (u'dollars', 7)
# (u'racial', 7)
# (u'roosevelt', 7)
# (u'major', 7)
# (u'rid', 7)
# (u'strongest', 7)
# (u'classrooms', 7)
# (u'1992', 7)
# (u'quickly', 7)
# (u'tougher', 7)
# (u'employers', 7)
# (u'offer', 7)
# (u'reading', 7)
# (u'inflation', 7)
# (u'rewards', 7)
# (u'treasures', 7)
# (u'computer', 7)
# (u'toughest', 7)
# (u'j', 7)
# (u'this:', 7)
# (u"he's", 7)
# (u'pregnancy', 6)
# (u'high-tech', 6)
# (u'love', 6)
# (u'afford', 6)
# (u'rules', 6)
# (u'food', 6)
# (u'impact', 6)
# (u'gas', 6)
# (u'consensus', 6)
# (u'forge', 6)
# (u'central', 6)
# (u'zones', 6)
# (u'guests', 6)
# (u'humanity', 6)
# (u'shared', 6)
# (u'dropped', 6)
# (u'aging', 6)
# (u'cars', 6)
# (u'checks', 6)
# (u'represent', 6)
# (u'rooted', 6)
# (u'yesterday', 6)
# (u'deficits', 6)
# (u'promotion', 6)
# (u'went', 6)
# (u'alive', 6)
# (u'doors', 6)
# (u'haiti', 6)
# (u'falling', 6)
# (u'hillary', 6)
# (u'senior', 6)
# (u'endeavor', 6)
# (u'500', 6)
# (u'hour', 6)
# (u'ireland', 6)
# (u'competitive', 6)
# (u'key', 6)
# (u'smart', 6)
# (u'begun', 6)
# (u'hundreds', 6)
# (u'americans:', 6)
# (u'john', 6)
# (u'testing', 6)
# (u'son', 6)
# (u'critical', 6)
# (u'brave', 6)
# (u'sign', 6)
# (u'honest', 6)
# (u'doctor', 6)
# (u'journey', 6)
# (u'level', 6)
# (u'partnerships', 6)
# (u'policing', 6)
# (u'resolve', 6)
# (u'church', 6)
# (u'older', 6)
# (u'cutting', 6)
# (u'individual', 6)
# (u'keeps', 6)
# (u'master', 5)
# (u'ii', 5)
# (u'low-income', 5)
# (u'losing', 5)
# (u'mass', 5)
# (u'1999', 5)
# (u'write', 5)
# (u'anyone', 5)
# (u'deduction', 5)
# (u'speed', 5)
# (u'tv', 5)
# (u'please', 5)
# (u'marriage', 5)
# (u'endanger', 5)
# (u'landmark', 5)
# (u'started', 5)
# (u'worldwide', 5)
# (u'closer', 5)
# (u'safest', 5)
# (u'taxpayers', 5)
# (u'star', 5)
# (u'jack', 5)
# (u'1998', 5)
# (u'recovery', 5)
# (u'aisle', 5)
# (u'spent', 5)
# (u'deadly', 5)
# (u'1994', 5)
# (u'organizations', 5)
# (u'unnecessary', 5)
# (u'workplace', 5)
# (u'biological', 5)
# (u'smarter', 5)
# (u'gains', 5)
# (u'pell', 5)
# (u'eliminate', 5)
# (u'credits', 5)
# (u'deserve', 5)
# (u'punish', 5)
# (u'emissions', 5)
# (u'smoking', 5)
# (u'inner', 5)
# (u'launched', 5)
# (u'demanding', 5)
# (u'weeks', 5)
# (u'television', 5)
# (u'bureaucratic', 5)
# (u'trouble', 5)
# (u'possibility', 5)
# (u"here's", 5)
# (u'veteran', 5)
# (u'celebrate', 5)
# (u'emergency', 5)
# (u'accountable', 5)
# (u'20th', 5)
# (u'learned', 5)
# (u'skill', 5)
# (u'fathers', 5)
# (u'agenda', 5)
# (u'shut', 5)
# (u'partisan', 5)
# (u'terrorism', 5)
# (u'40', 5)
# (u'trying', 5)
# (u'truman', 5)
# (u"who's", 5)
# (u'speak', 5)
# (u'mother', 5)
# (u'apart', 5)
# (u'hunt', 5)
# (u'diplomacy', 5)
# (u'futures', 5)
# (u'heritage', 5)
# (u'legacy', 5)
# (u'potential', 5)
# (u'knew', 5)
# (u'dramatic', 5)
# (u'diverse', 5)
# (u'missiles', 5)
# (u'scholarships', 5)
# (u'graduate', 5)
# (u'woman', 5)
# (u'constructive', 5)
# (u'iraq', 5)
# (u'station', 5)
# (u'$1', 5)
# (u'70', 5)
# (u'courage', 5)
# (u'levels', 5)
# (u'edge', 5)
# (u'goods', 5)
# (u'renewal', 5)
# (u'missile', 5)
# (u'bills', 5)
# (u'ethnic', 5)
# (u'smallest', 5)
# (u'scholarship', 5)
# (u'spread', 5)
# (u'meaningful', 4)
# (u'governors', 4)
# (u'veto', 4)
# (u'spur', 4)
# (u'worker', 4)
# (u'track', 4)
# (u'democracies', 4)
# (u'saddam', 4)
# (u'55', 4)
# (u'honored', 4)
# (u'medicaid', 4)
# (u'managed', 4)
# (u'father', 4)
# (u'veterans', 4)
# (u'proposals', 4)
# (u'sake', 4)
# (u'visit', 4)
# (u'possibilities', 4)
# (u'19', 4)
# (u'efficient', 4)
# (u'founders', 4)
# (u'facing', 4)
# (u'backgrounds', 4)
# (u'prosecutors', 4)
# (u'town', 4)
# (u'planet', 4)
# (u'try', 4)
# (u'everglades', 4)
# (u'hit', 4)
# (u'approve', 4)
# (u'creativity', 4)
# (u'modernize', 4)
# (u'contributions', 4)
# (u'ukraine', 4)
# (u'standing', 4)
# (u"generation's", 4)
# (u'baby', 4)
# (u"alzheimer's", 4)
# (u'meant', 4)
# (u'soviet', 4)
# (u'mccaffrey', 4)
# (u'path', 4)
# (u'cigarettes', 4)
# (u'polluters', 4)
# (u'grows', 4)
# (u'target', 4)
# (u'lucas', 4)
# (u'advances', 4)
# (u'marketing', 4)
# (u'hiring', 4)
# (u'floods', 4)
# (u'sensible', 4)
# (u'combined', 4)
# (u'diseases', 4)
# (u'desperately', 4)
# (u'shrink', 4)
# (u'ended', 4)
# (u'joined', 4)
# (u'turmoil', 4)
# (u'iras', 4)
# (u'treatments', 4)
# (u'response', 4)
# (u'mental', 4)
# (u"they've", 4)
# (u'projected', 4)
# (u'reverend', 4)
# (u'lobby', 4)
# (u'risks', 4)
# (u'longest', 4)
# (u'reverse', 4)
# (u'spend', 4)
# (u'grass-roots', 4)
# (u'reconciliation', 4)
# (u'fulfill', 4)
# (u'heart', 4)
# (u'ties', 4)
# (u'$15', 4)
# (u'strengthened', 4)
# (u"president's", 4)
# (u'boom', 4)
# (u'employees', 4)
# (u'handguns', 4)
# (u'globalization', 4)
# (u'superhighway', 4)
# (u'dawn', 4)
# (u'enormous', 4)
# (u'top', 4)
# (u'outlaw', 4)
# (u'background', 4)
# (u'library', 4)
# (u'raised', 4)
# (u'launching', 4)
# (u'educate', 4)
# (u'goes', 4)
# (u'judy', 4)
# (u'subsidies', 4)
# (u'tipper', 4)
# (u'stress', 4)
# (u'oklahoma', 4)
# (u'modest', 4)
# (u'fifth', 4)
# (u'actions', 4)
# (u'policies', 4)
# (u'researchers', 4)
# (u'competition', 4)
# (u'neighbor', 4)
# (u'fast', 4)
# (u'ten', 4)
# (u'penalties', 4)
# (u'trained', 4)
# (u"haven't", 4)
# (u'significant', 4)
# (u'achievement', 4)
# (u'doubled', 4)
# (u'gases', 4)
# (u'dole', 4)
# (u'meaning', 4)
# (u'explore', 4)
# (u'implement', 4)
# (u'child-care', 4)
# (u'red', 4)
# (u'parks', 4)
# (u'combat', 4)
# (u"wouldn't", 4)
# (u'warming', 4)
# (u'poorest', 4)
# (u'reforms', 4)
# (u'street', 4)
# (u'strengthening', 4)
# (u'kristen', 4)
# (u'foremost', 4)
# (u'genes', 4)
# (u'tonight:', 4)
# (u'digital', 4)
# (u'vietnam', 4)
# (u'wait', 4)
# (u'memory', 4)
# (u'productive', 4)
# (u'rock', 4)
# (u'voices', 4)
# (u'mrs', 4)
# (u'watching', 4)
# (u'27', 4)
# (u'developing', 4)
# (u'civic', 4)
# (u'fairness', 4)
# (u'sitting', 4)
# (u'pick', 4)
# (u'someone', 4)
# (u"year's", 4)
# (u'traveled', 4)
# (u'doctors', 4)
# (u'years;', 4)
# (u'won', 4)
# (u'latin', 4)
# (u'g.i', 4)
# (u'guarantees', 4)
# (u'innovation', 4)
# (u'pollution', 4)
# (u'accountability', 4)
# (u'humanities', 4)
# (u'night', 4)
# (u'stable', 4)
# (u'entertainment', 4)
# (u'finest', 4)
# (u'privacy', 4)
# (u'employer', 4)
# (u'foster', 4)
# (u'hero', 3)
# (u'trading', 3)
# (u'conscience', 3)
# (u'dr', 3)
# (u'faced', 3)
# (u"california's", 3)
# (u'dean', 3)
# (u'collections', 3)
# (u'tip', 3)
# (u'promoting', 3)
# (u'says', 3)
# (u'root', 3)
# (u'ailing', 3)
# (u'india', 3)
# (u'104th', 3)
# (u'jackson', 3)
# (u'11', 3)
# (u'pain', 3)
# (u'discovered', 3)
# (u'partisanship', 3)
# (u'juveniles', 3)
# (u'embrace', 3)
# (u'breakdown', 3)
# (u'sweeping', 3)
# (u'bloc', 3)
# (u'reap', 3)
# (u'theodore', 3)
# (u'week', 3)
# (u'balancing', 3)
# (u'feingold', 3)
# (u'oppose', 3)
# (u'"if', 3)
# (u'24', 3)
# (u'feet', 3)
# (u'threatening', 3)
# (u'kill', 3)
# (u'libraries', 3)
# (u'peacetime', 3)
# (u'costly', 3)
# (u'$10,000', 3)
# (u'finding', 3)
# (u'jonesboro', 3)
# (u'curb', 3)
# (u'caribbean', 3)
# (u'world-class', 3)
# (u'universities', 3)
# (u'recession', 3)
# (u'sought', 3)
# (u'destroying', 3)
# (u'blocks', 3)
# (u'restrain', 3)
# (u'payroll', 3)
# (u'steel', 3)
# (u'candidates', 3)
# (u'group', 3)
# (u'member', 3)
# (u'ideals', 3)
# (u'employment', 3)
# (u'happens', 3)
# (u'endeavors', 3)
# (u'tackle', 3)
# (u'goal:', 3)
# (u'biggest', 3)
# (u'compete', 3)
# (u'elaine', 3)
# (u'expands', 3)
# (u'factory', 3)
# (u'asian', 3)
# (u'pursuit', 3)
# (u'90', 3)
# (u'childhood', 3)
# (u'network', 3)
# (u'foundation', 3)
# (u"yesterday's", 3)
# (u'talking', 3)
# (u'disaster', 3)
# (u'deepen', 3)
# (u'los', 3)
# (u'200', 3)
# (u'bold', 3)
# (u'pays', 3)
# (u'transform', 3)
# (u'forming', 3)
# (u'failure', 3)
# (u'flood', 3)
# (u'debate', 3)
# (u'fueled', 3)
# (u'tejeda', 3)
# (u'invests', 3)
# (u'indeed', 3)
# (u'disasters', 3)
# (u'playing', 3)
# (u'elected', 3)
# (u'talented', 3)
# (u'tutors', 3)
# (u'fastest', 3)
# (u'eitc', 3)
# (u'decent', 3)
# (u'sixth', 3)
# (u'arsenals', 3)
# (u'hard-working', 3)
# (u'sun', 3)
# (u'tragedy', 3)
# (u'stick', 3)
# (u'budgets', 3)
# (u'missed', 3)
# (u'18', 3)
# (u'imports', 3)
# (u'work-study', 3)
# (u'healing', 3)
# (u'threaten', 3)
# (u'all-time', 3)
# (u'franklin', 3)
# (u'presidents', 3)
# (u'traffickers', 3)
# (u'junior', 3)
# (u"tomorrow's", 3)
# (u'centers', 3)
# (u'locks', 3)
# (u'breast', 3)
# (u'sergeant', 3)
# (u'loved', 3)
# (u'distinguished', 3)
# (u'teenagers', 3)
# (u'empowering', 3)
# (u'partner', 3)
# (u'cross', 3)
# (u'center', 3)
# (u'hall', 3)
# (u'obey', 3)
# (u'commitments', 3)
# (u'illusion', 3)
# (u'governing', 3)
# (u'achievable', 3)
# (u'1997', 3)
# (u'damaged', 3)
# (u'innocent', 3)
# (u'percentage', 3)
# (u'frankly', 3)
# (u"who've", 3)
# (u'cooperation', 3)
# (u'match', 3)
# (u'elderly', 3)
# (u'premiums', 3)
# (u'flexibility', 3)
# (u'heroes', 3)
# (u'lifting', 3)
# (u'recipients', 3)
# (u'happen', 3)
# (u'eyes', 3)
# (u'13', 3)
# (u'17', 3)
# (u'reinforce', 3)
# (u'wealthiest', 3)
# (u'spark', 3)
# (u'undermine', 3)
# (u'rebuild', 3)
# (u'bravery', 3)
# (u'strikes', 3)
# (u'poison', 3)
# (u'driving', 3)
# (u'finished', 3)
# (u'overseas', 3)
# (u'pledged', 3)
# (u'identity', 3)
# (u'common-sense', 3)
# (u'israel', 3)
# (u'sacred', 3)
# (u'drinking', 3)
# (u'taxpayer', 3)
# (u"parkinson's", 3)
# (u'grandchildren', 3)
# (u'enact', 3)
# (u'juvenile', 3)
# (u'hatred', 3)
# (u'fewer', 3)
# (u'waiting', 3)
# (u'servants', 3)
# (u'educational', 3)
# (u'buildings', 3)
# (u'hussein', 3)
# (u'wondered', 3)
# (u'1.2', 3)
# (u'communist', 3)
# (u'declining', 3)
# (u'genetic', 3)
# (u'paycheck', 3)
# (u'happiness', 3)
# (u'time:', 3)
# (u"aren't", 3)
# (u'diabetes', 3)
# (u'listen', 3)
# (u'retire', 3)
# (u'16', 3)
# (u'discovery', 3)
# (u'evening', 3)
# (u'economics', 3)
# (u'failing', 3)
# (u'bottom', 3)
# (u'cherish', 3)
# (u'book', 3)
# (u'nixon', 3)
# (u'synagogues', 3)
# (u'accomplishments', 3)
# (u'reducing', 3)
# (u'stake', 3)
# (u'reality', 3)
# (u'team', 3)
# (u'graduates', 3)
# (u'conservation', 3)
# (u'jim', 3)
# (u'happened', 3)
# (u'qualified', 3)
# (u'protections', 3)
# (u'convene', 3)
# (u'sat', 3)
# (u'mccain', 3)
# (u'morning', 3)
# (u'innovations', 3)
# (u'kennedy', 3)
# (u'earlier', 3)
# (u'god-given', 3)
# (u'taught', 3)
# (u'winning', 3)
# (u'pressing', 3)
# (u'v-chip', 3)
# (u'computers', 3)
# (u'tom', 3)
# (u'trapped', 3)
# (u'after-school', 3)
# (u'cheaper', 3)
# (u'summit', 3)
# (u'shaped', 3)
# (u'seize', 3)
# (u'reserve', 3)
# (u'educators', 3)
# (u'experiment', 3)
# (u'gene', 3)
# (u'surpluses', 3)
# (u'communism', 3)
# (u'piece', 3)
# (u'nafta', 3)
# (u'serving', 3)
# (u'gets', 3)
# (u'sets', 3)
# (u'work;', 3)
# (u'farsighted', 3)
# (u'preexisting', 3)
# (u'waves', 3)
# (u'ratify', 3)
# (u'disability', 2)
# (u'disclose', 2)
# (u'pioneering', 2)
# (u'reagan', 2)
# (u'strike', 2)
# (u'paperwork', 2)
# (u'outdated', 2)
# (u'gatt', 2)
# (u'transforming', 2)
# (u'worst', 2)
# (u'explode', 2)
# (u'consolidate', 2)
# (u'crucial', 2)
# (u'strangers', 2)
# (u'medicine', 2)
# (u'nonpartisan', 2)
# (u'do:', 2)
# (u'radio', 2)
# (u'lethal', 2)
# (u'watch', 2)
# (u'mandatory', 2)
# (u'hammer', 2)
# (u'lots', 2)
# (u'experts', 2)
# (u'potentially', 2)
# (u'corporate', 2)
# (u'identify', 2)
# (u'manual', 2)
# (u'specific', 2)
# (u'ignore', 2)
# (u'purple', 2)
# (u'shifting', 2)
# (u'harmful', 2)
# (u'trailers', 2)
# (u'leads', 2)
# (u'paychecks', 2)
# (u'1995', 2)
# (u'excellence', 2)
# (u"patients'", 2)
# (u'"mr', 2)
# (u'angels', 2)
# (u'1980s', 2)
# (u'requirements', 2)
# (u'middle-income', 2)
# (u'profit', 2)
# (u'replacing', 2)
# (u'seventh', 2)
# (u'turned', 2)
# (u'mastectomy', 2)
# (u'shot', 2)
# (u'vaccines', 2)
# (u'outrage', 2)
# (u'congregations', 2)
# (u'punished', 2)
# (u'enabling', 2)
# (u'speech', 2)
# (u'births', 2)
# (u'disadvantaged', 2)
# (u'mortgages', 2)
# (u'risking', 2)
# (u'thinking', 2)
# (u'stagnant', 2)
# (u'community;', 2)
# (u'home:', 2)
# (u'yellowstone', 2)
# (u'teamwork', 2)
# (u'shrinking', 2)
# (u'dependable', 2)
# (u"workers'", 2)
# (u'drift', 2)
# (u'gifts', 2)
# (u'remote', 2)
# (u'awful', 2)
# (u'neighborhood', 2)
# (u'eye', 2)
# (u'plan:', 2)
# (u'tide', 2)
# (u'productivity', 2)
# (u'intolerable', 2)
# (u'engaging', 2)
# (u'inspection', 2)
# (u'miss', 2)
# (u'hallowed', 2)
# (u'jordan', 2)
# (u'$6', 2)
# (u'youth', 2)
# (u'sell', 2)
# (u'park', 2)
# (u'sponsored', 2)
# (u'targeted', 2)
# (u'newborn', 2)
# (u'stamp', 2)
# (u'extends', 2)
# (u'disrupt', 2)
# (u'cents', 2)
# (u'chris', 2)
# (u'singing', 2)
# (u"china's", 2)
# (u'shine', 2)
# (u'refugees', 2)
# (u'2002', 2)
# (u'compact', 2)
# (u'telling', 2)
# (u'punishing', 2)
# (u'video', 2)
# (u'self-defeating', 2)
# (u'youngest', 2)
# (u'getsla', 2)
# (u'world:', 2)
# (u'banner', 2)
# (u'defining', 2)
# (u'hate', 2)
# (u'elementary', 2)
# (u'rev', 2)
# (u'priority', 2)
# (u'passionately', 2)
# (u'saying:', 2)
# (u'painting', 2)
# (u'tolerance', 2)
# (u'breathe', 2)
# (u'droughts', 2)
# (u'instant', 2)
# (u'chosen', 2)
# (u'grief', 2)
# (u'underclass', 2)
# (u'front', 2)
# (u'twilight', 2)
# (u'wider', 2)
# (u'angeles', 2)
# (u'rightly', 2)
# (u'rubble', 2)
# (u'best-trained', 2)
# (u'courageous', 2)
# (u'shouting', 2)
# (u'suzann', 2)
# (u'lengthen', 2)
# (u'phone', 2)
# (u'movies', 2)
# (u'damage', 2)
# (u'minority', 2)
# (u'senators', 2)
# (u'vouchers', 2)
# (u'represents', 2)
# (u'forty', 2)
# (u'vetoed', 2)
# (u'heading', 2)
# (u'hook', 2)
# (u'afterschool', 2)
# (u'dwell', 2)
# (u'urban', 2)
# (u"god's", 2)
# (u'news', 2)
# (u'negative', 2)
# (u'telecommunications', 2)
# (u'"i', 2)
# (u'uncharted', 2)
# (u'cherry', 2)
# (u'wright', 2)
# (u'gridlock', 2)
# (u'dignity', 2)
# (u'unrivaled', 2)
# (u'mccain-feingold', 2)
# (u'core', 2)
# (u'catalyst', 2)
# (u'absent', 2)
# (u'builds', 2)
# (u'picture', 2)
# (u'restores', 2)
# (u'adult', 2)
# (u'focus', 2)
# (u'foundations', 2)
# (u'round', 2)
# (u'voucher', 2)
# (u'grandparents', 2)
# (u'say:', 2)
# (u'shift', 2)
# (u'minimum-wage', 2)
# (u'10,000', 2)
# (u'nearest', 2)
# (u'nursing', 2)
# (u'divides', 2)
# (u'worship', 2)
# (u'cleanest', 2)
# (u'name', 2)
# (u'reminds', 2)
# (u'massive', 2)
# (u'corporations', 2)
# (u'legally', 2)
# (u'nutrition', 2)
# (u'elsewhere', 2)
# (u'borrow', 2)
# (u'predicted', 2)
# (u'sites', 2)
# (u'65', 2)
# (u'missions', 2)
# (u'spotlight', 2)
# (u'everyday', 2)
# (u'105th', 2)
# (u'diploma', 2)
# (u'pakistan', 2)
# (u'mob', 2)
# (u'enacting', 2)
# (u'philadelphia', 2)
# (u'illnesses', 2)
# (u'idea--the', 2)
# (u'tomorrows', 2)
# (u'40-year', 2)
# (u'bombed', 2)
# (u'columbine', 2)
# (u'interconnected', 2)
# (u'options', 2)
# (u'sens', 2)
# (u'powell', 2)
# (u'academic', 2)
# (u'paths', 2)
# (u'chart', 2)
# (u'dealers', 2)
# (u'obligation:', 2)
# (u'wide', 2)
# (u'teen-ager', 2)
# (u'rodgers', 2)
# (u'boy', 2)
# (u'32', 2)
# (u'clear:', 2)
# (u'ratings', 2)
# (u'skyrocketing', 2)
# (u'anybody', 2)
# (u'networks', 2)
# (u"o'neill", 2)
# (u'eager', 2)
# (u'accelerate', 2)
# (u'best-equipped', 2)
# (u'positive', 2)
# (u'congressman', 2)
# (u'post-cold-war', 2)
# (u"hasn't", 2)
# (u'virtually', 2)
# (u'helps', 2)
# (u'mobilize', 2)
# (u'reemployment', 2)
# (u'best-prepared', 2)
# (u'abiding', 2)
# (u'us:', 2)
# (u'counted', 2)
# (u'history--and', 2)
# (u'auto', 2)
# (u'mention', 2)
# (u'identified', 2)
# (u'redwoods', 2)
# (u'frank', 2)
# (u'nationally', 2)
# (u'freer', 2)
# (u'pursued', 2)
# (u'gunned', 2)
# (u'mountaintop', 2)
# (u'parenting', 2)
# (u'gallery', 2)
# (u'impression', 2)
# (u'brighter', 2)
# (u'suburbs', 2)
# (u'equip', 2)
# (u'destiny', 2)
# (u'treat', 2)
# (u'abandoned', 2)
# (u'workplaces', 2)
# (u'watched', 2)
# (u'devastated', 2)
# (u'personnel', 2)
# (u'distress', 2)
# (u'lake', 2)
# (u'advertising', 2)
# (u'fema', 2)
# (u'monetary', 2)
# (u'complacency', 2)
# (u'children;', 2)
# (u'congresswoman', 2)
# (u'200,000', 2)
# (u'tirelessly', 2)
# (u'inner-city', 2)
# (u'cindy', 2)
# (u'counts', 2)
# (u'well-trained', 2)
# (u'preventive', 2)
# (u'reforming', 2)
# (u'carlos', 2)
# (u'priorities', 2)
# (u'repealed', 2)
# (u'speeds', 2)
# (u'deserving', 2)
# (u'mostly', 2)
# (u'anti-drug', 2)
# (u'shots', 2)
# (u'accord', 2)
# (u'epidemic', 2)
# (u'study', 2)
# (u'finalize', 2)
# (u'smoke', 2)
# (u'birth', 2)
# (u'sporting', 2)
# (u'purchasing', 2)
# (u'ease', 2)
# (u'gift', 2)
# (u'private-sector', 2)
# (u'hard-pressed', 2)
# (u'beings', 2)
# (u'coastal', 2)
# (u'hemisphere', 2)
# (u'reinventing', 2)
# (u'talents', 2)
# (u"80's", 2)
# (u'summoned', 2)
# (u'congratulating', 2)
# (u'colin', 2)
# (u'sunday', 2)
# (u'grandson', 2)
# (u'block', 2)
# (u'introduce', 2)
# (u'stabilize', 2)
# (u'fires', 2)
# (u'entering', 2)
# (u'card', 2)
# (u'anderson', 2)
# (u'fraction', 2)
# (u'gathering', 2)
# (u'kevin', 2)
# (u'ideal', 2)
# (u'heat', 2)
# (u'8-year-olds', 2)
# (u'vision', 2)
# (u'eliminating', 2)
# (u'insist', 2)
# (u'airwaves', 2)
# (u'ambitious', 2)
# (u'listening', 2)
# (u'stops', 2)
# (u'lifted', 2)
# (u'stars', 2)
# (u'naysayers', 2)
# (u'podium', 2)
# (u'calls', 2)
# (u'tanner', 2)
# (u'colleges', 2)
# (u'pointing', 2)
# (u'modernization', 2)
# (u'lawmakers', 2)
# (u"founders'", 2)
# (u'mount', 2)
# (u'sue', 2)
# (u'consumers', 2)
# (u'search', 2)
# (u'inspired', 2)
# (u'company', 2)
# (u'roots', 2)
# (u'rebuilt', 2)
# (u'hurting', 2)
# (u'bigger', 2)
# (u"isn't", 2)
# (u'kinslow', 2)
# (u'unimaginable', 2)
# (u"they'll", 2)
# (u'risen', 2)
# (u'nigeria', 2)
# (u'wilson', 2)
# (u'zero', 2)
# (u'play', 2)
# (u'explodes', 2)
# (u'circle', 2)
# (u'roles', 2)
# (u'progressive', 2)
# (u'wrote', 2)
# (u'institutes', 2)
# (u'assuring', 2)
# (u'expensive', 2)
# (u'secret', 2)
# (u'dialogue', 2)
# (u'schuller', 2)
# (u'reads', 2)
# (u'anymore', 2)
# (u'withdraw', 2)
# (u'customers', 2)
# (u'adversaries', 2)
# (u'couple', 2)
# (u'bit', 2)
# (u'disrepair', 2)
# (u'appalachia', 2)
# (u'vaccine', 2)
# (u'meehan', 2)
# (u'abusive', 2)
# (u'lesson', 2)
# (u'bolsters', 2)
# (u'gi', 2)
# (u'rewarding', 2)
# (u'depression', 2)
# (u'guidance', 2)
# (u'cripple', 2)
# (u'usa', 2)
# (u'tied', 2)
# (u'flew', 2)
# (u'university', 2)
# (u'interdependence', 2)
# (u'staying', 2)
# (u'smog', 2)
# (u'completely', 2)
# (u'1988', 2)
# (u'reversed', 2)
# (u'chemicals', 2)
# (u'bed', 2)
# (u'patients', 2)
# (u'cohen', 2)
# (u'russians', 2)
# (u'deny', 2)
# (u'controls', 2)
# (u'requirement', 2)
# (u'ends', 2)
# (u'unite', 2)
# (u'weapon', 2)
# (u'homework', 2)
# (u'habitat', 2)
# (u'salaries', 2)
# (u'host', 2)
# (u'perks', 2)
# (u'cells', 2)
# (u'percent;', 2)
# (u'four-year', 2)
# (u'eligible', 2)
# (u'regional', 2)
# (u'basics', 2)
# (u'reinvent', 2)
# (u'sterile', 2)
# (u'humility', 2)
# (u'celebration', 2)
# (u'ignoring', 2)
# (u'hurt', 2)
# (u'1996', 2)
# (u'benefited', 2)
# (u'leaner', 2)
# (u'mastering', 2)
# (u'tangle', 2)
# (u'dozen', 2)
# (u'visionary', 2)
# (u'shalt', 2)
# (u'bureaucracies', 2)
# (u'untapped', 2)
# (u'sanctuary', 2)
# (u'grader', 2)
# (u'pilot', 2)
# (u'inappropriate', 2)
# (u'handful', 2)
# (u'accident', 2)
# (u'expense', 2)
# (u'winski', 2)
# (u'recover', 2)
# (u'belongs', 2)
# (u'fraud', 2)
# (u'jennifer', 2)
# (u'drink', 2)
# (u'pose', 2)
# (u'palestinian', 2)
# (u'indonesia', 2)
# (u'low-', 2)
# (u'greatness', 2)
# (u'non-discrimination', 2)
# (u'enlist', 2)
# (u'fell', 2)
# (u'overdue', 2)
# (u"it'll", 2)
# (u'locke', 2)
# (u'16,000', 2)
# (u'st', 2)
# (u'typical', 2)
# (u'challenged', 2)
# (u'torch', 2)
# (u'worried', 2)
# (u'shays', 2)
# (u'lucius', 2)
# (u'ministry', 2)
# (u'transition', 2)
# (u'suspend', 2)
# (u'freeze', 2)
# (u'self-employed', 2)
# (u'illness', 2)
# (u'detect', 2)
# (u'foothold', 2)
# (u'un-american', 2)
# (u'jett', 2)
# (u'countless', 2)
# (u'operate', 2)
# (u'conclude', 2)
# (u'supercomputers', 2)
# (u'1989', 2)
# (u'understandings', 2)
# (u'policeman', 2)
# (u'y2k', 2)
# (u'package', 2)
# (u'harness', 2)
# (u'cycle', 2)
# (u'abuses', 2)
# (u"citizen's", 2)
# (u'equivalency', 2)
# (u'harry', 2)
# (u'promotes', 2)
# (u'movement', 2)
# (u'policemen', 2)
# (u'wisely', 2)
# (u'cherrey', 2)
# (u'23', 2)
# (u'solving', 2)
# (u'despair', 2)
# (u'base', 2)
# (u'warheads', 2)
# (u'welcome', 2)
# (u'uniforms', 2)
# (u'u.s', 2)
# (u'welfare;', 2)
# (u'kosovo', 2)
# (u'heavens', 2)
# (u'poisoned', 2)
# (u'gaps', 2)
# (u'barely', 2)
# (u'cheapest', 2)
# (u'dropping', 2)
# (u'pack', 2)
# (u'dime', 2)
# (u'zarfos', 2)
# (u'wiser', 2)
# (u'behave', 2)
# (u'limitless', 2)
# (u'bankruptcy', 2)
# (u'delta', 2)
# (u'unparalleled', 2)
# (u'confusing', 2)
# (u'squeeze', 2)
# (u'$1,000', 2)
# (u'train', 2)
# (u'degradation', 2)
# (u'holds', 2)
# (u'area', 2)
# (u'ratification', 2)
# (u'strategic', 2)
# (u'creator', 2)
# (u'overwhelming', 2)
# (u'limiting', 2)
# (u'afraid', 2)
# (u'agency', 2)
# (u'concerns', 2)
# (u'deploy', 2)
# (u'gather', 2)
# (u'irs', 2)
# (u'mean?', 2)
# (u'married', 2)
# (u'david', 2)
# (u'ensuring', 2)
# (u'volunteer', 2)
# (u'terrorist', 2)
# (u'crack', 2)
# (u'matched', 2)
# (u'sizes', 2)
# (u'trillion', 2)
# (u'line-item', 2)
# (u'"you', 2)
# (u'penny', 2)
# (u'85', 2)
# (u'schoolhouse', 2)
# (u'"the', 2)
# (u'craft', 2)
# (u'parole', 2)
# (u'dynamic', 1)
# (u'super-efficient', 1)
# (u'9,000', 1)
# (u'340', 1)
# (u'week--28', 1)
# (u"driver's", 1)
# (u"daughter's", 1)
# (u'opportunity--and', 1)
# (u'hide', 1)
# (u'solemn', 1)
# (u'revolutionize', 1)
# (u'represented', 1)
# (u'daughter', 1)
# (u'rests', 1)
# (u'museums', 1)
# (u'unwanted', 1)
# (u'criticism', 1)
# (u'forums', 1)
# (u'sarah', 1)
# (u'inner-cities', 1)
# (u'overhead', 1)
# (u'separated', 1)
# (u'high-wage', 1)
# (u'warn', 1)
# (u'employees;', 1)
# (u'working;', 1)
# (u'defuse', 1)
# (u'28-percent', 1)
# (u'attract', 1)
# (u'well-connected', 1)
# (u'machine', 1)
# (u'millimeter', 1)
# (u'lax', 1)
# (u'stronghold', 1)
# (u'green', 1)
# (u'uninsured', 1)
# (u'athletes', 1)
# (u'dollar--every', 1)
# (u'staff--generals', 1)
# (u'9', 1)
# (u"administration's", 1)
# (u'arrested', 1)
# (u'newport', 1)
# (u'eliminated;', 1)
# (u'all-abusive', 1)
# (u'families--and', 1)
# (u'backing', 1)
# (u'day:', 1)
# (u"water's", 1)
# (u'eternal', 1)
# (u'drug-free', 1)
# (u'atf', 1)
# (u'creates', 1)
# (u'thanking', 1)
# (u'"no', 1)
# (u'onto', 1)
# (u'inspectors', 1)
# (u'groundbreaking', 1)
# (u'too:', 1)
# (u'be:', 1)
# (u'corps--working', 1)
# (u'ordered', 1)
# (u'bitter', 1)
# (u'seniors--affordable', 1)
# (u'overseas--they', 1)
# (u'force--with', 1)
# (u'rates--let', 1)
# (u'prosperity:', 1)
# (u'consumer', 1)
# (u'reductions', 1)
# (u'endowment', 1)
# (u'lessons', 1)
# (u'ads--either', 1)
# (u'century--an', 1)
# (u'criticized', 1)
# (u'$10', 1)
# (u'bar', 1)
# (u'large-capacity', 1)
# (u'olympics', 1)
# (u'integrate', 1)
# (u'weak', 1)
# (u'33,000', 1)
# (u'dedication', 1)
# (u'games', 1)
# (u'tinge', 1)
# (u'widen', 1)
# (u'gleaming', 1)
# (u'targeting', 1)
# (u'falter', 1)
# (u'horrors', 1)
# (u'ceilings', 1)
# (u'stopping', 1)
# (u'flooding', 1)
# (u'remembering', 1)
# (u'hank', 1)
# (u'heartbroken', 1)
# (u'scribble', 1)
# (u'terrific', 1)
# (u'belfast', 1)
# (u'boot', 1)
# (u'evidenced', 1)
# (u'shoulder', 1)
# (u'unequivocally', 1)
# (u'results--proud', 1)
# (u'country:', 1)
# (u'51', 1)
# (u'deaf', 1)
# (u'unmistakable;', 1)
# (u'there--no', 1)
# (u'dear', 1)
# (u'attack;', 1)
# (u'fox', 1)
# (u'repression', 1)
# (u'209', 1)
# (u'clinton,"', 1)
# (u'attacks', 1)
# (u'combine', 1)
# (u'for?', 1)
# (u'incumbents', 1)
# (u'repairers', 1)
# (u'czech', 1)
# (u'us--the', 1)
# (u'peninsula', 1)
# (u'reduced-cost', 1)
# (u'peacemaker', 1)
# (u'crediting', 1)
# (u'discriminate', 1)
# (u'agreeing', 1)
# (u'intend', 1)
# (u'models', 1)
# (u'invested', 1)
# (u'pessimists', 1)
# (u'anti-ballistic', 1)
# (u'ahead;', 1)
# (u'someplace', 1)
# (u'technology--and', 1)
# (u'anti-pregnancy', 1)
# (u'medicare--a', 1)
# (u'2000;', 1)
# (u'discovering', 1)
# (u'shoot', 1)
# (u'emergencies', 1)
# (u'10-year', 1)
# (u'timor', 1)
# (u'stiffen', 1)
# (u'clouds', 1)
# (u'us--we', 1)
# (u'build--to', 1)
# (u'bars."', 1)
# (u'threshold', 1)
# (u'majors', 1)
# (u'celebrates', 1)
# (u'baseball', 1)
# (u"hadn't", 1)
# (u'teaches', 1)
# (u'here?', 1)
# (u'institute', 1)
# (u'studies', 1)
# (u'rededicate', 1)
# (u'patriots', 1)
# (u't.]', 1)
# (u'game;', 1)
# (u'union--not', 1)
# (u'envelope', 1)
# (u'lines--and', 1)
# (u'liberty."', 1)
# (u'conceal', 1)
# (u'my--my', 1)
# (u'pink', 1)
# (u'beat', 1)
# (u'[hussein]', 1)
# (u'recipients;', 1)
# (u'data', 1)
# (u'better--even', 1)
# (u'together--dreams', 1)
# (u'work--two', 1)
# (u'kazakhstan', 1)
# (u'undermines', 1)
# (u'downsizing', 1)
# (u'boats', 1)
# (u'outweigh', 1)
# (u'hastert', 1)
# (u'directing', 1)
# (u'entitlements', 1)
# (u'marine', 1)
# (u'learning;', 1)
# (u'programming', 1)
# (u'spoken', 1)
# (u'anymore;', 1)
# (u'reinvestment', 1)
# (u'raged', 1)
# (u'tragic', 1)
# (u'broadcast', 1)
# (u'push', 1)
# (u'representing', 1)
# (u'automakers', 1)
# (u'cards', 1)
# (u'formula:', 1)
# (u'13th', 1)
# (u'isolate', 1)
# (u'note', 1)
# (u'surf', 1)
# (u'iwo', 1)
# (u'four-word', 1)
# (u'detective', 1)
# (u'bigots', 1)
# (u'enriched', 1)
# (u'contracts', 1)
# (u'overworked', 1)
# (u'18-year-old', 1)
# (u'worries', 1)
# (u'fortify', 1)
# (u'corridors', 1)
# (u'encourages', 1)
# (u'chinese-american', 1)
# (u'anchored', 1)
# (u'clips', 1)
# (u'partisans', 1)
# (u'mission:', 1)
# (u'blame', 1)
# (u'concentrated', 1)
# (u'lifeline', 1)
# (u'expression', 1)
# (u'68', 1)
# (u'two-year', 1)
# (u'tornado', 1)
# (u'caring', 1)
# (u'stretch', 1)
# (u'$2,400', 1)
# (u'centerpiece', 1)
# (u'wake', 1)
# (u'commitment:', 1)
# (u'margin', 1)
# (u'curfews', 1)
# (u'couples', 1)
# (u'confident:', 1)
# (u'high-paying', 1)
# (u'ireland;', 1)
# (u'patchwork', 1)
# (u'fateful', 1)
# (u'zeros', 1)
# (u'engulfed', 1)
# (u'welfare--work', 1)
# (u'seams', 1)
# (u'zion', 1)
# (u'it--now', 1)
# (u'miraculous', 1)
# (u'endorsed', 1)
# (u'images', 1)
# (u'booming', 1)
# (u'dumps', 1)
# (u'ellis', 1)
# (u'recorded', 1)
# (u'families--', 1)
# (u'refundable', 1)
# (u'bono', 1)
# (u'communicate', 1)
# (u'tape', 1)
# (u'checkup', 1)
# (u'tie-breaking', 1)
# (u'diana', 1)
# (u'dislocated', 1)
# (u'assault-weapon', 1)
# (u'jones', 1)
# (u"lobbyists'", 1)
# (u'antiquated', 1)
# (u'irreversible', 1)
# (u"wasn't", 1)
# (u'aneurysm', 1)
# (u'restorer', 1)
# (u'engine', 1)
# (u"nato's", 1)
# (u'ill."', 1)
# (u"baseball's", 1)
# (u'proudly', 1)
# (u'post-cold', 1)
# (u'compel', 1)
# (u'rubber', 1)
# (u'emphysema', 1)
# (u'fuel-efficient', 1)
# (u'regardless', 1)
# (u'sector--and', 1)
# (u'bullets', 1)
# (u"saddam's", 1)
# (u'observers', 1)
# (u'mask', 1)
# (u'them--we', 1)
# (u'starting', 1)
# (u'deadline', 1)
# (u'talks', 1)
# (u'minors', 1)
# (u'a.m.e', 1)
# (u'handgun', 1)
# (u'midwest', 1)
# (u'highways', 1)
# (u'benjamin', 1)
# (u'built-in', 1)
# (u'principle:', 1)
# (u'milosevic', 1)
# (u'children--then', 1)
# (u'hubs', 1)
# (u'threads', 1)
# (u'vandenburg', 1)
# (u'infringe', 1)
# (u'streamline', 1)
# (u'self-evident', 1)
# (u'1946', 1)
# (u'languages', 1)
# (u'mysterious', 1)
# (u'chestnut', 1)
# (u'minority--of', 1)
# (u'waterways', 1)
# (u'cisneros', 1)
# (u'other--if', 1)
# (u'nineteen', 1)
# (u'guards', 1)
# (u'beautiful', 1)
# (u'bravely', 1)
# (u'meaner', 1)
# (u'needy', 1)
# (u'helium', 1)
# (u'goals:', 1)
# (u'lighting', 1)
# (u'childbearing', 1)
# (u'mexican', 1)
# (u'pray', 1)
# (u'action--action', 1)
# (u'inquiry', 1)
# (u'colleague', 1)
# (u'it:', 1)
# (u'mystery', 1)
# (u'truths', 1)
# (u'house"', 1)
# (u'status', 1)
# (u'here--another', 1)
# (u"dean's", 1)
# (u'solvent', 1)
# (u'six-fold', 1)
# (u'prejudice', 1)
# (u'$255', 1)
# (u'feed', 1)
# (u'genetically', 1)
# (u'shifted', 1)
# (u'"made', 1)
# (u'usa."', 1)
# (u'convinced', 1)
# (u'2020', 1)
# (u'treated', 1)
# (u'unrelenting', 1)
# (u'comrades', 1)
# (u'but--but', 1)
# (u'onset', 1)
# (u'deepening', 1)
# (u'cut--our', 1)
# (u'measured', 1)
# (u'salary', 1)
# (u'traditional', 1)
# (u'liberate', 1)
# (u'things--invest', 1)
# (u'carefully', 1)
# (u'you--only', 1)
# (u'$2', 1)
# (u'isolationist', 1)
# (u'intensify', 1)
# (u'boost', 1)
# (u'see--as', 1)
# (u'uses', 1)
# (u'injecting', 1)
# (u'explosion', 1)
# (u'thou', 1)
# (u'spirit:', 1)
# (u'police--and', 1)
# (u'world--creating', 1)
# (u'success;', 1)
# (u'generation--', 1)
# (u'advocating', 1)
# (u'solid', 1)
# (u'healthy', 1)
# (u'replaced', 1)
# (u'key;', 1)
# (u'clear;', 1)
# (u'energizing', 1)
# (u'flooded', 1)
# (u'frozen', 1)
# (u'accumulate', 1)
# (u'profoundly', 1)
# (u'vouchers--rent', 1)
# (u'vigilant', 1)
# (u'further--to', 1)
# (u'ahead."', 1)
# (u'program--two', 1)
# (u'bin', 1)
# (u'victims', 1)
# (u'defies', 1)
# (u'unlimited', 1)
# (u'wrong--those', 1)
# (u'work--that', 1)
# (u'abundantly', 1)
# (u'delegation', 1)
# (u'sanity', 1)
# (u'pet', 1)
# (u'adoptive', 1)
# (u'will--', 1)
# (u'full-scale', 1)
# (u'"more', 1)
# (u'dismantle', 1)
# (u'here."', 1)
# (u'experiences', 1)
# (u'tenants', 1)
# (u"zarfos--they're", 1)
# (u'osama', 1)
# (u'america--in', 1)
# (u"forces'", 1)
# (u'blueprint', 1)
# (u'jewish', 1)
# (u'link', 1)
# (u'ling', 1)
# (u'fades', 1)
# (u'hair', 1)
# (u'principles:', 1)
# (u'"e"', 1)
# (u'foresight', 1)
# (u'tocqueville', 1)
# (u'boomers', 1)
# (u'300,000', 1)
# (u'reopening', 1)
# (u'252,000', 1)
# (u'nationalism', 1)
# (u'$400', 1)
# (u'fears', 1)
# (u'weight;', 1)
# (u'spectators', 1)
# (u"bricklayer's", 1)
# (u'e', 1)
# (u'gripped', 1)
# (u'jason', 1)
# (u'steve', 1)
# (u'medicaid--not', 1)
# (u'stave', 1)
# (u'intensive', 1)
# (u'pro-family', 1)
# (u'andersons', 1)
# (u'michael', 1)
# (u'deals', 1)
# (u'barbara', 1)
# (u'licenses', 1)
# (u"patient's", 1)
# (u'plays', 1)
# (u'cell', 1)
# (u'again--quickly', 1)
# (u'life-enhancing', 1)
# (u'distressed', 1)
# (u'grander', 1)
# (u'me--a', 1)
# (u'stabilization', 1)
# (u'squarely', 1)
# (u'limb', 1)
# (u'patrol', 1)
# (u'recalling', 1)
# (u'testified', 1)
# (u'symbolizing', 1)
# (u'deregulate', 1)
# (u'iii', 1)
# (u'rampant', 1)
# (u'reserved', 1)
# (u'job-training', 1)
# (u'supervised', 1)
# (u'fare', 1)
# (u'ronald', 1)
# (u'class--double', 1)
# (u'alike--to', 1)
# (u'persuaded', 1)
# (u'region;', 1)
# (u'struggle"', 1)
# (u'tony', 1)
# (u'ignite', 1)
# (u'contain--more', 1)
# (u'outer', 1)
# (u'lech', 1)
# (u'401-k', 1)
# (u'satellites', 1)
# (u'pools', 1)
# (u'lung', 1)
# (u'700', 1)
# (u'aggravated', 1)
# (u'sands', 1)
# (u'age."', 1)
# (u'sexual', 1)
# (u'armor', 1)
# (u'achievements', 1)
# (u'eighty', 1)
# (u'sustainable', 1)
# (u'ridge', 1)
# (u'20,000', 1)
# (u'misuse', 1)
# (u'unworthy', 1)
# (u'sadly', 1)
# (u'flourish', 1)
# (u'new:', 1)
# (u"europe's", 1)
# (u'riches', 1)
# (u'injured', 1)
# (u'bare', 1)
# (u'medicaid--these', 1)
# (u'1.4', 1)
# (u'rules-based', 1)
# (u'accountants', 1)
# (u'business;', 1)
# (u'draws', 1)
# (u'medal', 1)
# (u'cultures:', 1)
# (u'placement', 1)
# (u'airlift', 1)
# (u'halting', 1)
# (u'litigation', 1)
# (u'grabbed', 1)
# (u'canyons', 1)
# (u'burglary', 1)
# (u'tactics', 1)
# (u'chips', 1)
# (u'default', 1)
# (u'gibson', 1)
# (u'if--if', 1)
# (u'knowing', 1)
# (u'lives--with', 1)
# (u'triples', 1)
# (u"utah's", 1)
# (u'nominees', 1)
# (u'stories', 1)
# (u'industries', 1)
# (u'asked:', 1)
# (u'chamber:', 1)
# (u'together;', 1)
# (u'congresses', 1)
# (u'cowards', 1)
# (u'living?"', 1)
# (u"lady's", 1)
# (u'painted', 1)
# (u'assert', 1)
# (u'maim', 1)
# (u'kicks', 1)
# (u'wild', 1)
# (u'attend;', 1)
# (u"fda's", 1)
# (u'censorship;', 1)
# (u'inch', 1)
# (u'fierce', 1)
# (u'groans', 1)
# (u'newest', 1)
# (u'looked', 1)
# (u'moments', 1)
# (u'utah', 1)
# (u"who'd", 1)
# (u'soft', 1)
# (u'immunizations', 1)
# (u'fending', 1)
# (u'export', 1)
# (u'passion', 1)
# (u'all--raising', 1)
# (u'gained', 1)
# (u'monthly', 1)
# (u'one--asking', 1)
# (u'taxpaying', 1)
# (u'cigarettes:', 1)
# (u'assess', 1)
# (u'van', 1)
# (u'frustrations', 1)
# (u'higher-crime', 1)
# (u'achievement;', 1)
# (u'serbia', 1)
# (u'transformed', 1)
# (u'administrators', 1)
# (u'wealthier', 1)
# (u'cpl', 1)
# (u'clean-energy', 1)
# (u'outgun', 1)
# (u'infants', 1)
# (u'nurses', 1)
# (u'tb', 1)
# (u'flight', 1)
# (u'46', 1)
# (u'tenth', 1)
# (u'42', 1)
# (u"we're--excuse", 1)
# (u'news:', 1)
# (u'cerebral', 1)
# (u'does."', 1)
# (u'crises', 1)
# (u'up?', 1)
# (u'repay--now', 1)
# (u'immunized', 1)
# (u'solution', 1)
# (u'americorps--while', 1)
# (u'ups', 1)
# (u'chew', 1)
# (u'phones', 1)
# (u'thunder', 1)
# (u'meals', 1)
# (u'fingers', 1)
# (u'specialist', 1)
# (u'offenses', 1)
# (u'interdependent', 1)
# (u'year--every', 1)
# (u'items', 1)
# (u'nation."', 1)
# (u'shortened', 1)
# (u'subsided', 1)
# (u'patience', 1)
# (u'best-selling', 1)
# (u'chooses', 1)
# (u'apprenticeships', 1)
# (u'escapism', 1)
# (u'md', 1)
# (u'refusing', 1)
# (u'message--without', 1)
# (u'in."', 1)
# (u'indicates', 1)
# (u'rescue', 1)
# (u'glenn!', 1)
# (u"franklin's", 1)
# (u'badly', 1)
# (u'biting', 1)
# (u'wins', 1)
# (u"tubman's", 1)
# (u'pro-work', 1)
# (u'reentered', 1)
# (u'employers--and', 1)
# (u'vaclav', 1)
# (u'eventually', 1)
# (u'tourist', 1)
# (u'enrich', 1)
# (u'toughest-ever', 1)
# (u'potatoes', 1)
# (u'[russell]', 1)
# (u'lillie', 1)
# (u'prohibit', 1)
# (u"we'd", 1)
# (u'enormity', 1)
# (u'balanced-budget', 1)
# (u'unholy', 1)
# (u'george', 1)
# (u'upbringing', 1)
# (u'assures', 1)
# (u'starts', 1)
# (u'deadwood', 1)
# (u'99.9', 1)
# (u'collapse', 1)
# (u'japanese', 1)
# (u'endure', 1)
# (u'lull', 1)
# (u'concrete', 1)
# (u'do?', 1)
# (u'airlines--will', 1)
# (u'haitian-americans', 1)
# (u"park--it's", 1)
# (u'entry', 1)
# (u'prosperity;', 1)
# (u'notion', 1)
# (u'advisory', 1)
# (u'inspire', 1)
# (u'ovarian', 1)
# (u'availability', 1)
# (u"deficit's", 1)
# (u'challengers', 1)
# (u'rancor--we', 1)
# (u'25,000', 1)
# (u'progress;', 1)
# (u'them:', 1)
# (u'architecture', 1)
# (u'isolation', 1)
# (u'ethical', 1)
# (u'insurance?', 1)
# (u'cloning', 1)
# (u'truancy', 1)
# (u'pressures', 1)
# (u'felony', 1)
# (u'wear', 1)
# (u'tuzla', 1)
# (u'shrinks', 1)
# (u'arsenals;', 1)
# (u'flexible', 1)
# (u'warmth', 1)
# (u'deeper', 1)
# (u'169', 1)
# (u'able-bodied', 1)
# (u'step:', 1)
# (u'ugly', 1)
# (u'"a', 1)
# (u'child-support', 1)
# (u'most-sacred', 1)
# (u'bullet--used', 1)
# (u'--to', 1)
# (u'forsaking', 1)
# (u'catholic', 1)
# (u'workforce', 1)
# (u'provisions:', 1)
# (u'faiths', 1)
# (u'hispanic', 1)
# (u'studying', 1)
# (u'barons', 1)
# (u'unified', 1)
# (u'traditions', 1)
# (u'unfair', 1)
# (u'overcoming', 1)
# (u'proposes', 1)
# (u'hills', 1)
# (u'america--a', 1)
# (u'addicts', 1)
# (u'performance', 1)
# (u'58', 1)
# (u'alice', 1)
# (u'remind', 1)
# (u'country;', 1)
# (u"war's", 1)
# (u'christmas', 1)
# (u'co-pays', 1)
# (u'rosas', 1)
# (u'theirs', 1)
# (u'afternoon', 1)
# (u'opic', 1)
# (u'froze', 1)
# (u'bound', 1)
# (u'thankful', 1)
# (u'raises', 1)
# (u'1990s', 1)
# (u'rounds', 1)
# (u'why?', 1)
# (u'width', 1)
# (u'physicists', 1)
# (u'150,000', 1)
# (u'intolerance', 1)
# (u'captive', 1)
# (u'dominicans', 1)
# (u'emotional', 1)
# (u'grenades', 1)
# (u'150', 1)
# (u'revitalize', 1)
# (u'brings', 1)
# (u'tie', 1)
# (u'roll', 1)
# (u'mentor', 1)
# (u'gallon--the', 1)
# (u'professional', 1)
# (u'coastlines', 1)
# (u'finger-pointing', 1)
# (u'nonproliferation', 1)
# (u'religion', 1)
# (u'questions:', 1)
# (u'roadless', 1)
# (u'automobiles', 1)
# (u'aggressively', 1)
# (u'impressive', 1)
# (u'die', 1)
# (u'subway', 1)
# (u'they--if', 1)
# (u'grandparent?', 1)
# (u'discover', 1)
# (u'affiliation', 1)
# (u'targets', 1)
# (u"thing's", 1)
# (u'surplus?', 1)
# (u'somalia', 1)
# (u'bearers', 1)
# (u'prosperity--which', 1)
# (u'collateral', 1)
# (u'fend', 1)
# (u'people--have', 1)
# (u'earthquake', 1)
# (u'here:', 1)
# (u'exams', 1)
# (u'priceless', 1)
# (u'respite', 1)
# (u'emerge', 1)
# (u'paralyzed', 1)
# (u'aids;', 1)
# (u'car', 1)
# (u'soul', 1)
# (u'[martin', 1)
# (u'nowhere', 1)
# (u'lucky', 1)
# (u'apprenticeship', 1)
# (u'6th', 1)
# (u'marshal', 1)
# (u'embassies', 1)
# (u'record;', 1)
# (u'conversations', 1)
# (u'touched', 1)
# (u'corners', 1)
# (u'decade:', 1)
# (u'importation', 1)
# (u'significantly', 1)
# (u'cyberspace', 1)
# (u'tensions', 1)
# (u'formula', 1)
# (u'challenge:', 1)
# (u'dispatcher', 1)
# (u'virtues;', 1)
# (u'65--the', 1)
# (u'america--and', 1)
# (u'stuck', 1)
# (u'indicate', 1)
# (u'non-citizens', 1)
# (u'hum', 1)
# (u'specialists', 1)
# (u'professionals', 1)
# (u'14', 1)
# (u'recruit', 1)
# (u'buried', 1)
# (u'area--and', 1)
# (u'equipment', 1)
# (u'second-graders', 1)
# (u'trafficking', 1)
# (u'"sacred', 1)
# (u'science;', 1)
# (u'rating', 1)
# (u'arrears', 1)
# (u'corner', 1)
# (u'flood;', 1)
# (u'given--republicans', 1)
# (u'defenders', 1)
# (u'multimillion', 1)
# (u'source;', 1)
# (u'worrying', 1)
# (u'ignored', 1)
# (u'world,"', 1)
# (u'declares', 1)
# (u'janet', 1)
# (u'permeates', 1)
# (u'cleaning', 1)
# (u'biofuels', 1)
# (u'letterman', 1)
# (u'probation', 1)
# (u'brightly', 1)
# (u'accounts--to', 1)
# (u'50,000', 1)
# (u'nationalist', 1)
# (u'barry', 1)
# (u'vacation', 1)
# (u'mary', 1)
# (u'andrew', 1)
# (u'polly', 1)
# (u'slumber', 1)
# (u'orientation', 1)
# (u'endowed', 1)
# (u'strain', 1)
# (u'kenya', 1)
# (u'wage--can', 1)
# (u'narco-traffickers', 1)
# (u'$290', 1)
# (u'"america:', 1)
# (u'independents', 1)
# (u'ira', 1)
# (u'special--because', 1)
# (u'rose', 1)
# (u'eisenhower', 1)
# (u'heightened', 1)
# (u'jews', 1)
# (u'credit;', 1)
# (u'memories', 1)
# (u'mastered', 1)
# (u'continue--we', 1)
# (u'pastors', 1)
# (u'thailand', 1)
# (u'fraying', 1)
# (u'hopefulness;', 1)
# (u'blessed', 1)
# (u'spinal', 1)
# (u'happening', 1)
# (u'log', 1)
# (u'mauser', 1)
# (u'desert', 1)
# (u'cultures', 1)
# (u'deposits', 1)
# (u'shrunk', 1)
# (u'shapers', 1)
# (u'brain', 1)
# (u'pull', 1)
# (u'dominican', 1)
# (u'bipartisanship', 1)
# (u'american--social', 1)
# (u'600', 1)
# (u'bishop', 1)
# (u'credibility', 1)
# (u'self-reliance', 1)
# (u'lapel', 1)
# (u'drive-through', 1)
# (u'again--but', 1)
# (u'initiative--to', 1)
# (u'kuwait', 1)
# (u'right-to-know', 1)
# (u'government-funded', 1)
# (u'forged', 1)
# (u'shattered', 1)
# (u'america--over', 1)
# (u'realities', 1)
# (u'chartering', 1)
# (u'hill', 1)
# (u'activities', 1)
# (u'louis', 1)
# (u'those--one', 1)
# (u'burger', 1)
# (u'aptly', 1)
# (u'that--together', 1)
# (u'most--', 1)
# (u'prevailed', 1)
# (u'responded', 1)
# (u'combating', 1)
# (u'discipline--then', 1)
# (u'horrified', 1)
# (u'240', 1)
# (u"lord's", 1)
# (u'know?', 1)
# (u'aimed', 1)
# (u'iraqi', 1)
# (u'generate', 1)
# (u'pearl', 1)
# (u'lowering', 1)
# (u'emission', 1)
# (u'21st-century', 1)
# (u'done--to', 1)
# (u'strategies', 1)
# (u'challenging', 1)
# (u'bus', 1)
# (u'hand-in-hand', 1)
# (u'gallon', 1)
# (u'steps----to', 1)
# (u'imminent', 1)
# (u'ratifies', 1)
# (u'growth--as', 1)
# (u'crippling', 1)
# (u'renewing', 1)
# (u'threatens', 1)
# (u'earning;', 1)
# (u'essence', 1)
# (u'outraged', 1)
# (u'21', 1)
# (u'reflected', 1)
# (u'it;', 1)
# (u'soundness', 1)
# (u'2,600', 1)
# (u'turndown', 1)
# (u'courses', 1)
# (u'predators', 1)
# (u'gender', 1)
# (u'house;', 1)
# (u'system--the', 1)
# (u'assignments', 1)
# (u'longtime', 1)
# (u'bask', 1)
# (u'"eitc"', 1)
# (u"freedom's", 1)
# (u'funded--50,000', 1)
# (u'relate', 1)
# (u'sympathy', 1)
# (u"you'd", 1)
# (u'passes', 1)
# (u'2025;', 1)
# (u'power:', 1)
# (u'more-affordable', 1)
# (u'grace', 1)
# (u'reflection', 1)
# (u'courage--and', 1)
# (u'bio-based', 1)
# (u'76', 1)
# (u'stands', 1)
# (u'charitable', 1)
# (u'dragged', 1)
# (u'rule:', 1)
# (u'league', 1)
# (u'$3', 1)
# (u'test-prep', 1)
# (u'saluting', 1)
# (u'desert;', 1)
# (u'doubles', 1)
# (u'relentless', 1)
# (u'gravest', 1)
# (u'arm', 1)
# (u'repairs', 1)
# (u'binds', 1)
# (u'prohibits', 1)
# (u'threat:', 1)
# (u'riddled', 1)
# (u'superfund', 1)
# (u'rosa', 1)
# (u'openness', 1)
# (u'arsenal', 1)
# (u'transformations', 1)
# (u'ensured', 1)
# (u'reason:', 1)
# (u'champion', 1)
# (u'disruptive', 1)
# (u'fleet', 1)
# (u'birthright', 1)
# (u'eve', 1)
# (u'$20,000', 1)
# (u'centennial', 1)
# (u'president--the', 1)
# (u'fairer', 1)
# (u'2032', 1)
# (u'work--and', 1)
# (u'things--', 1)
# (u'credentials', 1)
# (u'home--with', 1)
# (u'children--', 1)
# (u'methods', 1)
# (u'gateway', 1)
# (u"russia's", 1)
# (u'temple', 1)
# (u'concealed', 1)
# (u'entrepreneurs', 1)
# (u'seeing', 1)
# (u'drifted', 1)
# (u'wrote:', 1)
# (u'weakness;', 1)
# (u'boys', 1)
# (u'homeownership', 1)
# (u'characteristic', 1)
# (u'highlight', 1)
# (u'five-day', 1)
# (u'problem:', 1)
# (u'liberalize', 1)
# (u'buck', 1)
# (u'gears', 1)
# (u'genome', 1)
# (u"gore's", 1)
# (u'pesticides', 1)
# (u'fugitives', 1)
# (u'chechnya;', 1)
# (u'she--will', 1)
# (u'gang', 1)
# (u'mainstream', 1)
# (u'together--one', 1)
# (u'"long', 1)
# (u'fibrosis;', 1)
# (u'rearing', 1)
# (u'traveling', 1)
# (u'hungary', 1)
# (u'honors', 1)
# (u'unavailable', 1)
# (u'anthem', 1)
# (u'industrialized', 1)
# (u'oars', 1)
# (u'indivisible', 1)
# (u'inalienable', 1)
# (u'all--that', 1)
# (u'historically', 1)
# (u'$20', 1)
# (u'crowe--have', 1)
# (u'--especially', 1)
# (u'dedicates', 1)
# (u'arafat', 1)
# (u'lock', 1)
# (u'daring', 1)
# (u'class;', 1)
# (u'shalikashvili', 1)
# (u'skeletal', 1)
# (u'bind', 1)
# (u'well-insured', 1)
# (u'program--chip--so', 1)
# (u'looks', 1)
# (u'yesterdays', 1)
# (u'flex', 1)
# (u'systems--', 1)
# (u'insisting', 1)
# (u'trimmed', 1)
# (u'should--i', 1)
# (u'enforceable', 1)
# (u'thriving', 1)
# (u'integrated', 1)
# (u'percent--of', 1)
# (u'afterward', 1)
# (u'dismantled', 1)
# (u'fascism', 1)
# (u'conversation', 1)
# (u'cut--a', 1)
# (u'touring', 1)
# (u'drastic', 1)
# (u'(r-ariz.)', 1)
# (u'jima', 1)
# (u'chemotherapy', 1)
# (u'gear', 1)
# (u'power--no', 1)
# (u'ever--to', 1)
# (u'pakistan;', 1)
# (u'infectious', 1)
# (u'1.1', 1)
# (u'mothers--and', 1)
# (u'linked', 1)
# (u'competency', 1)
# (u'children?', 1)
# (u'hire--in', 1)
# (u'passed--220,000', 1)
# (u'houston', 1)
# (u'$180', 1)
# (u'prosecute', 1)
# (u'intellectually', 1)
# (u'stripes', 1)
# (u'champions', 1)
# (u'consecutive', 1)
# (u'streamlined', 1)
# (u'people--we', 1)
# (u'excesses', 1)
# (u'citizens--and', 1)
# (u'framers', 1)
# (u'chairmen', 1)
# (u'faith-based', 1)
# (u'joy', 1)
# (u'agencies', 1)
# (u'asunder', 1)
# (u'are;', 1)
# (u'invites', 1)
# (u'web--', 1)
# (u'earning', 1)
# (u'reexamine', 1)
# (u'fourth-graders', 1)
# (u'tutor', 1)
# (u'trips--all', 1)
# (u'carter', 1)
# (u'schools--or', 1)
# (u'minority--but', 1)
# (u'standards--not', 1)
# (u'soft-money', 1)
# (u'exhorted', 1)
# (u'privileged', 1)
# (u'well--by', 1)
# (u'overcrowded', 1)
# (u'stay-at-home', 1)
# (u'disrupted', 1)
# (u'away--now', 1)
# (u'yasir', 1)
# (u'1,100', 1)
# (u'43', 1)
# (u'rooms', 1)
# (u'states--to', 1)
# (u'years--is', 1)
# (u'attractive', 1)
# (u'earthquakes', 1)
# (u'vibrant', 1)
# (u'roth', 1)
# (u'sarajevo', 1)
# (u'page', 1)
# (u'"what', 1)
# (u'democracies--like', 1)
# (u'startling', 1)
# (u'selecting', 1)
# (u'genome--the', 1)
# (u'universe', 1)
# (u'dependence', 1)
# (u'dependency', 1)
# (u'sweat', 1)
# (u'13-year-old', 1)
# (u'103rd', 1)
# (u'charities', 1)
# (u'fired', 1)
# (u'should--we', 1)
# (u'fastest-growing', 1)
# (u'overtime', 1)
# (u'insured', 1)
# (u'lloyd', 1)
# (u'bug', 1)
# (u'assets', 1)
# (u'lynn', 1)
# (u'deporting', 1)
# (u'corporation', 1)
# (u'forests', 1)
# (u'self-government', 1)
# (u'4.25', 1)
# (u'percent--40', 1)
# (u'aggression', 1)
# (u'bureaucrats', 1)
# (u'slowest', 1)
# (u'lure', 1)
# (u'peace-loving', 1)
# (u'harriet', 1)
# (u'bank--and', 1)
# (u'disciplines', 1)
# (u'10,000-page', 1)
# (u'airmen', 1)
# (u'"judicial', 1)
# (u"parents'", 1)
# (u'deadbeat', 1)
# (u'discipline;', 1)
# (u'conditions;', 1)
# (u'swearing', 1)
# (u'audience--i', 1)
# (u'unit', 1)
# (u'old-fashioned', 1)
# (u'aaron', 1)
# (u'tenant', 1)
# (u'advocacy', 1)
# (u"affiliation--we've", 1)
# (u'pollute', 1)
# (u'household', 1)
# (u'confidential', 1)
# (u'livable', 1)
# (u'potential:', 1)
# (u'beauty', 1)
# (u'weapons;', 1)
# (u'types', 1)
# (u'lifesaving', 1)
# (u'choking', 1)
# (u'heal', 1)
# (u'disease--in', 1)
# (u'rewarded', 1)
# (u'kosovo--to', 1)
# (u'unemployed', 1)
# (u'bank', 1)
# (u'rhetoric', 1)
# (u'detroit', 1)
# (u'signing', 1)
# (u'environmentally-sustainable', 1)
# (u'crime:', 1)
# (u'tempting', 1)
# (u"senate'", 1)
# (u'philosophical', 1)
# (u'thick', 1)
# (u'olds', 1)
# (u'bosnia----', 1)
# (u'tool', 1)
# (u'negotiating', 1)
# (u'threats--while', 1)
# (u'energy-efficient', 1)
# (u'sportsmen', 1)
# (u'echoed', 1)
# (u'town."', 1)
# (u'eagerly', 1)
# (u'peers', 1)
# (u'tanzania', 1)
# (u'competitors', 1)
# (u'$30-billion', 1)
# (u'pope', 1)
# (u'spurred', 1)
# (u'attempts', 1)
# (u'peddle', 1)
# (u'important:', 1)
# (u'reaffirm', 1)
# (u'explain', 1)
# (u'bust', 1)
# (u'bush', 1)
# (u'rich', 1)
# (u'warmest', 1)
# (u'blinking', 1)
# (u'swept', 1)
# (u'sensitivity', 1)
# (u'malaria', 1)
# (u'artificial', 1)
# (u'mug', 1)
# (u'succeeding', 1)
# (u'occupational', 1)
# (u'face:', 1)
# (u'ill', 1)
# (u'irresponsible', 1)
# (u'administrations', 1)
# (u'energy--and', 1)
# (u'puts', 1)
# (u'now:', 1)
# (u'basin', 1)
# (u'riley', 1)
# (u'exception', 1)
# (u'conviction', 1)
# (u'ground-breaking', 1)
# (u'accounts--usa', 1)
# (u'metropolitan', 1)
# (u'said:', 1)
# (u'"mrs', 1)
# (u'moderate-income', 1)
# (u'babies', 1)
# (u'nih', 1)
# (u'nothing--nothing--is', 1)
# (u'ownership', 1)
# (u'edinboro', 1)
# (u'$1,100', 1)
# (u'inherit', 1)
# (u'alabama', 1)
# (u'outlived', 1)
# (u'star-spangled', 1)
# (u'fifth-grade', 1)
# (u'electronically', 1)
# (u'handshake', 1)
# (u'stray', 1)
# (u'emphasis', 1)
# (u'beloved', 1)
# (u'goals--$51', 1)
# (u'survival', 1)
# (u'retreat', 1)
# (u'53', 1)
# (u'attorney', 1)
# (u'appliances', 1)
# (u'clash', 1)
# (u'immunization', 1)
# (u'proposed--and', 1)
# (u'restructuring', 1)
# (u'woodrow', 1)
# (u'post', 1)
# (u'horizon', 1)
# (u'real--which', 1)
# (u'cracking', 1)
# (u'formerly', 1)
# (u'czar', 1)
# (u'amidst', 1)
# (u'$200', 1)
# (u'dead', 1)
# (u'protestant', 1)
# (u'inside', 1)
# (u'devices', 1)
# (u'bombing--now', 1)
# (u'$110', 1)
# (u'covers', 1)
# (u'fatherhood', 1)
# (u'marking', 1)
# (u'pledging', 1)
# (u"you'll", 1)
# (u'1993--these', 1)
# (u'palms', 1)
# (u'propelling', 1)
# (u'berlin', 1)
# (u'emerging', 1)
# (u'deliveries', 1)
# (u'theaters', 1)
# (u'government:', 1)
# (u'vet', 1)
# (u'standard:', 1)
# (u'congregation', 1)
# (u'centralized', 1)
# (u'minute', 1)
# (u'keepers', 1)
# (u'olympic', 1)
# (u'findings', 1)
# (u'pregnancies', 1)
# (u'b-1b', 1)
# (u'helpless', 1)
# (u'one:', 1)
# (u'dust;', 1)
# (u'shares', 1)
# (u'inauguration', 1)
# (u'thirty', 1)
# (u'bob', 1)
# (u'reclaim', 1)
# (u'penalizes', 1)
# (u'lending', 1)
# (u'verge', 1)
# (u'fbi', 1)
# (u'me--fathers', 1)
# (u'entrance', 1)
# (u'1,200', 1)
# (u'communities;', 1)
# (u'non-member', 1)
# (u'semi-automatic', 1)
# (u'crazy', 1)
# (u'fortunes', 1)
# (u'future:', 1)
# (u'pine', 1)
# (u'security--and', 1)
# (u'springfield', 1)
# (u'membership', 1)
# (u'peacemakers', 1)
# (u'wheelchair', 1)
# (u'switch', 1)
# (u'supplemented', 1)
# (u'amazing', 1)
# (u'1957', 1)
# (u'term', 1)
# (u'unauthorized', 1)
# (u'repairer', 1)
# (u'trouble!', 1)
# (u'doctrine', 1)
# (u'ships;', 1)
# (u"parent's", 1)
# (u'it--requiring', 1)
# (u'3rd', 1)
# (u'12-year-old', 1)
# (u'showroom', 1)
# (u'bill--longer', 1)
# (u'adoptions', 1)
# (u'watts', 1)
# (u'us--i', 1)
# (u'best-known', 1)
# (u'nonprofit', 1)
# (u'waited', 1)
# (u'destined', 1)
# (u'soaring', 1)
# (u'misfortune', 1)
# (u'caught', 1)
# (u'technology--all', 1)
# (u'friend', 1)
# (u'appointees', 1)
# (u'eliminated', 1)
# (u'optimism', 1)
# (u'drugs."', 1)
# (u'reno', 1)
# (u'nominating', 1)
# (u'conversion', 1)
# (u'illness:', 1)
# (u'ban--we', 1)
# (u'underemployed', 1)
# (u'bill--to', 1)
# (u'flawlessly', 1)
# (u'five-hour', 1)
# (u'benefits;', 1)
# (u'nightmare', 1)
# (u'walking', 1)
# (u'eighth-graders', 1)
# (u'merit', 1)
# (u'bright', 1)
# (u'aggressive', 1)
# (u'specifically', 1)
# (u'daily', 1)
# (u'energy-saving', 1)
# (u"'til", 1)
# (u'neighbors;', 1)
# (u'prosecutions', 1)
# (u'unmarried', 1)
# (u'barring', 1)
# (u'reformers', 1)
# (u'trade:', 1)
# (u"bosnia's", 1)
# (u'therapies', 1)
# (u'screen', 1)
# (u'college--just', 1)
# (u'recovered', 1)
# (u'[christopher]', 1)
# (u'boat', 1)
# (u'crime-mapping', 1)
# (u'children--if', 1)
# (u'proven', 1)
# (u'sow', 1)
# (u'pettiness', 1)
# (u'engineering', 1)
# (u'ideals;', 1)
# (u'conferences', 1)
# (u'worry', 1)
# (u'heirs', 1)
# (u'cancer--and', 1)
# (u'defy', 1)
# (u'renewable', 1)
# (u'weakened', 1)
# (u'toxics', 1)
# (u'grounded', 1)
# (u'verse', 1)
# (u'struck', 1)
# (u'reformed', 1)
# (u'miracle', 1)
# (u'obligation--', 1)
# (u"couldn't", 1)
# (u'this--none', 1)
# (u'equivalent', 1)
# (u'dictators', 1)
# (u'crafting', 1)
# (u'inviting', 1)
# (u'thrive', 1)
# (u'iran;', 1)
# (u'gregory', 1)
# (u'hunters', 1)
# (u'quietly', 1)
# (u'burning', 1)
# (u'spreading', 1)
# (u"community's", 1)
# (u'modernizes', 1)
# (u'decision--not', 1)
# (u'stark', 1)
# (u'decisive', 1)
# (u'jackets', 1)
# (u'fast-track', 1)
# (u'hurricanes', 1)
# (u'cords', 1)
# (u'bentsen', 1)
# (u'arabs', 1)
# (u'deep', 1)
# (u'rates;', 1)
# (u'inspections', 1)
# (u'4.3', 1)
# (u'live--and', 1)
# (u'americans?', 1)
# (u'decorated', 1)
# (u'repay', 1)
# (u'pta', 1)
# (u'fervor', 1)
# (u'straightforward', 1)
# (u'college;', 1)
# (u'salmonella', 1)
# (u'strand', 1)
# (u'dictatorship', 1)
# (u'depestre', 1)
# (u'companies--working', 1)
# (u'are--two', 1)
# (u'misread', 1)
# (u'answers', 1)
# (u'beacon', 1)
# (u'constituency', 1)
# (u'non-nato', 1)
# (u'brutal', 1)
# (u'skyrocket', 1)
# (u'tax-free', 1)
# (u'marriages', 1)
# (u'time--nearly', 1)
# (u'more--most', 1)
# (u'campolo', 1)
# (u'broke', 1)
# (u'glad', 1)
# (u'$1,500', 1)
# (u'opportunity?', 1)
# (u'justice."', 1)
# (u'he--or', 1)
# (u'unshakable', 1)
# (u'leader--stand', 1)
# (u'deluge', 1)
# (u'embark', 1)
# (u'veterans;', 1)
# (u'smiling', 1)
# (u'absence', 1)
# (u'walls', 1)
# (u'e-rate', 1)
# (u'today,"', 1)
# (u'repayment', 1)
# (u'undertake', 1)
# (u'$1.5', 1)
# (u'unsurpassed', 1)
# (u'wedlock', 1)
# (u'robert', 1)
# (u'salute', 1)
# (u'enforcing', 1)
# (u'diversity--we', 1)
# (u'revival', 1)
# (u'tab', 1)
# (u'story', 1)
# (u'financed', 1)
# (u'store', 1)
# (u'$8', 1)
# (u'costs:', 1)
# (u'dispensed', 1)
# (u'unbroken', 1)
# (u'stale', 1)
# (u'angeles;', 1)
# (u'recognizing', 1)
# (u'u.n', 1)
# (u'loopholes', 1)
# (u'unwed', 1)
# (u'thomas', 1)
# (u'there:', 1)
# (u'10-point', 1)
# (u'headlines', 1)
# (u'giant', 1)
# (u'california;', 1)
# (u'pretty', 1)
# (u'straight-a', 1)
# (u'hiv', 1)
# (u'banned', 1)
# (u'ninth', 1)
# (u'$1000', 1)
# (u'regulations?', 1)
# (u'dump', 1)
# (u'spangled', 1)
# (u'capps', 1)
# (u'excellence;', 1)
# (u'bronze', 1)
# (u'full-time', 1)
# (u'license', 1)
# (u'small-business', 1)
# (u'context', 1)
# (u'shortsighted', 1)
# (u'liked', 1)
# (u'hackers', 1)
# (u'sammy', 1)
# (u'ensures', 1)
# (u'lets', 1)
# (u'gay', 1)
# (u'towns', 1)
# (u'areas--minimum', 1)
# (u'behavior', 1)
# (u'community--investing', 1)
# (u'burdensome', 1)
# (u'ideologies', 1)
# (u'decency', 1)
# (u'residents', 1)
# (u'poland', 1)
# (u'cheer', 1)
# (u'meanest', 1)
# (u'law-enforcement', 1)
# (u'interests;', 1)
# (u'excluding', 1)
# (u'arthur', 1)
# (u'd.c', 1)
# (u'serves', 1)
# (u'1917', 1)
# (u'pen', 1)
# (u'slash', 1)
# (u'taught:', 1)
# (u'robbery', 1)
# (u'first-time', 1)
# (u'lasts', 1)
# (u'wildlife', 1)
# (u'completing', 1)
# (u'youthful', 1)
# (u'militarily', 1)
# (u'sonny', 1)
# (u'8:00', 1)
# (u'teachers--listen--with', 1)
# (u'revitalizing', 1)
# (u'slobodan', 1)
# (u'presided', 1)
# (u'lyn', 1)
# (u'revolution--of', 1)
# (u'beginnings', 1)
# (u'650,000', 1)
# (u'freeways', 1)
# (u'independently', 1)
# (u'walked', 1)
# (u'banishing', 1)
# (u"israel's", 1)
# (u'surplus--until', 1)
# (u'nuns', 1)
# (u'peace:', 1)
# (u'torture', 1)
# (u'surgeon', 1)
# (u'crop', 1)
# (u'$2,600', 1)
# (u'reinvented', 1)
# (u'hardest', 1)
# (u'that:', 1)
# (u'firms', 1)
# (u'education--at', 1)
# (u'murdered', 1)
# (u'17,000', 1)
# (u'motor', 1)
# (u'unleashed', 1)
# (u"hillary's", 1)
# (u'tahoe', 1)
# (u'reflects', 1)
# (u'upcoming', 1)
# (u'conducting', 1)
# (u"edison's", 1)
# (u'ride', 1)
# (u'stroke', 1)
# (u'nurture', 1)
# (u'unveiled', 1)
# (u'links', 1)
# (u'slip', 1)
# (u'rape', 1)
# (u'mysteries', 1)
# (u'africa;', 1)
# (u"doctrine's", 1)
# (u'realized', 1)
# (u"victims'", 1)
# (u'22nd', 1)
# (u'ladies', 1)
# (u'hugged', 1)
# (u'heroism', 1)
# (u'prosper', 1)
# (u'everybody--for', 1)
# (u'outlined', 1)
# (u'struggled', 1)
# (u'preschool', 1)
# (u'establishes', 1)
# (u'slipping', 1)
# (u'beneath', 1)
# (u'seesaw', 1)
# (u'limousines', 1)
# (u'quo', 1)
# (u'on--comprehensive', 1)
# (u'cyprus;', 1)
# (u'reaches', 1)
# (u'underclass?', 1)
# (u'sosa', 1)
# (u'blows', 1)
# (u'innovate', 1)
# (u'dead-end', 1)
# (u'bet', 1)
# (u'1.6', 1)
# (u'asia--', 1)
# (u'responsibility--they', 1)
# (u'korean', 1)
# (u'land:', 1)
# (u'persistence', 1)
# (u'fuels', 1)
# (u'savaged', 1)
# (u'awe', 1)
# (u'capita', 1)
# (u'atmosphere', 1)
# (u'chapters', 1)
# (u'pathbreaking', 1)
# (u'2013', 1)
# (u"anderson's", 1)
# (u'endangers', 1)
# (u'nations--combined', 1)
# (u'forfeit', 1)
# (u'listened', 1)
# (u'glory', 1)
# (u'ago--the', 1)
# (u'extremists', 1)
# (u'compliment', 1)
# (u'intensity', 1)
# (u'people--to', 1)
# (u'students;', 1)
# (u'infants--all', 1)
# (u'hits', 1)
# (u'revitalized', 1)
# (u'this?', 1)
# (u'clogged', 1)
# (u'preparedness', 1)
# (u'pin', 1)
# (u'composed;', 1)
# (u"it--we've", 1)
# (u'boundless', 1)
# (u'hottest', 1)
# (u'environment?', 1)
# (u'environment;', 1)
# (u'livable--so', 1)
# (u'ahead--and', 1)
# (u'atlanta', 1)
# (u'stunning', 1)
# (u'inefficiency', 1)
# (u'capital--to', 1)
# (u'waterfronts', 1)
# (u'$30,000', 1)
# (u"surplus--that's", 1)
# (u'emotionally', 1)
# (u'wye', 1)
# (u'union?', 1)
# (u'clinic', 1)
# (u'paul', 1)
# (u'wei', 1)
# (u"hemisphere's", 1)
# (u'say--let', 1)
# (u'environmentalists', 1)
# (u'anti-terrorism', 1)
# (u'heed', 1)
# (u'backlog', 1)
# (u'5,600', 1)
# (u'$150', 1)
# (u'250', 1)
# (u'obsessed', 1)
# (u'breakthroughs', 1)
# (u'is--a', 1)
# (u'sister', 1)
# (u'top-down', 1)
# (u'engines', 1)
# (u'wilderness', 1)
# (u'billions', 1)
# (u'weekends', 1)
# (u'female', 1)
# (u'prospects', 1)
# (u'place;', 1)
# (u'mohair', 1)
# (u'leave--all', 1)
# (u'44,000', 1)
# (u'overlapping', 1)
# (u'$34', 1)
# (u'strengthens', 1)
# (u'marketplace', 1)
# (u'forces--and', 1)
# (u'slowing', 1)
# (u'crusade', 1)
# (u'goodness', 1)
# (u'girl', 1)
# (u'12th-graders', 1)
# (u'48', 1)
# (u'shoulders', 1)
# (u'since:', 1)
# (u'$70', 1)
# (u'technology--enhancing', 1)
# (u'co-signing', 1)
# (u'presidential', 1)
# (u'year--since', 1)
# (u'europeans', 1)
# (u'oldest', 1)
# (u'reform;', 1)
# (u'voter', 1)
# (u'exploding', 1)
# (u"women's", 1)
# (u'monsanto', 1)
# (u'civility', 1)
# (u'29th', 1)
# (u'spouses', 1)
# (u'prisons', 1)
# (u'programs--', 1)
# (u'decoding', 1)
# (u'century;', 1)
# (u'broadcasters', 1)
# (u'newly-elected', 1)
# (u'right;', 1)
# (u'symphony', 1)
# (u'credit--a', 1)
# (u'today--our', 1)
# (u'shook', 1)
# (u'governments--all', 1)
# (u'bitterest', 1)
# (u'seattle', 1)
# (u'writers', 1)
# (u'faulty', 1)
# (u'fanaticism', 1)
# (u'criminals;', 1)
# (u'leadership--ratifying', 1)
# (u'scourge', 1)
# (u'unlawfully', 1)
# (u'atrocity', 1)
# (u'executed', 1)
# (u'devote', 1)
# (u'keyboard', 1)
# (u'bombing', 1)
# (u'belarus', 1)
# (u'grand', 1)
# (u'year--last', 1)
# (u'rocks', 1)
# (u'mandates', 1)
# (u'forgot', 1)
# (u'associate', 1)
# (u'standard', 1)
# (u'bail-out', 1)
# (u'"this', 1)
# (u'1970s', 1)
# (u'farmlands', 1)
# (u'fears:', 1)
# (u'sentence', 1)
# (u'hearing', 1)
# (u'senate:', 1)
# (u'crime-fighting', 1)
# (u'nation?', 1)
# (u'engagement', 1)
# (u'heights', 1)
# (u'growth;', 1)
# (u'livelihoods', 1)
# (u'murder', 1)
# (u'things--end', 1)
# (u'tithe', 1)
# (u'isaiah', 1)
# (u'him--a', 1)
# (u'gun-safety', 1)
# (u'$35,000', 1)
# (u'expanses', 1)
# (u'children--and', 1)
# (u'causing', 1)
# (u'conducive', 1)
# (u'deadlock', 1)
# (u'pursuing', 1)
# (u'monuments', 1)
# (u'de', 1)
# (u'immigrants;', 1)
# (u'taliaferro', 1)
# (u'headed', 1)
# (u'roadmap', 1)
# (u'horrendous', 1)
# (u'$1.50', 1)
# (u'hattiesburg', 1)
# (u'sail', 1)
# (u'score', 1)
# (u'it--as', 1)
# (u'boss', 1)
# (u'sun."', 1)
# (u'wto', 1)
# (u"chicago's", 1)
# (u"countries'", 1)
# (u'uncertainty', 1)
# (u'research--', 1)
# (u'con', 1)
# (u'"please', 1)
# (u'eulogized', 1)
# (u'height', 1)
# (u'lick', 1)
# (u'petty', 1)
# (u'$300', 1)
# (u'miraculously', 1)
# (u'threw', 1)
# (u'sad', 1)
# (u'58:12', 1)
# (u'appeals', 1)
# (u'eighteen', 1)
# (u'trickle', 1)
# (u'acquire', 1)
# (u'victory."', 1)
# (u'decision-making', 1)
# (u'kid', 1)
# (u"mother's", 1)
# (u'practices', 1)
# (u'camps', 1)
# (u'year-old', 1)
# (u'prison', 1)
# (u'designate', 1)
# (u'1978', 1)
# (u'ago:', 1)
# (u'unique', 1)
# (u'challenge--to', 1)
# (u'serbian', 1)
# (u'bunch', 1)
# (u'starvation', 1)
# (u'joining', 1)
# (u'companions', 1)
# (u'creative', 1)
# (u'cheating', 1)
# (u'paralysis', 1)
# (u'penalty--without', 1)
# (u'treaty--this', 1)
# (u'peoples', 1)
# (u'happy', 1)
# (u'manufacturers', 1)
# (u'fireworks', 1)
# (u'incomes?', 1)
# (u'220', 1)
# (u'responding', 1)
# (u'contaminated', 1)
# (u'panels', 1)
# (u'computing', 1)
# (u'floor', 1)
# (u'setting', 1)
# (u'short-term', 1)
# (u'exporter', 1)
# (u'football', 1)
# (u'healthiest', 1)
# (u"truman's", 1)
# (u'teeth', 1)
# (u'burdened', 1)
# (u'bomber', 1)
# (u'killings', 1)
# (u'technique', 1)
# (u'1945', 1)
# (u'women;', 1)
# (u'boosting', 1)
# (u'klaas', 1)
# (u'blast', 1)
# (u'fragile', 1)
# (u'planning', 1)
# (u'eroding', 1)
# (u'plan--a', 1)
# (u'repetitive', 1)
# (u'reaffirmed', 1)
# (u'snipers', 1)
# (u'endangering', 1)
# (u'henry', 1)
# (u'studied', 1)
# (u'state--turn', 1)
# (u'shootings', 1)
# (u'extra', 1)
# (u'rarely', 1)
# (u'sports', 1)
# (u'untargeted', 1)
# (u'convention--this', 1)
# (u'cap', 1)
# (u'mind:', 1)
# (u'high-crime', 1)
# (u'one--the', 1)
# (u'incredible', 1)
# (u'counting', 1)
# (u'future?', 1)
# (u'agonizing', 1)
# (u'five-year', 1)
# (u'designer', 1)
# (u'149', 1)
# (u'kassebaum', 1)
# (u'coli', 1)
# (u'blocked', 1)
# (u'ago--one', 1)
# (u'civilian', 1)
# (u'wealthy', 1)
# (u'balances', 1)
# (u'spaces--for', 1)
# (u'drop', 1)
# (u'back-to-back', 1)
# (u'persian', 1)
# (u'medication', 1)
# (u'arthritis', 1)
# (u'224', 1)
# (u'invitation', 1)
# (u'schoolchildren', 1)
# (u'yourself', 1)
# (u'people--all', 1)
# (u'unduly', 1)
# (u'(d-mass.)', 1)
# (u"bill's", 1)
# (u'expanse', 1)
# (u'cleaned', 1)
# (u'law--the', 1)
# (u'undermined', 1)
# (u'frontier', 1)
# (u'fruits', 1)
# (u'lunches', 1)
# (u'welfare-to-work', 1)
# (u"iraq's", 1)
# (u'homerun', 1)
# (u'wonder', 1)
# (u'1,700', 1)
# (u'mammograms', 1)
# (u'probes', 1)
# (u'tackling', 1)
# (u'applauding', 1)
# (u'slow', 1)
# (u'title', 1)
# (u'dick', 1)
# (u'interstate', 1)
# (u'killers', 1)
# (u'secondary', 1)
# (u'settings', 1)
# (u'marred', 1)
# (u'rwanda', 1)
# (u'slashed', 1)
# (u'parking', 1)
# (u'"thou', 1)
# (u'trade;', 1)
# (u'label', 1)
# (u'priests', 1)
# (u'endless', 1)
# (u'67', 1)
# (u'well-protected', 1)
# (u'able--afraid', 1)
# (u'$3,000--and', 1)
# (u'curbing', 1)
# (u'gun--and', 1)
# (u'$1500', 1)
# (u'cafes', 1)
# (u'capping', 1)
# (u'$22', 1)
# (u'insurers', 1)
# (u'refusal', 1)
# (u'associations:', 1)
# (u'weave', 1)
# (u'drain', 1)
# (u'1835', 1)
# (u'strive', 1)
# (u'laboratories', 1)
# (u'justify', 1)
# (u'fueling', 1)
# (u'safeguards', 1)
# (u'pollutions', 1)
# (u'forbearers', 1)
# (u'hint', 1)
# (u'trigger', 1)
# (u'skier', 1)
# (u'vacuum', 1)
# (u'buddies', 1)
# (u'lightning', 1)
# (u'offenders', 1)
# (u'non-nuclear', 1)
# (u'permitting', 1)
# (u'demeaning', 1)
# (u'renounce', 1)
# (u'teardrop', 1)
# (u'year--four', 1)
# (u'wrong?"', 1)
# (u'fractured', 1)
# (u'francis', 1)
# (u'cures', 1)
# (u'heavens--the', 1)
# (u'investigative', 1)
# (u'gary', 1)
# (u'shells', 1)
# (u'descendants', 1)
# (u'mindless', 1)
# (u'again."', 1)
# (u"child's", 1)
# (u'sophisticated', 1)
# (u'steven', 1)
# (u'grass', 1)
# (u'combining', 1)
# (u'currencies', 1)
# (u'walks', 1)
# (u'cleanup', 1)
# (u'instantly', 1)
# (u'children--a', 1)
# (u'brotherhood', 1)
# (u'observe', 1)
# (u'grassroots', 1)
# (u'wyoming', 1)
# (u'enjoying', 1)
# (u'godspeed', 1)
# (u'african-american', 1)
# (u'answer:', 1)
# (u'invention', 1)
# (u'polluted', 1)
# (u'promising', 1)
# (u'cystic', 1)
# (u'toys', 1)
# (u'contains--all', 1)
# (u'garnish', 1)
# (u'factories', 1)
# (u'petaluma', 1)
# (u'initiative:', 1)
# (u'microchips', 1)
# (u'breaking', 1)
# (u'cleansing', 1)
# (u'kosovo--enabling', 1)
# (u'perry', 1)
# (u'worst-performing', 1)
# (u'ninety-eight', 1)
# (u'more?', 1)
# (u'signature', 1)
# (u'speak;', 1)
# (u'plane', 1)
# (u'softball', 1)
# (u'register', 1)
# (u'public-private', 1)
# (u'medic', 1)
# (u'command--general', 1)
# (u'soot', 1)
# (u'responsibility:', 1)
# (u'ricardo', 1)
# (u'peace--from', 1)
# (u'measures;', 1)
# (u'passage?', 1)
# (u'fanatics', 1)
# (u'pregnant', 1)
# (u'wires', 1)
# (u'murders', 1)
# (u'america?', 1)
# (u'fiber', 1)
# (u"laden's", 1)
# (u'equipped', 1)
# (u'lag', 1)
# (u"'round", 1)
# (u'way--it', 1)
# (u'walesa', 1)
# (u'talked', 1)
# (u'script', 1)
# (u'coasts', 1)
# (u'headache', 1)
# (u'selling', 1)
# (u"citizens'", 1)
# (u'isolating', 1)
# (u'laws;', 1)
# (u'forging', 1)
# (u'sentences', 1)
# (u'aged', 1)
# (u'yitzhak', 1)
# (u'couch', 1)
# (u'lifts', 1)
# (u'sturdy', 1)
# (u'humanitarian', 1)
# (u'dodging', 1)
# (u'3:00', 1)
# (u'cds', 1)
# (u'$5', 1)
# (u'sharing', 1)
# (u'd.a.r.e', 1)
# (u'meanwhile', 1)
# (u"'follow", 1)
# (u'stored', 1)
# (u'restaurants', 1)
# (u'achieved', 1)
# (u'proliferation', 1)
# (u'musicians', 1)
# (u'them--joined', 1)
# (u"other's", 1)
# (u'inaction', 1)
# (u'mayflower', 1)
# (u'days!', 1)
# (u'union"', 1)
# (u'us--by', 1)
# (u'congestion', 1)
# (u'hollow', 1)
# (u'rewrite', 1)
# (u'widening', 1)
# (u"carolina's", 1)
# (u'unleash', 1)
# (u'deter', 1)
# (u'smoking-related', 1)
# (u'far-sighted', 1)
# (u'designing', 1)
# (u'fight;', 1)
# (u'(r-conn.)', 1)
# (u'sizeable', 1)
# (u"program's", 1)
# (u'encountered', 1)
# (u'alliances', 1)
# (u'unfunded', 1)
# (u'$120,000', 1)
# (u'2030', 1)
# (u'indianapolis', 1)
# (u'rabin', 1)
# (u'uninsured--buy', 1)
# (u'people?', 1)
# (u'people;', 1)
# (u'languish', 1)
# (u'project:', 1)
# (u'corps--americorps', 1)
# (u'americas', 1)
# (u'tames', 1)
# (u'tolbert', 1)
# (u'advocate', 1)
# (u'defied', 1)
# (u'bad-apple', 1)
# (u'overriding', 1)
# (u'scale', 1)
# (u'400,000', 1)
# (u'people--the', 1)
# (u'epic', 1)
# (u'unconscionably', 1)
# (u'taxing', 1)
# (u'stockpiles', 1)
# (u'refused', 1)
# (u'stalkers', 1)
# (u'cheered', 1)
# (u'deductibles', 1)
# (u'repaid', 1)
# (u'factor', 1)
# (u'summer--not', 1)
# (u'suit', 1)
# (u'certification', 1)
# (u'translate', 1)
# (u'rogue', 1)
# (u'retina', 1)
# (u'livability', 1)
# (u'paducah', 1)
# (u'four-and-a-quarter', 1)
# (u'un', 1)
# (u'faded', 1)
# (u'fiscally', 1)
# (u'ancestors', 1)
# (u'curriculum', 1)
# (u'replace', 1)
# (u'ruthlessly', 1)
# (u'balkans;', 1)
# (u'alongside', 1)
# (u'enrolled', 1)
# (u'higher-drug-rate', 1)
# (u'tearing', 1)
# (u'--more', 1)
# (u'typewriter', 1)
# (u'jeffords', 1)
# (u'quadrupled', 1)
# (u'stiff', 1)
# (u'sanctions', 1)
# (u'dealt', 1)
# (u"government's", 1)
# (u'out-compete', 1)
# (u'year--but', 1)
# (u'ammunition', 1)
# (u'ration', 1)
# (u'engage', 1)
# (u'ears', 1)
# (u'president]', 1)
# (u'infantry', 1)
# (u'unimagined', 1)
# (u'rarest', 1)
# (u'tattered', 1)
# (u'usual--the', 1)
# (u'be--a', 1)
# (u'oh', 1)
# (u'refinanced', 1)
# (u'weaker', 1)
# (u'$357', 1)
# (u'job-creating', 1)
# (u'weaken', 1)
# (u'sit', 1)
# (u'idea--and', 1)
# (u'ticks;', 1)
# (u'says:', 1)
# (u'27,000', 1)
# (u"century's", 1)
# (u'future;', 1)
# (u"mexico's", 1)
# (u'bill--the', 1)
# (u'bombers', 1)
# (u'civics', 1)
# (u'healthcare', 1)
# (u'130', 1)
# (u'hand;', 1)
# (u'publicly-held', 1)
# (u'woolsey', 1)
# (u'literacy', 1)
# (u'frayed', 1)
# (u'covering', 1)
# (u'us--are', 1)
# (u'70,000', 1)
# (u'81', 1)
# (u'[iraqi', 1)
# (u'maintains', 1)
# (u'ancestry', 1)
# (u'families:', 1)
# (u'mars', 1)
# (u'farmland', 1)
# (u'teleprompter', 1)
# (u'receding', 1)
# (u'succeeds', 1)
# (u'walter', 1)
# (u"pac's", 1)
# (u'economy;', 1)
# (u'economy?', 1)
# (u'ancient', 1)
# (u'rated', 1)
# (u'co-hosted', 1)
# (u'electing', 1)
# (u'allied', 1)
# (u'havel', 1)
# (u'hearings', 1)
# (u"korea's", 1)
# (u"through--there's", 1)
# (u'comfortable', 1)
# (u"georgia's", 1)
# (u'provokes', 1)
# (u'about--challenging', 1)
# (u'inexorable', 1)
# (u'within--from', 1)
# (u'congress--across', 1)
# (u'staff', 1)
# (u'bases', 1)
# (u'inherited', 1)
# (u'undivided', 1)
# (u'roles--our', 1)
# (u'ashtray', 1)
# (u'teams', 1)
# (u'fund-raising', 1)
# (u'widow', 1)
# (u'affirms', 1)
# (u'immigrant', 1)
# (u'felons', 1)
# (u'greece', 1)
# (u'incomprehensively', 1)
# (u'comforts', 1)
# (u'superb', 1)
# (u'tour--to', 1)
# (u'bought', 1)
# (u'reauthorize', 1)
# (u'all--something', 1)
# (u'values:', 1)
# (u'(d-wis.)', 1)
# (u'done:', 1)
# (u'steps:', 1)
# (u'$1,800', 1)
# (u'define', 1)
# (u'scrutiny', 1)
# (u'years--the', 1)
# (u'troubled', 1)
# (u'way--to', 1)
# (u'deductible', 1)
# (u'molecular', 1)
# (u'ball', 1)
# (u'reporting', 1)
# (u'world!', 1)
# (u'argue', 1)
# (u'modeled', 1)
# (u'heavily', 1)
# (u'test:', 1)
# (u'seats', 1)
# (u'far-reaching', 1)
# (u'jeff', 1)
# (u'delta;', 1)
# (u'desk', 1)
# (u'incessant', 1)
# (u'forcing', 1)
# (u'bigotry', 1)
# (u'loses', 1)
# (u'standards;', 1)
# (u'debt-free', 1)
# (u'eight-year-old', 1)
# (u'disrupting', 1)
# (u'14th', 1)
# (u'before;', 1)
# (u'hiding', 1)
# (u'surge', 1)
# (u'introduced', 1)
# (u'software', 1)
# (u'alliance', 1)
# (u'artists', 1)
# (u'dispossessed', 1)
# (u'1985', 1)
# (u'rushed', 1)
# (u'indictments', 1)
# (u'our--let', 1)
# (u'convince', 1)
# (u'time--for', 1)
# (u'ink', 1)
# (u'erie', 1)
# (u'jesse', 1)
# (u'tick', 1)
# (u'49', 1)
# (u'[john]', 1)
# (u'normal', 1)
# (u'repeal', 1)
# (u'time;', 1)
# (u'corporations--sprint', 1)
# (u'moynihan', 1)
# (u'ideological', 1)

# %%
for x in word_count_gwb_clean.subtractByKey(word_count_al_clean).sortBy(lambda x: x[1],ascending=False).collect():
    print x
# Out:
# (u'terrorists', 83)
# (u'iraq', 80)
# (u'tonight', 76)
# (u'terror', 63)
# (u'weapons', 56)
# (u'iraqi', 48)
# (u'jobs', 36)
# (u'al', 36)
# (u'workers', 36)
# (u'terrorist', 36)
# (u'afghanistan', 35)
# (u'goal', 32)
# (u'nuclear', 32)
# (u'qaeda', 32)
# (u'million', 31)
# (u'leaders', 30)
# (u"america's", 30)
# (u'middle', 29)
# (u'fellow', 28)
# (u'budget', 27)
# (u'regime', 27)
# (u'schools', 26)
# (u'allies', 26)
# (u'insurance', 26)
# (u'today', 26)
# (u'families', 25)
# (u'saddam', 25)
# (u'thank', 25)
# (u'lead', 25)
# (u'democracy', 24)
# (u'child', 24)
# (u'funding', 23)
# (u'medical', 23)
# (u'economic', 23)
# (u'courage', 23)
# (u'spending', 22)
# (u'hussein', 22)
# (u'technology', 21)
# (u'iraqis', 20)
# (u'homeland', 20)
# (u'billion', 19)
# (u'medicare', 19)
# (u'dollars', 19)
# (u'drug', 19)
# (u'threat', 19)
# (u'job', 19)
# (u'democratic', 19)
# (u'compassion', 18)
# (u'iran', 18)
# (u'mass', 18)
# (u'coalition', 18)
# (u'behind', 18)
# (u'coverage', 18)
# (u'program', 18)
# (u'strengthen', 17)
# (u'programs', 17)
# (u'proud', 17)
# (u'ensure', 16)
# (u'ahead', 16)
# (u'oil', 16)
# (u'research', 16)
# (u'drugs', 15)
# (u'attacks', 15)
# (u'helping', 15)
# (u'stronger', 15)
# (u'extremists', 15)
# (u'murder', 15)
# (u'standards', 15)
# (u'businesses', 14)
# (u'commitment', 14)
# (u'achieve', 14)
# (u'encourage', 14)
# (u'regimes', 14)
# (u'costs', 14)
# (u'medicine', 13)
# (u'stop', 13)
# (u'students', 13)
# (u'threats', 13)
# (u'values', 13)
# (u'marriage', 13)
# (u'speaker', 13)
# (u'percent', 13)
# (u'urge', 13)
# (u'chamber', 13)
# (u'mission', 13)
# (u'young', 13)
# (u'math', 13)
# (u'terrorism', 13)
# (u"iraq's", 13)
# (u'strategy', 13)
# (u'initiative', 12)
# (u'decisions', 12)
# (u'kill', 12)
# (u'rising', 12)
# (u'george', 12)
# (u'deserve', 12)
# (u'groups', 12)
# (u'bush', 12)
# (u'keeping', 12)
# (u'clean', 12)
# (u'competitive', 12)
# (u'challenge', 12)
# (u'reforms', 12)
# (u'camps', 12)
# (u'inspectors', 11)
# (u'challenges', 11)
# (u'markets', 11)
# (u'parents', 11)
# (u'offensive', 11)
# (u'dignity', 11)
# (u'focus', 11)
# (u'plans', 11)
# (u'baghdad', 11)
# (u'empower', 11)
# (u'welcome', 11)
# (u'2001', 11)
# (u'resolve', 11)
# (u'police', 10)
# (u'taliban', 10)
# (u'affordable', 10)
# (u'elected', 10)
# (u'treatment', 10)
# (u'deny', 10)
# (u'pursuing', 10)
# (u'basic', 10)
# (u'palestinian', 10)
# (u'global', 10)
# (u'leadership', 10)
# (u'choices', 10)
# (u'doctors', 10)
# (u'skills', 9)
# (u'track', 9)
# (u'tyranny', 9)
# (u'decades', 9)
# (u'path', 9)
# (u'got', 9)
# (u'biological', 9)
# (u'around', 9)
# (u'thanks', 9)
# (u'illegal', 9)
# (u'start', 9)
# (u'debate', 9)
# (u'faith-based', 9)
# (u'friend', 9)
# (u'w', 9)
# (u'korea', 9)
# (u'cannot', 9)
# (u'developing', 9)
# (u'bill', 9)
# (u'train', 9)
# (u'girls', 8)
# (u'prescription', 8)
# (u'(applause)', 8)
# (u'afford', 8)
# (u'problems', 8)
# (u'expanding', 8)
# (u'islamic', 8)
# (u'grow', 8)
# (u'remember', 8)
# (u'ended', 8)
# (u"freedom's", 8)
# (u'dramatically', 8)
# (u'distinguished', 8)
# (u'partners', 8)
# (u'earmarks', 8)
# (u'savings', 8)
# (u'retreat', 8)
# (u'renew', 8)
# (u'technologies', 8)
# (u'israel', 8)
# (u'alternative', 8)
# (u'hatred', 8)
# (u'air', 8)
# (u'level', 8)
# (u'brave', 8)
# (u'crime', 8)
# (u'going', 8)
# (u'killers', 8)
# (u"nation's", 8)
# (u'hard', 8)
# (u'prison', 8)
# (u'achieved', 8)
# (u'environment', 7)
# (u'marine', 7)
# (u'building', 7)
# (u'cheney', 7)
# (u'faced', 7)
# (u'makes', 7)
# (u'love', 7)
# (u'role', 7)
# (u'recession', 7)
# (u'disarm', 7)
# (u'worker', 7)
# (u'guests', 7)
# (u'everything', 7)
# (u'asked', 7)
# (u'supporting', 7)
# (u'commitments', 7)
# (u'deficit', 7)
# (u'threaten', 7)
# (u'eliminate', 7)
# (u'hiv/aids', 7)
# (u'chaos', 7)
# (u'funds', 7)
# (u'employees', 7)
# (u'innocent', 7)
# (u'priorities', 7)
# (u'defeated', 7)
# (u'rebuild', 7)
# (u'rest', 7)
# (u'ladies', 7)
# (u'al-qaida', 7)
# (u'younger', 7)
# (u'trained', 7)
# (u'lawsuits', 7)
# (u'major', 7)
# (u'citizens:', 7)
# (u'achievement', 7)
# (u'begun', 7)
# (u'mom', 7)
# (u'korean', 7)
# (u'cells', 7)
# (u'key', 7)
# (u'housing', 7)
# (u'strengthening', 7)
# (u'speak', 7)
# (u'evening', 7)
# (u'shia', 7)
# (u'diplomacy', 7)
# (u'cuts', 7)
# (u'standard', 7)
# (u'critical', 7)
# (u'bipartisan', 7)
# (u'fall', 7)
# (u'iranian', 7)
# (u'vice', 7)
# (u'officials', 7)
# (u'hide', 6)
# (u'confronting', 6)
# (u'11', 6)
# (u'anyone', 6)
# (u'15', 6)
# (u'turned', 6)
# (u'dream', 6)
# (u'2006', 6)
# (u'conscience', 6)
# (u'stopped', 6)
# (u'poverty', 6)
# (u'victims', 6)
# (u'baby', 6)
# (u'group', 6)
# (u'increasingly', 6)
# (u'compete', 6)
# (u'diseases', 6)
# (u'options', 6)
# (u'failure', 6)
# (u'cars', 6)
# (u'senator', 6)
# (u'saudi', 6)
# (u"world's", 6)
# (u'using', 6)
# (u'methods', 6)
# (u'"we', 6)
# (u'sergeant', 6)
# (u'haven', 6)
# (u'center', 6)
# (u'personnel', 6)
# (u'record', 6)
# (u'emergency', 6)
# (u'dreams', 6)
# (u'prepare', 6)
# (u'hour', 6)
# (u'actions', 6)
# (u'decade', 6)
# (u'sorrow', 6)
# (u'proposal', 6)
# (u'problem', 6)
# (u'hundreds', 6)
# (u'testing', 6)
# (u'lift', 6)
# (u'offer', 6)
# (u'outcome', 6)
# (u'reauthorize', 6)
# (u'cities', 6)
# (u'woman', 6)
# (u'scientists', 6)
# (u'trying', 6)
# (u'areas', 6)
# (u'historic', 6)
# (u'expire', 6)
# (u'spread', 6)
# (u'saved', 5)
# (u'grief', 5)
# (u'addicted', 5)
# (u'operatives', 5)
# (u'medicaid', 5)
# (u'tough', 5)
# (u'democracies', 5)
# (u'corporate', 5)
# (u'low-income', 5)
# (u'honored', 5)
# (u'losing', 5)
# (u'says', 5)
# (u'20', 5)
# (u'60', 5)
# (u'poor', 5)
# (u'religious', 5)
# (u'hours', 5)
# (u'anger', 5)
# (u'arabia', 5)
# (u'food', 5)
# (u'sunni', 5)
# (u'please', 5)
# (u'bin', 5)
# (u'uranium', 5)
# (u'watch', 5)
# (u'nato', 5)
# (u'voted', 5)
# (u'risk', 5)
# (u'plot', 5)
# (u'brings', 5)
# (u'grows', 5)
# (u'network', 5)
# (u'announce', 5)
# (u'mentors', 5)
# (u'humanity', 5)
# (u'advances', 5)
# (u'tell', 5)
# (u'organizations', 5)
# (u'heart', 5)
# (u'10', 5)
# (u'anthrax', 5)
# (u'investment', 5)
# (u'terrible', 5)
# (u'cleaner', 5)
# (u'clear:', 5)
# (u'presidents', 5)
# (u'boys', 5)
# (u'allowing', 5)
# (u'intentions', 5)
# (u'goals', 5)
# (u'agencies', 5)
# (u'julie', 5)
# (u'showed', 5)
# (u'neighborhoods', 5)
# (u'skill', 5)
# (u'worked', 5)
# (u'gift', 5)
# (u'defeating', 5)
# (u'aggressive', 5)
# (u'momentum', 5)
# (u'brutal', 5)
# (u'grandchildren', 5)
# (u'fbi', 5)
# (u'patriot', 5)
# (u'broader', 5)
# (u'agenda', 5)
# (u'decisive', 5)
# (u'combat', 5)
# (u'john', 5)
# (u'laden', 5)
# (u'muslim', 5)
# (u'dominate', 5)
# (u'dramatic', 5)
# (u'movement', 5)
# (u'embassy', 5)
# (u'islam', 5)
# (u'despair', 5)
# (u'innovation', 5)
# (u'2005', 5)
# (u'code', 5)
# (u'troubled', 5)
# (u'afghan', 5)
# (u'surge', 5)
# (u'quickly', 5)
# (u'arrested', 4)
# (u'veto', 4)
# (u'weak', 4)
# (u'paychecks', 4)
# (u'healthy', 4)
# (u'sake', 4)
# (u'tehran', 4)
# (u'19', 4)
# (u'closer', 4)
# (u'prime', 4)
# (u'college', 4)
# (u'fears', 4)
# (u'disrupt', 4)
# (u'leads', 4)
# (u'intimidate', 4)
# (u'know:', 4)
# (u'helped', 4)
# (u'founders', 4)
# (u'week', 4)
# (u'consequence', 4)
# (u'jordan', 4)
# (u'youth', 4)
# (u'long-term', 4)
# (u'gas', 4)
# (u'ignore', 4)
# (u'try', 4)
# (u'ukraine', 4)
# (u'started', 4)
# (u'ideology', 4)
# (u'defining', 4)
# (u'dad', 4)
# (u'front', 4)
# (u'payroll', 4)
# (u'quality', 4)
# (u'instant', 4)
# (u'servicemen', 4)
# (u'recovery', 4)
# (u'responded', 4)
# (u'ethical', 4)
# (u'pays', 4)
# (u'1990s', 4)
# (u'extremism', 4)
# (u'democrats', 4)
# (u'seeing', 4)
# (u'bound', 4)
# (u'rebuilding', 4)
# (u'equipment', 4)
# (u'passenger', 4)
# (u'50,000', 4)
# (u'eventually', 4)
# (u'pakistan', 4)
# (u'invest', 4)
# (u'tragedy', 4)
# (u"afghanistan's", 4)
# (u'debates', 4)
# (u'playing', 4)
# (u'calm', 4)
# (u'idea', 4)
# (u'electric', 4)
# (u'freedoms', 4)
# (u'risks', 4)
# (u'spent', 4)
# (u'spend', 4)
# (u'pell', 4)
# (u'congressman', 4)
# (u'sectarian', 4)
# (u'madam', 4)
# (u'catastrophic', 4)
# (u'agreements', 4)
# (u'dependence', 4)
# (u'discretionary', 4)
# (u'respects', 4)
# (u'ethanol', 4)
# (u'holy', 4)
# (u'top', 4)
# (u'patients', 4)
# (u'd.c', 4)
# (u'ownership', 4)
# (u'raised', 4)
# (u'ambitious', 4)
# (u'finally', 4)
# (u'happen', 4)
# (u'marines', 4)
# (u'undermine', 4)
# (u'hezbollah', 4)
# (u'learning', 4)
# (u'weeks', 4)
# (u'policies', 4)
# (u'renewable', 4)
# (u'deep', 4)
# (u'20th', 4)
# (u'story', 4)
# (u'tool', 4)
# (u'secret', 4)
# (u'decency', 4)
# (u'lower', 4)
# (u'reduces', 4)
# (u'usa', 4)
# (u'addiction', 4)
# (u'fuels', 4)
# (u'teach', 4)
# (u'unity', 4)
# (u'frivolous', 4)
# (u'weapon', 4)
# (u'breakthroughs', 4)
# (u'junk', 4)
# (u'oppression', 4)
# (u'criminals', 4)
# (u'innovative', 4)
# (u'rejects', 4)
# (u'failing', 4)
# (u'societies', 4)
# (u'uncertainty', 4)
# (u'faces', 4)
# (u'$300', 4)
# (u'unemployment', 4)
# (u'reducing', 4)
# (u'scores', 4)
# (u'extra', 4)
# (u'conservation', 4)
# (u'happened', 4)
# (u'employers', 4)
# (u'potential', 4)
# (u'un', 4)
# (u'reading', 4)
# (u'resentment', 4)
# (u'strive', 4)
# (u'gather', 4)
# (u'compassionate', 4)
# (u'skilled', 4)
# (u'civilians', 4)
# (u'surveillance', 4)
# (u'everyone', 4)
# (u'needless', 4)
# (u'stewards', 4)
# (u'americas', 4)
# (u'assassins', 4)
# (u'replace', 4)
# (u'stock', 4)
# (u'cutting', 4)
# (u'bills', 4)
# (u'prayers', 4)
# (u'serving', 4)
# (u'lonely', 4)
# (u'rostrum', 4)
# (u'republicans', 4)
# (u'dynamic', 3)
# (u'hate', 3)
# (u'criticism', 3)
# (u'crucial', 3)
# (u'phase', 3)
# (u'reductions', 3)
# (u'lessons', 3)
# (u'convictions', 3)
# (u'peninsula', 3)
# (u'uncovered', 3)
# (u'laura', 3)
# (u'idealism', 3)
# (u'india', 3)
# (u'hydrogen', 3)
# (u'revealed', 3)
# (u'moments', 3)
# (u'pentagon', 3)
# (u'entitlements', 3)
# (u'objective', 3)
# (u'discovered', 3)
# (u'imagined', 3)
# (u'nominees', 3)
# (u'deduction', 3)
# (u'caring', 3)
# (u'dictator', 3)
# (u'status', 3)
# (u'blow', 3)
# (u'real', 3)
# (u'read', 3)
# (u'lady', 3)
# (u'images', 3)
# (u'totalitarian', 3)
# (u'syrian', 3)
# (u'starting', 3)
# (u'upholds', 3)
# (u'allows', 3)
# (u'protects', 3)
# (u'oppose', 3)
# (u'28', 3)
# (u'feed', 3)
# (u'recruiting', 3)
# (u'threatening', 3)
# (u'ashley', 3)
# (u'treated', 3)
# (u'measured', 3)
# (u'approve', 3)
# (u'earmark', 3)
# (u'modernize', 3)
# (u'clinton', 3)
# (u'osama', 3)
# (u'prevail', 3)
# (u'bomb', 3)
# (u'contributions', 3)
# (u'result:', 3)
# (u'cell', 3)
# (u'standing', 3)
# (u'patrol', 3)
# (u'powerful', 3)
# (u'priority', 3)
# (u'palestine', 3)
# (u'vigorous', 3)
# (u'tactics', 3)
# (u'tolerance', 3)
# (u'world:', 3)
# (u'command', 3)
# (u'ideals', 3)
# (u'proposals', 3)
# (u'burma', 3)
# (u'star', 3)
# (u'pursuit', 3)
# (u'supporters', 3)
# (u'norwood', 3)
# (u'massive', 3)
# (u'ultimate', 3)
# (u'joined', 3)
# (u'tomorrow', 3)
# (u'nominate', 3)
# (u'inspire', 3)
# (u'supplies', 3)
# (u"children's", 3)
# (u'cloning', 3)
# (u'wear', 3)
# (u'news', 3)
# (u'teachers', 3)
# (u'unfair', 3)
# (u'dropped', 3)
# (u'solved', 3)
# (u'shared', 3)
# (u'teacher', 3)
# (u'passengers', 3)
# (u'emerge', 3)
# (u'opposed', 3)
# (u'car', 3)
# (u'shield', 3)
# (u'sponsor', 3)
# (u'self-government', 3)
# (u'minority', 3)
# (u'released', 3)
# (u'unfortunately', 3)
# (u'checks', 3)
# (u'reaction', 3)
# (u'talented', 3)
# (u'treatments', 3)
# (u'decent', 3)
# (u'blessed', 3)
# (u'achieving', 3)
# (u'response', 3)
# (u'charities', 3)
# (u'courses', 3)
# (u'plotting', 3)
# (u'syria', 3)
# (u'orders', 3)
# (u'stands', 3)
# (u'gains', 3)
# (u'fastest', 3)
# (u'byron', 3)
# (u'pace', 3)
# (u'guide', 3)
# (u'lie', 3)
# (u'networks', 3)
# (u'big', 3)
# (u'radicalism', 3)
# (u'professionals', 3)
# (u'entrepreneurs', 3)
# (u'2003', 3)
# (u'2007', 3)
# (u'enrichment', 3)
# (u'havens', 3)
# (u'reconciliation', 3)
# (u'isolationism', 3)
# (u'honorable', 3)
# (u"you're", 3)
# (u'punish', 3)
# (u'loved', 3)
# (u'isolation', 3)
# (u'chambers', 3)
# (u'corruption', 3)
# (u'wesley', 3)
# (u'destiny', 3)
# (u'deficits', 3)
# (u'watched', 3)
# (u'partner', 3)
# (u'drawing', 3)
# (u'name', 3)
# (u'retirees', 3)
# (u'colleges', 3)
# (u'campaign', 3)
# (u'raids', 3)
# (u'hidden', 3)
# (u'comforted', 3)
# (u'outlaw', 3)
# (u'exports', 3)
# (u'asking:', 3)
# (u'succeeding', 3)
# (u'ideal', 3)
# (u'birth', 3)
# (u'deal', 3)
# (u'creed', 3)
# (u'learned', 3)
# (u'inside', 3)
# (u'senior', 3)
# (u'21st', 3)
# (u'goes', 3)
# (u'flexibility', 3)
# (u'debating', 3)
# (u'dikembe', 3)
# (u'vision', 3)
# (u'reminder', 3)
# (u'unfairly', 3)
# (u'bombs', 3)
# (u'conviction', 3)
# (u'eliminating', 3)
# (u'steadfast', 3)
# (u"can't", 3)
# (u'worry', 3)
# (u'accountable', 3)
# (u'serves', 3)
# (u'competition', 3)
# (u'spreading', 3)
# (u'fast', 3)
# (u'strikes', 3)
# (u'symbol', 3)
# (u'overseas', 3)
# (u'opportunities', 3)
# (u'malaria', 3)
# (u'roosevelt', 3)
# (u'refuse', 3)
# (u'fundamental', 3)
# (u'ally', 3)
# (u'initiatives', 3)
# (u'vulnerable', 3)
# (u'play', 3)
# (u'researchers', 3)
# (u'strongholds', 3)
# (u'transitional', 3)
# (u'medicines', 3)
# (u'deploying', 3)
# (u'firefighters', 3)
# (u'match', 3)
# (u'ideologies', 3)
# (u'doubling', 3)
# (u'orderly', 3)
# (u'meaning', 3)
# (u'uphold', 3)
# (u'fighters', 3)
# (u'fewer', 3)
# (u'gathered', 3)
# (u'involves', 3)
# (u'servants', 3)
# (u'hugged', 3)
# (u'dan', 3)
# (u'partisan', 3)
# (u'videos', 3)
# (u'rieman', 3)
# (u'enact', 3)
# (u'adversity', 3)
# (u'embryos', 3)
# (u'abstinence', 3)
# (u'embolden', 3)
# (u'shannon', 3)
# (u'told', 3)
# (u'hamas', 3)
# (u'competitiveness', 3)
# (u'levels', 3)
# (u'listen', 3)
# (u'dozen', 3)
# (u'hardworking', 3)
# (u'dozens', 3)
# (u'dismiss', 3)
# (u'unique', 3)
# (u'peoples', 3)
# (u'morning', 3)
# (u'stays', 3)
# (u'team', 3)
# (u'sign', 3)
# (u'wait', 3)
# (u'sports', 3)
# (u'inflation', 3)
# (u'productive', 3)
# (u'civilian', 3)
# (u'persian', 3)
# (u'strengths', 3)
# (u'normal', 3)
# (u'capable', 3)
# (u'football', 3)
# (u'pressing', 3)
# (u'wisely', 3)
# (u'missiles', 3)
# (u'finish', 3)
# (u'wasteful', 3)
# (u'einstein', 3)
# (u'2009', 3)
# (u'winning', 3)
# (u'streets', 3)
# (u'launch', 3)
# (u'selling', 3)
# (u'reward', 3)
# (u'seize', 3)
# (u'fiscally', 3)
# (u'latin', 3)
# (u'alert', 3)
# (u'u.s', 3)
# (u'australia', 3)
# (u'accountability', 3)
# (u'reserve', 3)
# (u'delivering', 3)
# (u'disarming', 3)
# (u'activist', 3)
# (u'strategic', 3)
# (u'journey', 3)
# (u'missile', 3)
# (u'45', 3)
# (u'ideological', 3)
# (u'achievements', 2)
# (u'solemn', 2)
# (u'2042', 2)
# (u'electricity', 2)
# (u'gasoline', 2)
# (u'barriers', 2)
# (u'uninsured', 2)
# (u'shadows', 2)
# (u'autry', 2)
# (u'lawyers', 2)
# (u'strangers', 2)
# (u'millennium', 2)
# (u'creates', 2)
# (u'accompany', 2)
# (u'mandatory', 2)
# (u'confronted', 2)
# (u'patrolling', 2)
# (u'beneficiary', 2)
# (u'tallest', 2)
# (u'falter', 2)
# (u'daughter', 2)
# (u'uninterrupted', 2)
# (u'arab', 2)
# (u'55', 2)
# (u'dear', 2)
# (u'genocide', 2)
# (u'ballistic', 2)
# (u'intend', 2)
# (u'veterans', 2)
# (u'fly', 2)
# (u'landmark', 2)
# (u'impartial', 2)
# (u'classroom', 2)
# (u'midnight', 2)
# (u'aspirations', 2)
# (u'possibilities', 2)
# (u'transforming', 2)
# (u'$18', 2)
# (u'pain', 2)
# (u'vaccines', 2)
# (u'"if', 2)
# (u'humbled', 2)
# (u'unethical', 2)
# (u'horrors', 2)
# (u'ongoing', 2)
# (u'reminded', 2)
# (u'followers', 2)
# (u'solve', 2)
# (u'certain:', 2)
# (u'backgrounds', 2)
# (u'capability', 2)
# (u'assembly', 2)
# (u'central', 2)
# (u'applying', 2)
# (u'hit', 2)
# (u'hybrid', 2)
# (u'worst', 2)
# (u'treating', 2)
# (u'lighting', 2)
# (u'onto', 2)
# (u'egg', 2)
# (u'pray', 2)
# (u'speech', 2)
# (u'heavy', 2)
# (u'fierce', 2)
# (u'sell', 2)
# (u'finding', 2)
# (u'province', 2)
# (u'mentoring', 2)
# (u'creativity', 2)
# (u'flight', 2)
# (u'you.\'"', 2)
# (u'cedar', 2)
# (u'discarded', 2)
# (u'patient', 2)
# (u'you."', 2)
# (u'path:', 2)
# (u'liberate', 2)
# (u'mosque', 2)
# (u'michael', 2)
# (u'focused', 2)
# (u'talent', 2)
# (u'uss', 2)
# (u'sought', 2)
# (u'founding', 2)
# (u'fits', 2)
# (u'aigner-clark', 2)
# (u'chosen', 2)
# (u'us."', 2)
# (u'20,000', 2)
# (u'"god', 2)
# (u'facing', 2)
# (u'placement', 2)
# (u'looked', 2)
# (u'chips', 2)
# (u'reinforcements', 2)
# (u'fulfilled', 2)
# (u'diplomats', 2)
# (u'congresses', 2)
# (u'consequential', 2)
# (u'shortfall', 2)
# (u'member', 2)
# (u'battery', 2)
# (u'taxpayers', 2)
# (u'shelter', 2)
# (u'gained', 2)
# (u'goal:', 2)
# (u'function', 2)
# (u'plague', 2)
# (u'nurses', 2)
# (u'solution', 2)
# (u'items', 2)
# (u'patience', 2)
# (u'spoke', 2)
# (u'sobered', 2)
# (u'"i', 2)
# (u'disruption', 2)
# (u'adult', 2)
# (u'era', 2)
# (u'verify', 2)
# (u'toxin', 2)
# (u'gate', 2)
# (u'defenders', 2)
# (u'series', 2)
# (u'aisle', 2)
# (u'took', 2)
# (u'target', 2)
# (u'scenes', 2)
# (u'endure', 2)
# (u'hijackers', 2)
# (u'talking', 2)
# (u'yours', 2)
# (u'legislate', 2)
# (u'solutions', 2)
# (u'traditions', 2)
# (u'jailed', 2)
# (u'fields', 2)
# (u'troop', 2)
# (u'disaster', 2)
# (u'southeast', 2)
# (u'fallujah', 2)
# (u'sciences', 2)
# (u'anbar', 2)
# (u'performance', 2)
# (u'brutality', 2)
# (u'visible', 2)
# (u'battlefield', 2)
# (u'200', 2)
# (u'blackmail', 2)
# (u'nerve', 2)
# (u'generosity', 2)
# (u'rally', 2)
# (u'tim', 2)
# (u'trafficking', 2)
# (u'update', 2)
# (u'gallons', 2)
# (u'sponsors', 2)
# (u'automobiles', 2)
# (u'aggressively', 2)
# (u'bioterrorism', 2)
# (u'pro-growth', 2)
# (u'mankind', 2)
# (u'embassies', 2)
# (u'records', 2)
# (u'hall', 2)
# (u'entrepreneur', 2)
# (u'marshals', 2)
# (u'el', 2)
# (u'retreating', 2)
# (u'eliminates', 2)
# (u'ideas', 2)
# (u'enthusiasm', 2)
# (u'janet', 2)
# (u'adults', 2)
# (u'suspected', 2)
# (u'missions', 2)
# (u'harsh', 2)
# (u'tradition', 2)
# (u'gangs', 2)
# (u'provincial', 2)
# (u'deceiving', 2)
# (u'rose', 2)
# (u'jews', 2)
# (u'madrid', 2)
# (u'generates', 2)
# (u'credits', 2)
# (u'resolute', 2)
# (u'cultures', 2)
# (u'teachings', 2)
# (u'beliefs', 2)
# (u"enemy's", 2)
# (u'politics', 2)
# (u'activities', 2)
# (u'lisa', 2)
# (u'nearing', 2)
# (u'disruptions', 2)
# (u'staggering', 2)
# (u'strategies', 2)
# (u'challenging', 2)
# (u'transform', 2)
# (u'generate', 2)
# (u'sympathy', 2)
# (u'guest', 2)
# (u'option', 2)
# (u'grace', 2)
# (u'imports', 2)
# (u'chairman', 2)
# (u'charitable', 2)
# (u'mercy', 2)
# (u'retaliation', 2)
# (u'gravest', 2)
# (u'arm', 2)
# (u'dividends', 2)
# (u'decline', 2)
# (u'rulers', 2)
# (u'atomic', 2)
# (u'traffickers', 2)
# (u'resilience', 2)
# (u'religion', 2)
# (u'homeownership', 2)
# (u'scandals', 2)
# (u'centers', 2)
# (u'honors', 2)
# (u'industrialized', 2)
# (u'chose', 2)
# (u'healing', 2)
# (u'lower-income', 2)
# (u'fulfill', 2)
# (u'airline', 2)
# (u'2018', 2)
# (u'fascism', 2)
# (u'familiar', 2)
# (u'gray', 2)
# (u'generational', 2)
# (u'clearing', 2)
# (u'site', 2)
# (u'cross', 2)
# (u'coaches', 2)
# (u'distinction', 2)
# (u'safia', 2)
# (u'200,000', 2)
# (u'unfolding', 2)
# (u'deadly', 2)
# (u'boom', 2)
# (u'appetite', 2)
# (u'charter', 2)
# (u'seeks', 2)
# (u'governing', 2)
# (u'study', 2)
# (u'transparency', 2)
# (u'travel', 2)
# (u'amazing', 2)
# (u'demanding', 2)
# (u'preventive', 2)
# (u'drawdown', 2)
# (u'reformers', 2)
# (u"hussein's", 2)
# (u'went', 2)
# (u'principled', 2)
# (u'newly', 2)
# (u'up-or-down', 2)
# (u'qualities', 2)
# (u'rich', 2)
# (u'earn', 2)
# (u'cooperation', 2)
# (u'counsel', 2)
# (u'stricter', 2)
# (u'gathering', 2)
# (u'launched', 2)
# (u'tax-free', 2)
# (u'beloved', 2)
# (u'arrivals', 2)
# (u'dead', 2)
# (u'participation', 2)
# (u'$200', 2)
# (u'elderly', 2)
# (u'solar', 2)
# (u'beamer', 2)
# (u'dying', 2)
# (u'weakening', 2)
# (u'iraq:', 2)
# (u'philippines', 2)
# (u'botulinum', 2)
# (u'patrols', 2)
# (u'havoc', 2)
# (u'falling', 2)
# (u'hardest', 2)
# (u'repressing', 2)
# (u'dedicated', 2)
# (u'unwavering', 2)
# (u'sunday', 2)
# (u'fourth', 2)
# (u'staying', 2)
# (u'lifting', 2)
# (u'conquest', 2)
# (u'boehner', 2)
# (u'possibility', 2)
# (u'unchanging', 2)
# (u'television', 2)
# (u'investors', 2)
# (u'oppressive', 2)
# (u'wind', 2)
# (u'violated', 2)
# (u'indicted', 2)
# (u'rescuers', 2)
# (u'insist', 2)
# (u'thousand', 2)
# (u'proven', 2)
# (u'libya', 2)
# (u'tribal', 2)
# (u'stepped', 2)
# (u'closest', 2)
# (u'nest', 2)
# (u'bodies', 2)
# (u'confirmed', 2)
# (u'lets', 2)
# (u'bigger', 2)
# (u'buying', 2)
# (u'daily', 2)
# (u'depth', 2)
# (u'driving', 2)
# (u'$30', 2)
# (u'hunting', 2)
# (u'pledged', 2)
# (u'dictatorship', 2)
# (u'inspired', 2)
# (u'company', 2)
# (u'sacred', 2)
# (u"today's", 2)
# (u'committee', 2)
# (u'environmentally', 2)
# (u'taxpayer', 2)
# (u'ryan', 2)
# (u'america:', 2)
# (u'shipment', 2)
# (u'zarqawi', 2)
# (u'slipped', 2)
# (u'aims', 2)
# (u'despise', 2)
# (u'waiting', 2)
# (u'flights', 2)
# (u'feels', 2)
# (u'redefine', 2)
# (u'9/11', 2)
# (u'volunteered', 2)
# (u'starving', 2)
# (u'rid', 2)
# (u'fate', 2)
# (u'poland', 2)
# (u'displaced', 2)
# (u'miracle', 2)
# (u'significant', 2)
# (u'entitlement', 2)
# (u'deployed', 2)
# (u'thugs', 2)
# (u'2004', 2)
# (u'torture', 2)
# (u'explore', 2)
# (u'love."', 2)
# (u'reflects', 2)
# (u'hiv', 2)
# (u'realized', 2)
# (u'2017', 2)
# (u'homeless', 2)
# (u'doubled', 2)
# (u'shut', 2)
# (u'reaches', 2)
# (u'switch', 2)
# (u'skeptics', 2)
# (u'pursues', 2)
# (u'witness', 2)
# (u"you'll", 2)
# (u'succeeded', 2)
# (u'trucks', 2)
# (u'nationwide', 2)
# (u'minds', 2)
# (u'provinces', 2)
# (u'arabic', 2)
# (u'paycheck', 2)
# (u'diversify', 2)
# (u'7,000', 2)
# (u'entering', 2)
# (u'horrific', 2)
# (u'girl', 2)
# (u'skies', 2)
# (u'christians', 2)
# (u'jihad', 2)
# (u'feeding', 2)
# (u'basics', 2)
# (u'tired', 2)
# (u'spouses', 2)
# (u'graders', 2)
# (u'oceans', 2)
# (u'homeowners', 2)
# (u'bombing', 2)
# (u'self-appointed', 2)
# (u'belarus', 2)
# (u"terrorists'", 2)
# (u'sixteen', 2)
# (u'victories', 2)
# (u'whim', 2)
# (u'truman', 2)
# (u'steroids', 2)
# (u'night', 2)
# (u'abandoning', 2)
# (u'errors', 2)
# (u'sanctuary', 2)
# (u'hunger', 2)
# (u'pearson', 2)
# (u'analyze', 2)
# (u'defiance', 2)
# (u'doubts', 2)
# (u'kindness', 2)
# (u'recover', 2)
# (u'endless', 2)
# (u'apart', 2)
# (u'starvation', 2)
# (u'bottom', 2)
# (u'creative', 2)
# (u'palestinians', 2)
# (u'son', 2)
# (u'greatness', 2)
# (u'happy', 2)
# (u'wood', 2)
# (u'prayer', 2)
# (u'floor', 2)
# (u'stake', 2)
# (u'setting', 2)
# (u'skin', 2)
# (u'hijacked', 2)
# (u'tonight:', 2)
# (u'planes', 2)
# (u'memory', 2)
# (u'loving', 2)
# (u'sharing', 2)
# (u'approving', 2)
# (u'goods', 2)
# (u'destructive', 2)
# (u'futures', 2)
# (u'sparing', 2)
# (u'transition', 2)
# (u'honest', 2)
# (u'custom', 2)
# (u'convene', 2)
# (u'30,000', 2)
# (u"'you've", 2)
# (u'detect', 2)
# (u'farmers', 2)
# (u'infrastructure', 2)
# (u'doctor', 2)
# (u'dealt', 2)
# (u'civic', 2)
# (u'liters', 2)
# (u'overthrow', 2)
# (u'kennedy', 2)
# (u'zimbabwe', 2)
# (u'jerusalem', 2)
# (u'exceptional', 2)
# (u'allah', 2)
# (u'rage', 2)
# (u'vehicles', 2)
# (u'summit', 2)
# (u'individual', 2)
# (u'americans:', 2)
# (u'atrocity', 2)
# (u'witnessed', 2)
# (u'promising', 2)
# (u'tracking', 2)
# (u'plane', 2)
# (u'23', 2)
# (u'resentments', 2)
# (u'responders', 2)
# (u'base', 2)
# (u'patenting', 2)
# (u'arc', 2)
# (u'years;', 2)
# (u'minorities', 2)
# (u'alliances', 2)
# (u'(laughter)', 2)
# (u'edge', 2)
# (u'question:', 2)
# (u'drove', 2)
# (u'mirror', 2)
# (u'pollution', 2)
# (u'consultation', 2)
# (u'humanitarian', 2)
# (u'package', 2)
# (u'defines', 2)
# (u'stable', 2)
# (u'shock', 2)
# (u'parliament', 2)
# (u'sanctions', 2)
# (u'fringe', 2)
# (u'sit', 2)
# (u'sexually-transmitted', 2)
# (u'pollution-free', 2)
# (u'despite', 2)
# (u'literacy', 2)
# (u'electing', 2)
# (u'limiting', 2)
# (u'agency', 2)
# (u'deploy', 2)
# (u'staff', 2)
# (u'won', 2)
# (u"qaeda's", 2)
# (u'superb', 2)
# (u'squads', 2)
# (u'volunteer', 2)
# (u'doctor-patient', 2)
# (u'camp', 2)
# (u'reporting', 2)
# (u'desk', 2)
# (u'hiding', 2)
# (u'communism', 2)
# (u'alliance', 2)
# (u'this:', 2)
# (u'deaths', 2)
# (u'afghans', 2)
# (u'uzbekistan', 1)
# (u'blaspheme', 1)
# (u'admire', 1)
# (u'resilient', 1)
# (u'hero', 1)
# (u'reagan', 1)
# (u'military:', 1)
# (u'dna', 1)
# (u'coal-fired', 1)
# (u'enriching', 1)
# (u'music', 1)
# (u'strike', 1)
# (u'type', 1)
# (u'high-wage', 1)
# (u'expeditionary', 1)
# (u'95', 1)
# (u"workers'", 1)
# (u'walsh', 1)
# (u'consumer', 1)
# (u'kabul', 1)
# (u'mess', 1)
# (u'complacent', 1)
# (u'41st', 1)
# (u'policy...choose', 1)
# (u'untold', 1)
# (u'wound', 1)
# (u'world...is', 1)
# (u'principle"', 1)
# (u'messages', 1)
# (u'electronic', 1)
# (u'bitter', 1)
# (u'self-reliant', 1)
# (u'non-security', 1)
# (u'shipments', 1)
# (u'two-and-a-half', 1)
# (u'imported', 1)
# (u'on:', 1)
# (u'mutombo', 1)
# (u'8\\1/2\\', 1)
# (u'7.2', 1)
# (u'lethal', 1)
# (u'endowment', 1)
# (u'folks', 1)
# (u'bahrain', 1)
# (u'asbestos', 1)
# (u'$10', 1)
# (u'excel', 1)
# (u'birmingham', 1)
# (u'ruins', 1)
# (u'thing--(laughter)--but', 1)
# (u'grievous', 1)
# (u'adapting', 1)
# (u'attention...and', 1)
# (u'policy--(applause)--a', 1)
# (u'threads', 1)
# (u'years--4,000', 1)
# (u'wider', 1)
# (u'economy--our', 1)
# (u'transformed', 1)
# (u'dots', 1)
# (u'options:', 1)
# (u'tide', 1)
# (u'harms', 1)
# (u'stopping', 1)
# (u'$7,500', 1)
# (u'out-produce', 1)
# (u'governors', 1)
# (u'devalued', 1)
# (u'singapore...a', 1)
# (u'identify', 1)
# (u'partnering', 1)
# (u'leaders:', 1)
# (u'leading-edge', 1)
# (u'casting', 1)
# (u'shoulder', 1)
# (u'hitlerism', 1)
# (u'sends', 1)
# (u'proudly', 1)
# (u'1,178', 1)
# (u'musharraf', 1)
# (u'aggression..with', 1)
# (u'shifting', 1)
# (u'chapter', 1)
# (u'hastert', 1)
# (u'balanced', 1)
# (u'understandable', 1)
# (u'occupiers', 1)
# (u'originating', 1)
# (u'infections', 1)
# (u'reenter', 1)
# (u'discriminate', 1)
# (u'underworld--including', 1)
# (u'pessimists', 1)
# (u'purple', 1)
# (u'push', 1)
# (u'someplace', 1)
# (u'father', 1)
# (u'tragedy--especially', 1)
# (u'1999', 1)
# (u'excellence', 1)
# (u'ebola', 1)
# (u'nationalized', 1)
# (u'boost', 1)
# (u'litigation', 1)
# (u'baseball', 1)
# (u'teaches', 1)
# (u'guilty', 1)
# (u'awakening."', 1)
# (u'everybody', 1)
# (u'remaking', 1)
# (u'abbas', 1)
# (u'towers', 1)
# (u'abortion', 1)
# (u'districts', 1)
# (u'posing', 1)
# (u'monitoring', 1)
# (u'fortunately', 1)
# (u'usa."', 1)
# (u'contracts', 1)
# (u'mae', 1)
# (u'borrowing', 1)
# (u'outpouring', 1)
# (u'jail', 1)
# (u'pulled', 1)
# (u'miracles', 1)
# (u'ethic', 1)
# (u'selves', 1)
# (u'norway', 1)
# (u'interview', 1)
# (u'prospers', 1)
# (u'directing', 1)
# (u'farewell', 1)
# (u'incentives', 1)
# (u'departments;', 1)
# (u'programming', 1)
# (u'spoken', 1)
# (u'encourages', 1)
# (u'tragic', 1)
# (u'broadcast', 1)
# (u'$14', 1)
# (u'company;', 1)
# (u'malaria-related', 1)
# (u'applause.)', 1)
# (u'efficient', 1)
# (u'note', 1)
# (u'shop', 1)
# (u'shot', 1)
# (u'threshold', 1)
# (u'productivity', 1)
# (u'thompson', 1)
# (u'hostage', 1)
# (u"saddam's", 1)
# (u'flaunt', 1)
# (u'famine', 1)
# (u'mission:', 1)
# (u'affecting', 1)
# (u'ink-stained', 1)
# (u'jets', 1)
# (u'congregations', 1)
# (u'successes', 1)
# (u'reluctantly', 1)
# (u'151', 1)
# (u'madness', 1)
# (u'ordered', 1)
# (u'lawsuit', 1)
# (u'crawford', 1)
# (u'truths', 1)
# (u'dropouts', 1)
# (u'embrace', 1)
# (u'allawi', 1)
# (u'participant', 1)
# (u'hermis', 1)
# (u'disadvantaged', 1)
# (u'mortgages', 1)
# (u'coordinate', 1)
# (u'yearly', 1)
# (u'homeland;', 1)
# (u'sights', 1)
# (u'risking', 1)
# (u'accumulate', 1)
# (u'represented', 1)
# (u'thinking', 1)
# (u'stagnant', 1)
# (u'grid', 1)
# (u'opportunity--a', 1)
# (u'wrongful', 1)
# (u'miraculous', 1)
# (u'health--(applause)--and', 1)
# (u'caribbean', 1)
# (u'sudan', 1)
# (u'refundable', 1)
# (u'seconds', 1)
# (u'assemble', 1)
# (u'misunderstanding:', 1)
# (u'tremendous', 1)
# (u'rallied', 1)
# (u'fundamentals', 1)
# (u'you;', 1)
# (u'drills', 1)
# (u'grasp', 1)
# (u'viruses', 1)
# (u'29,984', 1)
# (u'endeavors', 1)
# (u'bullets', 1)
# (u'tackle', 1)
# (u'pelosi', 1)
# (u'remote', 1)
# (u'people...and', 1)
# (u'diesel', 1)
# (u'base...and', 1)
# (u'founded', 1)
# (u'talks', 1)
# (u'tv', 1)
# (u'clerics', 1)
# (u'blood-soaked', 1)
# (u'premium', 1)
# (u'stimulus', 1)
# (u'pledge:', 1)
# (u'ted', 1)
# (u"pennsylvania's", 1)
# (u'witnesses', 1)
# (u'option:', 1)
# (u'multinational', 1)
# (u'vx', 1)
# (u'hopelessness', 1)
# (u'petroleum', 1)
# (u'promoting', 1)
# (u'self-sacrifice', 1)
# (u'protectionists', 1)
# (u'non-negotiable', 1)
# (u'half-century', 1)
# (u'aspire', 1)
# (u'mislead', 1)
# (u'wreaking', 1)
# (u'human-animal', 1)
# (u'materialistic', 1)
# (u'commuters', 1)
# (u'24', 1)
# (u'401k', 1)
# (u'tyrants', 1)
# (u'it:', 1)
# (u'loosely', 1)
# (u'engaging', 1)
# (u'labs', 1)
# (u'director', 1)
# (u'baathist', 1)
# (u'logistics', 1)
# (u'feet', 1)
# (u'slower', 1)
# (u'visions', 1)
# (u'tate', 1)
# (u'hallowed', 1)
# (u'attendants', 1)
# (u'treasured', 1)
# (u'"made', 1)
# (u'purposes:', 1)
# (u'employ', 1)
# (u'vial', 1)
# (u'stalk', 1)
# (u'unrelenting', 1)
# (u'servitude', 1)
# (u'three-quarters', 1)
# (u'unused', 1)
# (u'shareholder', 1)
# (u'security;', 1)
# (u'mobile', 1)
# (u'hamid', 1)
# (u'tubes', 1)
# (u'sector', 1)
# (u'carefully', 1)
# (u'routinely', 1)
# (u'impact', 1)
# (u'"thank', 1)
# (u'indifference', 1)
# (u'devastate', 1)
# (u'timeless', 1)
# (u'art', 1)
# (u'2.3', 1)
# (u'expertise', 1)
# (u'oversee', 1)
# (u'load', 1)
# (u'tongues', 1)
# (u'(laughter.)', 1)
# (u'spotting', 1)
# (u'described', 1)
# (u'monthly', 1)
# (u'preamble', 1)
# (u'ran', 1)
# (u'complicated', 1)
# (u'clean-energy', 1)
# (u'employer-provided', 1)
# (u'replaced', 1)
# (u'scheduled', 1)
# (u'backing', 1)
# (u'binding', 1)
# (u'confound', 1)
# (u'reprogram', 1)
# (u'lengths', 1)
# (u'rules', 1)
# (u'2033', 1)
# (u'timid', 1)
# (u'flags', 1)
# (u'letting', 1)
# (u'pillars', 1)
# (u'yield;', 1)
# (u're-entry', 1)
# (u'short-changing', 1)
# (u'systematically', 1)
# (u'peril...from', 1)
# (u'unstable', 1)
# (u'together."', 1)
# (u'selfishness', 1)
# (u'singing', 1)
# (u'donations', 1)
# (u'refuses', 1)
# (u'crowds', 1)
# (u'freddie', 1)
# (u'blackmailed', 1)
# (u'credible', 1)
# (u'gavel', 1)
# (u'credibly', 1)
# (u'prey', 1)
# (u'fulfilling', 1)
# (u'boomers', 1)
# (u'300,000', 1)
# (u'shortcuts', 1)
# (u'duration', 1)
# (u'traditional', 1)
# (u'backed', 1)
# (u'2002', 1)
# (u'humvee', 1)
# (u'buffalo', 1)
# (u'cabinet-level', 1)
# (u'highways', 1)
# (u'intensive', 1)
# (u'fences', 1)
# (u'afghanistan:', 1)
# (u'inspection', 1)
# (u'youngest', 1)
# (u'second-rate', 1)
# (u'technical', 1)
# (u'environment--(applause)', 1)
# (u"dad's", 1)
# (u'limb', 1)
# (u'timetable', 1)
# (u'benchmark', 1)
# (u'israelis', 1)
# (u'posturing', 1)
# (u'insists', 1)
# (u'me--i', 1)
# (u'favorite', 1)
# (u'$350', 1)
# (u'profile', 1)
# (u'farm', 1)
# (u'requirements', 1)
# (u'chasing', 1)
# (u'erasing', 1)
# (u'industries', 1)
# (u'banner', 1)
# (u'restrain', 1)
# (u'moutardier', 1)
# (u'indexing', 1)
# (u'investor', 1)
# (u'"each', 1)
# (u'jones', 1)
# (u'constitute', 1)
# (u'sands', 1)
# (u'lists;', 1)
# (u'category', 1)
# (u'critics', 1)
# (u'three-year', 1)
# (u'disclose', 1)
# (u'hesitation', 1)
# (u'release', 1)
# (u'repairing', 1)
# (u'450', 1)
# (u'sadly', 1)
# (u'guys', 1)
# (u'elite', 1)
# (u'roberts', 1)
# (u'steep', 1)
# (u'1.4', 1)
# (u'unelected', 1)
# (u'intention:', 1)
# (u'prisoner', 1)
# (u'draws', 1)
# (u'crate', 1)
# (u'lifetime--to', 1)
# (u'brutalized', 1)
# (u'p.s.:', 1)
# (u'samarra', 1)
# (u'tape', 1)
# (u'mohammed', 1)
# (u"won't", 1)
# (u'half-million', 1)
# (u'spotted', 1)
# (u"patients'", 1)
# (u'turbulent', 1)
# (u'sanity', 1)
# (u'birth."', 1)
# (u'unravel', 1)
# (u'dignity:', 1)
# (u'swift', 1)
# (u'karzai', 1)
# (u"lebanon's", 1)
# (u'walt', 1)
# (u'shaikh', 1)
# (u'slowly', 1)
# (u'moved', 1)
# (u'airplanes', 1)
# (u'petroleum-based', 1)
# (u'welcoming', 1)
# (u'fearful', 1)
# (u'harden', 1)
# (u'$880', 1)
# (u'weighed', 1)
# (u'hearted', 1)
# (u'units', 1)
# (u'disagree', 1)
# (u'throngs', 1)
# (u'soviet', 1)
# (u'excessive', 1)
# (u'falter!', 1)
# (u'usage', 1)
# (u'refugees', 1)
# (u'sponsoring', 1)
# (u'levees', 1)
# (u'regain', 1)
# (u'dismantle', 1)
# (u'prohibited', 1)
# (u'targeting', 1)
# (u'rare', 1)
# (u'nationals', 1)
# (u'angeles', 1)
# (u'ridge', 1)
# (u'mastermind', 1)
# (u'firefighter', 1)
# (u'misguided', 1)
# (u'biggest', 1)
# (u'manhunt', 1)
# (u'recruited', 1)
# (u'breakthrough', 1)
# (u'infants', 1)
# (u'3,200', 1)
# (u'confidence;', 1)
# (u'kurds', 1)
# (u'dictatorships', 1)
# (u'irons', 1)
# (u'risked', 1)
# (u'outdated', 1)
# (u'bioshield', 1)
# (u'write', 1)
# (u'asian', 1)
# (u'courageous', 1)
# (u'implanting', 1)
# (u'miller', 1)
# (u'surrounding', 1)
# (u'275', 1)
# (u'venture:', 1)
# (u'preferences', 1)
# (u'fingers', 1)
# (u'churches', 1)
# (u'confronts', 1)
# (u'analysts', 1)
# (u'golden', 1)
# (u'equipment;', 1)
# (u'reflected', 1)
# (u'negative', 1)
# (u'violently', 1)
# (u'90', 1)
# (u'blocking', 1)
# (u'player', 1)
# (u'rulings', 1)
# (u'determining', 1)
# (u'wonder-working', 1)
# (u'indicates', 1)
# (u'rescue', 1)
# (u'aging', 1)
# (u'violence."', 1)
# (u'childhood', 1)
# (u'mayor', 1)
# (u'damascus', 1)
# (u'enrich', 1)
# (u'intimidation', 1)
# (u'band', 1)
# (u'represents', 1)
# (u'prohibit', 1)
# (u'celebrating', 1)
# (u'railed', 1)
# (u'sliding', 1)
# (u'foundation', 1)
# (u'enough:', 1)
# (u'disappearing', 1)
# (u'escalation', 1)
# (u'ranging', 1)
# (u'emissions-free', 1)
# (u'job-creators', 1)
# (u'fairest', 1)
# (u'charlie', 1)
# (u'georgetown', 1)
# (u'tells', 1)
# (u"norwood's", 1)
# (u'orphaned', 1)
# (u'treats', 1)
# (u'brilliance', 1)
# (u'religions', 1)
# (u'touched', 1)
# (u'wide', 1)
# (u'25,000', 1)
# (u'new;', 1)
# (u'pressures', 1)
# (u'decide:', 1)
# (u'sacrificing', 1)
# (u'terror...the', 1)
# (u'players', 1)
# (u'planned', 1)
# (u'agile', 1)
# (u'affiliated', 1)
# (u'captive', 1)
# (u'flexible', 1)
# (u'teenager', 1)
# (u'deeper', 1)
# (u'japan;', 1)
# (u'preeminent', 1)
# (u'forsaking', 1)
# (u'mentor', 1)
# (u'hispanic', 1)
# (u'investments', 1)
# (u'war?', 1)
# (u'transforms', 1)
# (u'"mutombo', 1)
# (u'melting', 1)
# (u'"evil', 1)
# (u'scavenger', 1)
# (u'country?', 1)
# (u'years--(applause)--and', 1)
# (u'congratulate', 1)
# (u'filming', 1)
# (u'christmas', 1)
# (u'bold', 1)
# (u'discount', 1)
# (u'fumes', 1)
# (u'why?', 1)
# (u'sovereign', 1)
# (u'stuck', 1)
# (u'starve', 1)
# (u'builds', 1)
# (u'prevents', 1)
# (u'torturing', 1)
# (u'propaganda', 1)
# (u'examples', 1)
# (u'150', 1)
# (u'covert', 1)
# (u'hungry', 1)
# (u'revitalize', 1)
# (u'accounting', 1)
# (u'complicit', 1)
# (u'tie', 1)
# (u'embodied', 1)
# (u'$15,000', 1)
# (u'defying', 1)
# (u'turns', 1)
# (u'democrat', 1)
# (u'subway', 1)
# (u'round', 1)
# (u'discover', 1)
# (u'crescent', 1)
# (u'verifiably', 1)
# (u'targets', 1)
# (u'somalia', 1)
# (u'jungles', 1)
# (u'exams', 1)
# (u'departures', 1)
# (u"god's", 1)
# (u'undersigned', 1)
# (u'unmarked', 1)
# (u'soul', 1)
# (u'battered', 1)
# (u'bankrupt', 1)
# (u'immune', 1)
# (u'drastic', 1)
# (u'candles', 1)
# (u'inform', 1)
# (u'deposit', 1)
# (u'hiring', 1)
# (u'citizenship', 1)
# (u'equip', 1)
# (u'monitor', 1)
# (u'shalala', 1)
# (u'corners', 1)
# (u'realistic', 1)
# (u'quartet', 1)
# (u'significantly', 1)
# (u'cairo', 1)
# (u'americorps', 1)
# (u'tempore', 1)
# (u'factory', 1)
# (u'pumping', 1)
# (u'matchless', 1)
# (u'people."', 1)
# (u'indicate', 1)
# (u'legally', 1)
# (u'recruit', 1)
# (u'hydrogen-fueled', 1)
# (u'elsewhere', 1)
# (u'warriors', 1)
# (u'600,000', 1)
# (u'clearer', 1)
# (u'visitors', 1)
# (u'buckingham', 1)
# (u'jakarta', 1)
# (u'asia...a', 1)
# (u'jumped', 1)
# (u'professional', 1)
# (u'sites', 1)
# (u'casablanca', 1)
# (u'fend', 1)
# (u'unkind', 1)
# (u'dull', 1)
# (u'rejoiced', 1)
# (u'biodiesel', 1)
# (u'reveal', 1)
# (u'honesty', 1)
# (u'declares', 1)
# (u'stigma', 1)
# (u'praise...they', 1)
# (u'alarming', 1)
# (u'boy', 1)
# (u'import', 1)
# (u'disagreed', 1)
# (u'dome', 1)
# (u'mountaintops', 1)
# (u'implementing', 1)
# (u'sensible', 1)
# (u'companionship', 1)
# (u'airlines', 1)
# (u'grenades', 1)
# (u'combined', 1)
# (u'life:', 1)
# (u'telephone', 1)
# (u'strains', 1)
# (u'attacks...the', 1)
# (u'exhaust', 1)
# (u'centuries', 1)
# (u'roughly', 1)
# (u'(laughter', 1)
# (u'gates', 1)
# (u'support...and', 1)
# (u'rejoin', 1)
# (u'grim', 1)
# (u'patrick', 1)
# (u'god;s', 1)
# (u'twelve', 1)
# (u'manhood', 1)
# (u'freer', 1)
# (u'pioneer', 1)
# (u'sixth', 1)
# (u'outreach', 1)
# (u'pastors', 1)
# (u'thailand', 1)
# (u'treatable', 1)
# (u'all:', 1)
# (u'grows;', 1)
# (u'philadelphia', 1)
# (u'desert', 1)
# (u'los', 1)
# (u'tireless', 1)
# (u'treat', 1)
# (u'continents', 1)
# (u'victory;', 1)
# (u'emissions', 1)
# (u'600', 1)
# (u'requested', 1)
# (u'conspiracies', 1)
# (u'message:', 1)
# (u'assets', 1)
# (u'represent', 1)
# (u'discouraging', 1)
# (u'lining', 1)
# (u'returned', 1)
# (u'surprise', 1)
# (u'overseas:', 1)
# (u'safe."', 1)
# (u'portable', 1)
# (u'prevailed', 1)
# (u'zarqawi:', 1)
# (u"safia's", 1)
# (u'samar', 1)
# (u'toughness', 1)
# (u'"let\'s', 1)
# (u'aimed', 1)
# (u'unpredictable', 1)
# (u'forcefully', 1)
# (u"d'alesandro", 1)
# (u'budgets', 1)
# (u'kenya', 1)
# (u'imminent', 1)
# (u'maps', 1)
# (u'uprising', 1)
# (u'sneak', 1)
# (u'sharon', 1)
# (u'fi', 1)
# (u'crippling', 1)
# (u'dread', 1)
# (u'$20', 1)
# (u'truth:', 1)
# (u'29', 1)
# (u'disclosed', 1)
# (u'waged', 1)
# (u"you've", 1)
# (u'2,600', 1)
# (u'privileged', 1)
# (u'mastered', 1)
# (u'modernized', 1)
# (u'$1.2', 1)
# (u'threatens', 1)
# (u'i.r.s', 1)
# (u'diploma', 1)
# (u'enforce', 1)
# (u'gibraltar', 1)
# (u'witnessing', 1)
# (u'grass-roots', 1)
# (u'pflugerville', 1)
# (u'reflection', 1)
# (u'2025', 1)
# (u'doubly', 1)
# (u'paths', 1)
# (u'trip', 1)
# (u'screenings', 1)
# (u'dealers', 1)
# (u'ends:', 1)
# (u'anthem', 1)
# (u'perseverance', 1)
# (u'sanctity', 1)
# (u'betray', 1)
# (u'unsuited', 1)
# (u'doubles', 1)
# (u'relentless', 1)
# (u'premise:', 1)
# (u'declines', 1)
# (u'sanctuaries', 1)
# (u'hungry;', 1)
# (u'minorities--(applause)--and', 1)
# (u'guantanamo', 1)
# (u'reverse', 1)
# (u'sensitive', 1)
# (u'month--over', 1)
# (u'arsenal', 1)
# (u'twenty-eight', 1)
# (u'creed:', 1)
# (u'coalitions', 1)
# (u'all-time', 1)
# (u'chant', 1)
# (u'carbon', 1)
# (u'ruler', 1)
# (u'smallpox...and', 1)
# (u'franklin', 1)
# (u'robust', 1)
# (u'tables', 1)
# (u'medicines..many', 1)
# (u'advisers', 1)
# (u'transformation', 1)
# (u'knock', 1)
# (u'donna', 1)
# (u'pierre', 1)
# (u'redefining', 1)
# (u'integration', 1)
# (u'concealed', 1)
# (u'intense', 1)
# (u'"ordinary', 1)
# (u'disclosure', 1)
# (u'hometown', 1)
# (u'hope:', 1)
# (u'wrote:', 1)
# (u'uncertainties', 1)
# (u'forces:', 1)
# (u'occupy', 1)
# (u'mounting', 1)
# (u'segregation', 1)
# (u'junior', 1)
# (u'security:', 1)
# (u'problem:', 1)
# (u'divisive', 1)
# (u'graceful', 1)
# (u'petraeus', 1)
# (u'fixing', 1)
# (u'democratically', 1)
# (u'explaining', 1)
# (u'mustard', 1)
# (u'intensified', 1)
# (u'restrained', 1)
# (u'oppress', 1)
# (u'memories', 1)
# (u'advisory', 1)
# (u'gang', 1)
# (u'attackers', 1)
# (u'murderous', 1)
# (u'incoherent', 1)
# (u're-defined', 1)
# (u'eve', 1)
# (u'hungary', 1)
# (u'radicals', 1)
# (u'examining', 1)
# (u'$60,000', 1)
# (u'screeners', 1)
# (u'journalists', 1)
# (u'finery', 1)
# (u'us:', 1)
# (u'fulfillment', 1)
# (u'dripping', 1)
# (u'effectively', 1)
# (u'hesitate', 1)
# (u'daring', 1)
# (u'forest', 1)
# (u'sir', 1)
# (u'recognizes', 1)
# (u'ties', 1)
# (u'reminder:', 1)
# (u'coordinated', 1)
# (u'136', 1)
# (u'pachachi', 1)
# (u'invest;', 1)
# (u'covered', 1)
# (u'physicians', 1)
# (u'disrupted', 1)
# (u'insisting', 1)
# (u'worlds', 1)
# (u'warned', 1)
# (u'identified', 1)
# (u'arlene', 1)
# (u'america."', 1)
# (u'thirteen', 1)
# (u'secretly', 1)
# (u'36-percent', 1)
# (u'afterward', 1)
# (u'mortar', 1)
# (u'unknown', 1)
# (u'gear', 1)
# (u'environmental', 1)
# (u'unfurling', 1)
# (u'coretta', 1)
# (u'descriptions', 1)
# (u'teenagers', 1)
# (u'linked', 1)
# (u'free-flowing', 1)
# (u'pursued', 1)
# (u'mix', 1)
# (u'bosnian', 1)
# (u'rediscovered', 1)
# (u'destruction-related', 1)
# (u'gallery', 1)
# (u'sing;', 1)
# (u'wounded', 1)
# (u'$500', 1)
# (u'perversion', 1)
# (u'greenhouse', 1)
# (u'declared:', 1)
# (u'hijacking', 1)
# (u'wellness', 1)
# (u'embryonic', 1)
# (u'directs', 1)
# (u'interpreter', 1)
# (u'hardship', 1)
# (u'notice:', 1)
# (u'watch--yet', 1)
# (u'intimidated', 1)
# (u'joy', 1)
# (u'"catch', 1)
# (u'dividend', 1)
# (u'words:', 1)
# (u'home;', 1)
# (u'nations...built', 1)
# (u'abandoned', 1)
# (u'see...and', 1)
# (u'entry...posted', 1)
# (u'optimistic', 1)
# (u'conserve', 1)
# (u'seoul', 1)
# (u'powell', 1)
# (u'scholars', 1)
# (u'patterns', 1)
# (u'arsenals..and', 1)
# (u'wanted."', 1)
# (u'1,100', 1)
# (u'checks--', 1)
# (u'crushed', 1)
# (u'gephardt', 1)
# (u'represses', 1)
# (u'issues:', 1)
# (u'searching', 1)
# (u'money;', 1)
# (u'beslan', 1)
# (u'4,000', 1)
# (u'merge', 1)
# (u'dependency', 1)
# (u'unbelievers', 1)
# (u'shoreless', 1)
# (u'inner', 1)
# (u'maze', 1)
# (u'captives', 1)
# (u'instructing', 1)
# (u'ruling', 1)
# (u"dictatator's", 1)
# (u'airports...begun', 1)
# (u'forests', 1)
# (u'disasters', 1)
# (u'illusion', 1)
# (u'biotechnology', 1)
# (u'persistent', 1)
# (u'rural', 1)
# (u'mombasa', 1)
# (u'bureaucrats', 1)
# (u'seriously', 1)
# (u'unanswered', 1)
# (u'rational', 1)
# (u'presidency', 1)
# (u'guiding', 1)
# (u'c-span', 1)
# (u'triumph', 1)
# (u'1,600', 1)
# (u'panama', 1)
# (u'airmen', 1)
# (u'behavior', 1)
# (u'affiliates', 1)
# (u'108', 1)
# (u'rightness', 1)
# (u'interpret', 1)
# (u'luther', 1)
# (u'remnant', 1)
# (u'counts', 1)
# (u'hospital', 1)
# (u'well-trained', 1)
# (u'expose', 1)
# (u'1993', 1)
# (u'heartless', 1)
# (u'totaled', 1)
# (u'tragedy--god', 1)
# (u'gamble', 1)
# (u'undergoing', 1)
# (u'damaged', 1)
# (u'assimilates', 1)
# (u"taxpayers'", 1)
# (u'presiding', 1)
# (u'reforming', 1)
# (u'choices"', 1)
# (u'enlisted', 1)
# (u'coffee', 1)
# (u'man-made', 1)
# (u'bank', 1)
# (u'oxygen', 1)
# (u'shadowy', 1)
# (u'milan', 1)
# (u'banning', 1)
# (u'enormous', 1)
# (u'recovering', 1)
# (u'refugee', 1)
# (u'tempting', 1)
# (u'bite', 1)
# (u'disfigured', 1)
# (u'awoke', 1)
# (u'confirming', 1)
# (u'percentage', 1)
# (u'villager', 1)
# (u'emergencies;', 1)
# (u'idle', 1)
# (u'historical', 1)
# (u"company's", 1)
# (u'well?', 1)
# (u'willingness', 1)
# (u'wagered', 1)
# (u'eagerly', 1)
# (u'doors', 1)
# (u'explanation', 1)
# (u'reverence', 1)
# (u'explosives', 1)
# (u'tanzania', 1)
# (u'competitors', 1)
# (u'confederation', 1)
# (u'unmistakable', 1)
# (u'terror;', 1)
# (u'explain', 1)
# (u'myth', 1)
# (u'shutting', 1)
# (u'man:', 1)
# (u'tribute', 1)
# (u'determined:', 1)
# (u'blew', 1)
# (u'artificial', 1)
# (u'beacon', 1)
# (u'country...and', 1)
# (u'250', 1)
# (u'sam', 1)
# (u'tiny', 1)
# (u'darfur', 1)
# (u'incite', 1)
# (u'reconnaissance', 1)
# (u'doha', 1)
# (u'80,000', 1)
# (u'scenario', 1)
# (u'possessed', 1)
# (u'inherit', 1)
# (u'detained', 1)
# (u'afghanistan...a', 1)
# (u'background', 1)
# (u'life-saving', 1)
# (u'yes', 1)
# (u'ease', 1)
# (u'grounding', 1)
# (u'shadow', 1)
# (u'justice;', 1)
# (u'[and]', 1)
# (u'dedicating', 1)
# (u'uncertainty:', 1)
# (u'clash', 1)
# (u'unit', 1)
# (u'defensive', 1)
# (u'codify', 1)
# (u'cracking', 1)
# (u'murderers', 1)
# (u'mosques', 1)
# (u'launching', 1)
# (u'congratulations', 1)
# (u'private-sector', 1)
# (u'infections...treat', 1)
# (u'delays', 1)
# (u'hole', 1)
# (u'ticking', 1)
# (u'broadly', 1)
# (u'refinance', 1)
# (u'responsibility;', 1)
# (u'minute', 1)
# (u'comforting', 1)
# (u'educate', 1)
# (u'regrouping', 1)
# (u'bob', 1)
# (u'reclaim', 1)
# (u'teenage', 1)
# (u'citizens--leaving', 1)
# (u'verge', 1)
# (u'sanitizing', 1)
# (u'wondering', 1)
# (u'ob/gyn', 1)
# (u'communities;', 1)
# (u'libertyunites.org', 1)
# (u'agent', 1)
# (u'hides', 1)
# (u'140', 1)
# (u'mac', 1)
# (u'heroes', 1)
# (u'party--yet', 1)
# (u'block', 1)
# (u'talk', 1)
# (u'foreclosure', 1)
# (u'yearn', 1)
# (u'partial-birth', 1)
# (u'hot', 1)
# (u'enlisting', 1)
# (u'community-based', 1)
# (u'small;', 1)
# (u'fires', 1)
# (u'now--leaving', 1)
# (u'emerged', 1)
# (u'showroom', 1)
# (u'guardsmen:', 1)
# (u'card', 1)
# (u'collapsing', 1)
# (u'promotion', 1)
# (u'waited', 1)
# (u'romania', 1)
# (u'reprisal', 1)
# (u'sounds', 1)
# (u'crossings', 1)
# (u'eyes', 1)
# (u'inmates', 1)
# (u"here's", 1)
# (u'17', 1)
# (u'mutilation', 1)
# (u'addressing', 1)
# (u'"hearing', 1)
# (u'veteran', 1)
# (u"al-qaida's", 1)
# (u'heat', 1)
# (u'dispersed', 1)
# (u'"death', 1)
# (u'awareness', 1)
# (u'cia', 1)
# (u'friends;', 1)
# (u'aluminum', 1)
# (u'anti-retroviral', 1)
# (u'threats;', 1)
# (u'premiums', 1)
# (u'inoculating', 1)
# (u'benchmarks', 1)
# (u'parent', 1)
# (u'recedes', 1)
# (u'jr', 1)
# (u'resides', 1)
# (u'newfound', 1)
# (u'grooming', 1)
# (u'hybrids', 1)
# (u'500', 1)
# (u'irans', 1)
# (u'sectors', 1)
# (u'awakened', 1)
# (u'undercut', 1)
# (u'at-risk', 1)
# (u'bans', 1)
# (u'$23', 1)
# (u"veterans'", 1)
# (u'"tell', 1)
# (u'marking', 1)
# (u'nightmare', 1)
# (u'weakened', 1)
# (u'model', 1)
# (u'mobilizing', 1)
# (u'lifelines', 1)
# (u'legitimately', 1)
# (u'smugglers', 1)
# (u'struck', 1)
# (u'pot', 1)
# (u'address:', 1)
# (u'politely', 1)
# (u'vanished', 1)
# (u'bravery', 1)
# (u'christina', 1)
# (u'collective', 1)
# (u"couldn't", 1)
# (u'nazism', 1)
# (u'unmatched', 1)
# (u'unchecked--our', 1)
# (u'equivalent', 1)
# (u'dictators', 1)
# (u'pluralism', 1)
# (u'roaming', 1)
# (u'conducting', 1)
# (u'piety', 1)
# (u'pockets', 1)
# (u'tariffs', 1)
# (u'burning', 1)
# (u"berlin's", 1)
# (u'explosions', 1)
# (u'transitioning', 1)
# (u'smuggling', 1)
# (u'survived', 1)
# (u'embedded', 1)
# (u'poison', 1)
# (u'own:', 1)
# (u'dependents', 1)
# (u'research:', 1)
# (u'totaling', 1)
# (u'alarm', 1)
# (u'casualty', 1)
# (u'istanbul', 1)
# (u'nancy', 1)
# (u'benefitted', 1)
# (u'plutonium', 1)
# (u'13', 1)
# (u'calls', 1)
# (u'mobilized', 1)
# (u'overwatch', 1)
# (u'abortions', 1)
# (u'forbidden', 1)
# (u'duty-free', 1)
# (u'glimpse', 1)
# (u'horror', 1)
# (u'ten', 1)
# (u'nba', 1)
# (u'consumers', 1)
# (u'--broader', 1)
# (u'avenues', 1)
# (u'contrast', 1)
# (u'tracks', 1)
# (u'search', 1)
# (u'defectors', 1)
# (u'parties:', 1)
# (u'purveyors', 1)
# (u'sensors', 1)
# (u'shareholders', 1)
# (u'objectives', 1)
# (u'competes', 1)
# (u"family's", 1)
# (u'domination', 1)
# (u'broke', 1)
# (u'glad', 1)
# (u'pataki', 1)
# (u'compare', 1)
# (u'success,"', 1)
# (u'purchased', 1)
# (u'airplane', 1)
# (u'plant', 1)
# (u'infant', 1)
# (u'attitude', 1)
# (u'heirs', 1)
# (u'unleashing', 1)
# (u'imprisoned', 1)
# (u'reservists', 1)
# (u'evade', 1)
# (u'athletics', 1)
# (u'totalitarianism', 1)
# (u'bali', 1)
# (u'risen', 1)
# (u'attendant', 1)
# (u'revival', 1)
# (u'airport', 1)
# (u'13,000', 1)
# (u'guaranteeing', 1)
# (u'180', 1)
# (u'rails', 1)
# (u'tighter', 1)
# (u'carnage', 1)
# (u'financing', 1)
# (u'europe..and', 1)
# (u'rights--(applause)--to', 1)
# (u'zero', 1)
# (u'self', 1)
# (u'pretending', 1)
# (u'u.n', 1)
# (u'eaten', 1)
# (u'kay', 1)
# (u'part-time', 1)
# (u'malignant', 1)
# (u'pretty', 1)
# (u'all-powerful', 1)
# (u'banned', 1)
# (u'nominee', 1)
# (u'ninety-two', 1)
# (u'bloated', 1)
# (u'wrote', 1)
# (u'training--and', 1)
# (u'men...free', 1)
# (u'older:', 1)
# (u'unions', 1)
# (u'rite', 1)
# (u'aircraft', 1)
# (u'slogans', 1)
# (u'union?', 1)
# (u'flies', 1)
# (u'expensive', 1)
# (u'yemen...the', 1)
# (u'empty', 1)
# (u'india;', 1)
# (u"parents'", 1)
# (u'owes', 1)
# (u'daughters', 1)
# (u'restrains', 1)
# (u'weapons...lay', 1)
# (u'haul', 1)
# (u'prevention', 1)
# (u'sima', 1)
# (u'thorough', 1)
# (u'wealth...will', 1)
# (u'anti-drug', 1)
# (u'customers', 1)
# (u'lacking', 1)
# (u'fathers', 1)
# (u'prosecuted', 1)
# (u'$85', 1)
# (u'hostages', 1)
# (u'wildlife', 1)
# (u'virus', 1)
# (u'range', 1)
# (u'silence', 1)
# (u'gases', 1)
# (u'rivalries', 1)
# (u'shared...and', 1)
# (u'archaic', 1)
# (u'dole', 1)
# (u'diagrams', 1)
# (u'calculated', 1)
# (u'mindful', 1)
# (u'listening', 1)
# (u'endurance', 1)
# (u'beginnings', 1)
# (u'departs', 1)
# (u'2008', 1)
# (u'thomas', 1)
# (u"'ashley", 1)
# (u'capturing', 1)
# (u'excluded', 1)
# (u'meetings', 1)
# (u'more:', 1)
# (u'attempts', 1)
# (u'directive', 1)
# (u'assisted', 1)
# (u'relent', 1)
# (u'bench:', 1)
# (u'slaughter', 1)
# (u'stalks', 1)
# (u'31', 1)
# (u'guidance', 1)
# (u'reprocessing', 1)
# (u'terrorizing', 1)
# (u'classrooms', 1)
# (u'22-percent', 1)
# (u'consumption', 1)
# (u'unjustly', 1)
# (u'duplicate', 1)
# (u'infection', 1)
# (u'ride', 1)
# (u'links', 1)
# (u'$600', 1)
# (u'slip', 1)
# (u'rape', 1)
# (u'speech;', 1)
# (u'contempt', 1)
# (u'qaeda-iraq', 1)
# (u'buildings', 1)
# (u'highs', 1)
# (u'solidarity', 1)
# (u'invulnerability', 1)
# (u'alito', 1)
# (u'strike?', 1)
# (u'operative', 1)
# (u'image', 1)
# (u'violating', 1)
# (u'bolder', 1)
# (u'presidential', 1)
# (u'progressive', 1)
# (u'university', 1)
# (u'slipping', 1)
# (u'globe', 1)
# (u'related', 1)
# (u"die.'", 1)
# (u'islamist', 1)
# (u'announced', 1)
# (u'completely', 1)
# (u'cutting-edge', 1)
# (u'quo', 1)
# (u'comrade', 1)
# (u'"help', 1)
# (u'israelis;', 1)
# (u'painful', 1)
# (u'frustration', 1)
# (u'doomed', 1)
# (u'reaffirm', 1)
# (u'johnson', 1)
# (u'abetting', 1)
# (u'supplies...and', 1)
# (u'1.2', 1)
# (u'institutes', 1)
# (u'20s', 1)
# (u'purchasing', 1)
# (u'palace', 1)
# (u'awe', 1)
# (u'envy', 1)
# (u'tire', 1)
# (u'sarin', 1)
# (u'listened', 1)
# (u'122', 1)
# (u'stagnation', 1)
# (u'correctly', 1)
# (u'advanced-placement', 1)
# (u'ends', 1)
# (u'broadly-based', 1)
# (u'commands', 1)
# (u'strengthens', 1)
# (u'chest', 1)
# (u'sense:', 1)
# (u'laugh', 1)
# (u'choice:', 1)
# (u'ramallah', 1)
# (u'disney', 1)
# (u'finished', 1)
# (u'hateful', 1)
# (u'unlike', 1)
# (u'prosper', 1)
# (u'landmarks', 1)
# (u'unite', 1)
# (u'coached', 1)
# (u'student', 1)
# (u'giuliani', 1)
# (u'baltimore', 1)
# (u'mistaken', 1)
# (u'batteries', 1)
# (u'centralizing', 1)
# (u'happiness', 1)
# (u'capabilities', 1)
# (u'irresponsible', 1)
# (u'epidemic', 1)
# (u'unseen', 1)
# (u'nanotechnology', 1)
# (u'inviting', 1)
# (u'heed', 1)
# (u'traitors', 1)
# (u'illegally', 1)
# (u'morris', 1)
# (u'ripped', 1)
# (u'host', 1)
# (u'hijack', 1)
# (u'carries', 1)
# (u'calling:', 1)
# (u'billions', 1)
# (u'terminates', 1)
# (u'bud', 1)
# (u'sunnis', 1)
# (u'stirring', 1)
# (u'slowing', 1)
# (u'goodness', 1)
# (u'inspectors;', 1)
# (u'areas:', 1)
# (u'sick', 1)
# (u'reckless', 1)
# (u'animosity', 1)
# (u'hemisphere', 1)
# (u'diagnosis', 1)
# (u'four-year', 1)
# (u'khalid', 1)
# (u'poorly', 1)
# (u'poorest', 1)
# (u'protections', 1)
# (u"women's", 1)
# (u"civilization's", 1)
# (u'whirlwind', 1)
# (u'guidelines', 1)
# (u'street', 1)
# (u'infiltration', 1)
# (u'incompatible', 1)
# (u'kicked', 1)
# (u'reporter', 1)
# (u"aren't", 1)
# (u'celebration', 1)
# (u'kids', 1)
# (u"i'd", 1)
# (u'mobility', 1)
# (u'hindsight', 1)
# (u'newly-elected', 1)
# (u'experimentation', 1)
# (u'adnan', 1)
# (u'$40', 1)
# (u'1996', 1)
# (u'caves--you', 1)
# (u'quarrel', 1)
# (u'day--and', 1)
# (u'egyptian', 1)
# (u'waging', 1)
# (u'unpunished', 1)
# (u'executed', 1)
# (u'devote', 1)
# (u'sheltering', 1)
# (u'striking', 1)
# (u'400', 1)
# (u'selma', 1)
# (u'heaven', 1)
# (u'mandates', 1)
# (u'parasites', 1)
# (u'forgot', 1)
# (u'sleepless', 1)
# (u'wanted', 1)
# (u'jubilant', 1)
# (u'1970s', 1)
# (u'soldiers."', 1)
# (u'second-guessing', 1)
# (u'sentence', 1)
# (u'hearing', 1)
# (u'clarity', 1)
# (u'villages', 1)
# (u'non-public', 1)
# (u'responsibly', 1)
# (u'cole...an', 1)
# (u'inspections--then', 1)
# (u'shuffling', 1)
# (u'rice', 1)
# (u'foremost', 1)
# (u'reviewed', 1)
# (u'headed', 1)
# (u'tommy', 1)
# (u'temptation', 1)
# (u'lott', 1)
# (u"there's", 1)
# (u'apathy', 1)
# (u'caves', 1)
# (u'discovery', 1)
# (u'splinter', 1)
# (u'kitchen', 1)
# (u'argue', 1)
# (u'drugs...and', 1)
# (u'legs', 1)
# (u'condescending', 1)
# (u'affirm', 1)
# (u'played', 1)
# (u'hebrew', 1)
# (u'fatherless', 1)
# (u'acquire', 1)
# (u'embezzlers', 1)
# (u'humble', 1)
# (u'practices', 1)
# (u'acid', 1)
# (u'financially', 1)
# (u'ever-higher', 1)
# (u'technological', 1)
# (u'defied', 1)
# (u'explained', 1)
# (u'gregg', 1)
# (u'law;', 1)
# (u'ago:', 1)
# (u'hunt', 1)
# (u'52', 1)
# (u'arbitrary', 1)
# (u'bio-terrorism', 1)
# (u'miscalculated:', 1)
# (u'knew', 1)
# (u'pose', 1)
# (u'swings', 1)
# (u'manufacturing', 1)
# (u'egregious', 1)
# (u'roll."', 1)
# (u'accomplishments', 1)
# (u'manufacturers', 1)
# (u'responding', 1)
# (u'trains', 1)
# (u'retire', 1)
# (u'daddy', 1)
# (u'inclusive', 1)
# (u'reality', 1)
# (u'al-suhail', 1)
# (u'short-term', 1)
# (u'permitting', 1)
# (u'faction', 1)
# (u'fell', 1)
# (u'110th', 1)
# (u'derail', 1)
# (u'"affordable', 1)
# (u'coach', 1)
# (u'sowed', 1)
# (u'uneven', 1)
# (u'1941', 1)
# (u'1945', 1)
# (u'ever-larger', 1)
# (u'marks', 1)
# (u'disunity', 1)
# (u'responsibility:', 1)
# (u'respiratory', 1)
# (u'fragile', 1)
# (u'tougher', 1)
# (u'reaffirmed', 1)
# (u'word:', 1)
# (u'class-actions', 1)
# (u'upgrade', 1)
# (u'refused', 1)
# (u'plotted', 1)
# (u'tasks', 1)
# (u'rarely', 1)
# (u'doctors..and', 1)
# (u'planted', 1)
# (u'flying', 1)
# (u'judd', 1)
# (u'gathers', 1)
# (u'sued', 1)
# (u'provoke', 1)
# (u'condemn', 1)
# (u"enemies'", 1)
# (u'$4,500', 1)
# (u'experiments', 1)
# (u'undermined', 1)
# (u'hambali', 1)
# (u'qualified', 1)
# (u'wealthy', 1)
# (u'matched', 1)
# (u'worried', 1)
# (u'space', 1)
# (u'truly', 1)
# (u'side-by-side', 1)
# (u'earlier', 1)
# (u'deceived', 1)
# (u'suspend', 1)
# (u'yourself', 1)
# (u'release"', 1)
# (u'breed', 1)
# (u'hug', 1)
# (u'surges', 1)
# (u'16', 1)
# (u"o'connor", 1)
# (u'schooled', 1)
# (u'hmos', 1)
# (u'delegates."', 1)
# (u'voices', 1)
# (u'conspiracy', 1)
# (u'distorted', 1)
# (u'mourners', 1)
# (u'roadside', 1)
# (u'programs;', 1)
# (u'keeps', 1)
# (u'operate', 1)
# (u'unkept', 1)
# (u'applauding', 1)
# (u'de-baathification', 1)
# (u'yorkers:', 1)
# (u'slow', 1)
# (u'deck', 1)
# (u'watching', 1)
# (u'battalions', 1)
# (u'"return', 1)
# (u'emboldened', 1)
# (u'reorganized', 1)
# (u'bulgaria', 1)
# (u'preach', 1)
# (u'concentrate', 1)
# (u'jo', 1)
# (u'mandate', 1)
# (u'spann', 1)
# (u'crew', 1)
# (u'howard', 1)
# (u'fleeing', 1)
# (u'government-run', 1)
# (u'confessions', 1)
# (u'defeatism', 1)
# (u'performance-enhancing', 1)
# (u'"semper', 1)
# (u'weakest', 1)
# (u'it."', 1)
# (u'canister', 1)
# (u'jaish-i-mohammed--operates', 1)
# (u'caskets', 1)
# (u'"dear', 1)
# (u'safeguards', 1)
# (u'summed', 1)
# (u'things."', 1)
# (u'hotel', 1)
# (u'clay', 1)
# (u'nice', 1)
# (u'weve', 1)
# (u'routines', 1)
# (u'intact', 1)
# (u'scholarships', 1)
# (u'confirm', 1)
# (u'conservative', 1)
# (u'staffs', 1)
# (u'tuition', 1)
# (u'70', 1)
# (u'terrified', 1)
# (u'multi-party', 1)
# (u'subdued', 1)
# (u'contagion', 1)
# (u'fights', 1)
# (u'muslims', 1)
# (u'iran:', 1)
# (u'leads:', 1)
# (u'area', 1)
# (u'--because', 1)
# (u'cycle', 1)
# (u'cures', 1)
# (u'god-given', 1)
# (u'abuses', 1)
# (u'grass', 1)
# (u'doses', 1)
# (u'moves', 1)
# (u'4.6', 1)
# (u'forcing', 1)
# (u'brotherhood', 1)
# (u'breaux', 1)
# (u'grassroots', 1)
# (u'debris', 1)
# (u'song', 1)
# (u'baton', 1)
# (u'taleb', 1)
# (u'african-american', 1)
# (u'truer', 1)
# (u'healed', 1)
# (u'"when', 1)
# (u'92,000', 1)
# (u'suicide', 1)
# (u'thrift', 1)
# (u"regime's", 1)
# (u'emptied', 1)
# (u'destination', 1)
# (u'factories', 1)
# (u'bias', 1)
# (u'greeted', 1)
# (u'perverts', 1)
# (u'hormuz', 1)
# (u'marginalized', 1)
# (u'assassinated', 1)
# (u'axis', 1)
# (u'speeding', 1)
# (u'mazur-e-sharif', 1)
# (u'need:', 1)
# (u'[people]', 1)
# (u'burn', 1)
# (u'congo', 1)
# (u'zero-emission', 1)
# (u'someone', 1)
# (u'milestone', 1)
# (u'iranians', 1)
# (u'instructions', 1)
# (u'protecting."', 1)
# (u'todd', 1)
# (u'catalogued', 1)
# (u'computerizing', 1)
# (u'paradise', 1)
# (u'friday', 1)
# (u'coasts', 1)
# (u'discouraged', 1)
# (u'talked', 1)
# (u'protectionism', 1)
# (u'"', 1)
# (u'property;', 1)
# (u'station', 1)
# (u'temptations', 1)
# (u'trapped', 1)
# (u'tom', 1)
# (u'isolating', 1)
# (u'consult', 1)
# (u'waking', 1)
# (u'2027', 1)
# (u'obstacles', 1)
# (u'valor', 1)
# (u'confirms', 1)
# (u'nights', 1)
# (u'jeopardize', 1)
# (u'sandra', 1)
# (u'78', 1)
# (u'scholarship', 1)
# (u'kosovo', 1)
# (u'defended', 1)
# (u'permission', 1)
# (u'cheaper', 1)
# (u'basement', 1)
# (u'adulthood', 1)
# (u'interim', 1)
# (u'cole', 1)
# (u'creator', 1)
# (u'"disintegration', 1)
# (u'visiting', 1)
# (u'currently', 1)
# (u'missing', 1)
# (u'appropriations', 1)
# (u'plug-in', 1)
# (u'became', 1)
# (u'church', 1)
# (u'instilled', 1)
# (u'describes', 1)
# (u'wedding', 1)
# (u'georgia', 1)
# (u'opportunity:', 1)
# (u'chase', 1)
# (u'clerical', 1)
# (u'repel', 1)
# (u'2030', 1)
# (u'arrives', 1)
# (u'fannie', 1)
# (u'older', 1)
# (u'yemen', 1)
# (u'people;', 1)
# (u'rudolph', 1)
# (u'1787', 1)
# (u'project:', 1)
# (u'praying', 1)
# (u'u-2', 1)
# (u'brand-new', 1)
# (u'advocate', 1)
# (u"clay's", 1)
# (u'awaken', 1)
# (u'pakistanis;', 1)
# (u'harlem', 1)
# (u'glimpsed', 1)
# (u'scale', 1)
# (u'women;', 1)
# (u'epic', 1)
# (u'father:', 1)
# (u'stem', 1)
# (u'asserting', 1)
# (u'row', 1)
# (u'firing', 1)
# (u'germ', 1)
# (u'bankruptcy', 1)
# (u'suit', 1)
# (u'singled', 1)
# (u'plunge', 1)
# (u'line-item', 1)
# (u'posted', 1)
# (u'goodwill', 1)
# (u'hydrogen-powered', 1)
# (u'.s', 1)
# (u'candor', 1)
# (u'five-year-old', 1)
# (u'destinies', 1)
# (u'luxuries', 1)
# (u'country."', 1)
# (u'brigade', 1)
# (u'confirmation', 1)
# (u'huddled', 1)
# (u'populism', 1)
# (u'riyadh', 1)
# (u'experiment', 1)
# (u'proliferation', 1)
# (u"history's", 1)
# (u'conveyed', 1)
# (u'behead', 1)
# (u'ears', 1)
# (u'$1,000', 1)
# (u'panel', 1)
# (u'farewell:', 1)
# (u'taliban:', 1)
# (u'magnificently', 1)
# (u'holds', 1)
# (u'carrier', 1)
# (u'await', 1)
# (u'rations', 1)
# (u'militarism', 1)
# (u'bombers', 1)
# (u'counter', 1)
# (u'escalating', 1)
# (u'130', 1)
# (u'cruise', 1)
# (u'2012', 1)
# (u'richness', 1)
# (u'personally', 1)
# (u'eased', 1)
# (u'worse."', 1)
# (u'70,000', 1)
# (u'upward', 1)
# (u'internationalized', 1)
# (u'burdened', 1)
# (u'repress', 1)
# (u'philosophy', 1)
# (u'spill', 1)
# (u'depriving', 1)
# (u'retail', 1)
# (u'finest', 1)
# (u'succeeds', 1)
# (u'ethnic', 1)
# (u'walling', 1)
# (u'coverage--(applause)--to', 1)
# (u'privacy', 1)
# (u'says:', 1)
# (u'pakistani', 1)
# (u'beard', 1)
# (u'possible."', 1)
# (u'shrapnel', 1)
# (u'comfortable', 1)
# (u'supercomputing', 1)
# (u'dictate', 1)
# (u'afraid', 1)
# (u'gunner', 1)
# (u'concerns', 1)
# (u'800,000', 1)
# (u'lowered', 1)
# (u'planning', 1)
# (u'rouge', 1)
# (u'insurgency', 1)
# (u'employer', 1)
# (u'teams', 1)
# (u'38,000', 1)
# (u'shake', 1)
# (u'exploited', 1)
# (u'bought', 1)
# (u'vanish', 1)
# (u'david', 1)
# (u'well-qualified', 1)
# (u'wonder', 1)
# (u'steps:', 1)
# (u'cynicism', 1)
# (u'watering', 1)
# (u'mafia', 1)
# (u'"street"', 1)
# (u'protective', 1)
# (u'powered', 1)
# (u'sara', 1)
# (u'$1,800', 1)
# (u'define', 1)
# (u'qadhafi', 1)
# (u'hamburg', 1)
# (u'overturn', 1)
# (u'killings', 1)
# (u'owns', 1)
# (u'snuck', 1)
# (u'sits', 1)
# (u'wicked', 1)
# (u'qaedas', 1)
# (u'gets', 1)
# (u'recriminations', 1)
# (u'diabetes', 1)
# (u'privilege:', 1)
# (u'indonesia', 1)
# (u'brandenburg', 1)
# (u'life-extending', 1)
# (u'moynihan', 1)
# (u'objectives--to', 1)
# (u'fingerprints', 1)
# (u'martin', 1)
# (u"islam's", 1)
# (u'116', 1)
# (u'moderates', 1)
# (u'retirements', 1)
# (u'out-compete', 1)
# (u'gemayel', 1)
# (u'bombings', 1)
# (u'daschle', 1)
# (u'getting', 1)
# (u'stakes', 1)
# (u'weather', 1)
# (u'utility', 1)
# (u'permits', 1)
# (u'rushed', 1)
# (u'indictments', 1)
# (u'high-skilled', 1)
# (u'seniors:', 1)
# (u'convince', 1)
# (u'$35', 1)
# (u'penny', 1)
# (u'ink', 1)
# (u'incredible', 1)
# (u'blown', 1)
# (u'welcomes', 1)
# (u'conclusion', 1)
# (u'searched', 1)
# (u'upwards', 1)
# (u'"the', 1)

# %%
for x in word_count_al_clean.subtractByKey(word_count_bo_clean).sortBy(lambda x: x[1],ascending=False).collect():
    print x
# Out:
# (u'persons', 30)
# (u'naval', 27)
# (u'present', 27)
# (u'emancipation', 25)
# (u'consideration', 22)
# (u'receipts', 22)
# (u'however', 21)
# (u'measures', 20)
# (u'slavery', 19)
# (u'proclamation', 17)
# (u'vessels', 17)
# (u'indian', 17)
# (u'believed', 16)
# (u'powers', 16)
# (u'actual', 16)
# (u'rebellion', 16)
# (u'slave', 15)
# (u'territories', 15)
# (u'adopted', 15)
# (u'sum', 15)
# (u'courts', 15)
# (u'insurgents', 14)
# (u'1861', 14)
# (u'aggregate', 14)
# (u'commercial', 14)
# (u'importance', 14)
# (u'colored', 14)
# (u'expenditures', 14)
# (u'submitted', 14)
# (u'recommend', 14)
# (u'june', 13)
# (u'therefore', 13)
# (u'favorable', 13)
# (u'although', 13)
# (u'property', 13)
# (u'insurrection', 13)
# (u'disbursements', 13)
# (u'territory', 13)
# (u'existing', 13)
# (u'favor', 12)
# (u'insurgent', 12)
# (u'recommendation', 12)
# (u'established', 11)
# (u'heretofore', 11)
# (u'intercourse', 11)
# (u'cent', 11)
# (u'loyal', 11)
# (u'stated', 11)
# (u'presented', 11)
# (u'terms', 10)
# (u'derived', 10)
# (u'treaties', 10)
# (u'greatly', 10)
# (u'1860', 10)
# (u'extent', 10)
# (u'laborers', 10)
# (u'district', 10)
# (u'satisfactory', 10)
# (u'maryland', 10)
# (u'provision', 9)
# (u'claim', 9)
# (u'cash', 9)
# (u'slaves', 9)
# (u'ought', 9)
# (u'suppression', 9)
# (u'britain', 9)
# (u'indians', 9)
# (u'convention', 9)
# (u'proposition', 9)
# (u'difficulties', 9)
# (u'postal', 9)
# (u'expediency', 8)
# (u'relation', 8)
# (u'expected', 8)
# (u'pensions', 8)
# (u'telegraph', 8)
# (u'consent', 8)
# (u'blockade', 8)
# (u'invite', 8)
# (u'considerable', 8)
# (u'opinion', 8)
# (u'respectfully', 8)
# (u'forever', 8)
# (u'circuit', 8)
# (u'extensive', 8)
# (u'herewith', 8)
# (u'length', 8)
# (u'provisions', 8)
# (u'appropriation', 8)
# (u'object', 8)
# (u'missouri', 8)
# (u'hoped', 8)
# (u'bonds', 8)
# (u'correspondence', 7)
# (u'similar', 7)
# (u'therein', 7)
# (u'30th', 7)
# (u'except', 7)
# (u'virginia', 7)
# (u'island', 7)
# (u'communication', 7)
# (u'sales', 7)
# (u'due', 7)
# (u'tribes', 7)
# (u'mode', 7)
# (u'1864', 7)
# (u'seem', 7)
# (u'judges', 7)
# (u'duties', 7)
# (u'maritime', 7)
# (u'maintained', 7)
# (u'1863', 7)
# (u'empire', 7)
# (u'estimated', 7)
# (u'disloyal', 7)
# (u'african', 7)
# (u'necessarily', 7)
# (u'largely', 7)
# (u'refer', 7)
# (u'forth', 6)
# (u'following', 6)
# (u'ratio', 6)
# (u'gratifying', 6)
# (u'hence', 6)
# (u'distinct', 6)
# (u'vessel', 6)
# (u'pensioners', 6)
# (u'commend', 6)
# (u'agriculture', 6)
# (u'minnesota', 6)
# (u'postmaster-general', 6)
# (u'massachusetts', 6)
# (u'assumed', 6)
# (u'mountains', 6)
# (u'friendly', 6)
# (u'carried', 6)
# (u'purposes', 6)
# (u'articles', 6)
# (u'deemed', 6)
# (u'reports', 6)
# (u'necessity', 6)
# (u'reference', 6)
# (u'preceding', 6)
# (u'entirely', 6)
# (u'assurance', 6)
# (u'notes', 6)
# (u'separation', 6)
# (u'furnish', 6)
# (u'completed', 6)
# (u'nevada', 6)
# (u'abundant', 6)
# (u'labors', 6)
# (u'careful', 6)
# (u'accepted', 6)
# (u'settlement', 6)
# (u'river', 6)
# (u'restoration', 6)
# (u'continues', 6)
# (u'doubtful', 6)
# (u'1862', 6)
# (u'post-office', 5)
# (u'considered', 5)
# (u'generally', 5)
# (u'useful', 5)
# (u'hostilities', 5)
# (u'oath', 5)
# (u'prospect', 5)
# (u'whites', 5)
# (u'consuls', 5)
# (u'completion', 5)
# (u'patriotism', 5)
# (u'evils', 5)
# (u'notwithstanding', 5)
# (u'establishment', 5)
# (u'transmitted', 5)
# (u'arising', 5)
# (u'reported', 5)
# (u'principles', 5)
# (u'authorized', 5)
# (u'port', 5)
# (u'representatives', 5)
# (u'rolls', 5)
# (u'mineral', 5)
# (u'agricultural', 5)
# (u'hostile', 5)
# (u'deficiency', 5)
# (u'detail', 5)
# (u'commencement', 5)
# (u'conducted', 5)
# (u'entered', 5)
# (u'contemplated', 5)
# (u'evil', 5)
# (u'suggestion', 5)
# (u'merely', 5)
# (u'peru', 5)
# (u'british', 5)
# (u'unusual', 5)
# (u'direction', 5)
# (u'fellow-citizens', 5)
# (u'circulation', 5)
# (u'section', 5)
# (u'belligerent', 5)
# (u'sea', 5)
# (u'invalid', 5)
# (u'arisen', 5)
# (u'foreigners', 5)
# (u'boundary', 5)
# (u'sufficient', 5)
# (u'scarcely', 5)
# (u'economical', 5)
# (u'portion', 5)
# (u'presence', 5)
# (u'points', 5)
# (u'execution', 5)
# (u'basis', 5)
# (u'suitable', 5)
# (u'census', 5)
# (u'square', 5)
# (u'homestead', 5)
# (u'summary', 5)
# (u'freed', 5)
# (u'6', 5)
# (u'contest', 5)
# (u'ocean', 5)
# (u'settlements', 5)
# (u'quarters', 5)
# (u'element', 5)
# (u'promptly', 5)
# (u'delaware', 5)
# (u'laborer', 4)
# (u'securities', 4)
# (u'authorities', 4)
# (u'concur', 4)
# (u'suppressed', 4)
# (u'satisfaction', 4)
# (u'representatives:', 4)
# (u'friendship', 4)
# (u'revolutionary', 4)
# (u'cease', 4)
# (u'numerous', 4)
# (u'legislature', 4)
# (u'adoption', 4)
# (u'sections', 4)
# (u'insurrectionary', 4)
# (u'compensated', 4)
# (u'egypt', 4)
# (u'possession', 4)
# (u'expenditure', 4)
# (u'(or', 4)
# (u'consular', 4)
# (u'currency', 4)
# (u'suggest', 4)
# (u'rocky', 4)
# (u'seamen', 4)
# (u'peculiar', 4)
# (u'convenient', 4)
# (u'sale', 4)
# (u'injurious', 4)
# (u'miscellaneous', 4)
# (u'propriety', 4)
# (u'intended', 4)
# (u'article', 4)
# (u'costa', 4)
# (u'cordial', 4)
# (u'earnest', 4)
# (u'disposed', 4)
# (u'existence', 4)
# (u'justly', 4)
# (u'banking', 4)
# (u'superior', 4)
# (u'sufficiently', 4)
# (u'rhode', 4)
# (u'liberia', 4)
# (u"majesty's", 4)
# (u'pardon', 4)
# (u'besides', 4)
# (u'route', 4)
# (u'acquisition', 4)
# (u'latter', 4)
# (u'render', 4)
# (u'proceedings', 4)
# (u'hayti', 4)
# (u'commissioner', 4)
# (u'thereby', 4)
# (u'taxation', 4)
# (u'myself', 4)
# (u'voluntarily', 4)
# (u'respective', 4)
# (u'statement', 4)
# (u'remove', 4)
# (u'colonizing', 4)
# (u'signal', 4)
# (u'concerned', 4)
# (u'harvests', 4)
# (u'compensation', 4)
# (u'invited', 4)
# (u'jersey', 4)
# (u'spain', 4)
# (u'advisable', 4)
# (u'encouragement', 4)
# (u'earnestly', 4)
# (u'disturbed', 4)
# (u'wisdom', 4)
# (u'rivers', 4)
# (u'exercised', 4)
# (u'rica', 4)
# (u'eastern', 4)
# (u'previous', 4)
# (u'amounted', 4)
# (u'internal', 4)
# (u'quantity', 4)
# (u'apparent', 4)
# (u'conventions', 4)
# (u'attended', 4)
# (u'adopt', 4)
# (u'expended', 4)
# (u'movements', 4)
# (u'stipulations', 4)
# (u'readily', 4)
# (u'injury', 4)
# (u'short', 4)
# (u'residing', 4)
# (u'wherein', 4)
# (u'modifying', 4)
# (u'manifest', 4)
# (u'colonization', 4)
# (u'adjustment', 4)
# (u'deem', 4)
# (u'destruction', 4)
# (u'abolish', 4)
# (u'rapid', 4)
# (u'rendered', 4)
# (u'lawful', 4)
# (u'partially', 4)
# (u'recommendations', 4)
# (u'desirable', 3)
# (u'integrity', 3)
# (u'acknowledged', 3)
# (u'commissioners', 3)
# (u'chaplains', 3)
# (u'adapted', 3)
# (u'conference', 3)
# (u'suppose', 3)
# (u'cessation', 3)
# (u'assigned', 3)
# (u'judge', 3)
# (u'suggestions', 3)
# (u'complaints', 3)
# (u'proceeding', 3)
# (u'navigation', 3)
# (u'mainly', 3)
# (u'aiding', 3)
# (u'administer', 3)
# (u'advantages', 3)
# (u'remainder', 3)
# (u'bureau', 3)
# (u'acquiring', 3)
# (u'turkey', 3)
# (u'intimately', 3)
# (u'discussed', 3)
# (u'introduction', 3)
# (u'73', 3)
# (u'various', 3)
# (u'patriotic', 3)
# (u'nicaragua', 3)
# (u'consequently', 3)
# (u'apparently', 3)
# (u'duly', 3)
# (u'amounts', 3)
# (u'1/3', 3)
# (u'retract', 3)
# (u'decrease', 3)
# (u'ships', 3)
# (u'them;', 3)
# (u'occupied', 3)
# (u'arkansas', 3)
# (u'"can', 3)
# (u'diminished', 3)
# (u'facilitate', 3)
# (u'exhibit', 3)
# (u'detailed', 3)
# (u'columbia', 3)
# (u'nevertheless', 3)
# (u'negotiation', 3)
# (u'distant', 3)
# (u'press', 3)
# (u'doubtless', 3)
# (u'assembled', 3)
# (u'prize', 3)
# (u'mail', 3)
# (u'bounties', 3)
# (u'ere', 3)
# (u'unjust', 3)
# (u'destitution', 3)
# (u'better?"', 3)
# (u'satisfied', 3)
# (u'perceive', 3)
# (u'injuries', 3)
# (u'moneys', 3)
# (u'descent', 3)
# (u'pertaining', 3)
# (u'existed', 3)
# (u'attempted', 3)
# (u'faithful', 3)
# (u'regret', 3)
# (u'appear', 3)
# (u'lakes', 3)
# (u'appears', 3)
# (u'till', 3)
# (u'vicinity', 3)
# (u'voluntary', 3)
# (u'afterwards', 3)
# (u'minister', 3)
# (u'noble', 3)
# (u'easily', 3)
# (u'three-fourths', 3)
# (u'immense', 3)
# (u'brief', 3)
# (u'difficulty', 3)
# (u'perpetuate', 3)
# (u'proceed', 3)
# (u'pleasure', 3)
# (u'disunion', 3)
# (u'populous', 3)
# (u'cargo', 3)
# (u'accepting', 3)
# (u'representative', 3)
# (u'providence', 3)
# (u'issued', 3)
# (u'respectively', 3)
# (u'occurred', 3)
# (u'emigration', 3)
# (u'self-sustaining', 3)
# (u'instance', 3)
# (u'statute', 3)
# (u'interesting', 3)
# (u'suspension', 3)
# (u'mines', 3)
# (u'intention', 3)
# (u'wish', 3)
# (u'proceeds', 3)
# (u'adopting', 3)
# (u'overrun', 3)
# (u'advancing', 3)
# (u'reasonably', 3)
# (u'enlightened', 3)
# (u'somewhat', 3)
# (u'requisite', 3)
# (u'iron', 3)
# (u'reconstruction', 3)
# (u'seizure', 3)
# (u'commenced', 3)
# (u'connecticut', 3)
# (u'naturalized', 3)
# (u'amicable', 3)
# (u'died', 3)
# (u'marked', 3)
# (u'discharged', 3)
# (u'venture', 3)
# (u'concurrence', 3)
# (u'doubted', 3)
# (u'estimate', 3)
# (u'1900', 3)
# (u'influences', 3)
# (u'supervision', 3)
# (u'northern', 3)
# (u'admission', 3)
# (u'recommended', 3)
# (u'aliens', 3)
# (u'mitigate', 3)
# (u'consist', 3)
# (u'vacancies', 3)
# (u'addressed', 3)
# (u'equally', 3)
# (u'pending', 3)
# (u'masters', 3)
# (u'collection', 3)
# (u'surrendered', 3)
# (u'exists', 3)
# (u'fostering', 3)
# (u'enlarging', 3)
# (u'privileges', 3)
# (u'recognized', 3)
# (u'warrants', 3)
# (u'mississippi', 3)
# (u'faithfully', 3)
# (u'unanimity', 3)
# (u'consequent', 3)
# (u'preserving', 3)
# (u'cheerfully', 3)
# (u'nominal', 3)
# (u'coin', 3)
# (u'abolishment', 3)
# (u'conduct', 3)
# (u'awarded', 3)
# (u'augmented', 3)
# (u'claimants', 3)
# (u'france', 3)
# (u'touching', 3)
# (u'enacted', 3)
# (u'quite', 3)
# (u'copy', 3)
# (u'voters', 3)
# (u'adjudication', 3)
# (u'bondage', 3)
# (u'separate', 3)
# (u'regiments', 3)
# (u'referred', 3)
# (u'induced', 3)
# (u'occupation', 3)
# (u'speedily', 3)
# (u'subjects', 3)
# (u'properly', 3)
# (u'cotton', 3)
# (u'definitely', 3)
# (u'seemed', 3)
# (u'proof', 3)
# (u'arrangement', 3)
# (u'fortunate', 3)
# (u'hitherto', 3)
# (u'selection', 3)
# (u'furnished', 3)
# (u'seaboard', 3)
# (u'practice', 3)
# (u'ascertain', 3)
# (u'civilization', 3)
# (u'constantly', 3)
# (u'consists', 2)
# (u'remodeled', 2)
# (u'indefinitely', 2)
# (u'pardons', 2)
# (u'estimates', 2)
# (u'haste', 2)
# (u'shorten', 2)
# (u'content', 2)
# (u'seceded', 2)
# (u'speedy', 2)
# (u'cooperating', 2)
# (u'practiced', 2)
# (u'character', 2)
# (u'solely', 2)
# (u'borrowed', 2)
# (u'installments', 2)
# (u'obtained', 2)
# (u'applied', 2)
# (u'profitably', 2)
# (u'associations', 2)
# (u'perform', 2)
# (u'prussia', 2)
# (u'zeal', 2)
# (u'rallying', 2)
# (u'continuance', 2)
# (u'$901,125,674.86', 2)
# (u'to-day', 2)
# (u'permanently', 2)
# (u'cheap', 2)
# (u'inland', 2)
# (u'remembered', 2)
# (u'vigor', 2)
# (u'intelligible', 2)
# (u'relinquish', 2)
# (u'explicit', 2)
# (u'canada', 2)
# (u'patronage', 2)
# (u'1920', 2)
# (u'multiply', 2)
# (u'circulating', 2)
# (u'designated', 2)
# (u'portions', 2)
# (u'scott', 2)
# (u'arrival', 2)
# (u'relative', 2)
# (u'definite', 2)
# (u'unanimous', 2)
# (u'postage', 2)
# (u'unforeseen', 2)
# (u'colony', 2)
# (u'constant', 2)
# (u'accessible', 2)
# (u'insurrectionists', 2)
# (u'sums', 2)
# (u'considering', 2)
# (u'mixed', 2)
# (u'anomalous', 2)
# (u'inexhaustible', 2)
# (u'benevolent', 2)
# (u'destitute', 2)
# (u'exigencies', 2)
# (u'judicious', 2)
# (u'modify', 2)
# (u'authorize', 2)
# (u'navy-yard', 2)
# (u'corrected', 2)
# (u'prompt', 2)
# (u'reopened', 2)
# (u'excepted', 2)
# (u'energies', 2)
# (u'decennial', 2)
# (u'arbitration', 2)
# (u'charges', 2)
# (u'distributed', 2)
# (u'adhered', 2)
# (u'tender', 2)
# (u'agents', 2)
# (u'convicted', 2)
# (u'respecting', 2)
# (u'frankness', 2)
# (u'anxious', 2)
# (u'exaggerated', 2)
# (u'steady', 2)
# (u'inducements', 2)
# (u'accustomed', 2)
# (u'imposts', 2)
# (u'debtors', 2)
# (u'prudence', 2)
# (u'harbor', 2)
# (u'settlers', 2)
# (u'concluded', 2)
# (u'conformity', 2)
# (u'steamers', 2)
# (u'earnestness', 2)
# (u'enactments', 2)
# (u'adjournment', 2)
# (u'branches', 2)
# (u'observed', 2)
# (u'addition', 2)
# (u'compensating', 2)
# (u'corresponding', 2)
# (u'hospitals', 2)
# (u'dakota', 2)
# (u'interoceanic', 2)
# (u'discretion', 2)
# (u'cordiality', 2)
# (u'resumption', 2)
# (u'effected', 2)
# (u'ranks', 2)
# (u'secondly', 2)
# (u'loyalty', 2)
# (u'aforesaid', 2)
# (u'situated', 2)
# (u'steam', 2)
# (u'consummation', 2)
# (u'confusion', 2)
# (u'armored', 2)
# (u'actuated', 2)
# (u'damages', 2)
# (u'possibly', 2)
# (u'embarrassments', 2)
# (u'specie', 2)
# (u'satisfactorily', 2)
# (u'forborne', 2)
# (u'dues', 2)
# (u'one-third', 2)
# (u'displace', 2)
# (u'gratulation', 2)
# (u'lever', 2)
# (u'fugitive-slave', 2)
# (u'armies', 2)
# (u'seacoast', 2)
# (u'seventy', 2)
# (u'britannic', 2)
# (u'clause', 2)
# (u'considerably', 2)
# (u'printed', 2)
# (u'maine', 2)
# (u'liberation', 2)
# (u'expectation', 2)
# (u'concert', 2)
# (u'morocco', 2)
# (u'fluctuations', 2)
# (u'firmness', 2)
# (u'almighty', 2)
# (u'superintendency', 2)
# (u'unsatisfactory', 2)
# (u'nobly', 2)
# (u'afforded', 2)
# (u'pirates', 2)
# (u'delayed', 2)
# (u'103,208,415', 2)
# (u'original', 2)
# (u'ceased', 2)
# (u'preserved', 2)
# (u'marginal', 2)
# (u'chiefly', 2)
# (u'accommodated', 2)
# (u'congenial', 2)
# (u'occurs', 2)
# (u'surveyed', 2)
# (u'instituted', 2)
# (u'rendering', 2)
# (u'4', 2)
# (u'pressed', 2)
# (u'impracticable', 2)
# (u'machinery', 2)
# (u'localities', 2)
# (u'questioned', 2)
# (u'excited', 2)
# (u'follows', 2)
# (u'communications', 2)
# (u'essential', 2)
# (u'exceeding', 2)
# (u'neutrality', 2)
# (u'thirdly', 2)
# (u'confiscate', 2)
# (u'gross', 2)
# (u'proclamations', 2)
# (u'disposal', 2)
# (u'breach', 2)
# (u'suggests', 2)
# (u'prizes', 2)
# (u'inaugural', 2)
# (u'academy', 2)
# (u'$18,842,558.71', 2)
# (u'beg', 2)
# (u'gradual', 2)
# (u'secretaries', 2)
# (u'denmark', 2)
# (u'approval', 2)
# (u'plain', 2)
# (u'administered', 2)
# (u'loss', 2)
# (u'90,000', 2)
# (u'location', 2)
# (u'$13,606,759.11', 2)
# (u'inadequate', 2)
# (u'outlets', 2)
# (u'granting', 2)
# (u'potomac', 2)
# (u'abolishing', 2)
# (u'cordially', 2)
# (u'glance', 2)
# (u'interposition', 2)
# (u'entertained', 2)
# (u'indicated', 2)
# (u'deducted', 2)
# (u'fit', 2)
# (u'exhibits', 2)
# (u'confidently', 2)
# (u'suspended', 2)
# (u'thereof', 2)
# (u'manifested', 2)
# (u'supplied', 2)
# (u'hostility', 2)
# (u'fullness', 2)
# (u'tons', 2)
# (u'grave', 2)
# (u'condemned', 2)
# (u'concerning', 2)
# (u'colonies', 2)
# (u'vermont', 2)
# (u'approbation', 2)
# (u'mclean', 2)
# (u'consciousness', 2)
# (u'regarded', 2)
# (u'northward', 2)
# (u'beneficial', 2)
# (u'undisturbed', 2)
# (u'head', 2)
# (u'blockading', 2)
# (u'apprehensions', 2)
# (u'were:', 2)
# (u'product', 2)
# (u'deceive', 2)
# (u'statistical', 2)
# (u'tendency', 2)
# (u'1830', 2)
# (u'inferior', 2)
# (u'adjacent', 2)
# (u'orphans', 2)
# (u'contained', 2)
# (u'authorizes', 2)
# (u'plea', 2)
# (u'language', 2)
# (u'annum', 2)
# (u'seldom', 2)
# (u'diversities', 2)
# (u'justified', 2)
# (u'notice', 2)
# (u'motives', 2)
# (u'granted', 2)
# (u'civilized', 2)
# (u'aspect', 2)
# (u'amendments', 2)
# (u'onerous', 2)
# (u'induce', 2)
# (u'advantageous', 2)
# (u'november', 2)
# (u'disposition', 2)
# (u'enactment', 2)
# (u'surface', 2)
# (u'labored', 2)
# (u'ratified', 2)
# (u'idaho', 2)
# (u'juan', 2)
# (u'preservation', 2)
# (u'enlarged', 2)
# (u'5th', 2)
# (u'inflexible', 2)
# (u'remedy', 2)
# (u'$181,086,635.07', 2)
# (u'circuits;', 2)
# (u'15th', 2)
# (u'incident', 2)
# (u'maintenance', 2)
# (u'developments', 2)
# (u'judgments', 2)
# (u'possessory', 2)
# (u'exclusively', 2)
# (u'governmental', 2)
# (u'appropriate', 2)
# (u'metals', 2)
# (u'bank-note', 2)
# (u'urged', 2)
# (u'resolutions', 2)
# (u'hampshire', 2)
# (u'sanctioned', 2)
# (u'revived', 2)
# (u'accredited', 2)
# (u'beginner', 2)
# (u'sentiment', 2)
# (u'owned', 2)
# (u'profoundest', 2)
# (u'repeated', 2)
# (u'humane', 2)
# (u'mcclellan', 2)
# (u'republics', 2)
# (u'amply', 2)
# (u'additions', 2)
# (u'distribution', 2)
# (u'36.45', 2)
# (u'stipulated', 2)
# (u'dissatisfaction', 2)
# (u'absolute', 2)
# (u'reaccept', 2)
# (u'customs', 2)
# (u'enter', 2)
# (u'durability', 2)
# (u'resume', 2)
# (u'redress', 2)
# (u'regular', 2)
# (u'suffrage', 2)
# (u'losses', 2)
# (u'omission', 2)
# (u'agitation', 2)
# (u'successfully', 2)
# (u'inhuman', 2)
# (u'constituting', 2)
# (u'lieu', 2)
# (u'remained', 2)
# (u'novel', 2)
# (u'widows', 2)
# (u'withhold', 2)
# (u'unavoidable', 2)
# (u'whoever', 2)
# (u'excellent', 2)
# (u'appeal', 2)
# (u'entertain', 2)
# (u'believes', 2)
# (u'derive', 2)
# (u'inflicted', 2)
# (u'emigrants', 2)
# (u'populated', 2)
# (u'investigation', 2)
# (u'liberally', 2)
# (u'spanish', 2)
# (u'occurring', 2)
# (u'folly', 2)
# (u'exceeded', 2)
# (u'dispute', 2)
# (u'treasure', 2)
# (u'fruitful', 2)
# (u'unwise', 2)
# (u'commander', 2)
# (u'specified', 2)
# (u'moderate', 2)
# (u'intimate', 2)
# (u'convertibility', 2)
# (u'two-thirds', 2)
# (u'removal', 2)
# (u'returning', 2)
# (u'squadrons', 2)
# (u'accompanying', 2)
# (u'adjust', 2)
# (u'$5,329,044.21', 2)
# (u'cultivation', 2)
# (u'1790', 2)
# (u'anticipated', 2)
# (u'omit', 2)
# (u'3,982,011', 2)
# (u'$895,796,630.65', 2)
# (u'jefferson', 2)
# (u'reunion', 2)
# (u'inaugurate', 2)
# (u'exhibiting', 2)
# (u'opposing', 2)
# (u'comfort', 2)
# (u'exempt', 2)
# (u'races', 2)
# (u'owing', 2)
# (u'forfeited', 2)
# (u'4th', 2)
# (u'capital;', 2)
# (u'enable', 2)
# (u'commanders', 2)
# (u'entitled', 2)
# (u'wholly', 2)
# (u'remunerative', 2)
# (u'declarations', 2)
# (u'intrusted', 2)
# (u'cooperate', 2)
# (u'auspices', 2)
# (u'advocates', 2)
# (u'activity', 2)
# (u'improvements', 2)
# (u'acquiescence', 2)
# (u'preliminary', 2)
# (u'magistrate', 2)
# (u'grounds', 2)
# (u'$700,000', 2)
# (u'wisest', 2)
# (u'bench', 2)
# (u'elapsed', 2)
# (u'prominent', 2)
# (u'1,456,514', 2)
# (u'assuming', 2)
# (u'imperfectly', 2)
# (u'successors', 2)
# (u'emperor', 2)
# (u'naturally', 2)
# (u'reciprocated', 2)
# (u'aided', 1)
# (u'paris', 1)
# (u'"an', 1)
# (u'oriental', 1)
# (u'deliberations', 1)
# (u'cruising', 1)
# (u'crops', 1)
# (u'seven?', 1)
# (u'present;', 1)
# (u'immunities', 1)
# (u'rigorous', 1)
# (u'lesser', 1)
# (u'favorers', 1)
# (u'5,304,937', 1)
# (u'dry', 1)
# (u'occupying', 1)
# (u'cured', 1)
# (u'casualties', 1)
# (u'obeying', 1)
# (u'philanthropic', 1)
# (u'exceptions', 1)
# (u'caution', 1)
# (u'inhabitants', 1)
# (u'vagrant', 1)
# (u'resignation', 1)
# (u'35.87', 1)
# (u'delicacy', 1)
# (u'97,918', 1)
# (u'1810', 1)
# (u'157;', 1)
# (u'patronized', 1)
# (u'esteemed', 1)
# (u'17th', 1)
# (u'undeveloped', 1)
# (u'regularly', 1)
# (u'secured?', 1)
# (u'capricious', 1)
# (u'substantially', 1)
# (u'disloyalty', 1)
# (u'springing', 1)
# (u'campaigns', 1)
# (u'reserving', 1)
# (u'22,767', 1)
# (u'occasioned', 1)
# (u'outlay', 1)
# (u'belligerents', 1)
# (u'absorbed', 1)
# (u'transmit', 1)
# (u'rest;', 1)
# (u'indemnification', 1)
# (u'calmness', 1)
# (u'pasha', 1)
# (u'decidedly', 1)
# (u'undue', 1)
# (u'uneasiness', 1)
# (u'disbursed', 1)
# (u'considerate', 1)
# (u'beset', 1)
# (u'115,141', 1)
# (u'stead', 1)
# (u'resist', 1)
# (u'campbell', 1)
# (u'$84,578,834.47', 1)
# (u'contraband', 1)
# (u'confessedly', 1)
# (u'abstracts', 1)
# (u'alleghanies', 1)
# (u'appeared', 1)
# (u'royal', 1)
# (u'here--congress', 1)
# (u'active', 1)
# (u'$27,505,599.46', 1)
# (u'proceeded', 1)
# (u'excite', 1)
# (u'catch', 1)
# (u'apprehension', 1)
# (u'lessen', 1)
# (u'aim', 1)
# (u'congratulation', 1)
# (u'long-pending', 1)
# (u'quartermaster-general', 1)
# (u'involuntary', 1)
# (u'jealous', 1)
# (u'shortly', 1)
# (u'mingle', 1)
# (u"senate's", 1)
# (u'averting', 1)
# (u'meanly', 1)
# (u'$102,316,152.99', 1)
# (u'espoused', 1)
# (u'sailors', 1)
# (u'$865,234,087.86;', 1)
# (u'59', 1)
# (u'dense', 1)
# (u'forever."', 1)
# (u'ironclad', 1)
# (u'accepts', 1)
# (u'133,000,000', 1)
# (u'rigor', 1)
# (u'statements', 1)
# (u'emigrate', 1)
# (u'resulted', 1)
# (u'145,551', 1)
# (u'$3,046,615.35', 1)
# (u'connection--the', 1)
# (u'simplifying', 1)
# (u'willingly', 1)
# (u'uttered', 1)
# (u'eternity', 1)
# (u'customary', 1)
# (u'devoted', 1)
# (u'persevere', 1)
# (u'penniless', 1)
# (u'liability', 1)
# (u'42,323,341', 1)
# (u'$1,795,331.73', 1)
# (u'satisfy', 1)
# (u'exemption', 1)
# (u'subtract', 1)
# (u'wrongs', 1)
# (u'upheld', 1)
# (u'$2,112,814.57', 1)
# (u'$86,835,900.27', 1)
# (u'impair', 1)
# (u'incidents', 1)
# (u'14,410+', 1)
# (u'yard', 1)
# (u'dispositions', 1)
# (u'sworn', 1)
# (u'strictness', 1)
# (u'refund', 1)
# (u'$42,674,569.69;', 1)
# (u'troubles', 1)
# (u'compelled', 1)
# (u'repaired', 1)
# (u'honduras', 1)
# (u'1821', 1)
# (u'(1864)', 1)
# (u'advantage?', 1)
# (u'inadequacy', 1)
# (u'suggesting', 1)
# (u'disrespect', 1)
# (u'contemplation', 1)
# (u'conversions', 1)
# (u'checked', 1)
# (u'seas', 1)
# (u'$1,740,690,489.49', 1)
# (u'holden', 1)
# (u'revolt', 1)
# (u'foreigner', 1)
# (u'unavailing', 1)
# (u'discarding', 1)
# (u'unwisely', 1)
# (u'derangement--in', 1)
# (u'$570,841,700.25', 1)
# (u'pursuant', 1)
# (u'gratified', 1)
# (u'77,246', 1)
# (u'sierra', 1)
# (u'dreaded', 1)
# (u'clerks', 1)
# (u'deprecate', 1)
# (u'$12,644,786.20', 1)
# (u'circuits', 1)
# (u'physically', 1)
# (u'470,745', 1)
# (u'cadets', 1)
# (u'whereabouts', 1)
# (u'16,924', 1)
# (u'menacing', 1)
# (u'awards', 1)
# (u'sentinel', 1)
# (u'pugets', 1)
# (u'derogation', 1)
# (u'way?', 1)
# (u'spare', 1)
# (u'inquire', 1)
# (u'gentlemen', 1)
# (u'sitana', 1)
# (u'deference', 1)
# (u'figures', 1)
# (u'compensation;', 1)
# (u'theater', 1)
# (u'objection', 1)
# (u'domicile', 1)
# (u'exceeds', 1)
# (u'surest', 1)
# (u'272,143', 1)
# (u'perpetuated?', 1)
# (u'misapprehensions', 1)
# (u'lebanon', 1)
# (u'limits;', 1)
# (u'perverse', 1)
# (u'1850', 1)
# (u'22,198', 1)
# (u'free;', 1)
# (u'cinnabar', 1)
# (u'clerkship', 1)
# (u'hazards', 1)
# (u'$96,096,922.09;', 1)
# (u'proportionately', 1)
# (u'estoppel', 1)
# (u'domingo', 1)
# (u'arranged', 1)
# (u'hardly', 1)
# (u'lawfully', 1)
# (u'severally', 1)
# (u'exhausted', 1)
# (u'sanguine', 1)
# (u'5', 1)
# (u'gaining', 1)
# (u'insomuch', 1)
# (u'bounded', 1)
# (u'$150,417.25', 1)
# (u'accomac', 1)
# (u'laborers;', 1)
# (u'$8,349,296.40', 1)
# (u'oppressed', 1)
# (u'disquiet', 1)
# (u'hatteras', 1)
# (u'presentation', 1)
# (u'norfolk', 1)
# (u'venezuela', 1)
# (u'canvass', 1)
# (u'assaults', 1)
# (u'residue', 1)
# (u'melioration', 1)
# (u'crush', 1)
# (u'ranges', 1)
# (u'operating', 1)
# (u'graves', 1)
# (u'35.58', 1)
# (u'exceptionally', 1)
# (u'suddenly', 1)
# (u'viz', 1)
# (u'thrown', 1)
# (u'controlling', 1)
# (u'22,187', 1)
# (u'purchaser', 1)
# (u'42,534', 1)
# (u'neglected', 1)
# (u'began;', 1)
# (u'state;', 1)
# (u'charge?', 1)
# (u'acquisitions', 1)
# (u'effecting', 1)
# (u'groundless', 1)
# (u'rounded', 1)
# (u'disabled', 1)
# (u'brig', 1)
# (u'desirable--almost', 1)
# (u'countrymen', 1)
# (u'induces', 1)
# (u'favored', 1)
# (u'dominating', 1)
# (u'insure', 1)
# (u'relieved', 1)
# (u'countries--results', 1)
# (u'imposing', 1)
# (u'____', 1)
# (u'$4,504,616.92', 1)
# (u'decrees', 1)
# (u'equaled', 1)
# (u'hires', 1)
# (u'transcending', 1)
# (u'us?', 1)
# (u'concessions', 1)
# (u'barren', 1)
# (u'scattered', 1)
# (u'inaugurated', 1)
# (u'connections', 1)
# (u'5,000', 1)
# (u'causes?', 1)
# (u'sacrifices', 1)
# (u'throwing', 1)
# (u'preparation', 1)
# (u'aqueduct', 1)
# (u'contrary', 1)
# (u'liberian', 1)
# (u'indiscriminately', 1)
# (u'influential', 1)
# (u'reside', 1)
# (u'suppressing', 1)
# (u'enterprising', 1)
# (u'partly', 1)
# (u'ages', 1)
# (u'congress."', 1)
# (u'resulting', 1)
# (u'tolerate', 1)
# (u'brilliant', 1)
# (u'identical', 1)
# (u'42,844', 1)
# (u'renounced', 1)
# (u'italy', 1)
# (u'consolations', 1)
# (u'dishonor', 1)
# (u'shorter', 1)
# (u'modification', 1)
# (u'survey', 1)
# (u'dark', 1)
# (u'abandonment', 1)
# (u'informal', 1)
# (u'33.49', 1)
# (u'harmonize', 1)
# (u'ordnance', 1)
# (u'indication', 1)
# (u'counsels', 1)
# (u'magnificent', 1)
# (u'aptitudes', 1)
# (u'conditionally', 1)
# (u'inimical', 1)
# (u'300', 1)
# (u'dictated', 1)
# (u'militia', 1)
# (u'affirmatively', 1)
# (u'truckee', 1)
# (u'convulsion', 1)
# (u'extremely', 1)
# (u'reiterates', 1)
# (u'state-bank', 1)
# (u'1890', 1)
# (u'remissions', 1)
# (u'oblige', 1)
# (u'directness', 1)
# (u'proposed--the', 1)
# (u'wards', 1)
# (u'provost-marshal-general', 1)
# (u'1854', 1)
# (u'$4,557,462.71', 1)
# (u'sumter', 1)
# (u'seized', 1)
# (u'perthshire', 1)
# (u'petitions', 1)
# (u'timely', 1)
# (u'barbary', 1)
# (u'limitations', 1)
# (u'property--property', 1)
# (u'composed', 1)
# (u'abideth', 1)
# (u'examination', 1)
# (u'formally', 1)
# (u'disabling', 1)
# (u'crossed', 1)
# (u'unchanged;', 1)
# (u'us;', 1)
# (u'indulgence', 1)
# (u'promptitude', 1)
# (u'hereinafter', 1)
# (u'sentiments', 1)
# (u'tact', 1)
# (u'advocated', 1)
# (u'56,967,216', 1)
# (u'ourselves--to', 1)
# (u'hanover', 1)
# (u'mentioned', 1)
# (u'perspicuity', 1)
# (u'previously', 1)
# (u'flee', 1)
# (u'them?', 1)
# (u'relinquishment', 1)
# (u'expressly', 1)
# (u'indulged', 1)
# (u'gallant', 1)
# (u'amendatory', 1)
# (u'follows:', 1)
# (u'discussions', 1)
# (u'date', 1)
# (u'4,610', 1)
# (u'depressing', 1)
# (u'aught', 1)
# (u'objectionable', 1)
# (u'embody', 1)
# (u'insignificance', 1)
# (u're-enslave', 1)
# (u'arduous', 1)
# (u'1,000,000', 1)
# (u'assurances', 1)
# (u'ably', 1)
# (u'$474,744,778.16', 1)
# (u'expired', 1)
# (u'volume', 1)
# (u'violation', 1)
# (u'138,918,526', 1)
# (u'attained', 1)
# (u'displayed', 1)
# (u'92,502', 1)
# (u'committees', 1)
# (u'pertains', 1)
# (u'intervening', 1)
# (u'acquired', 1)
# (u'capitalists', 1)
# (u'exhaustion;', 1)
# (u'savannah)', 1)
# (u'merit;', 1)
# (u'streams', 1)
# (u'habitual', 1)
# (u'resorting', 1)
# (u'migrate', 1)
# (u'pity', 1)
# (u'appearance', 1)
# (u'cereals', 1)
# (u'51,000', 1)
# (u'remodeling', 1)
# (u')', 1)
# (u'$50,000', 1)
# (u'$109,741,134.10', 1)
# (u'disenthralled', 1)
# (u'arming', 1)
# (u'nicholasville', 1)
# (u'southward', 1)
# (u'arresting', 1)
# (u'unsoundness', 1)
# (u'intimated', 1)
# (u'267', 1)
# (u'recurs', 1)
# (u'traders', 1)
# (u'regulated', 1)
# (u'liquidation', 1)
# (u'65,953', 1)
# (u'motive', 1)
# (u'results:', 1)
# (u'compatible', 1)
# (u'$96,739,905.73', 1)
# (u'boundaries', 1)
# (u'crooked', 1)
# (u'delivery', 1)
# (u'valuation', 1)
# (u'recede', 1)
# (u'slaves?', 1)
# (u'russian', 1)
# (u'mechanics', 1)
# (u'devise', 1)
# (u'paraguay', 1)
# (u'exhausting', 1)
# (u'kinds', 1)
# (u'astounding', 1)
# (u'793', 1)
# (u'seceding', 1)
# (u'110,000', 1)
# (u'reservations', 1)
# (u'effectually', 1)
# (u'dispense', 1)
# (u'misunderstanding', 1)
# (u'affect', 1)
# (u'enhance', 1)
# (u'dwindled', 1)
# (u'ungenerous', 1)
# (u'dogmas', 1)
# (u'271', 1)
# (u'subordinate', 1)
# (u'subject--a', 1)
# (u'liberated', 1)
# (u'admiral', 1)
# (u'richest', 1)
# (u'unobjectionable', 1)
# (u'punishment', 1)
# (u'inflicting', 1)
# (u'insecurity', 1)
# (u'accommodation', 1)
# (u'averaging', 1)
# (u'consulates', 1)
# (u'$5,939.009.29;', 1)
# (u'long-felt', 1)
# (u'description', 1)
# (u'sioux', 1)
# (u'neglect', 1)
# (u'restriction', 1)
# (u'then;', 1)
# (u'silver', 1)
# (u'3,929,827', 1)
# (u'interruption', 1)
# (u'hushed', 1)
# (u'tried', 1)
# (u'fugitive', 1)
# (u'248', 1)
# (u'grasses', 1)
# (u'increased;', 1)
# (u'features', 1)
# (u'art.--congress', 1)
# (u'specially', 1)
# (u'rewritten', 1)
# (u'19,931', 1)
# (u'kindest', 1)
# (u'set-tier', 1)
# (u'cent--has', 1)
# (u'"compensated', 1)
# (u'$100,000', 1)
# (u'committing', 1)
# (u'secession', 1)
# (u'reimbursement', 1)
# (u'stating', 1)
# (u'eminent', 1)
# (u'enjoyed', 1)
# (u'orleans', 1)
# (u'painfully', 1)
# (u'deepest', 1)
# (u'lexington', 1)
# (u'consisting', 1)
# (u'$49,056,397.62', 1)
# (u'richer', 1)
# (u'interruptions', 1)
# (u'solicitude', 1)
# (u'disavowed', 1)
# (u'unexhausted', 1)
# (u'performed--the', 1)
# (u'variance', 1)
# (u'springs', 1)
# (u'apprehended', 1)
# (u'165,538', 1)
# (u'unhappily', 1)
# (u'criticised', 1)
# (u'exhibition', 1)
# (u'suppress', 1)
# (u'punctually', 1)
# (u'spring?', 1)
# (u'adaptations', 1)
# (u"earth's", 1)
# (u'contemplates', 1)
# (u'characterize', 1)
# (u'675,156', 1)
# (u'respectively;', 1)
# (u'harbored', 1)
# (u'sacramento', 1)
# (u'671', 1)
# (u'norwegian', 1)
# (u'3,870,222', 1)
# (u'palpable', 1)
# (u'prescribed', 1)
# (u'capitol', 1)
# (u'farther', 1)
# (u'pecuniary', 1)
# (u'insubordination', 1)
# (u'purposes,"', 1)
# (u"surveyors'", 1)
# (u'auspicious', 1)
# (u'sanitary', 1)
# (u'$3,145,000', 1)
# (u'matter,"', 1)
# (u'confer', 1)
# (u'985.52;', 1)
# (u'considerations', 1)
# (u'1,430', 1)
# (u'furnishing', 1)
# (u'pages', 1)
# (u'$2,481,000', 1)
# (u'10,000,000', 1)
# (u'enrolling', 1)
# (u'mails', 1)
# (u"dixon's", 1)
# (u'assiduous', 1)
# (u'discharge', 1)
# (u'occurrence', 1)
# (u'annuity', 1)
# (u'tribunals', 1)
# (u'point--a', 1)
# (u'island;', 1)
# (u'answered', 1)
# (u'$7,517,930.97', 1)
# (u'1859', 1)
# (u'feeble', 1)
# (u'p', 1)
# (u'utter', 1)
# (u'conventions)', 1)
# (u'amounting', 1)
# (u'drafted', 1)
# (u'availed', 1)
# (u'redemption', 1)
# (u'inducing', 1)
# (u'logically', 1)
# (u'118,840', 1)
# (u'isles', 1)
# (u'permitted', 1)
# (u'introducing', 1)
# (u'blood?', 1)
# (u'many?', 1)
# (u'webster', 1)
# (u'irruption', 1)
# (u'exclude', 1)
# (u'offense', 1)
# (u'occur', 1)
# (u'winter', 1)
# (u'stricken', 1)
# (u'receivability', 1)
# (u'eighth', 1)
# (u'representation', 1)
# (u'exclusive', 1)
# (u'feature', 1)
# (u'constituted', 1)
# (u'chiefest', 1)
# (u'discuss', 1)
# (u'soon?', 1)
# (u'154,747', 1)
# (u'richly', 1)
# (u'collisions', 1)
# (u'correct', 1)
# (u'existed;', 1)
# (u'theory', 1)
# (u'telegraphs', 1)
# (u'vicious', 1)
# (u'rebel', 1)
# (u'communicated', 1)
# (u'charleston', 1)
# (u'175,487', 1)
# (u'12,866,020', 1)
# (u'debts--was', 1)
# (u'hirers', 1)
# (u'cite', 1)
# (u'season', 1)
# (u'halls', 1)
# (u'embroil', 1)
# (u'payable', 1)
# (u'contemporary', 1)
# (u'discounts', 1)
# (u'"free', 1)
# (u'expects', 1)
# (u'1820', 1)
# (u'audited', 1)
# (u'subsequent', 1)
# (u'justifies', 1)
# (u'altercation', 1)
# (u'thickly', 1)
# (u'temper', 1)
# (u'resided', 1)
# (u'$3,750,000', 1)
# (u'overland', 1)
# (u'31,443,790', 1)
# (u'surgeon-general', 1)
# (u'soil', 1)
# (u'commanded', 1)
# (u'abhors', 1)
# (u'denying', 1)
# (u'arose', 1)
# (u'modes', 1)
# (u'event;', 1)
# (u'announcement', 1)
# (u'instrument', 1)
# (u'occasions', 1)
# (u'$13,043,546.81', 1)
# (u'colonial', 1)
# (u'extensively', 1)
# (u'sprung', 1)
# (u'throw', 1)
# (u'practicable', 1)
# (u'tribe', 1)
# (u'attainable', 1)
# (u'$1,298,056,101.89', 1)
# (u'aids', 1)
# (u'33,874', 1)
# (u'residence', 1)
# (u'equitable', 1)
# (u'external', 1)
# (u'parcel', 1)
# (u'1,500', 1)
# (u'resistance', 1)
# (u'economically', 1)
# (u'1,538,614', 1)
# (u'asiatic', 1)
# (u'recruits', 1)
# (u'1846', 1)
# (u'soldier', 1)
# (u'abroad--some', 1)
# (u'tendered', 1)
# (u'always;', 1)
# (u'recall', 1)
# (u'forbearance', 1)
# (u'42,441', 1)
# (u'plan?', 1)
# (u'collision', 1)
# (u'earnings', 1)
# (u'vigilance', 1)
# (u'yedo', 1)
# (u'altercations', 1)
# (u'730,664', 1)
# (u'invasion', 1)
# (u'departure', 1)
# (u'precautionary', 1)
# (u'resort', 1)
# (u'alter', 1)
# (u'sides;', 1)
# (u'$776,682,361.57', 1)
# (u'primary', 1)
# (u'it?', 1)
# (u'outbreak', 1)
# (u'hereafter', 1)
# (u'impugning', 1)
# (u'intricacy', 1)
# (u'maturely', 1)
# (u'compensation:', 1)
# (u'exhibited', 1)
# (u'indebted', 1)
# (u'seeming', 1)
# (u'radical', 1)
# (u'instances', 1)
# (u'contended', 1)
# (u'territorially', 1)
# (u'devolved', 1)
# (u'swarm', 1)
# (u'aves', 1)
# (u'aristocracy', 1)
# (u'favorably', 1)
# (u'men--and', 1)
# (u'appreciation', 1)
# (u'1910', 1)
# (u'king', 1)
# (u'kindly', 1)
# (u'acknowledgment', 1)
# (u'unpaid', 1)
# (u'extorted', 1)
# (u'undertaken', 1)
# (u'well-appointed', 1)
# (u'outgrown', 1)
# (u'performances', 1)
# (u'reflections', 1)
# (u'swelling', 1)
# (u'emoluments', 1)
# (u'obstructed', 1)
# (u'deserts', 1)
# (u'creditable', 1)
# (u'instinctive', 1)
# (u'enemy', 1)
# (u'armature', 1)
# (u'severing', 1)
# (u'class--neither', 1)
# (u'$714,709,995.58', 1)
# (u'probable', 1)
# (u'attainment', 1)
# (u'redemptions', 1)
# (u'adaptation', 1)
# (u'(thirty-seven', 1)
# (u'cruelty', 1)
# (u'consulate', 1)
# (u'owed', 1)
# (u'slavery?', 1)
# (u'slavery;', 1)
# (u'evading', 1)
# (u'restraint', 1)
# (u'$98,239,733.09', 1)
# (u'thoroughly', 1)
# (u'$238,647,262.35', 1)
# (u'macedonian', 1)
# (u'disenthrall', 1)
# (u'constitutions', 1)
# (u'dominions', 1)
# (u'improbably', 1)
# (u'repossession', 1)
# (u'd', 1)
# (u'6,151,405', 1)
# (u'$12,528,000', 1)
# (u'beneficially', 1)
# (u'augmenting', 1)
# (u'quota', 1)
# (u'mingled', 1)
# (u'extending', 1)
# (u'unintentional', 1)
# (u'necessity--that', 1)
# (u'impressed', 1)
# (u'impeded', 1)
# (u'repeatedly', 1)
# (u'world-encircling', 1)
# (u'reconcile', 1)
# (u'35.02', 1)
# (u'granada', 1)
# (u'energetic', 1)
# (u'reservation', 1)
# (u'presenting', 1)
# (u'thenceforward', 1)
# (u'results;', 1)
# (u'712', 1)
# (u'42,427', 1)
# (u'positions', 1)
# (u'thronging', 1)
# (u'substituting', 1)
# (u'climes', 1)
# (u'war;', 1)
# (u'colonel', 1)
# (u'overwhelmed', 1)
# (u'sink', 1)
# (u'cumberland', 1)
# (u'thirty-one', 1)
# (u'congress:', 1)
# (u'ministers', 1)
# (u'periodically', 1)
# (u'judged', 1)
# (u'shipwreck', 1)
# (u'gladly', 1)
# (u'bend', 1)
# (u'varied', 1)
# (u'tropics', 1)
# (u'facilitated', 1)
# (u'exclusion', 1)
# (u'eastward', 1)
# (u'grievances', 1)
# (u'commended', 1)
# (u'pursuits', 1)
# (u'relates', 1)
# (u'honorably', 1)
# (u'obstructions', 1)
# (u'delegates', 1)
# (u'embarrass', 1)
# (u'informs', 1)
# (u'deprived', 1)
# (u'illicit', 1)
# (u'retain', 1)
# (u'stimulate', 1)
# (u'years);', 1)
# (u'publication', 1)
# (u'diminish', 1)
# (u'migration', 1)
# (u'50,000,000', 1)
# (u'regenerated', 1)
# (u'inhabiting', 1)
# (u'gravity', 1)
# (u'seacoast--touches', 1)
# (u'16,770', 1)
# (u'$14,129,771.50;', 1)
# (u'neighboring', 1)
# (u'absurd', 1)
# (u'daughters--work', 1)
# (u'of--', 1)
# (u'reorganizing', 1)
# (u'legitimate', 1)
# (u'freemen;', 1)
# (u'influenced', 1)
# (u'allusion', 1)
# (u'artisans', 1)
# (u'usefulness', 1)
# (u'court--two', 1)
# (u'closes', 1)
# (u'genius', 1)
# (u'injustice', 1)
# (u'4,221,342', 1)
# (u'bearing', 1)
# (u'expiration', 1)
# (u'capture', 1)
# (u'northwest', 1)
# (u'72,703', 1)
# (u'conflicting', 1)
# (u'inhabit:', 1)
# (u'frequently', 1)
# (u'scruples', 1)
# (u'enemy;', 1)
# (u'parchment', 1)
# (u'fled', 1)
# (u'definitive', 1)
# (u'sweep', 1)
# (u'decease', 1)
# (u'guaranty', 1)
# (u'deliverance', 1)
# (u'reimbursements', 1)
# (u'unchangeably', 1)
# (u'unchangeable', 1)
# (u'piled', 1)
# (u'17,069,453', 1)
# (u'$1,339,710.35;', 1)
# (u'display', 1)
# (u'arms;', 1)
# (u'resting', 1)
# (u'83', 1)
# (u'prodded', 1)
# (u'$583,885,247.06', 1)
# (u'quantities', 1)
# (u'precision', 1)
# (u'period?', 1)
# (u'extinguishing', 1)
# (u'$4,292,776.18', 1)
# (u'lasted', 1)
# (u'foul', 1)
# (u'better?', 1)
# (u'whatsoever', 1)
# (u'conjecture', 1)
# (u'encounter', 1)
# (u'trusting', 1)
# (u'net', 1)
# (u'harbors', 1)
# (u'abolition', 1)
# (u'perpetuated', 1)
# (u'169,533', 1)
# (u'award', 1)
# (u'stade', 1)
# (u'divorced', 1)
# (u'adoption?', 1)
# (u'$5,656,705.49', 1)
# (u'degenerate', 1)
# (u'just--a', 1)
# (u'containing', 1)
# (u'lieutenant-general', 1)
# (u'$96,096,922.09', 1)
# (u'combination', 1)
# (u'disturb', 1)
# (u'(two-thirds', 1)
# (u'redressed', 1)
# (u'affords', 1)
# (u'barrier', 1)
# (u'appointments', 1)
# (u'certified', 1)
# (u'reclamations', 1)
# (u'thereon', 1)
# (u'alienage', 1)
# (u'$200,000,000', 1)
# (u'enhancing', 1)
# (u'unintended', 1)
# (u'fitting', 1)
# (u'alluded', 1)
# (u'spite', 1)
# (u'factious', 1)
# (u'behrings', 1)
# (u'adequate', 1)
# (u'chesapeake', 1)
# (u'mints', 1)
# (u'implication', 1)
# (u'sweden', 1)
# (u'convertible', 1)
# (u'negatively', 1)
# (u'poverty;', 1)
# (u'reconsideration', 1)
# (u'topics', 1)
# (u'justices', 1)
# (u'complaint', 1)
# (u'elicit', 1)
# (u'memorial', 1)
# (u'unfortunate', 1)
# (u'declaring', 1)
# (u'grades', 1)
# (u'$931,787.64;', 1)
# (u'$206,652.42', 1)
# (u'states;', 1)
# (u'indefinitely?', 1)
# (u'rank', 1)
# (u'corn', 1)
# (u'illustration', 1)
# (u'navy-yards', 1)
# (u'surround', 1)
# (u'prisoners', 1)
# (u'scrip', 1)
# (u'$13,190,324.45;', 1)
# (u'accordingly', 1)
# (u'3,800,000', 1)
# (u'submitting', 1)
# (u'abstract', 1)
# (u'radically', 1)
# (u'$11,314,206.84', 1)
# (u'supplemental', 1)
# (u'avowal', 1)
# (u'sovereignty', 1)
# (u'1,470,018', 1)
# (u'navigable', 1)
# (u'fullest', 1)
# (u'denounced', 1)
# (u'recapture', 1)
# (u'inconsiderately', 1)
# (u'$678,007.21', 1)
# (u'$8,299,820.90', 1)
# (u'$23,253,922.08', 1)
# (u'coerced', 1)
# (u'accomplished', 1)
# (u'$475,648.96', 1)
# (u'relating', 1)
# (u'undergone', 1)
# (u'acceptable', 1)
# (u'stream', 1)
# (u'14,410', 1)
# (u'council', 1)
# (u'depopulated', 1)
# (u'unimportant', 1)
# (u'pointed', 1)
# (u'domain', 1)
# (u'fostered', 1)
# (u'befell', 1)
# (u'effectual', 1)
# (u'unfriendly', 1)
# (u'proffered', 1)
# (u'unfrequently', 1)
# (u'surviving', 1)
# (u'$599,298,600.83', 1)
# (u'fiery', 1)
# (u'sound;', 1)
# (u'specify', 1)
# (u'sailing', 1)
# (u'respectability', 1)
# (u'desperate', 1)
# (u'pro', 1)
# (u'vice-admiral', 1)
# (u'trace', 1)
# (u'assault', 1)
# (u'paymaster-general', 1)
# (u'stormy', 1)
# (u'lighten', 1)
# (u'$200,000', 1)
# (u"d'affaires", 1)
# (u'fortifications', 1)
# (u'348,235', 1)
# (u'friends?', 1)
# (u'100,000,000', 1)
# (u'fidelity', 1)
# (u'contract', 1)
# (u'railway', 1)
# (u'laudable', 1)
# (u'concede', 1)
# (u'exhaustion', 1)
# (u'suspicions', 1)
# (u'217,186,000', 1)
# (u'premature', 1)
# (u'shops', 1)
# (u'sincere', 1)
# (u'discrepancy', 1)
# (u'diversion', 1)
# (u'concurring)', 1)
# (u'midshipmen', 1)
# (u'guided', 1)
# (u'reimbursed', 1)
# (u'arbitrament', 1)
# (u'defection', 1)
# (u'tax;', 1)
# (u'280,645', 1)
# (u'commissary-general', 1)
# (u'custody', 1)
# (u'expressing', 1)
# (u'arts', 1)
# (u'bona', 1)
# (u'manufactures', 1)
# (u'characterized', 1)
# (u'161,911', 1)
# (u'$394,368,407.36;', 1)
# (u'wit:', 1)
# (u'$14,396,250.51', 1)
# (u'alleges', 1)
# (u'tycoon', 1)
# (u'amongst', 1)
# (u'$37,640,787.95', 1)
# (u'accents', 1)
# (u'examine', 1)
# (u'unhesitatingly', 1)
# (u'cherokees', 1)
# (u'selfishly', 1)
# (u'briefly', 1)
# (u'overreach', 1)
# (u'$884,076,646.57;', 1)
# (u'a?', 1)
# (u'beware', 1)
# (u'subjected', 1)
# (u'solicit', 1)
# (u'north?', 1)
# (u'north;', 1)
# (u'belonging', 1)
# (u'emancipation;', 1)
# (u'ticket', 1)
# (u'31,000,000', 1)
# (u'$63,211,105.27', 1)
# (u'assured', 1)
# (u'tordenskiold', 1)
# (u'outgoing', 1)
# (u'inconsiderable', 1)
# (u'$1,485,103.61', 1)
# (u'99;', 1)
# (u'merchants', 1)
# (u'conventional', 1)
# (u'uniformity', 1)
# (u'minor', 1)
# (u'abridged', 1)
# (u'diffused', 1)
# (u'objections', 1)
# (u'proclaimed', 1)
# (u'fondest', 1)
# (u'preponderating', 1)
# (u'$588,333.29', 1)
# (u'territorial', 1)
# (u'argentine', 1)
# (u'prejudices', 1)
# (u'association', 1)
# (u'designation', 1)
# (u'instruct', 1)
# (u'76,677,872', 1)
# (u'contiguous', 1)
# (u'40,000', 1)
# (u'ever-enduring', 1)
# (u'blacks', 1)
# (u'no-more', 1)
# (u'differ', 1)
# (u'34.60', 1)
# (u'$9,049,296.40', 1)
# (u'numerous?', 1)
# (u'embraces', 1)
# (u'128,680', 1)
# (u'1870', 1)
# (u'regulation', 1)
# (u'$865,234,087.86', 1)
# (u'elaborate', 1)
# (u'urgently', 1)
# (u'essentially', 1)
# (u'9,638,131', 1)
# (u'exempted', 1)
# (u'market--increase', 1)
# (u'jeopardy', 1)
# (u'fertile?', 1)
# (u'55,811', 1)
# (u'to-day;', 1)
# (u'dividing', 1)
# (u'unhappy', 1)
# (u'pretenses', 1)
# (u'invoke', 1)
# (u'closely', 1)
# (u'promotive', 1)
# (u'surrendering', 1)
# (u'obscure', 1)
# (u'woo', 1)
# (u'burned', 1)
# (u'$720,039,039.79', 1)
# (u'union;', 1)
# (u'$11,163,789.59', 1)
# (u'majesty', 1)
# (u'well;', 1)
# (u'volumes)', 1)
# (u'supplying', 1)
# (u'143,331', 1)
# (u'unnecessarily', 1)
# (u'grains', 1)
# (u'portugal', 1)
# (u'overlooked', 1)
# (u'152,180', 1)
# (u'lengthy', 1)
# (u'elevated', 1)
# (u'339,693', 1)
# (u'rear', 1)
# (u'surprised', 1)
# (u'4,015,773', 1)
# (u'clemency', 1)
# (u'modifications', 1)
# (u'austria', 1)
# (u'34,799', 1)
# (u'amicably', 1)
# (u'hinted', 1)
# (u'steamer', 1)
# (u'settlers;', 1)
# (u'obliges', 1)
# (u'gradually', 1)
# (u'fragments', 1)
# (u'peculiarly', 1)
# (u'bureaus', 1)
# (u'conciliatory', 1)
# (u'$487,788,324.97', 1)
# (u'cherished', 1)
# (u'withholding', 1)
# (u'reciprocity', 1)
# (u'adjusting', 1)
# (u'states--certainly', 1)
# (u'retard', 1)
# (u'.at', 1)
# (u'75,000,000', 1)
# (u'adjudicate', 1)
# (u'250,000,000', 1)
# (u'depredations', 1)
# (u'reestablished', 1)
# (u'accidental', 1)
# (u'structure', 1)
# (u'tybee', 1)
# (u'ascertained', 1)
# (u'fitted', 1)
# (u'emancipation."', 1)
# (u'one-half', 1)
# (u'inferences', 1)
# (u'$24,729,846.51', 1)
# (u'demonstrations', 1)
# (u'tempted', 1)
# (u'melancholy', 1)
# (u'eminently', 1)
# (u'expansion', 1)
# (u'canals', 1)
# (u'remark', 1)
# (u'35', 1)
# (u'sentiments--have', 1)
# (u'cross-purposes', 1)
# (u'$152,203.77;', 1)
# (u'counties', 1)
# (u'inclined', 1)
# (u'procuring', 1)
# (u'detaching', 1)
# (u'disabilities', 1)
# (u'admiralty', 1)
# (u'coincident', 1)
# (u'proportions', 1)
# (u'contrabands', 1)
# (u'defective', 1)
# (u'procured', 1)
# (u'hazard', 1)
# (u'1925--our', 1)
# (u'objected', 1)
# (u'misapprehension', 1)
# (u'designs', 1)
# (u'accumulates', 1)
# (u'accompanies', 1)
# (u'reintroducing', 1)
# (u'3,000', 1)
# (u'especial', 1)
# (u'lands:', 1)
# (u'584', 1)
# (u'588', 1)
# (u'strictly', 1)
# (u'establishments', 1)
# (u'69,111', 1)
# (u'commodity', 1)
# (u'abolished', 1)
# (u'creditors', 1)
# (u'unchanged', 1)
# (u'bark', 1)
# (u'324', 1)
# (u'best-informed', 1)
# (u'inspiring', 1)
# (u'replenishing', 1)
# (u'inhabit', 1)
# (u'fernandina', 1)
# (u'476,442', 1)
# (u'enhanced', 1)
# (u'spares', 1)
# (u'diligent', 1)
# (u'adjusted', 1)
# (u'freedmen', 1)
# (u'sanctifying', 1)
# (u'186,984,335', 1)
# (u'known--the', 1)
# (u'abrogating', 1)
# (u'debtor', 1)
# (u'cometh', 1)
# (u'incumbent', 1)
# (u'fide', 1)
# (u'oft', 1)
# (u'133;', 1)
# (u'insurrectionist', 1)
# (u'proximity', 1)
# (u'evince', 1)
# (u'virtual', 1)
# (u'expedite', 1)
# (u'capacities', 1)
# (u'admitted', 1)
# (u'hail', 1)
# (u'choosing', 1)
# (u'contested', 1)
# (u'demonstrated', 1)
# (u'162,413', 1)
# (u'imaginary', 1)
# (u'amnesty', 1)
# (u'refuge', 1)
# (u'concession', 1)
# (u'injuriously', 1)
# (u'breeding', 1)
# (u'neutral', 1)
# (u'cruel', 1)
# (u'"one', 1)
# (u'confided', 1)
# (u'$4,551,966.98', 1)
# (u'scheldt', 1)
# (u'organized;', 1)
# (u'volumes', 1)
# (u'comparatively', 1)
# (u'captain', 1)
# (u'1,379', 1)
# (u'exaggerate', 1)
# (u'deliberate', 1)
# (u'selected', 1)
# (u'toll', 1)
# (u'permit', 1)
# (u'ventured', 1)
# (u'administering', 1)
# (u'hereby', 1)
# (u'aware', 1)
# (u'inhabited', 1)
# (u'accomplishment', 1)
# (u'deficiencies', 1)
# (u'regaining', 1)
# (u'land?', 1)
# (u'128,331', 1)
# (u'1840', 1)
# (u'derangement--while', 1)
# (u'commending', 1)
# (u'writing', 1)
# (u'matured', 1)
# (u'$12,438,253.78', 1)
# (u'netherlands', 1)
# (u'uninhabitable', 1)
# (u'forts', 1)
# (u'pensacola', 1)
# (u'mason', 1)
# (u'daniel', 1)
# (u'$690,791,842.97', 1)
# (u'121,125', 1)
# (u'$13,000,000', 1)
# (u'anxiety', 1)
# (u'regulate', 1)
# (u'expeditions', 1)
# (u'rome', 1)
# (u'unsecured', 1)
# (u'unoccupied', 1)
# (u'800', 1)
# (u'subject?', 1)
# (u'pardoned', 1)
# (u'armament', 1)
# (u'appended', 1)
# (u'sugar', 1)
# (u'hudsons', 1)
# (u'inactive', 1)
# (u'mathematically', 1)
# (u'squadron', 1)
# (u'timber', 1)
# (u'authorizing', 1)
# (u'estimable', 1)
# (u'particulars', 1)
# (u'167', 1)
# (u'applies', 1)
# (u'mistake', 1)
# (u'colonists', 1)
# (u'straits', 1)
# (u'tolerating', 1)
# (u'homesteads', 1)
# (u'146,216', 1)
# (u'numerical', 1)
# (u'$102,532,509.27', 1)
# (u'insisted', 1)
# (u'francisco;', 1)
# (u'assembling', 1)
# (u'distribute', 1)
# (u'$1,019,446', 1)
# (u'86,616', 1)
# (u'progresses', 1)
# (u'passeth', 1)
# (u'free--honorable', 1)
# (u'$11,125,364.13', 1)
# (u'sympathies', 1)
# (u'brigades', 1)
# (u'substitution', 1)
# (u'251,680,914', 1)
# (u'572,697', 1)
# (u'renown', 1)
# (u'impartiality', 1)
# (u'22d', 1)
# (u'initial', 1)
# (u'$47,511,448.10', 1)
# (u'bolivia', 1)
# (u'medium', 1)
# (u'fort', 1)
# (u'25th', 1)
# (u'customs;', 1)
# (u'productions', 1)
# (u'beaten;', 1)
# (u'despotism', 1)
# (u'physical', 1)
# (u'protested', 1)
# (u'$1,394,796,007.62', 1)
# (u'hackneyed', 1)
# (u'abridgment', 1)
# (u'1800', 1)
# (u'obviate', 1)
# (u'government;', 1)
# (u'discern', 1)
# (u'anticipation', 1)
# (u'passage', 1)
# (u'compensate', 1)
# (u'evaded', 1)
# (u'unexpected', 1)
# (u'exempts', 1)
# (u'contracted', 1)
# (u'paragraph', 1)
# (u'canadian', 1)
# (u'brazilian', 1)
# (u'simultaneous', 1)
# (u'odious', 1)
# (u'naturalizations', 1)
# (u'depots', 1)
# (u'arise', 1)
# (u'restitution', 1)
# (u'cuba', 1)
# (u'cultivation;', 1)
# (u'long-deferred', 1)
# (u'noteworthy', 1)
# (u'statesmen', 1)
# (u'vocation', 1)
# (u'significance', 1)
# (u'avocations', 1)
# (u'liberating', 1)
# (u'revised', 1)
# (u'receiving', 1)
# (u'impose', 1)
# (u'$529,692,460.50', 1)
# (u'engineer', 1)
# (u'bounty', 1)
# (u':$2,257,065.80', 1)
# (u'continuous', 1)
# (u'factions', 1)
# (u'accordance', 1)
# (u'32.67', 1)
# (u'cuttings', 1)
# (u'mates', 1)
# (u'$2,645,722.19', 1)
# (u"sherman's", 1)
# (u'nebr', 1)
# (u'sundry', 1)
# (u'opposite', 1)
# (u'falls', 1)
# (u'satisfying', 1)
# (u'slaver', 1)
# (u'$85,733,292.77', 1)
# (u'propagandism', 1)
# (u'guarded', 1)
# (u'liable', 1)
# (u'stipulation', 1)
# (u'overflowed', 1)
# (u'invoked', 1)
# (u'receipt', 1)
# (u'knoxville', 1)
# (u'illiberal', 1)
# (u'killing', 1)
# (u'deported', 1)
# (u'viz:', 1)
# (u'63', 1)
# (u'leaven', 1)
# (u'cares', 1)
# (u'educated', 1)
# (u'blessing', 1)
# (u'gunboat', 1)
# (u'declaration', 1)
# (u'hearty', 1)
# (u'polls', 1)
# (u'transactions', 1)
# (u'1930--say', 1)
# (u'adjudications', 1)
# (u'disadvantages', 1)
# (u'assist', 1)
# (u'fruit', 1)
# (u'"while', 1)
# (u'malicious', 1)
# (u'death', 1)
# (u'$8,683,000', 1)
# (u'papers', 1)
# (u'usefully', 1)
# (u'tanto', 1)
# (u'remorseless', 1)
# (u'recommends', 1)
# (u'depot', 1)
# (u'deduct', 1)
# (u'imprisonment', 1)
# (u'divine', 1)
# (u'peace;', 1)
# (u'forfeitures', 1)
# (u'exciting', 1)
# (u'government--the', 1)
# (u'bountiful', 1)
# (u'intervention', 1)
# (u'distracted', 1)
# (u'replies', 1)
# (u'510,396', 1)
# (u'judging', 1)
# (u'october', 1)
# (u'practically', 1)
# (u'size;', 1)
# (u'arises', 1)
# (u'hitchcock', 1)
# (u'valid', 1)
# (u'accounted', 1)
# (u'ferocity', 1)
# (u'conclusive', 1)
# (u'peninsular', 1)
# (u'embracing', 1)
# (u'welfare', 1)
# (u'candid', 1)
# (u'$137,476.26--a', 1)
# (u'6,000', 1)
# (u'employing', 1)
# (u'consummating', 1)
# (u'25,433', 1)
# (u'ranged', 1)
# (u'3,841,549', 1)
# (u'compliance', 1)
# (u'published', 1)
# (u'reclaimed', 1)
# (u'regiment', 1)
# (u'injure', 1)
# (u'contains', 1)
# (u'include', 1)
# (u'nebraska', 1)
# (u'foreseen', 1)
# (u'telegraphic', 1)
# (u'questioning', 1)
# (u'objects?', 1)
# (u'anticipations', 1)
# (u'detach', 1)
# (u'habits', 1)
# (u'beneficent', 1)
# (u'attendance--rising', 1)
# (u'expedient', 1)
# (u'before-mentioned', 1)
# (u'$9,383,000', 1)
# (u'wonderful', 1)
# (u'peaceably', 1)
# (u'16,039', 1)
# (u'$53,685,421.69', 1)
# (u'citizens;', 1)
# (u'assaulted', 1)
# (u'cargoes', 1)
# (u'well-selected', 1)
# (u'frauds', 1)
# (u'teems', 1)
# (u'disturbances', 1)
# (u'inconveniences', 1)
# (u'discord', 1)
# (u'relieves', 1)
# (u'unpleasant', 1)
# (u'compass', 1)
# (u'2,963,000', 1)
# (u'sacrificed', 1)
# (u'withdrawal', 1)
# (u'approaching', 1)
# (u'$4,216,520.79', 1)
# (u'vindicated', 1)
# (u'sole', 1)
# (u'terminus', 1)
# (u'sultan', 1)
# (u'forgotten', 1)
# (u'33,762', 1)
# (u'northeastern', 1)
# (u'complied', 1)
# (u'patiently', 1)
# (u'overlook', 1)
# (u'steamships', 1)
# (u'error', 1)
# (u'disappearance', 1)
# (u'ray', 1)
# (u'solicited', 1)
# (u'art.--all', 1)
# (u'changed;', 1)
# (u'openly', 1)
# (u'$69,059,642.40', 1)
# (u'alternate', 1)
# (u'recantation', 1)
# (u'dearly', 1)
# (u'yielded', 1)
# (u'munitions', 1)
# (u'art.--', 1)
# (u'irritation', 1)
# (u'7,500', 1)
# (u'tends', 1)
# (u'varying', 1)
# (u'unmindful', 1)
# (u'dictates', 1)
# (u'feelings', 1)
# (u'constraint', 1)
# (u'involving', 1)
# (u'12,000', 1)
# (u'ensue', 1)
# (u'placing', 1)
# (u'servile', 1)
# (u'legation', 1)
# (u'redeemed', 1)
# (u'148,513', 1)
# (u'expedition', 1)
# (u'warning', 1)
# (u'surveying', 1)
# (u'department:', 1)
# (u'revision', 1)
# (u'rightful', 1)
# (u'vow', 1)
# (u'23,191,876', 1)
# (u'restraining', 1)
# (u'compose', 1)
# (u'before?', 1)
# (u'pleasing', 1)
# (u'jurisdiction', 1)
# (u'wishes', 1)
# (u'facilitating', 1)
# (u'laws?', 1)
# (u'unprofitable', 1)
# (u'families--wives', 1)
# (u'adjust;', 1)
# (u'hereditary', 1)
# (u'outlying', 1)
# (u'$623,443,929.13', 1)
# (u'1930', 1)
# (u'debts', 1)
# (u'wit', 1)
# (u'lima', 1)
# (u'constitutionally', 1)
# (u'assumptions', 1)
# (u'africans', 1)
# (u'frontiers', 1)
# (u'reestablish', 1)
# (u'91,300', 1)
# (u'1880', 1)
# (u'tributary', 1)
# (u'produces', 1)
# (u'existence)', 1)
# (u'arrangements', 1)
# (u'criminal', 1)
# (u'successor', 1)
# (u'prevailing', 1)
# (u'heated', 1)
# (u'belgians', 1)
# (u'affliction', 1)
# (u'intermediate', 1)
# (u'colonization;', 1)
# (u'succeed;', 1)
# (u'comity', 1)
# (u'tracts', 1)
# (u'westward', 1)
# (u'appointing', 1)
# (u'7,239,814', 1)
# (u'constrained', 1)
# (u'montana', 1)
# (u'volunteers', 1)
# (u'devolving', 1)
# (u'asylum', 1)
# (u'northampton', 1)
# (u'emissaries', 1)
# (u'temporarily', 1)
# (u'tend', 1)
# (u'monarchy', 1)
# (u'interfere', 1)
# (u'(near', 1)
# (u'affording', 1)
# (u'choice;', 1)
# (u'remedied', 1)
# (u'mourning', 1)
# (u'therefor', 1)
# (u'examined', 1)
# (u'denial', 1)
# (u'52,257,065.80', 1)
# (u'$136,077.95', 1)
# (u'liberality', 1)
# (u'francisco', 1)
# (u'part;', 1)
# (u'latest', 1)
# (u'mistakes', 1)
# (u'afflicted', 1)
# (u'imposes', 1)
# (u'impassable', 1)
# (u'molding', 1)
# (u'inconstant', 1)
# (u'flagrant', 1)
# (u'severance', 1)
# (u'$167,617.17', 1)
# (u'blessings', 1)
# (u'brilliantly', 1)
# (u'unanswerable', 1)
# (u'imperial', 1)
# (u'46,195', 1)
# (u'incursions', 1)
# (u'naturalization', 1)
# (u'disbursement', 1)
# (u'jostle', 1)
# (u'$3,995,097.31', 1)
# (u'variety', 1)
# (u'sloping', 1)
# (u'treason', 1)
# (u'intentionally', 1)
# (u'8th', 1)
# (u'committals', 1)

# %%
for x in word_count_al_clean.subtractByKey(word_count_wjc_clean).sortBy(lambda x: x[1],ascending=False).collect():
    print x
# Out:
# (u'persons', 30)
# (u'navy', 28)
# (u'condition', 28)
# (u'naval', 27)
# (u'emancipation', 25)
# (u'thus', 23)
# (u'consideration', 22)
# (u'receipts', 22)
# (u'claims', 20)
# (u'interior', 18)
# (u'proclamation', 17)
# (u'vessels', 17)
# (u'believed', 16)
# (u'powers', 16)
# (u'actual', 16)
# (u'revenue', 16)
# (u'rebellion', 16)
# (u'territories', 15)
# (u'insurgents', 14)
# (u'1861', 14)
# (u'aggregate', 14)
# (u'colored', 14)
# (u'expenditures', 14)
# (u'submitted', 14)
# (u'1st', 14)
# (u'favorable', 13)
# (u'valuable', 13)
# (u'insurrection', 13)
# (u'disbursements', 13)
# (u'territory', 13)
# (u'favor', 12)
# (u'insurgent', 12)
# (u'cases', 12)
# (u'parts', 12)
# (u'recommendation', 12)
# (u'heretofore', 11)
# (u'cent', 11)
# (u'loyal', 11)
# (u'intercourse', 11)
# (u'stated', 11)
# (u'derived', 10)
# (u'treaties', 10)
# (u'ports', 10)
# (u'1860', 10)
# (u'extent', 10)
# (u'laborers', 10)
# (u'neither', 10)
# (u'satisfactory', 10)
# (u'maryland', 10)
# (u'supreme', 10)
# (u'cash', 9)
# (u'slaves', 9)
# (u'suppression', 9)
# (u'britain', 9)
# (u'indians', 9)
# (u'difficulties', 9)
# (u'postal', 9)
# (u'expediency', 8)
# (u'relation', 8)
# (u'temporary', 8)
# (u'expected', 8)
# (u'telegraph', 8)
# (u'blockade', 8)
# (u'considerable', 8)
# (u'respectfully', 8)
# (u'extensive', 8)
# (u'circuit', 8)
# (u'herewith', 8)
# (u'length', 8)
# (u'appropriation', 8)
# (u'object', 8)
# (u'missouri', 8)
# (u'hoped', 8)
# (u'liberal', 7)
# (u'correspondence', 7)
# (u'rapidly', 7)
# (u'similar', 7)
# (u'therein', 7)
# (u'30th', 7)
# (u'virginia', 7)
# (u'communication', 7)
# (u'due', 7)
# (u'tribes', 7)
# (u'mode', 7)
# (u'additional', 7)
# (u'1864', 7)
# (u'duties', 7)
# (u'maritime', 7)
# (u'maintained', 7)
# (u'railroad', 7)
# (u'1863', 7)
# (u'empire', 7)
# (u'disloyal', 7)
# (u'expenses', 7)
# (u'necessarily', 7)
# (u'tennessee', 7)
# (u'refer', 7)
# (u'ratio', 6)
# (u'hence', 6)
# (u'included', 6)
# (u'distinct', 6)
# (u'september', 6)
# (u'seems', 6)
# (u'vessel', 6)
# (u'atlantic', 6)
# (u'gratifying', 6)
# (u'pensioners', 6)
# (u'commend', 6)
# (u'limited', 6)
# (u'postmaster-general', 6)
# (u'san', 6)
# (u'massachusetts', 6)
# (u'mountains', 6)
# (u'friendly', 6)
# (u'articles', 6)
# (u'assumed', 6)
# (u'deemed', 6)
# (u'reference', 6)
# (u'preceding', 6)
# (u'assurance', 6)
# (u'owners', 6)
# (u'notes', 6)
# (u'separation', 6)
# (u'furnish', 6)
# (u'completed', 6)
# (u'shown', 6)
# (u'abundant', 6)
# (u'labors', 6)
# (u'careful', 6)
# (u'settlement', 6)
# (u'river', 6)
# (u'doubtful', 6)
# (u'coast', 6)
# (u'1862', 6)
# (u'post-office', 5)
# (u'hostilities', 5)
# (u'prospect', 5)
# (u'generally', 5)
# (u'whites', 5)
# (u'consuls', 5)
# (u'completion', 5)
# (u'patriotism', 5)
# (u'evils', 5)
# (u'notwithstanding', 5)
# (u'establishment', 5)
# (u'transmitted', 5)
# (u'arising', 5)
# (u'authorized', 5)
# (u'port', 5)
# (u'mineral', 5)
# (u'agricultural', 5)
# (u'ohio', 5)
# (u'deficiency', 5)
# (u'detail', 5)
# (u'commencement', 5)
# (u'conducted', 5)
# (u'entered', 5)
# (u'chile', 5)
# (u'contemplated', 5)
# (u'merely', 5)
# (u'peru', 5)
# (u'british', 5)
# (u'fellow-citizens', 5)
# (u'circulation', 5)
# (u'section', 5)
# (u'belligerent', 5)
# (u'invalid', 5)
# (u'arisen', 5)
# (u'foreigners', 5)
# (u'boundary', 5)
# (u'scarcely', 5)
# (u'generous', 5)
# (u'economical', 5)
# (u'branch', 5)
# (u'points', 5)
# (u'execution', 5)
# (u'altogether', 5)
# (u'suitable', 5)
# (u'homestead', 5)
# (u'summary', 5)
# (u'freed', 5)
# (u'6', 5)
# (u'contest', 5)
# (u'ocean', 5)
# (u'settlements', 5)
# (u'quarters', 5)
# (u'promptly', 5)
# (u'documents', 5)
# (u'interested', 5)
# (u'delaware', 5)
# (u'compared', 5)
# (u'iowa', 4)
# (u'laborer', 4)
# (u'securities', 4)
# (u'concur', 4)
# (u'proportion', 4)
# (u'suppressed', 4)
# (u'satisfaction', 4)
# (u'cease', 4)
# (u'late', 4)
# (u'representatives:', 4)
# (u'friendship', 4)
# (u'wisconsin', 4)
# (u'revolutionary', 4)
# (u'legislature', 4)
# (u'adoption', 4)
# (u'sections', 4)
# (u'directed', 4)
# (u'insurrectionary', 4)
# (u'compensated', 4)
# (u'egypt', 4)
# (u'possession', 4)
# (u'expenditure', 4)
# (u'judgment', 4)
# (u'(or', 4)
# (u'consular', 4)
# (u'suggest', 4)
# (u'rocky', 4)
# (u'seamen', 4)
# (u'peculiar', 4)
# (u'convenient', 4)
# (u'sale', 4)
# (u'propriety', 4)
# (u'intended', 4)
# (u'article', 4)
# (u'injurious', 4)
# (u'costa', 4)
# (u'cordial', 4)
# (u'earnest', 4)
# (u'miscellaneous', 4)
# (u'disposed', 4)
# (u'existence', 4)
# (u'event', 4)
# (u'justly', 4)
# (u'banking', 4)
# (u'allegiance', 4)
# (u'currency', 4)
# (u'names', 4)
# (u'appointed', 4)
# (u'superior', 4)
# (u'sufficiently', 4)
# (u'rhode', 4)
# (u'liberia', 4)
# (u'periods', 4)
# (u"majesty's", 4)
# (u'pardon', 4)
# (u'besides', 4)
# (u'route', 4)
# (u'acquisition', 4)
# (u'latter', 4)
# (u'hayti', 4)
# (u'oregon', 4)
# (u'taxation', 4)
# (u'review', 4)
# (u'offered', 4)
# (u'myself', 4)
# (u'respective', 4)
# (u'render', 4)
# (u'statement', 4)
# (u'colonizing', 4)
# (u'reliable', 4)
# (u'commissioner', 4)
# (u'harvests', 4)
# (u'compensation', 4)
# (u'proceedings', 4)
# (u'michigan', 4)
# (u'jersey', 4)
# (u'spain', 4)
# (u'advisable', 4)
# (u'encouragement', 4)
# (u'thereby', 4)
# (u'earnestly', 4)
# (u'leaves', 4)
# (u'attended', 4)
# (u'circumstances', 4)
# (u'exercised', 4)
# (u'rica', 4)
# (u'amounted', 4)
# (u'quantity', 4)
# (u'apparent', 4)
# (u'conventions', 4)
# (u'abraham', 4)
# (u'expended', 4)
# (u'movements', 4)
# (u'stipulations', 4)
# (u'deem', 4)
# (u'abolish', 4)
# (u'readily', 4)
# (u'injury', 4)
# (u'residing', 4)
# (u'wherein', 4)
# (u'modifying', 4)
# (u'manifest', 4)
# (u'colonization', 4)
# (u'adjustment', 4)
# (u'precisely', 4)
# (u'fixed', 4)
# (u'rendered', 4)
# (u'lawful', 4)
# (u'partially', 4)
# (u'recommendations', 4)
# (u'belong', 4)
# (u'desirable', 3)
# (u'integrity', 3)
# (u'presents', 3)
# (u'uncertain', 3)
# (u'remainder', 3)
# (u'acknowledged', 3)
# (u'commissioners', 3)
# (u'railroads', 3)
# (u'chaplains', 3)
# (u'administer', 3)
# (u'privilege', 3)
# (u'suppose', 3)
# (u'cessation', 3)
# (u'assigned', 3)
# (u'judge', 3)
# (u'obvious', 3)
# (u'suggestions', 3)
# (u'complaints', 3)
# (u'proceeding', 3)
# (u'mainly', 3)
# (u'aiding', 3)
# (u'advantages', 3)
# (u'bureau', 3)
# (u'acquiring', 3)
# (u'intimately', 3)
# (u'pennsylvania', 3)
# (u'introduction', 3)
# (u'73', 3)
# (u'various', 3)
# (u'competent', 3)
# (u'patriotic', 3)
# (u'navigation', 3)
# (u'nicaragua', 3)
# (u'consequently', 3)
# (u'apparently', 3)
# (u'duly', 3)
# (u'amounts', 3)
# (u'1/3', 3)
# (u'retract', 3)
# (u'decrease', 3)
# (u'adapted', 3)
# (u'ships', 3)
# (u'occupied', 3)
# (u'"can', 3)
# (u'diminished', 3)
# (u'facilitate', 3)
# (u'legislative', 3)
# (u'exhibit', 3)
# (u'louisiana', 3)
# (u'claimed', 3)
# (u'nevertheless', 3)
# (u'distant', 3)
# (u'tone', 3)
# (u'doubtless', 3)
# (u'assembled', 3)
# (u'prize', 3)
# (u'bounties', 3)
# (u'ere', 3)
# (u'unjust', 3)
# (u'destitution', 3)
# (u'better?"', 3)
# (u'detention', 3)
# (u'purchase', 3)
# (u'satisfied', 3)
# (u'perceive', 3)
# (u'injuries', 3)
# (u'moneys', 3)
# (u'descent', 3)
# (u'pertaining', 3)
# (u'cargo', 3)
# (u'appear', 3)
# (u'till', 3)
# (u'vicinity', 3)
# (u'existed', 3)
# (u'impossible', 3)
# (u'argument', 3)
# (u'attempted', 3)
# (u'afterwards', 3)
# (u'cast', 3)
# (u'noble', 3)
# (u'immense', 3)
# (u'caused', 3)
# (u'pleasure', 3)
# (u'easily', 3)
# (u'regret', 3)
# (u'finances', 3)
# (u'disunion', 3)
# (u'populous', 3)
# (u'intelligence', 3)
# (u'appears', 3)
# (u'representative', 3)
# (u'understood', 3)
# (u'providence', 3)
# (u'issued', 3)
# (u'respectively', 3)
# (u'occurred', 3)
# (u'emigration', 3)
# (u'self-sustaining', 3)
# (u'instance', 3)
# (u'statute', 3)
# (u'employed', 3)
# (u'three-fourths', 3)
# (u'mail', 3)
# (u'suspension', 3)
# (u'intention', 3)
# (u'proceeds', 3)
# (u'overrun', 3)
# (u'advancing', 3)
# (u'reasonably', 3)
# (u'enlightened', 3)
# (u'somewhat', 3)
# (u'requisite', 3)
# (u'iron', 3)
# (u'letter', 3)
# (u'seizure', 3)
# (u'commenced', 3)
# (u'naturalized', 3)
# (u'amicable', 3)
# (u'unwilling', 3)
# (u'died', 3)
# (u'discharged', 3)
# (u'venture', 3)
# (u'concurrence', 3)
# (u'ship', 3)
# (u'doubted', 3)
# (u'estimate', 3)
# (u'1900', 3)
# (u'influences', 3)
# (u'supervision', 3)
# (u'declined', 3)
# (u'degree', 3)
# (u'admission', 3)
# (u'mitigate', 3)
# (u'consist', 3)
# (u'attend', 3)
# (u'masters', 3)
# (u'collection', 3)
# (u'enforced', 3)
# (u'surrendered', 3)
# (u'exists', 3)
# (u'fostering', 3)
# (u'enlarging', 3)
# (u'privileges', 3)
# (u'avoid', 3)
# (u'warrants', 3)
# (u'faithfully', 3)
# (u'unanimity', 3)
# (u'consequent', 3)
# (u'revenues', 3)
# (u'cheerfully', 3)
# (u'nominal', 3)
# (u'coin', 3)
# (u'abolishment', 3)
# (u'augmented', 3)
# (u'selection', 3)
# (u'claimants', 3)
# (u'mile', 3)
# (u'denied', 3)
# (u'france', 3)
# (u'ascertain', 3)
# (u'exchanges', 3)
# (u'touching', 3)
# (u'copy', 3)
# (u'voters', 3)
# (u'adjudication', 3)
# (u'bondage', 3)
# (u'prudent', 3)
# (u'regiments', 3)
# (u'referred', 3)
# (u'induced', 3)
# (u'occupation', 3)
# (u'b', 3)
# (u'speedily', 3)
# (u'cotton', 3)
# (u'definitely', 3)
# (u'proof', 3)
# (u'arrangement', 3)
# (u'hitherto', 3)
# (u'furnished', 3)
# (u'seaboard', 3)
# (u'main', 3)
# (u'civilization', 3)
# (u'constantly', 3)
# (u'official', 3)
# (u'consists', 2)
# (u'remodeled', 2)
# (u'pardons', 2)
# (u'estimates', 2)
# (u'patent', 2)
# (u'haste', 2)
# (u'shorten', 2)
# (u'prevented', 2)
# (u'exigencies', 2)
# (u'content', 2)
# (u'seceded', 2)
# (u'speedy', 2)
# (u'cooperating', 2)
# (u'channels', 2)
# (u'practiced', 2)
# (u'solely', 2)
# (u'respecting', 2)
# (u'borrowed', 2)
# (u'diplomatic', 2)
# (u'installments', 2)
# (u'obtained', 2)
# (u'profitably', 2)
# (u'perform', 2)
# (u'prussia', 2)
# (u'zeal', 2)
# (u'rallying', 2)
# (u'continuance', 2)
# (u'portions', 2)
# (u'$901,125,674.86', 2)
# (u'to-day', 2)
# (u'permanently', 2)
# (u'cheap', 2)
# (u'inland', 2)
# (u'usually', 2)
# (u'intelligible', 2)
# (u'relinquish', 2)
# (u'explicit', 2)
# (u'forms', 2)
# (u'patronage', 2)
# (u'multiply', 2)
# (u'circulating', 2)
# (u'designated', 2)
# (u'definite', 2)
# (u'arrival', 2)
# (u'postage', 2)
# (u'unforeseen', 2)
# (u'colony', 2)
# (u'driven', 2)
# (u'accessible', 2)
# (u'insurrectionists', 2)
# (u'sums', 2)
# (u'considering', 2)
# (u'mixed', 2)
# (u'anomalous', 2)
# (u'inexhaustible', 2)
# (u'benevolent', 2)
# (u'laying', 2)
# (u'design', 2)
# (u'destitute', 2)
# (u'judicious', 2)
# (u'modify', 2)
# (u'authorize', 2)
# (u'navy-yard', 2)
# (u'corrected', 2)
# (u'prompt', 2)
# (u'reopened', 2)
# (u'excepted', 2)
# (u'energies', 2)
# (u'decennial', 2)
# (u'arbitration', 2)
# (u'compromise', 2)
# (u'charges', 2)
# (u'distributed', 2)
# (u'adhered', 2)
# (u'tender', 2)
# (u'convicted', 2)
# (u'funded', 2)
# (u'frankness', 2)
# (u'observed', 2)
# (u'imposed', 2)
# (u'exaggerated', 2)
# (u'inducements', 2)
# (u'accustomed', 2)
# (u'imposts', 2)
# (u'prudence', 2)
# (u'anxious', 2)
# (u'settlers', 2)
# (u'conformity', 2)
# (u'steamers', 2)
# (u'earnestness', 2)
# (u'debtors', 2)
# (u'enactments', 2)
# (u'adjournment', 2)
# (u'branches', 2)
# (u'vigor', 2)
# (u'1920', 2)
# (u'safely', 2)
# (u'compensating', 2)
# (u'corresponding', 2)
# (u'interoceanic', 2)
# (u'discretion', 2)
# (u'cordiality', 2)
# (u'resumption', 2)
# (u'effected', 2)
# (u'ranks', 2)
# (u'resolution', 2)
# (u'secondly', 2)
# (u'facilities', 2)
# (u'loyalty', 2)
# (u'situated', 2)
# (u'localities', 2)
# (u'steam', 2)
# (u'armored', 2)
# (u'actuated', 2)
# (u'damages', 2)
# (u'embarrassments', 2)
# (u'specie', 2)
# (u'quiet', 2)
# (u'forborne', 2)
# (u'anew', 2)
# (u'displace', 2)
# (u'gratulation', 2)
# (u'lever', 2)
# (u'fugitive-slave', 2)
# (u'trial', 2)
# (u'armies', 2)
# (u'seventy', 2)
# (u'britannic', 2)
# (u'clause', 2)
# (u'constructing', 2)
# (u'considerably', 2)
# (u'printed', 2)
# (u'satisfactorily', 2)
# (u'maine', 2)
# (u'liberation', 2)
# (u'expectation', 2)
# (u'concert', 2)
# (u'fluctuations', 2)
# (u'embarrassment', 2)
# (u'moreover', 2)
# (u'almighty', 2)
# (u'superintendency', 2)
# (u'unsatisfactory', 2)
# (u'according', 2)
# (u'nobly', 2)
# (u'103,208,415', 2)
# (u'administered', 2)
# (u'original', 2)
# (u'ceased', 2)
# (u'aforesaid', 2)
# (u'marginal', 2)
# (u'excuse', 2)
# (u'chiefly', 2)
# (u'accommodated', 2)
# (u'pirates', 2)
# (u'congenial', 2)
# (u'occurs', 2)
# (u'embraced', 2)
# (u'surveyed', 2)
# (u'instituted', 2)
# (u'rendering', 2)
# (u'pressed', 2)
# (u'manner', 2)
# (u'impracticable', 2)
# (u'machinery', 2)
# (u'questioned', 2)
# (u'excited', 2)
# (u'follows', 2)
# (u'exceeding', 2)
# (u'neutrality', 2)
# (u'thirdly', 2)
# (u'morocco', 2)
# (u'gross', 2)
# (u'proclamations', 2)
# (u'disposal', 2)
# (u'suggests', 2)
# (u'apply', 2)
# (u'afforded', 2)
# (u'confiscate', 2)
# (u'prizes', 2)
# (u'light', 2)
# (u'inaugural', 2)
# (u'consummation', 2)
# (u'academy', 2)
# (u'$18,842,558.71', 2)
# (u'beg', 2)
# (u'gradual', 2)
# (u'secretaries', 2)
# (u'denmark', 2)
# (u'confusion', 2)
# (u'bridges', 2)
# (u'firmness', 2)
# (u'approval', 2)
# (u'plain', 2)
# (u'discoveries', 2)
# (u'devised', 2)
# (u'seacoast', 2)
# (u'90,000', 2)
# (u'location', 2)
# (u'$13,606,759.11', 2)
# (u'inadequate', 2)
# (u'outlets', 2)
# (u'granting', 2)
# (u'abolishing', 2)
# (u'cordially', 2)
# (u'glance', 2)
# (u'trusted', 2)
# (u'midst', 2)
# (u'interposition', 2)
# (u'indicated', 2)
# (u'adjacent', 2)
# (u'deducted', 2)
# (u'exhibits', 2)
# (u'confidently', 2)
# (u'suspended', 2)
# (u'thereof', 2)
# (u'speaking', 2)
# (u'manifested', 2)
# (u'supplied', 2)
# (u'hostility', 2)
# (u'fullness', 2)
# (u'tons', 2)
# (u'grave', 2)
# (u'condemned', 2)
# (u'concerning', 2)
# (u'colonies', 2)
# (u'vermont', 2)
# (u'approbation', 2)
# (u'consciousness', 2)
# (u'candidate', 2)
# (u'northward', 2)
# (u'undisturbed', 2)
# (u'beneficial', 2)
# (u'blockading', 2)
# (u'apprehensions', 2)
# (u'entertained', 2)
# (u'were:', 2)
# (u'deceive', 2)
# (u'statistical', 2)
# (u'tendency', 2)
# (u'inferior', 2)
# (u'orphans', 2)
# (u'authorizes', 2)
# (u'returns', 2)
# (u'annum', 2)
# (u'seldom', 2)
# (u'diversities', 2)
# (u'declared', 2)
# (u'motives', 2)
# (u'aspect', 2)
# (u'captured', 2)
# (u'determine', 2)
# (u'amendments', 2)
# (u'onerous', 2)
# (u'legislatures', 2)
# (u'induce', 2)
# (u'advantageous', 2)
# (u'disposition', 2)
# (u'enactment', 2)
# (u'surface', 2)
# (u'labored', 2)
# (u'idaho', 2)
# (u'juan', 2)
# (u'mclean', 2)
# (u'enlarged', 2)
# (u'5th', 2)
# (u'remedy', 2)
# (u'$181,086,635.07', 2)
# (u'circuits;', 2)
# (u'sold', 2)
# (u'incident', 2)
# (u'maintenance', 2)
# (u'developments', 2)
# (u'ample', 2)
# (u'judgments', 2)
# (u'possessory', 2)
# (u'exclusively', 2)
# (u'governmental', 2)
# (u'metals', 2)
# (u'bank-note', 2)
# (u'patents', 2)
# (u'resolutions', 2)
# (u'closing', 2)
# (u'hampshire', 2)
# (u'sanctioned', 2)
# (u'revived', 2)
# (u'accredited', 2)
# (u'beginner', 2)
# (u'sentiment', 2)
# (u'owned', 2)
# (u'profoundest', 2)
# (u'humane', 2)
# (u'below', 2)
# (u'1830', 2)
# (u'mcclellan', 2)
# (u'functions', 2)
# (u'republics', 2)
# (u'amply', 2)
# (u'additions', 2)
# (u'regarded', 2)
# (u'distribution', 2)
# (u'potomac', 2)
# (u'saves', 2)
# (u'stipulated', 2)
# (u'excellent', 2)
# (u'dissatisfaction', 2)
# (u'reaccept', 2)
# (u'customs', 2)
# (u'entitled', 2)
# (u'durability', 2)
# (u'resume', 2)
# (u'redress', 2)
# (u'regular', 2)
# (u'folly', 2)
# (u'decided', 2)
# (u'unavoidable', 2)
# (u'omission', 2)
# (u'agitation', 2)
# (u'successfully', 2)
# (u'strife', 2)
# (u'inhuman', 2)
# (u'constituting', 2)
# (u'lieu', 2)
# (u'remained', 2)
# (u'novel', 2)
# (u'withhold', 2)
# (u'whoever', 2)
# (u'entertain', 2)
# (u'bloody', 2)
# (u'spanish', 2)
# (u'derive', 2)
# (u'inflicted', 2)
# (u'emigrants', 2)
# (u'investigation', 2)
# (u'liberally', 2)
# (u'occurring', 2)
# (u'exceeded', 2)
# (u'dispute', 2)
# (u'treasure', 2)
# (u'losses', 2)
# (u'fruitful', 2)
# (u'document', 2)
# (u'elements', 2)
# (u'specified', 2)
# (u'moderate', 2)
# (u'intimate', 2)
# (u'intrusted', 2)
# (u'convertibility', 2)
# (u'fill', 2)
# (u'returning', 2)
# (u'squadrons', 2)
# (u'accompanying', 2)
# (u'adjust', 2)
# (u'excess', 2)
# (u'$5,329,044.21', 2)
# (u'cultivation', 2)
# (u'1790', 2)
# (u'anticipated', 2)
# (u'earliest', 2)
# (u'omit', 2)
# (u'3,982,011', 2)
# (u'$895,796,630.65', 2)
# (u'jefferson', 2)
# (u'reunion', 2)
# (u'sometimes', 2)
# (u'inaugurate', 2)
# (u'exhibiting', 2)
# (u'comfort', 2)
# (u'forfeited', 2)
# (u'reliance', 2)
# (u'capital;', 2)
# (u'commanders', 2)
# (u'36.45', 2)
# (u'remunerative', 2)
# (u'declarations', 2)
# (u'auspices', 2)
# (u'advocates', 2)
# (u'ambition', 2)
# (u'magnitude', 2)
# (u'suffrage', 2)
# (u'wholly', 2)
# (u'activity', 2)
# (u'acquiescence', 2)
# (u'preliminary', 2)
# (u'magistrate', 2)
# (u'calling', 2)
# (u'grounds', 2)
# (u'$700,000', 2)
# (u'supply', 2)
# (u'wisest', 2)
# (u'bench', 2)
# (u'exempt', 2)
# (u'elapsed', 2)
# (u'perpetual', 2)
# (u'1,456,514', 2)
# (u'assuming', 2)
# (u'imperfectly', 2)
# (u'successors', 2)
# (u'emperor', 2)
# (u'populated', 2)
# (u'naturally', 2)
# (u'owing', 2)
# (u'reciprocated', 2)
# (u'aided', 1)
# (u'paris', 1)
# (u'"an', 1)
# (u'oriental', 1)
# (u'deliberations', 1)
# (u'cruising', 1)
# (u'railways', 1)
# (u'crops', 1)
# (u'seven?', 1)
# (u'present;', 1)
# (u'immunities', 1)
# (u'rigorous', 1)
# (u'lesser', 1)
# (u'favorers', 1)
# (u'5,304,937', 1)
# (u'dry', 1)
# (u'occupying', 1)
# (u'yard', 1)
# (u'casualties', 1)
# (u'obeying', 1)
# (u'philanthropic', 1)
# (u'exceptions', 1)
# (u'caution', 1)
# (u'vagrant', 1)
# (u'resignation', 1)
# (u'35.87', 1)
# (u'delicacy', 1)
# (u'97,918', 1)
# (u'1810', 1)
# (u'157;', 1)
# (u'london', 1)
# (u'patronized', 1)
# (u'esteemed', 1)
# (u'17th', 1)
# (u'undeveloped', 1)
# (u'secured?', 1)
# (u'capricious', 1)
# (u'substantially', 1)
# (u'reserving', 1)
# (u'jealous', 1)
# (u'power;', 1)
# (u'22,767', 1)
# (u'occasioned', 1)
# (u'outlay', 1)
# (u'belligerents', 1)
# (u'absorbed', 1)
# (u'transmit', 1)
# (u'rest;', 1)
# (u'indemnification', 1)
# (u'affirmatively', 1)
# (u'calmness', 1)
# (u'pasha', 1)
# (u'decidedly', 1)
# (u'undue', 1)
# (u'uneasiness', 1)
# (u'disbursed', 1)
# (u'considerate', 1)
# (u'beset', 1)
# (u'them?', 1)
# (u'115,141', 1)
# (u'stead', 1)
# (u'campbell', 1)
# (u'christian', 1)
# (u'contraband', 1)
# (u'profitable', 1)
# (u'confessedly', 1)
# (u'pity', 1)
# (u'abstracts', 1)
# (u'peacefully', 1)
# (u'alleghanies', 1)
# (u'appeared', 1)
# (u'royal', 1)
# (u'here--congress', 1)
# (u'residue', 1)
# (u'excite', 1)
# (u'apprehension', 1)
# (u'lessen', 1)
# (u'congratulation', 1)
# (u'long-pending', 1)
# (u'quartermaster-general', 1)
# (u'sailors', 1)
# (u'$865,234,087.86;', 1)
# (u'shortly', 1)
# (u'mingle', 1)
# (u'foreigner', 1)
# (u"senate's", 1)
# (u'meanly', 1)
# (u'$102,316,152.99', 1)
# (u'espoused', 1)
# (u'59', 1)
# (u'dense', 1)
# (u'accepts', 1)
# (u'133,000,000', 1)
# (u'rigor', 1)
# (u'obtaining', 1)
# (u'emigrate', 1)
# (u'resulted', 1)
# (u'145,551', 1)
# (u'$3,046,615.35', 1)
# (u'attached', 1)
# (u'connection--the', 1)
# (u'simplifying', 1)
# (u'willingly', 1)
# (u'uttered', 1)
# (u'eternity', 1)
# (u'forever."', 1)
# (u'controlling', 1)
# (u'customary', 1)
# (u'persevere', 1)
# (u'liability', 1)
# (u'42,323,341', 1)
# (u'$1,795,331.73', 1)
# (u'ironclad', 1)
# (u'satisfy', 1)
# (u'exemption', 1)
# (u'embarrassing', 1)
# (u'subtract', 1)
# (u'wrongs', 1)
# (u'upheld', 1)
# (u'$2,112,814.57', 1)
# (u'$86,835,900.27', 1)
# (u'impair', 1)
# (u'incidents', 1)
# (u'regularly', 1)
# (u'dispositions', 1)
# (u'sworn', 1)
# (u'strictness', 1)
# (u'inhabitants', 1)
# (u'arrived', 1)
# (u'refund', 1)
# (u'$42,674,569.69;', 1)
# (u'troubles', 1)
# (u'compelled', 1)
# (u'repaired', 1)
# (u'honduras', 1)
# (u'(1864)', 1)
# (u'advantage?', 1)
# (u'inadequacy', 1)
# (u'suggesting', 1)
# (u'disrespect', 1)
# (u'contemplation', 1)
# (u'conversions', 1)
# (u'checked', 1)
# (u'$1,740,690,489.49', 1)
# (u'holden', 1)
# (u'$27,505,599.46', 1)
# (u'revolt', 1)
# (u'unavailing', 1)
# (u'discarding', 1)
# (u'unwisely', 1)
# (u'derangement--in', 1)
# (u'$570,841,700.25', 1)
# (u'pursuant', 1)
# (u'77,246', 1)
# (u'sierra', 1)
# (u'dreaded', 1)
# (u'clerks', 1)
# (u'deprecate', 1)
# (u'$12,644,786.20', 1)
# (u'1821', 1)
# (u'circuits', 1)
# (u'physically', 1)
# (u'470,745', 1)
# (u'cadets', 1)
# (u'whereabouts', 1)
# (u'16,924', 1)
# (u'menacing', 1)
# (u'awards', 1)
# (u'color', 1)
# (u'sentinel', 1)
# (u'deposited', 1)
# (u'pugets', 1)
# (u'derogation', 1)
# (u'way?', 1)
# (u'spare', 1)
# (u'inquire', 1)
# (u'sitana', 1)
# (u'deference', 1)
# (u'figures', 1)
# (u'compensation;', 1)
# (u'theater', 1)
# (u'objection', 1)
# (u'occasional', 1)
# (u'domicile', 1)
# (u'272,143', 1)
# (u'resolved', 1)
# (u'perpetuated?', 1)
# (u'misapprehensions', 1)
# (u'lebanon', 1)
# (u'limits;', 1)
# (u'perverse', 1)
# (u'1850', 1)
# (u'1854', 1)
# (u'22,198', 1)
# (u'free;', 1)
# (u'averting', 1)
# (u'cinnabar', 1)
# (u'clerkship', 1)
# (u'$96,096,922.09;', 1)
# (u'hanover', 1)
# (u'proportionately', 1)
# (u'oppressed', 1)
# (u'estoppel', 1)
# (u'domingo', 1)
# (u'arranged', 1)
# (u'severally', 1)
# (u'sanguine', 1)
# (u'insomuch', 1)
# (u'bounded', 1)
# (u'disloyalty', 1)
# (u'$150,417.25', 1)
# (u'accomac', 1)
# (u'posts', 1)
# (u'laborers;', 1)
# (u'$8,349,296.40', 1)
# (u'disquiet', 1)
# (u'hatteras', 1)
# (u'presentation', 1)
# (u'norfolk', 1)
# (u'venezuela', 1)
# (u'canvass', 1)
# (u'assaults', 1)
# (u'melioration', 1)
# (u'crush', 1)
# (u'$84,578,834.47', 1)
# (u'ranges', 1)
# (u'operating', 1)
# (u'35.58', 1)
# (u'exceptionally', 1)
# (u'suddenly', 1)
# (u'viz', 1)
# (u'producing', 1)
# (u'22,187', 1)
# (u'purchaser', 1)
# (u'42,534', 1)
# (u'neglected', 1)
# (u'began;', 1)
# (u'thirty-seven', 1)
# (u'state;', 1)
# (u'charge?', 1)
# (u'acquisitions', 1)
# (u'groundless', 1)
# (u'springing', 1)
# (u'rounded', 1)
# (u'brig', 1)
# (u'desirable--almost', 1)
# (u'countrymen', 1)
# (u'induces', 1)
# (u'dominated', 1)
# (u'favored', 1)
# (u'dominating', 1)
# (u'insure', 1)
# (u'relieved', 1)
# (u'countries--results', 1)
# (u'imposing', 1)
# (u'inaugurated', 1)
# (u'____', 1)
# (u'contrary', 1)
# (u'$4,504,616.92', 1)
# (u'decrees', 1)
# (u'equaled', 1)
# (u'hires', 1)
# (u'transcending', 1)
# (u'us?', 1)
# (u'concessions', 1)
# (u'barren', 1)
# (u'scattered', 1)
# (u'connections', 1)
# (u'causes?', 1)
# (u'effecting', 1)
# (u'sacrifices', 1)
# (u'throwing', 1)
# (u'preparation', 1)
# (u'aqueduct', 1)
# (u'liberian', 1)
# (u'indiscriminately', 1)
# (u'influential', 1)
# (u'$50,000', 1)
# (u'remissions', 1)
# (u'ravages', 1)
# (u'suppressing', 1)
# (u'$96,739,905.73', 1)
# (u'partly', 1)
# (u'congress."', 1)
# (u'resulting', 1)
# (u'brilliant', 1)
# (u'identical', 1)
# (u'42,844', 1)
# (u'renounced', 1)
# (u'italy', 1)
# (u'consolations', 1)
# (u'dishonor', 1)
# (u'shorter', 1)
# (u'modification', 1)
# (u'dark', 1)
# (u'toil', 1)
# (u'abandonment', 1)
# (u'informal', 1)
# (u'33.49', 1)
# (u'harmonize', 1)
# (u'administrative', 1)
# (u'ordnance', 1)
# (u'indication', 1)
# (u'counsels', 1)
# (u'aptitudes', 1)
# (u'conditionally', 1)
# (u'inimical', 1)
# (u'militia', 1)
# (u'truckee', 1)
# (u'convulsion', 1)
# (u'canal', 1)
# (u'extremely', 1)
# (u'reiterates', 1)
# (u'state-bank', 1)
# (u'1890', 1)
# (u'oblige', 1)
# (u'directness', 1)
# (u'proposed--the', 1)
# (u'wards', 1)
# (u'provost-marshal-general', 1)
# (u'$4,557,462.71', 1)
# (u'sumter', 1)
# (u'seized', 1)
# (u'perthshire', 1)
# (u'petitions', 1)
# (u'timely', 1)
# (u'barbary', 1)
# (u'property--property', 1)
# (u'enterprising', 1)
# (u'abideth', 1)
# (u'examination', 1)
# (u'disabling', 1)
# (u'14,410+', 1)
# (u'unchanged;', 1)
# (u'us;', 1)
# (u'predecessor', 1)
# (u'indulgence', 1)
# (u'promptitude', 1)
# (u'hereinafter', 1)
# (u'sentiments', 1)
# (u'tact', 1)
# (u'advocated', 1)
# (u'56,967,216', 1)
# (u'ourselves--to', 1)
# (u'mentioned', 1)
# (u'perspicuity', 1)
# (u'resorting', 1)
# (u'degrees', 1)
# (u'exploration', 1)
# (u'seas', 1)
# (u'crossing', 1)
# (u'relinquishment', 1)
# (u'expressly', 1)
# (u'indulged', 1)
# (u'gallant', 1)
# (u'amendatory', 1)
# (u'cured', 1)
# (u'follows:', 1)
# (u'discussions', 1)
# (u'date', 1)
# (u'4,610', 1)
# (u'depressing', 1)
# (u'aught', 1)
# (u'objectionable', 1)
# (u'embody', 1)
# (u'insignificance', 1)
# (u're-enslave', 1)
# (u'arduous', 1)
# (u'1,000,000', 1)
# (u'assurances', 1)
# (u'ably', 1)
# (u'$474,744,778.16', 1)
# (u'expired', 1)
# (u'volume', 1)
# (u'violation', 1)
# (u'138,918,526', 1)
# (u'attained', 1)
# (u'displayed', 1)
# (u'92,502', 1)
# (u'committees', 1)
# (u'pertains', 1)
# (u'intervening', 1)
# (u'acquired', 1)
# (u'capitalists', 1)
# (u'merits', 1)
# (u'exhaustion;', 1)
# (u'savannah)', 1)
# (u'merit;', 1)
# (u'streams', 1)
# (u'habitual', 1)
# (u'migrate', 1)
# (u'appearance', 1)
# (u'cereals', 1)
# (u'respected', 1)
# (u'51,000', 1)
# (u'remodeling', 1)
# (u')', 1)
# (u'exceeds', 1)
# (u'$109,741,134.10', 1)
# (u'disenthralled', 1)
# (u'arming', 1)
# (u'nicholasville', 1)
# (u'southward', 1)
# (u'arresting', 1)
# (u'unsoundness', 1)
# (u'intimated', 1)
# (u'267', 1)
# (u'recurs', 1)
# (u'traders', 1)
# (u'regulated', 1)
# (u'surest', 1)
# (u'liquidation', 1)
# (u'65,953', 1)
# (u'motive', 1)
# (u'involuntary', 1)
# (u'results:', 1)
# (u'limitations', 1)
# (u'posterity', 1)
# (u'proceeded', 1)
# (u'compatible', 1)
# (u'boundaries', 1)
# (u'crooked', 1)
# (u'delivery', 1)
# (u'valuation', 1)
# (u'recede', 1)
# (u'slaves?', 1)
# (u'mechanics', 1)
# (u'devise', 1)
# (u'paraguay', 1)
# (u'exhausting', 1)
# (u'astounding', 1)
# (u'793', 1)
# (u'seceding', 1)
# (u'effectually', 1)
# (u'dispense', 1)
# (u'misunderstanding', 1)
# (u'ungenerous', 1)
# (u'dogmas', 1)
# (u"earth's", 1)
# (u'271', 1)
# (u'subordinate', 1)
# (u'contemplates', 1)
# (u'subject--a', 1)
# (u'liberated', 1)
# (u'avert', 1)
# (u'unobjectionable', 1)
# (u'owed', 1)
# (u'inflicting', 1)
# (u'insecurity', 1)
# (u'accommodation', 1)
# (u'averaging', 1)
# (u'consulates', 1)
# (u'$5,939.009.29;', 1)
# (u'worse', 1)
# (u'long-felt', 1)
# (u'description', 1)
# (u'sioux', 1)
# (u'amid', 1)
# (u'then;', 1)
# (u'3,929,827', 1)
# (u'laboratory', 1)
# (u'hushed', 1)
# (u'adapt', 1)
# (u'fugitive', 1)
# (u'248', 1)
# (u'grasses', 1)
# (u'hopeless', 1)
# (u'features', 1)
# (u'dwindled', 1)
# (u'art.--congress', 1)
# (u'palpable', 1)
# (u'specially', 1)
# (u'rewritten', 1)
# (u'19,931', 1)
# (u'kindest', 1)
# (u'distance', 1)
# (u'set-tier', 1)
# (u'cent--has', 1)
# (u'"compensated', 1)
# (u'$100,000', 1)
# (u'secession', 1)
# (u'reimbursement', 1)
# (u'orleans', 1)
# (u'painfully', 1)
# (u'lights', 1)
# (u'institution', 1)
# (u'consisting', 1)
# (u'$49,056,397.62', 1)
# (u'richer', 1)
# (u'solicitude', 1)
# (u'disavowed', 1)
# (u'richest', 1)
# (u'performed--the', 1)
# (u'variance', 1)
# (u'advancement', 1)
# (u'springs', 1)
# (u'165,538', 1)
# (u'unhappily', 1)
# (u'criticised', 1)
# (u'exhibition', 1)
# (u'confer', 1)
# (u'suppress', 1)
# (u'punctually', 1)
# (u'spring?', 1)
# (u'adaptations', 1)
# (u'surgeon-general', 1)
# (u'omaha', 1)
# (u'characterize', 1)
# (u'675,156', 1)
# (u'prior', 1)
# (u'respectively;', 1)
# (u'harbored', 1)
# (u'sacramento', 1)
# (u'671', 1)
# (u'norwegian', 1)
# (u'3,870,222', 1)
# (u'prescribed', 1)
# (u'$583,885,247.06', 1)
# (u'opinions', 1)
# (u'farther', 1)
# (u'pecuniary', 1)
# (u'insubordination', 1)
# (u'purposes,"', 1)
# (u"surveyors'", 1)
# (u'auspicious', 1)
# (u'sanitary', 1)
# (u'$3,145,000', 1)
# (u'matter,"', 1)
# (u'permitted', 1)
# (u'985.52;', 1)
# (u'chilean', 1)
# (u'unexhausted', 1)
# (u'creditable', 1)
# (u'enrolling', 1)
# (u'harmony', 1)
# (u"dixon's", 1)
# (u'eminent', 1)
# (u'discharge', 1)
# (u'occurrence', 1)
# (u'tribunals', 1)
# (u'point--a', 1)
# (u'$7,517,930.97', 1)
# (u'1859', 1)
# (u'feeble', 1)
# (u'p', 1)
# (u'utter', 1)
# (u'conventions)', 1)
# (u'drafted', 1)
# (u'availed', 1)
# (u'redemption', 1)
# (u'inducing', 1)
# (u'logically', 1)
# (u'118,840', 1)
# (u'isles', 1)
# (u'scope', 1)
# (u'introducing', 1)
# (u'many?', 1)
# (u'webster', 1)
# (u'irruption', 1)
# (u'exclude', 1)
# (u'offense', 1)
# (u'occur', 1)
# (u'stricken', 1)
# (u'receivability', 1)
# (u'informs', 1)
# (u'representation', 1)
# (u'feature', 1)
# (u'constituted', 1)
# (u'chiefest', 1)
# (u'1,430', 1)
# (u'discuss', 1)
# (u'soon?', 1)
# (u'furnishing', 1)
# (u'154,747', 1)
# (u'richly', 1)
# (u'collisions', 1)
# (u'correct', 1)
# (u'existed;', 1)
# (u'theory', 1)
# (u'telegraphs', 1)
# (u'vicious', 1)
# (u'rebel', 1)
# (u'communicated', 1)
# (u'charleston', 1)
# (u'12,866,020', 1)
# (u'$2,481,000', 1)
# (u'debts--was', 1)
# (u'hirers', 1)
# (u'cite', 1)
# (u'season', 1)
# (u'embroil', 1)
# (u'payable', 1)
# (u'restriction', 1)
# (u'contemporary', 1)
# (u'justifies', 1)
# (u'"free', 1)
# (u'expects', 1)
# (u'1820', 1)
# (u'audited', 1)
# (u'subsequent', 1)
# (u'altercation', 1)
# (u'thickly', 1)
# (u'temper', 1)
# (u'resided', 1)
# (u'$3,750,000', 1)
# (u'mails', 1)
# (u'overland', 1)
# (u'31,443,790', 1)
# (u'situation', 1)
# (u'soil', 1)
# (u'abhors', 1)
# (u'maturely', 1)
# (u'compensation:', 1)
# (u'arose', 1)
# (u'modes', 1)
# (u'event;', 1)
# (u'captures', 1)
# (u'guides', 1)
# (u'announcement', 1)
# (u'occasions', 1)
# (u'$13,043,546.81', 1)
# (u'table', 1)
# (u'colonial', 1)
# (u'extensively', 1)
# (u'sprung', 1)
# (u'meets', 1)
# (u'throw', 1)
# (u'assiduous', 1)
# (u'practicable', 1)
# (u'tribe', 1)
# (u'interruption', 1)
# (u'removing', 1)
# (u'increased;', 1)
# (u'attainable', 1)
# (u'$1,298,056,101.89', 1)
# (u'annuity', 1)
# (u'33,874', 1)
# (u'residence', 1)
# (u'equitable', 1)
# (u'parcel', 1)
# (u'1,500', 1)
# (u'resistance', 1)
# (u'endures', 1)
# (u'1,538,614', 1)
# (u'asiatic', 1)
# (u'recruits', 1)
# (u'1846', 1)
# (u'abroad--some', 1)
# (u'tendered', 1)
# (u'always;', 1)
# (u'forbearance', 1)
# (u'42,441', 1)
# (u'plan?', 1)
# (u'collision', 1)
# (u'sharp', 1)
# (u'earnings', 1)
# (u'yedo', 1)
# (u'altercations', 1)
# (u'730,664', 1)
# (u'invasion', 1)
# (u'departure', 1)
# (u'coal', 1)
# (u'precautionary', 1)
# (u'resort', 1)
# (u'alter', 1)
# (u'sides;', 1)
# (u'$776,682,361.57', 1)
# (u'primary', 1)
# (u'outbreak', 1)
# (u'hereafter', 1)
# (u'impugning', 1)
# (u'intricacy', 1)
# (u'exhibited', 1)
# (u'indebted', 1)
# (u'seeming', 1)
# (u'radical', 1)
# (u'instances', 1)
# (u'contended', 1)
# (u'territorially', 1)
# (u'twenty', 1)
# (u'devolved', 1)
# (u'swarm', 1)
# (u'aves', 1)
# (u'aristocracy', 1)
# (u'favorably', 1)
# (u'men--and', 1)
# (u'appreciation', 1)
# (u'1910', 1)
# (u'kindly', 1)
# (u'daughters--work', 1)
# (u'declare', 1)
# (u'acknowledgment', 1)
# (u'unpaid', 1)
# (u'extorted', 1)
# (u'undertaken', 1)
# (u'well-appointed', 1)
# (u'outgrown', 1)
# (u'performances', 1)
# (u'reflections', 1)
# (u'swelling', 1)
# (u'emoluments', 1)
# (u'obstructed', 1)
# (u'deserts', 1)
# (u'bend', 1)
# (u'instinctive', 1)
# (u'amounting', 1)
# (u'armature', 1)
# (u'severing', 1)
# (u'class--neither', 1)
# (u'$714,709,995.58', 1)
# (u'probable', 1)
# (u'freemen;', 1)
# (u'attainment', 1)
# (u'redemptions', 1)
# (u'adaptation', 1)
# (u'(thirty-seven', 1)
# (u'resting', 1)
# (u'cruelty', 1)
# (u'consulate', 1)
# (u'slavery?', 1)
# (u'slavery;', 1)
# (u'evading', 1)
# (u'restraint', 1)
# (u'negotiate', 1)
# (u'$98,239,733.09', 1)
# (u'thoroughly', 1)
# (u'stating', 1)
# (u'$238,647,262.35', 1)
# (u'macedonian', 1)
# (u'disenthrall', 1)
# (u'constitutions', 1)
# (u'dominions', 1)
# (u'improbably', 1)
# (u'repossession', 1)
# (u'd', 1)
# (u'6,151,405', 1)
# (u'10,000,000', 1)
# (u'$12,528,000', 1)
# (u'beneficially', 1)
# (u'augmenting', 1)
# (u'quota', 1)
# (u'mingled', 1)
# (u'unintentional', 1)
# (u'necessity--that', 1)
# (u'impressed', 1)
# (u'impeded', 1)
# (u'world-encircling', 1)
# (u'reconcile', 1)
# (u'likewise', 1)
# (u'35.02', 1)
# (u'granada', 1)
# (u'application', 1)
# (u'blood?', 1)
# (u'energetic', 1)
# (u'presenting', 1)
# (u'thenceforward', 1)
# (u'results;', 1)
# (u'commissions', 1)
# (u'712', 1)
# (u'yourselves', 1)
# (u'42,427', 1)
# (u'thronging', 1)
# (u'substituting', 1)
# (u'climes', 1)
# (u'colonel', 1)
# (u'overwhelmed', 1)
# (u'cumberland', 1)
# (u'thirty-one', 1)
# (u'periodically', 1)
# (u'eleven', 1)
# (u'shipwreck', 1)
# (u'varied', 1)
# (u'struggles', 1)
# (u'years);', 1)
# (u'tropics', 1)
# (u'facilitated', 1)
# (u'exclusion', 1)
# (u'eastward', 1)
# (u'grievances', 1)
# (u'72,703', 1)
# (u'commended', 1)
# (u'pursuits', 1)
# (u'lexington', 1)
# (u'relates', 1)
# (u'honorably', 1)
# (u'obstructions', 1)
# (u'delegates', 1)
# (u'embarrass', 1)
# (u'deprived', 1)
# (u'illicit', 1)
# (u'retain', 1)
# (u'publication', 1)
# (u'diminish', 1)
# (u'reverses', 1)
# (u'warfare', 1)
# (u'migration', 1)
# (u'50,000,000', 1)
# (u'regenerated', 1)
# (u'unlikely', 1)
# (u'interruptions', 1)
# (u'inhabiting', 1)
# (u'gravity', 1)
# (u'seacoast--touches', 1)
# (u'16,770', 1)
# (u'$14,129,771.50;', 1)
# (u'absurd', 1)
# (u'exclusive', 1)
# (u'of--', 1)
# (u'reorganizing', 1)
# (u'legitimate', 1)
# (u'shaping', 1)
# (u'influenced', 1)
# (u'175,487', 1)
# (u'allusion', 1)
# (u'artisans', 1)
# (u'court--two', 1)
# (u'genius', 1)
# (u'injustice', 1)
# (u'restrictions', 1)
# (u'4,221,342', 1)
# (u'expiration', 1)
# (u'capture', 1)
# (u'northwest', 1)
# (u'conflicting', 1)
# (u'inhabit:', 1)
# (u'frequently', 1)
# (u'scruples', 1)
# (u'obtain', 1)
# (u'enemy;', 1)
# (u'parchment', 1)
# (u'fled', 1)
# (u'definitive', 1)
# (u'sweep', 1)
# (u'decease', 1)
# (u'guaranty', 1)
# (u'deliverance', 1)
# (u'apprehended', 1)
# (u'reimbursements', 1)
# (u'unchangeably', 1)
# (u'unchangeable', 1)
# (u'island;', 1)
# (u'piled', 1)
# (u'17,069,453', 1)
# (u'transfer', 1)
# (u'$1,339,710.35;', 1)
# (u'demonstrate', 1)
# (u'diligently', 1)
# (u'arms;', 1)
# (u'83', 1)
# (u'prodded', 1)
# (u'quantities', 1)
# (u'period?', 1)
# (u'extinguishing', 1)
# (u'$4,292,776.18', 1)
# (u'lasted', 1)
# (u'foul', 1)
# (u'better?', 1)
# (u'containing', 1)
# (u'whatsoever', 1)
# (u'conjecture', 1)
# (u'encounter', 1)
# (u'justices', 1)
# (u'trusting', 1)
# (u'harbors', 1)
# (u'abolition', 1)
# (u'perpetuated', 1)
# (u'169,533', 1)
# (u'award', 1)
# (u'stade', 1)
# (u'divorced', 1)
# (u'adoption?', 1)
# (u'$5,656,705.49', 1)
# (u'degenerate', 1)
# (u'just--a', 1)
# (u'memorial', 1)
# (u'lieutenant-general', 1)
# (u'$96,096,922.09', 1)
# (u'combination', 1)
# (u'disturb', 1)
# (u'(two-thirds', 1)
# (u'redressed', 1)
# (u'affords', 1)
# (u'declaring', 1)
# (u'barrier', 1)
# (u'appointments', 1)
# (u'reclamations', 1)
# (u'thereon', 1)
# (u'alienage', 1)
# (u'pretenses', 1)
# (u'$200,000,000', 1)
# (u'rejected', 1)
# (u'unintended', 1)
# (u'well;', 1)
# (u'fitting', 1)
# (u'fitted', 1)
# (u'reorganize', 1)
# (u'spite', 1)
# (u'adequate', 1)
# (u'sailing', 1)
# (u'chesapeake', 1)
# (u'mints', 1)
# (u'implication', 1)
# (u'sweden', 1)
# (u'convertible', 1)
# (u'negatively', 1)
# (u'respectability', 1)
# (u'scrip', 1)
# (u'poverty;', 1)
# (u'reconsideration', 1)
# (u'topics', 1)
# (u'elicit', 1)
# (u'disappear', 1)
# (u'$931,787.64;', 1)
# (u'$206,652.42', 1)
# (u'distrust', 1)
# (u'indefinitely?', 1)
# (u'corn', 1)
# (u'illustration', 1)
# (u'navy-yards', 1)
# (u'surround', 1)
# (u'$13,190,324.45;', 1)
# (u'submitting', 1)
# (u'abstract', 1)
# (u'awhile', 1)
# (u'$11,314,206.84', 1)
# (u'profits', 1)
# (u'best-informed', 1)
# (u'contemplating', 1)
# (u'supplemental', 1)
# (u'avowal', 1)
# (u'sovereignty', 1)
# (u'1,470,018', 1)
# (u'navigable', 1)
# (u'fullest', 1)
# (u'denounced', 1)
# (u'detaching', 1)
# (u'recapture', 1)
# (u'inconsiderately', 1)
# (u'debated', 1)
# (u'$678,007.21', 1)
# (u'$8,299,820.90', 1)
# (u'$23,253,922.08', 1)
# (u'coerced', 1)
# (u'undergone', 1)
# (u'acceptable', 1)
# (u'14,410', 1)
# (u'depopulated', 1)
# (u'unimportant', 1)
# (u'domain', 1)
# (u'befell', 1)
# (u'effectual', 1)
# (u'abide', 1)
# (u'unfriendly', 1)
# (u'proffered', 1)
# (u'unfrequently', 1)
# (u'surviving', 1)
# (u'$599,298,600.83', 1)
# (u'fiery', 1)
# (u'sound;', 1)
# (u'specify', 1)
# (u'vice-admiral', 1)
# (u'offering', 1)
# (u'shore', 1)
# (u'paymaster-general', 1)
# (u'3,800,000', 1)
# (u'stormy', 1)
# (u'lighten', 1)
# (u'$200,000', 1)
# (u"d'affaires", 1)
# (u'fortifications', 1)
# (u'348,235', 1)
# (u'friends?', 1)
# (u'100,000,000', 1)
# (u'husband', 1)
# (u'dates', 1)
# (u'contract', 1)
# (u'railway', 1)
# (u'laudable', 1)
# (u'exhaustion', 1)
# (u'wounds', 1)
# (u'suspicions', 1)
# (u'217,186,000', 1)
# (u'premature', 1)
# (u'sincere', 1)
# (u'discrepancy', 1)
# (u'pan', 1)
# (u'no-more', 1)
# (u'radically', 1)
# (u'diversion', 1)
# (u'concurring)', 1)
# (u'midshipmen', 1)
# (u'reimbursed', 1)
# (u'arbitrament', 1)
# (u'defection', 1)
# (u'holding', 1)
# (u'tax;', 1)
# (u'280,645', 1)
# (u'commissary-general', 1)
# (u'settlers;', 1)
# (u'custody', 1)
# (u'expressing', 1)
# (u'bona', 1)
# (u'boldly', 1)
# (u'promotive', 1)
# (u'161,911', 1)
# (u'$394,368,407.36;', 1)
# (u'wit:', 1)
# (u'$14,396,250.51', 1)
# (u'alleges', 1)
# (u'tycoon', 1)
# (u'amongst', 1)
# (u'$37,640,787.95', 1)
# (u'accents', 1)
# (u'examine', 1)
# (u'unhesitatingly', 1)
# (u'cherokees', 1)
# (u'selfishly', 1)
# (u'briefly', 1)
# (u'merchants', 1)
# (u'overreach', 1)
# (u'$884,076,646.57;', 1)
# (u'a?', 1)
# (u'beware', 1)
# (u'solicit', 1)
# (u'north?', 1)
# (u'north;', 1)
# (u'belonging', 1)
# (u'emancipation;', 1)
# (u'ticket', 1)
# (u'31,000,000', 1)
# (u'$63,211,105.27', 1)
# (u'assured', 1)
# (u'inferences', 1)
# (u'tordenskiold', 1)
# (u'outgoing', 1)
# (u'inconsiderable', 1)
# (u'$1,485,103.61', 1)
# (u'99;', 1)
# (u'conventional', 1)
# (u'uniformity', 1)
# (u'minor', 1)
# (u'abridged', 1)
# (u'diffused', 1)
# (u'objections', 1)
# (u'salvador', 1)
# (u'proclaimed', 1)
# (u'fondest', 1)
# (u'preponderating', 1)
# (u'$588,333.29', 1)
# (u'territorial', 1)
# (u'argentine', 1)
# (u'prejudices', 1)
# (u'association', 1)
# (u'designation', 1)
# (u'instruct', 1)
# (u'76,677,872', 1)
# (u'characterized', 1)
# (u'harm', 1)
# (u'contiguous', 1)
# (u'ever-enduring', 1)
# (u'blacks', 1)
# (u'7', 1)
# (u'34.60', 1)
# (u'$9,049,296.40', 1)
# (u'heroic', 1)
# (u'alluded', 1)
# (u'numerous?', 1)
# (u'128,680', 1)
# (u'1870', 1)
# (u'differ', 1)
# (u'retard', 1)
# (u'$865,234,087.86', 1)
# (u'elaborate', 1)
# (u'urgently', 1)
# (u'essentially', 1)
# (u'9,638,131', 1)
# (u'exempted', 1)
# (u'market--increase', 1)
# (u'reestablished', 1)
# (u'jeopardy', 1)
# (u'fertile?', 1)
# (u'55,811', 1)
# (u'gold', 1)
# (u'to-day;', 1)
# (u'dividing', 1)
# (u'unhappy', 1)
# (u'invoke', 1)
# (u'surrendering', 1)
# (u'obscure', 1)
# (u'11th', 1)
# (u'woo', 1)
# (u'$720,039,039.79', 1)
# (u'union;', 1)
# (u'$11,163,789.59', 1)
# (u'majesty', 1)
# (u'volumes)', 1)
# (u'supplying', 1)
# (u'143,331', 1)
# (u'unnecessarily', 1)
# (u'grains', 1)
# (u'portugal', 1)
# (u'overlooked', 1)
# (u'152,180', 1)
# (u'lengthy', 1)
# (u'elevated', 1)
# (u'339,693', 1)
# (u'$475,648.96', 1)
# (u'presume', 1)
# (u'rear', 1)
# (u'surprised', 1)
# (u'complaint', 1)
# (u'4,015,773', 1)
# (u'clemency', 1)
# (u'modifications', 1)
# (u'austria', 1)
# (u'34,799', 1)
# (u'amicably', 1)
# (u'hinted', 1)
# (u'steamer', 1)
# (u'sight', 1)
# (u'obliges', 1)
# (u'gradually', 1)
# (u'fragments', 1)
# (u'peculiarly', 1)
# (u'relating', 1)
# (u'bureaus', 1)
# (u'conciliatory', 1)
# (u'fidelity', 1)
# (u'$487,788,324.97', 1)
# (u'inexcusable', 1)
# (u'opens', 1)
# (u'withholding', 1)
# (u'adjusting', 1)
# (u'states--certainly', 1)
# (u'.at', 1)
# (u'75,000,000', 1)
# (u'adjudicate', 1)
# (u'depredations', 1)
# (u'structure', 1)
# (u'ascertained', 1)
# (u'objected', 1)
# (u'farms', 1)
# (u'emancipation."', 1)
# (u'one-half', 1)
# (u'$24,729,846.51', 1)
# (u'colors', 1)
# (u'demonstrations', 1)
# (u'tempted', 1)
# (u'250,000,000', 1)
# (u'melancholy', 1)
# (u'eminently', 1)
# (u'canals', 1)
# (u'remark', 1)
# (u'sentiments--have', 1)
# (u'factious', 1)
# (u'behrings', 1)
# (u'cross-purposes', 1)
# (u'$152,203.77;', 1)
# (u'counties', 1)
# (u'reciprocity', 1)
# (u'inclined', 1)
# (u'procuring', 1)
# (u'admiralty', 1)
# (u'coincident', 1)
# (u'proportions', 1)
# (u'contrabands', 1)
# (u'defective', 1)
# (u'procured', 1)
# (u'especial', 1)
# (u'hazard', 1)
# (u'1925--our', 1)
# (u'misapprehension', 1)
# (u'designs', 1)
# (u'accumulates', 1)
# (u'accompanies', 1)
# (u'reintroducing', 1)
# (u'fostered', 1)
# (u'lands:', 1)
# (u'584', 1)
# (u'588', 1)
# (u'strictly', 1)
# (u'plainly', 1)
# (u'owning', 1)
# (u'establishments', 1)
# (u'lists', 1)
# (u'69,111', 1)
# (u'commodity', 1)
# (u'abolished', 1)
# (u'creditors', 1)
# (u'unchanged', 1)
# (u'bark', 1)
# (u'324', 1)
# (u'inspiring', 1)
# (u'replenishing', 1)
# (u'inhabit', 1)
# (u'fernandina', 1)
# (u'476,442', 1)
# (u'spares', 1)
# (u'diligent', 1)
# (u'adjusted', 1)
# (u'freedmen', 1)
# (u'sanctifying', 1)
# (u'186,984,335', 1)
# (u'known--the', 1)
# (u'abrogating', 1)
# (u'debtor', 1)
# (u'cometh', 1)
# (u'incumbent', 1)
# (u'fide', 1)
# (u'oft', 1)
# (u'133;', 1)
# (u'insurrectionist', 1)
# (u'proximity', 1)
# (u'evince', 1)
# (u'expedite', 1)
# (u'admitted', 1)
# (u'exceed', 1)
# (u'contested', 1)
# (u'tybee', 1)
# (u'demonstrated', 1)
# (u'162,413', 1)
# (u'imaginary', 1)
# (u'amnesty', 1)
# (u'refuge', 1)
# (u'concession', 1)
# (u'injuriously', 1)
# (u'possessions', 1)
# (u'guard', 1)
# (u'breeding', 1)
# (u'neutral', 1)
# (u'"one', 1)
# (u'virtual', 1)
# (u'confided', 1)
# (u'$4,551,966.98', 1)
# (u'scheldt', 1)
# (u'organized;', 1)
# (u'volumes', 1)
# (u'comparatively', 1)
# (u'1,379', 1)
# (u'exaggerate', 1)
# (u'sustaining', 1)
# (u'deliberate', 1)
# (u'selected', 1)
# (u'toll', 1)
# (u'ventured', 1)
# (u'administering', 1)
# (u'hereby', 1)
# (u'aware', 1)
# (u'inhabited', 1)
# (u'accomplishment', 1)
# (u'deficiencies', 1)
# (u'128,331', 1)
# (u'1840', 1)
# (u'derangement--while', 1)
# (u'sons', 1)
# (u'commending', 1)
# (u'matured', 1)
# (u'$12,438,253.78', 1)
# (u'netherlands', 1)
# (u'bond', 1)
# (u'uninhabitable', 1)
# (u'forts', 1)
# (u'pensacola', 1)
# (u'mason', 1)
# (u'arizona', 1)
# (u'$690,791,842.97', 1)
# (u'121,125', 1)
# (u'$13,000,000', 1)
# (u'anxiety', 1)
# (u'accordance', 1)
# (u'feeling', 1)
# (u'regulate', 1)
# (u'expeditions', 1)
# (u'rome', 1)
# (u'unoccupied', 1)
# (u'800', 1)
# (u'voting', 1)
# (u'armament', 1)
# (u'appended', 1)
# (u'sugar', 1)
# (u'hudsons', 1)
# (u'bay', 1)
# (u'mathematically', 1)
# (u'squadron', 1)
# (u'continually', 1)
# (u'timber', 1)
# (u'authorizing', 1)
# (u'32.67', 1)
# (u'particulars', 1)
# (u'167', 1)
# (u'possess', 1)
# (u'colonists', 1)
# (u'straits', 1)
# (u'complex', 1)
# (u'numerical', 1)
# (u'$102,532,509.27', 1)
# (u'insisted', 1)
# (u'gunboat', 1)
# (u'francisco;', 1)
# (u'assembling', 1)
# (u'distribute', 1)
# (u'$1,019,446', 1)
# (u'86,616', 1)
# (u'passeth', 1)
# (u'$11,125,364.13', 1)
# (u'states:', 1)
# (u'escape', 1)
# (u'substitution', 1)
# (u'251,680,914', 1)
# (u'572,697', 1)
# (u'renown', 1)
# (u'impartiality', 1)
# (u'initial', 1)
# (u'$47,511,448.10', 1)
# (u'bolivia', 1)
# (u'medium', 1)
# (u'25th', 1)
# (u'customs;', 1)
# (u'productions', 1)
# (u'despotism', 1)
# (u'physical', 1)
# (u'protested', 1)
# (u'$1,394,796,007.62', 1)
# (u'hackneyed', 1)
# (u'abridgment', 1)
# (u'progresses', 1)
# (u'1800', 1)
# (u'obviate', 1)
# (u'government;', 1)
# (u'discern', 1)
# (u'anticipation', 1)
# (u'compensate', 1)
# (u'evaded', 1)
# (u'unexpected', 1)
# (u'exempts', 1)
# (u'contracted', 1)
# (u'paragraph', 1)
# (u'canadian', 1)
# (u'brazilian', 1)
# (u'odious', 1)
# (u'naturalizations', 1)
# (u'depots', 1)
# (u'facilitating', 1)
# (u'arise', 1)
# (u'restitution', 1)
# (u'cultivation;', 1)
# (u'long-deferred', 1)
# (u'homesteads', 1)
# (u'unmindful', 1)
# (u'noteworthy', 1)
# (u'vocation', 1)
# (u'22d', 1)
# (u'reckoning', 1)
# (u'avocations', 1)
# (u'revised', 1)
# (u'occupations', 1)
# (u'146,216', 1)
# (u'$529,692,460.50', 1)
# (u'beaten', 1)
# (u'engineer', 1)
# (u':$2,257,065.80', 1)
# (u'continuous', 1)
# (u'factions', 1)
# (u'cuttings', 1)
# (u'mates', 1)
# (u'accounted', 1)
# (u'$2,645,722.19', 1)
# (u"sherman's", 1)
# (u'nebr', 1)
# (u'therefor', 1)
# (u'sundry', 1)
# (u'falls', 1)
# (u'satisfying', 1)
# (u'removed', 1)
# (u'slaver', 1)
# (u'$85,733,292.77', 1)
# (u'propagandism', 1)
# (u'surrender', 1)
# (u'fort', 1)
# (u'guarded', 1)
# (u'regaining', 1)
# (u'illiberal', 1)
# (u'liable', 1)
# (u'stipulation', 1)
# (u'overflowed', 1)
# (u'invoked', 1)
# (u'receipt', 1)
# (u'knoxville', 1)
# (u'beaten;', 1)
# (u'brigades', 1)
# (u'deported', 1)
# (u'viz:', 1)
# (u'leaven', 1)
# (u'educated', 1)
# (u'hearty', 1)
# (u'polls', 1)
# (u'proves', 1)
# (u'1930--say', 1)
# (u'adjudications', 1)
# (u'disadvantages', 1)
# (u'assist', 1)
# (u'fruit', 1)
# (u'"while', 1)
# (u'charged', 1)
# (u'malicious', 1)
# (u'statesmen', 1)
# (u'$8,683,000', 1)
# (u'papers', 1)
# (u'usefully', 1)
# (u'tanto', 1)
# (u'remorseless', 1)
# (u'depot', 1)
# (u'exposed', 1)
# (u'imprisonment', 1)
# (u'divine', 1)
# (u'forfeitures', 1)
# (u'1930', 1)
# (u'government--the', 1)
# (u'bountiful', 1)
# (u'intervention', 1)
# (u'distracted', 1)
# (u'recommends', 1)
# (u'replies', 1)
# (u'510,396', 1)
# (u'judging', 1)
# (u'land?', 1)
# (u'size;', 1)
# (u'valid', 1)
# (u'acceptance', 1)
# (u'ferocity', 1)
# (u'conclusive', 1)
# (u'$137,476.26--a', 1)
# (u'employing', 1)
# (u'consummating', 1)
# (u'25,433', 1)
# (u'ranged', 1)
# (u'3,841,549', 1)
# (u'compliance', 1)
# (u'published', 1)
# (u'reclaimed', 1)
# (u'regiment', 1)
# (u'injure', 1)
# (u'nebraska', 1)
# (u'foreseen', 1)
# (u'reject', 1)
# (u'telegraphic', 1)
# (u'questioning', 1)
# (u'objects?', 1)
# (u'anticipations', 1)
# (u'detach', 1)
# (u'beneficent', 1)
# (u'circumstance', 1)
# (u'free--honorable', 1)
# (u'attendance--rising', 1)
# (u'expedient', 1)
# (u'before-mentioned', 1)
# (u'fees', 1)
# (u'$9,383,000', 1)
# (u'peaceably', 1)
# (u'sympathies', 1)
# (u'16,039', 1)
# (u'$53,685,421.69', 1)
# (u'citizens;', 1)
# (u'relieves', 1)
# (u'assaulted', 1)
# (u'cargoes', 1)
# (u'well-selected', 1)
# (u'frauds', 1)
# (u'wastes', 1)
# (u'teems', 1)
# (u'constructed', 1)
# (u'disturbances', 1)
# (u'inconveniences', 1)
# (u'discord', 1)
# (u'unpleasant', 1)
# (u'flowing', 1)
# (u'compass', 1)
# (u'2,963,000', 1)
# (u'sacrificed', 1)
# (u'withdrawal', 1)
# (u'approaching', 1)
# (u'$4,216,520.79', 1)
# (u'sole', 1)
# (u'terminus', 1)
# (u'sultan', 1)
# (u'forgotten', 1)
# (u'33,762', 1)
# (u'northeastern', 1)
# (u'complied', 1)
# (u'patiently', 1)
# (u'overlook', 1)
# (u'peninsular', 1)
# (u'steamships', 1)
# (u'hitchcock', 1)
# (u'error', 1)
# (u'ray', 1)
# (u'solicited', 1)
# (u'art.--all', 1)
# (u'changed;', 1)
# (u'$69,059,642.40', 1)
# (u'alternate', 1)
# (u'recantation', 1)
# (u'dearly', 1)
# (u'yielded', 1)
# (u'unsecured', 1)
# (u'munitions', 1)
# (u'art.--', 1)
# (u'irritation', 1)
# (u'7,500', 1)
# (u'34,000', 1)
# (u'tends', 1)
# (u'varying', 1)
# (u'dictates', 1)
# (u'feelings', 1)
# (u'constraint', 1)
# (u'involving', 1)
# (u'ensue', 1)
# (u'placing', 1)
# (u'servile', 1)
# (u'legation', 1)
# (u'redeemed', 1)
# (u'148,513', 1)
# (u'expedition', 1)
# (u'surveying', 1)
# (u'department:', 1)
# (u'revision', 1)
# (u'rightful', 1)
# (u'practically', 1)
# (u'vow', 1)
# (u'23,191,876', 1)
# (u'subject?', 1)
# (u'restraining', 1)
# (u'compose', 1)
# (u'before?', 1)
# (u'pleasing', 1)
# (u'jurisdiction', 1)
# (u'wishes', 1)
# (u'laws?', 1)
# (u'unprofitable', 1)
# (u'families--wives', 1)
# (u'adjust;', 1)
# (u'hereditary', 1)
# (u'3d', 1)
# (u'exchange', 1)
# (u'outlying', 1)
# (u'$623,443,929.13', 1)
# (u'wit', 1)
# (u'lima', 1)
# (u'affording', 1)
# (u'constitutionally', 1)
# (u'assumptions', 1)
# (u'africans', 1)
# (u'seeds', 1)
# (u'reestablish', 1)
# (u'91,300', 1)
# (u'1880', 1)
# (u'tributary', 1)
# (u'produces', 1)
# (u'existence)', 1)
# (u'arrangements', 1)
# (u'successor', 1)
# (u'$167,617.17', 1)
# (u'prevailing', 1)
# (u'heated', 1)
# (u'belgians', 1)
# (u'affliction', 1)
# (u'intermediate', 1)
# (u'perfectly', 1)
# (u'colonization;', 1)
# (u'succeed;', 1)
# (u'comity', 1)
# (u'pardoned', 1)
# (u'tracts', 1)
# (u'westward', 1)
# (u'appointing', 1)
# (u'7,239,814', 1)
# (u'constrained', 1)
# (u'montana', 1)
# (u'ambitions', 1)
# (u'devolving', 1)
# (u'afloat', 1)
# (u'asylum', 1)
# (u'northampton', 1)
# (u'emissaries', 1)
# (u'vindicated', 1)
# (u'tend', 1)
# (u'monarchy', 1)
# (u'interfere', 1)
# (u'(near', 1)
# (u'choice;', 1)
# (u'arises', 1)
# (u'remedied', 1)
# (u'mourning', 1)
# (u'noticed', 1)
# (u'estimable', 1)
# (u'delaying', 1)
# (u'examined', 1)
# (u'denial', 1)
# (u'52,257,065.80', 1)
# (u'$136,077.95', 1)
# (u'liberality', 1)
# (u'francisco', 1)
# (u'variety', 1)
# (u'inactive', 1)
# (u'part;', 1)
# (u'imposes', 1)
# (u'impassable', 1)
# (u'molding', 1)
# (u'inconstant', 1)
# (u'flagrant', 1)
# (u'severance', 1)
# (u'naturalization', 1)
# (u'cleared', 1)
# (u'brilliantly', 1)
# (u'unanswerable', 1)
# (u'imperial', 1)
# (u'46,195', 1)
# (u'incursions', 1)
# (u'disbursement', 1)
# (u'jostle', 1)
# (u'$3,995,097.31', 1)
# (u'sloping', 1)
# (u'treason', 1)
# (u'intentionally', 1)
# (u'committals', 1)
